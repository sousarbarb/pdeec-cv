# %% [markdown]
# # Herbarium 2021 - Half-Earth Challenge - FGVC8 - ResNet
#
# The main goal of this work is to identify plant species of the Americas, Oceania, and the Pacific from herbarium specimens. The dataset that is used in this work - _The Herbarium 2021: Half-Earth Challenge_ - includes more than 2.5M images representing nearly 65.000 species from the Americas and Oceania. These images have been aligned to a standardized plant list ([LCVP v1.0.2](https://www.nature.com/articles/s41597-020-00702-z)).
#
# The model used in this notebook for classifying the images is ResNet ([arXiv:1512.03385](https://arxiv.org/abs/1512.03385)). ResNet makes it possible to train up to hundreds or even thousands of layers and still achieves compelling performance. Taking advantage of its powerful representational ability, the performance of many computer vision applications other than image classification have been bosted. As a classification model, it is considered to be a state-of-the-art method.

# %% [markdown]
# ## Setup
#
# ### Load libraries

# %%
# Math and Image
import numpy as np               # Math
import matplotlib.pyplot as plt  # Plot
import cv2                       # OpenCV
import PIL                       # Data Augmentation
import albumentations            # Data Augmentation
from albumentations.pytorch import ToTensorV2
# Operating System
import os
import time
import copy
# Utilities
import pandas as pd  # Handling CSV files
import random
import json
import tqdm          # Testing
import sklearn       # label encoding and metrics
from sklearn import preprocessing
# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
# TensorFlow
import tensorflow as tf

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets
# preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved
# outside of the current session will list all files under the input directory

print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.7.0
# Torchvision Version:  0.8.1

# %% [markdown]
# ### PC Configuration

# %%
# CPU Details - Number & Model
# !lscpu | grep "CPU(s):"
# !lscpu | grep Hz
# Total Memory
# !cat /proc/meminfo | grep MemTotal
# CUDA Check
print("Is CUDA Available?",
      torch.cuda.is_available())
if torch.cuda.is_available() == True: 
    print("Current CUDA device:",
        torch.cuda.get_device_name(0))

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: ",DEVICE)
# Out:
# CPU(s):              2
# NUMA node0 CPU(s):   0,1
# Model name:          Intel(R) Xeon(R) CPU @ 2.00GHz
# CPU MHz:             2000.170
# MemTotal:       16402020 kB
# Is CUDA Available? True
# Current CUDA device: Tesla P100-PCIE-16GB
# Device:  cuda

# %% [markdown]
# ### Ramdom seed
#
# The goal is to fix the random seed. For making the environment statically, fixing the random seed is needed. Also, it is essential to reproduce the experimental results.

# %%
def seed_fix(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_fix()
print("Seed fixed")
# Out:
# Seed fixed

# %% [markdown]
# ### Configuration

# %%
ROOT_DATA   = "/kaggle/input/herbarium-2021-fgvc8/"
DATA_TRAIN  = ROOT_DATA + "train/"
DATA_TEST   = ROOT_DATA + "test/"
ROOT_OUTPUT = "/kaggle/working/"
META        = "metadata.json"
BATCH_SIZE  = 384    # number of training examples utilized in one iteration
BATCH_EVAL  = 384
SHUFFLE     = True
EPOCHS      = 1
LEARN_RATE  = 4e-4
IMG_HEIGHT  = 224
IMG_WIDTH   = 224
NUM_CLASSES = None   # define below
NUM_WORKERS = 4
PRE_TRAINED = False

PATH_SAVE_MODEL = "/kaggle/working/ResNet34_run-02.pth"

ESTIMATED_MAX_TRAINING_TIME = 480 # hours (8h * 60 = 480min, leaving 1h to the test time)

print(ROOT_DATA)
# Out:
# /kaggle/input/herbarium-2021-fgvc8/

# %% [markdown]
# ## Create dataset

# %% [markdown]
# ### Generic information

# %%
# Training dataset
with open(os.path.join(DATA_TRAIN,META),"r",encoding="ISO-8859-1") as file:
    meta_train = json.load(file)
    print("Number of images (training dataset): ",
          len(meta_train["images"]),)
    for i in list(meta_train.keys()):
        print("  - sample and number of elements in category {}: ".format(i),
              len(list(meta_train[i])),)
        print("\t[0] ",
              list(meta_train[i])[0], end="\n")

NUM_CLASSES   = len(meta_train["categories"])
NUM_IMG_TRAIN = len(meta_train["annotations"])

# Validation dataset
with open(os.path.join(DATA_TEST,META),"r",encoding="ISO-8859-1") as file:
    meta_test = json.load(file)
    print("\nNumber of images (training dataset): ",
          len(meta_test["images"]),)
    for i in list(meta_test.keys()):
        print("  - sample and number of elements in category {}: ".format(i),
              len(list(meta_test[i])),)
        print("\t[0] ",
              list(meta_test[i])[0], end="\n")

NUM_IMG_TEST  = len(meta_test["images"]) 

# Print variables
print("\n\n"
      "Number of images for training: ",NUM_IMG_TRAIN)
print("Number of images for testing : ",NUM_IMG_TEST)
print("Number of classes            : ",NUM_CLASSES)
# Out:
# Number of images (training dataset):  2257759
#   - sample and number of elements in category annotations:  2257759
# 	[0]  {'category_id': 60492, 'id': 1814367, 'image_id': 1814367, 'institution_id': 0}
#   - sample and number of elements in category categories:  64500
# 	[0]  {'family': 'Orchidaceae', 'order': 'Asparagales', 'name': 'Aa calceata (Rchb.f.) Schltr.', 'id': 0}
#   - sample and number of elements in category images:  2257759
# 	[0]  {'file_name': 'images/604/92/1814367.jpg', 'height': 1000, 'id': 1814367, 'license': 0, 'width': 678}
#   - sample and number of elements in category info:  6
# 	[0]  contributor
#   - sample and number of elements in category licenses:  3
# 	[0]  {'id': 0, 'name': 'Public Domain Dedication', 'url': 'http://creativecommons.org/publicdomain/zero/1.0/'}
#   - sample and number of elements in category institutions:  5
# 	[0]  {'id': 0, 'name': 'New York Botanical Garden'}
#
# Number of images (training dataset):  243020
#   - sample and number of elements in category images:  243020
# 	[0]  {'file_name': 'images/000/0.jpg', 'height': 1000, 'id': 0, 'license': 0, 'width': 680}
#   - sample and number of elements in category info:  6
# 	[0]  contributor
#   - sample and number of elements in category licenses:  3
# 	[0]  {'id': 0, 'name': 'Public Domain Dedication', 'url': 'http://creativecommons.org/publicdomain/zero/1.0/'}
#
#
# Number of images for training:  2257759
# Number of images for testing :  243020
# Number of classes            :  64500

# %% [markdown]
# ### Process training and evaluation metadata
#
# Merge training images and annotations as a dataframe. The database-based joint operation merge is performed on the ids "image_id" (from images dataframe) and "id" (from annotations dataframe).
#
# The problem with the validation data is that the `.json` does not provide the labels to check if the model is classifying correctly or not the validation images.

# %%
# Process metadata json for training images into a DataFrame
train_img = pd.DataFrame(meta_train["images"])
train_ann = pd.DataFrame(meta_train["annotations"]).drop(columns="image_id")
train_df  = train_img.merge(train_ann,on="id") # Performs a database-style joint

# Check number of classes
print("Number of classes (expected): ",NUM_CLASSES)
print("Number of classes (computed): ",
      train_df["category_id"].max() - train_df["category_id"].min()+1)
print("\nShape training dataframe    :",train_df.shape)

# Process metadata json for test images into a DataFrame
test_df = pd.DataFrame(meta_test["images"])
# Out:
# Number of classes (expected):  64500
# Number of classes (computed):  64500
#
# Shape training dataframe    : (2257759, 7)

# %%
# Print the first 5 elements of the tables
train_df.head(n=5)
# Out:
#                    file_name  height       id  license  width  category_id  \
# 0  images/604/92/1814367.jpg    1000  1814367        0    678        60492
# 1  images/108/24/1308257.jpg    1000  1308257        0    666        10824
# 2  images/330/76/1270453.jpg    1000  1270453        0    739        33076
# 3  images/247/99/1123834.jpg    1000  1123834        0    672        24799
# 4  images/170/18/1042410.jpg    1000  1042410        0    675        17018
#
#    institution_id
# 0               0
# 1               0
# 2               3
# 3               0
# 4               0

# %%
# Print the first 5 elements of the tables
test_df.head(n=5)
# Out:
#           file_name  height  id  license  width
# 0  images/000/0.jpg    1000   0        0    680
# 1  images/000/1.jpg    1000   1        0    681
# 2  images/000/2.jpg    1000   2        0    676
# 3  images/000/3.jpg    1000   3        0    666
# 4  images/000/4.jpg    1000   4        0    676

# %% [markdown]
# ### Checkout samples

# %%
im = PIL.Image.open(DATA_TRAIN + train_df.file_name[0])
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=678x1000 at 0x7F557D06E250>

# %%
size_of_img = (36,36)
fig=plt.figure(figsize=(80,80))
for i in range(25):
    ax=fig.add_subplot(5,5,i+1)
    img = cv2.imread(DATA_TRAIN + meta_train["images"][i]["file_name"])
    img = cv2.resize(img,size_of_img)
    ax.imshow(img)

plt.show()

# %% [markdown]
# ## Prepare Submission

# %%
sample_submission = pd.read_csv(ROOT_DATA + "sample_submission.csv")
sample_submission.head(n=5)
# Out:
#    Id  Predicted
# 0   0          0
# 1   1          0
# 2   2          0
# 3   3          0
# 4   4          0

# %% [markdown]
# ## Label Encoder

# %%
# Fit the label encoder instance
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(train_df["category_id"])

# Transform labels to normalized encoding
train_df["category_id_le"] = label_encoder.transform(train_df["category_id"])
class_map = dict(sorted(train_df[["category_id_le","category_id"]].values.tolist()))

print("Labels converted to normalized encoding")
# Out:
# Labels converted to normalized encoding

# %% [markdown]
# ### Dataloaders

# %%
class TrainDataset(torch.utils.data.Dataset):
    def __init__(self, df, labels, transform=None):
        self.df = df
        self.labels = labels
        self.transform = transform
        
    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.df["file_name"].values[idx]
        file_path = DATA_TRAIN + file_name
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        label = self.labels.values[idx]
        
        if self.transform:
            img = self.transform(image=img)["image"]
        
        return img, label

# %%
class TestDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform
        
    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.df["file_name"].values[idx]
        file_path = DATA_TEST + file_name
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        if self.transform:
            img = self.transform(image=img)["image"]
        
        return img

# %% [markdown]
# ### Image Augmentation

# %%
def get_transforms(*, data: str):
    assert data in ("train","test")
    
    if data == "train":
        return albumentations.Compose([
            albumentations.Resize(IMG_HEIGHT,IMG_WIDTH),
            albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

    elif data == "test":
        return albumentations.Compose([
            albumentations.Resize(IMG_HEIGHT,IMG_WIDTH),
            albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Training Dataset

# %%
train_df.head(n=5)
# Out:
#                    file_name  height       id  license  width  category_id  \
# 0  images/604/92/1814367.jpg    1000  1814367        0    678        60492
# 1  images/108/24/1308257.jpg    1000  1308257        0    666        10824
# 2  images/330/76/1270453.jpg    1000  1270453        0    739        33076
# 3  images/247/99/1123834.jpg    1000  1123834        0    672        24799
# 4  images/170/18/1042410.jpg    1000  1042410        0    675        17018
#
#    institution_id  category_id_le
# 0               0           60492
# 1               0           10824
# 2               3           33076
# 3               0           24799
# 4               0           17018

# %%
train_dataset = TrainDataset(
    train_df,train_df["category_id_le"],
    transform=get_transforms(data="train"))
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,shuffle=SHUFFLE,num_workers=NUM_WORKERS)
print("Train data loader created")
# Out:
# Train data loader created

# %% [markdown]
# ### Test Dataset

# %%
test_df.head(n=5)
# Out:
#           file_name  height  id  license  width
# 0  images/000/0.jpg    1000   0        0    680
# 1  images/000/1.jpg    1000   1        0    681
# 2  images/000/2.jpg    1000   2        0    676
# 3  images/000/3.jpg    1000   3        0    666
# 4  images/000/4.jpg    1000   4        0    676

# %%
test_dataset = TestDataset(
    test_df,
    transform=get_transforms(data="test"))
test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=BATCH_EVAL,shuffle=False,num_workers=NUM_WORKERS)
print("Test data loader created")
# Out:
# Test data loader created

# %% [markdown]
# ## Model

# %%
def train_model(model,dataloader,criterion,optimizer,num_epochs=1):
    since = time.time()
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        model.train()
        
        running_loss = 0.0
        running_corrects = 0
        
        #for inputs, labels in tqdm.tqdm(enumerate(dataloader)):
        i = 0
        len_dataset = len(dataloader.dataset)
        for inputs, labels in dataloader:
            since_tmp = time.time()
            
            inputs = inputs.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                loss = criterion(outputs,labels)
                
                _,preds = torch.max(outputs,1)
                
                loss.backward()
                optimizer.step()
              
            loss_tmp = loss.item()
            pred_tmp = torch.sum(preds == labels.data)
            
            running_loss += loss_tmp * inputs.size(0)
            running_corrects += pred_tmp
            
            time_elapsed_tmp = time.time() - since_tmp
            
            print('  loss: {:.04f} corr: {:d} ({:d}/{:d}) completed in {:.0f}m {:.03f}s'.format(
                loss_tmp, pred_tmp,(i+1)*BATCH_SIZE,len_dataset,
                time_elapsed_tmp // 60, time_elapsed_tmp % 60))
            
            if ((time.time() - since) // 60 > ESTIMATED_MAX_TRAINING_TIME):
                break;
            
            i += 1
            
        epoch_loss = running_loss / len_dataset
        epoch_acc = running_corrects.double() / len_dataset
        
        torch.save(model.state_dict(),PATH_SAVE_MODEL)
        print(PATH_SAVE_MODEL)
        print('Loss: {:.04f} Acc: {:.04f}'.format(epoch_loss, epoch_acc))
        
        print()
            
        if ((time.time() - since) // 60 > ESTIMATED_MAX_TRAINING_TIME):
            break;
        
    time_elapsed = time.time() - since
    print('Loss: {:.04f} Acc: {:.04f}'.format(epoch_loss, epoch_acc))
    print('Training complete in {:.0f}m {:.03f}s'.format(time_elapsed // 60, time_elapsed % 60))
    
    #model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ### Construct model

# %%
model = torchvision.models.resnet34(pretrained=PRE_TRAINED)
model.avgpool = torch.nn.AdaptiveAvgPool2d(1)
model.fc = torch.nn.Linear(model.fc.in_features,NUM_CLASSES)

# %% [markdown]
# ### Use existent trained model

# %%
model.load_state_dict(torch.load("../input/herbarium-2021-rbs/ResNet34_run-01.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Train

# %%
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARN_RATE, amsgrad=False)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 'min', factor=0.75, patience=5, verbose=True, eps=1e-6)

criterion = torch.nn.CrossEntropyLoss()

# %%
model = train_model(model,train_loader,criterion,optimizer,EPOCHS)
# Out:
# Epoch 0/0
# ----------
#   loss: 3.5021 corr: 136 (384/2257759) completed in 0m 3.250s
#   loss: 3.5166 corr: 131 (768/2257759) completed in 0m 2.016s
#   loss: 3.4428 corr: 145 (1152/2257759) completed in 0m 1.607s
#   loss: 3.1537 corr: 132 (1536/2257759) completed in 0m 1.761s
#   loss: 3.2618 corr: 137 (1920/2257759) completed in 0m 1.726s
#   loss: 3.1226 corr: 140 (2304/2257759) completed in 0m 1.572s
#   loss: 3.2694 corr: 129 (2688/2257759) completed in 0m 1.671s
#   loss: 2.9226 corr: 149 (3072/2257759) completed in 0m 1.756s
#   loss: 3.2605 corr: 136 (3456/2257759) completed in 0m 1.594s
#   loss: 3.1635 corr: 121 (3840/2257759) completed in 0m 1.640s
#   loss: 3.2897 corr: 139 (4224/2257759) completed in 0m 1.660s
#   loss: 3.2834 corr: 121 (4608/2257759) completed in 0m 1.795s
#   loss: 3.3565 corr: 125 (4992/2257759) completed in 0m 1.681s
#   loss: 3.4885 corr: 125 (5376/2257759) completed in 0m 1.653s
#   loss: 3.3061 corr: 145 (5760/2257759) completed in 0m 1.591s
#   loss: 3.4114 corr: 122 (6144/2257759) completed in 0m 1.663s
#   loss: 3.3023 corr: 136 (6528/2257759) completed in 0m 1.748s
#   loss: 3.2165 corr: 136 (6912/2257759) completed in 0m 1.722s
#   loss: 3.3035 corr: 129 (7296/2257759) completed in 0m 1.678s
#   loss: 3.4613 corr: 112 (7680/2257759) completed in 0m 1.958s
#   loss: 3.5448 corr: 113 (8064/2257759) completed in 0m 1.667s
#   loss: 3.3360 corr: 139 (8448/2257759) completed in 0m 1.689s
#   loss: 3.3523 corr: 129 (8832/2257759) completed in 0m 1.570s
#   loss: 3.4884 corr: 126 (9216/2257759) completed in 0m 1.682s
#   loss: 3.6535 corr: 121 (9600/2257759) completed in 0m 1.669s
#   loss: 3.4132 corr: 139 (9984/2257759) completed in 0m 1.725s
#   loss: 3.7748 corr: 116 (10368/2257759) completed in 0m 1.556s
#   loss: 3.6374 corr: 133 (10752/2257759) completed in 0m 1.758s
#   loss: 3.4834 corr: 118 (11136/2257759) completed in 0m 1.773s
#   loss: 3.5745 corr: 126 (11520/2257759) completed in 0m 1.601s
#   loss: 3.7102 corr: 127 (11904/2257759) completed in 0m 1.663s
#   loss: 3.5977 corr: 121 (12288/2257759) completed in 0m 1.695s
#   loss: 3.6489 corr: 135 (12672/2257759) completed in 0m 1.655s
#   loss: 3.6881 corr: 132 (13056/2257759) completed in 0m 1.683s
#   loss: 3.7637 corr: 112 (13440/2257759) completed in 0m 1.716s
#   loss: 3.4138 corr: 138 (13824/2257759) completed in 0m 1.832s
#   loss: 3.6716 corr: 125 (14208/2257759) completed in 0m 1.657s
#   loss: 3.6291 corr: 129 (14592/2257759) completed in 0m 1.682s
#   loss: 3.6388 corr: 129 (14976/2257759) completed in 0m 1.710s
#   loss: 3.4162 corr: 140 (15360/2257759) completed in 0m 1.715s
#   loss: 3.5963 corr: 139 (15744/2257759) completed in 0m 1.727s
#   loss: 3.3523 corr: 136 (16128/2257759) completed in 0m 1.768s
#   loss: 3.5808 corr: 123 (16512/2257759) completed in 0m 1.605s
#   loss: 3.9751 corr: 112 (16896/2257759) completed in 0m 1.887s
#   loss: 3.6046 corr: 142 (17280/2257759) completed in 0m 1.578s
#   loss: 3.7334 corr: 121 (17664/2257759) completed in 0m 1.661s
#   loss: 3.6345 corr: 131 (18048/2257759) completed in 0m 1.560s
#   loss: 3.4288 corr: 137 (18432/2257759) completed in 0m 1.650s
#   loss: 4.0983 corr: 113 (18816/2257759) completed in 0m 1.656s
#   loss: 4.0066 corr: 113 (19200/2257759) completed in 0m 1.673s
#   loss: 3.9051 corr: 115 (19584/2257759) completed in 0m 1.668s
#   loss: 3.7055 corr: 121 (19968/2257759) completed in 0m 2.096s
#   loss: 3.8938 corr: 125 (20352/2257759) completed in 0m 1.641s
#   loss: 3.8319 corr: 116 (20736/2257759) completed in 0m 1.634s
#   loss: 3.6094 corr: 141 (21120/2257759) completed in 0m 1.637s
#   loss: 3.6323 corr: 115 (21504/2257759) completed in 0m 1.663s
#   loss: 3.7025 corr: 127 (21888/2257759) completed in 0m 1.644s
#   loss: 3.8388 corr: 131 (22272/2257759) completed in 0m 1.742s
#   loss: 3.6879 corr: 124 (22656/2257759) completed in 0m 1.591s
#   loss: 4.0165 corr: 107 (23040/2257759) completed in 0m 2.170s
#   loss: 3.7948 corr: 131 (23424/2257759) completed in 0m 1.639s
#   loss: 4.0362 corr: 120 (23808/2257759) completed in 0m 1.683s
#   loss: 3.4206 corr: 141 (24192/2257759) completed in 0m 1.660s
#   loss: 3.7623 corr: 120 (24576/2257759) completed in 0m 1.572s
#   loss: 3.7966 corr: 125 (24960/2257759) completed in 0m 1.739s
#   loss: 3.5399 corr: 128 (25344/2257759) completed in 0m 1.669s
#   loss: 3.7884 corr: 112 (25728/2257759) completed in 0m 1.681s
#   loss: 4.0117 corr: 111 (26112/2257759) completed in 0m 1.665s
#   loss: 3.4379 corr: 138 (26496/2257759) completed in 0m 1.678s
#   loss: 3.5133 corr: 137 (26880/2257759) completed in 0m 1.602s
#   loss: 3.6465 corr: 125 (27264/2257759) completed in 0m 1.618s
#   loss: 3.4001 corr: 141 (27648/2257759) completed in 0m 1.663s
#   loss: 3.8617 corr: 131 (28032/2257759) completed in 0m 1.725s
#   loss: 3.6058 corr: 137 (28416/2257759) completed in 0m 1.705s
#   loss: 3.3345 corr: 142 (28800/2257759) completed in 0m 1.742s
#   loss: 3.6705 corr: 131 (29184/2257759) completed in 0m 1.675s
#   loss: 3.9057 corr: 110 (29568/2257759) completed in 0m 1.744s
#   loss: 3.7583 corr: 128 (29952/2257759) completed in 0m 1.646s
#   loss: 3.6288 corr: 123 (30336/2257759) completed in 0m 1.759s
#   loss: 3.6419 corr: 119 (30720/2257759) completed in 0m 1.653s
#   loss: 3.7634 corr: 124 (31104/2257759) completed in 0m 1.623s
#   loss: 3.5598 corr: 127 (31488/2257759) completed in 0m 1.753s
#   loss: 4.0098 corr: 118 (31872/2257759) completed in 0m 1.596s
#   loss: 3.7100 corr: 123 (32256/2257759) completed in 0m 1.660s
#   loss: 3.5348 corr: 130 (32640/2257759) completed in 0m 1.634s
#   loss: 3.7838 corr: 147 (33024/2257759) completed in 0m 1.637s
#   loss: 4.0103 corr: 109 (33408/2257759) completed in 0m 1.615s
#   loss: 3.7036 corr: 133 (33792/2257759) completed in 0m 1.560s
#   loss: 3.6244 corr: 135 (34176/2257759) completed in 0m 1.634s
#   loss: 3.6601 corr: 140 (34560/2257759) completed in 0m 1.661s
#   loss: 3.7850 corr: 119 (34944/2257759) completed in 0m 1.788s
#   loss: 3.8418 corr: 122 (35328/2257759) completed in 0m 1.652s
#   loss: 3.6702 corr: 128 (35712/2257759) completed in 0m 1.705s
#   loss: 3.5786 corr: 119 (36096/2257759) completed in 0m 1.555s
#   loss: 4.0210 corr: 111 (36480/2257759) completed in 0m 1.603s
#   loss: 4.0646 corr: 113 (36864/2257759) completed in 0m 1.662s
#   loss: 3.8202 corr: 125 (37248/2257759) completed in 0m 1.698s
#   loss: 3.8528 corr: 124 (37632/2257759) completed in 0m 1.928s
#   loss: 4.3134 corr: 113 (38016/2257759) completed in 0m 1.698s
#   loss: 3.9835 corr: 123 (38400/2257759) completed in 0m 1.701s
#   loss: 3.6773 corr: 109 (38784/2257759) completed in 0m 1.713s
#   loss: 3.9801 corr: 118 (39168/2257759) completed in 0m 1.582s
#   loss: 3.8337 corr: 118 (39552/2257759) completed in 0m 1.653s
#   loss: 3.9183 corr: 138 (39936/2257759) completed in 0m 1.663s
#   loss: 3.6010 corr: 138 (40320/2257759) completed in 0m 1.861s
#   loss: 4.1365 corr: 106 (40704/2257759) completed in 0m 1.643s
#   loss: 3.6394 corr: 132 (41088/2257759) completed in 0m 1.663s
#   loss: 3.6172 corr: 123 (41472/2257759) completed in 0m 1.868s
#   loss: 3.8136 corr: 130 (41856/2257759) completed in 0m 1.654s
#   loss: 3.4371 corr: 156 (42240/2257759) completed in 0m 1.627s
#   loss: 3.8430 corr: 121 (42624/2257759) completed in 0m 1.655s
#   loss: 3.7742 corr: 132 (43008/2257759) completed in 0m 1.574s
#   loss: 3.8377 corr: 134 (43392/2257759) completed in 0m 1.681s
#   loss: 3.9254 corr: 128 (43776/2257759) completed in 0m 1.660s
#   loss: 3.5259 corr: 133 (44160/2257759) completed in 0m 1.886s
#   loss: 3.9824 corr: 108 (44544/2257759) completed in 0m 1.654s
#   loss: 4.0802 corr: 127 (44928/2257759) completed in 0m 1.672s
#   loss: 3.9630 corr: 110 (45312/2257759) completed in 0m 1.681s
#   loss: 3.8305 corr: 131 (45696/2257759) completed in 0m 1.759s
#   loss: 3.9215 corr: 115 (46080/2257759) completed in 0m 1.676s
#   loss: 3.8534 corr: 123 (46464/2257759) completed in 0m 1.750s
#   loss: 3.9842 corr: 129 (46848/2257759) completed in 0m 1.705s
#   loss: 3.7554 corr: 139 (47232/2257759) completed in 0m 1.841s
#   loss: 3.9444 corr: 133 (47616/2257759) completed in 0m 1.713s
#   loss: 3.7816 corr: 139 (48000/2257759) completed in 0m 1.704s
#   loss: 3.9510 corr: 121 (48384/2257759) completed in 0m 1.659s
#   loss: 4.1211 corr: 120 (48768/2257759) completed in 0m 1.663s
#   loss: 3.8838 corr: 125 (49152/2257759) completed in 0m 1.679s
#   loss: 4.0069 corr: 131 (49536/2257759) completed in 0m 1.701s
#   loss: 3.6378 corr: 152 (49920/2257759) completed in 0m 1.636s
#   loss: 3.7765 corr: 134 (50304/2257759) completed in 0m 1.659s
#   loss: 3.8565 corr: 116 (50688/2257759) completed in 0m 1.716s
#   loss: 3.7378 corr: 115 (51072/2257759) completed in 0m 1.715s
#   loss: 3.6285 corr: 117 (51456/2257759) completed in 0m 1.672s
#   loss: 4.0340 corr: 119 (51840/2257759) completed in 0m 1.675s
#   loss: 4.0727 corr: 123 (52224/2257759) completed in 0m 1.642s
#   loss: 3.8405 corr: 127 (52608/2257759) completed in 0m 1.709s
#   loss: 3.6666 corr: 137 (52992/2257759) completed in 0m 1.717s
#   loss: 3.8549 corr: 115 (53376/2257759) completed in 0m 1.643s
#   loss: 3.9557 corr: 123 (53760/2257759) completed in 0m 1.569s
#   loss: 3.8215 corr: 123 (54144/2257759) completed in 0m 1.713s
#   loss: 3.7858 corr: 122 (54528/2257759) completed in 0m 1.787s
#   loss: 3.9115 corr: 116 (54912/2257759) completed in 0m 1.666s
#   loss: 3.9758 corr: 127 (55296/2257759) completed in 0m 1.708s
#   loss: 4.1251 corr: 135 (55680/2257759) completed in 0m 1.668s
#   loss: 3.7211 corr: 125 (56064/2257759) completed in 0m 1.670s
#   loss: 3.9220 corr: 125 (56448/2257759) completed in 0m 1.701s
#   loss: 3.9990 corr: 129 (56832/2257759) completed in 0m 1.653s
#   loss: 4.0899 corr: 124 (57216/2257759) completed in 0m 1.744s
#   loss: 4.0936 corr: 123 (57600/2257759) completed in 0m 1.840s
#   loss: 4.0056 corr: 111 (57984/2257759) completed in 0m 1.611s
#   loss: 3.6234 corr: 142 (58368/2257759) completed in 0m 1.660s
#   loss: 3.9175 corr: 127 (58752/2257759) completed in 0m 1.632s
#   loss: 4.0321 corr: 125 (59136/2257759) completed in 0m 1.662s
#   loss: 3.7006 corr: 139 (59520/2257759) completed in 0m 1.641s
#   loss: 4.0015 corr: 116 (59904/2257759) completed in 0m 1.903s
#   loss: 3.8810 corr: 133 (60288/2257759) completed in 0m 1.661s
#   loss: 4.1478 corr: 119 (60672/2257759) completed in 0m 1.726s
#   loss: 3.7394 corr: 139 (61056/2257759) completed in 0m 1.757s
#   loss: 3.7387 corr: 127 (61440/2257759) completed in 0m 1.679s
#   loss: 3.9703 corr: 136 (61824/2257759) completed in 0m 1.662s
#   loss: 3.7165 corr: 135 (62208/2257759) completed in 0m 1.758s
#   loss: 4.1503 corr: 129 (62592/2257759) completed in 0m 1.682s
#   loss: 3.9673 corr: 131 (62976/2257759) completed in 0m 1.937s
#   loss: 3.8356 corr: 138 (63360/2257759) completed in 0m 1.806s
#   loss: 3.8184 corr: 127 (63744/2257759) completed in 0m 1.630s
#   loss: 3.9591 corr: 130 (64128/2257759) completed in 0m 1.805s
#   loss: 4.1219 corr: 129 (64512/2257759) completed in 0m 1.662s
#   loss: 3.7586 corr: 140 (64896/2257759) completed in 0m 1.659s
#   loss: 4.1263 corr: 117 (65280/2257759) completed in 0m 1.703s
#   loss: 4.0264 corr: 118 (65664/2257759) completed in 0m 1.639s
#   loss: 3.6892 corr: 136 (66048/2257759) completed in 0m 1.764s
#   loss: 4.0724 corr: 126 (66432/2257759) completed in 0m 1.737s
#   loss: 3.8140 corr: 140 (66816/2257759) completed in 0m 1.695s
#   loss: 3.7808 corr: 135 (67200/2257759) completed in 0m 1.665s
#   loss: 3.6068 corr: 130 (67584/2257759) completed in 0m 1.793s
#   loss: 3.9249 corr: 142 (67968/2257759) completed in 0m 1.731s
#   loss: 3.8450 corr: 135 (68352/2257759) completed in 0m 1.668s
#   loss: 3.6602 corr: 132 (68736/2257759) completed in 0m 1.680s
#   loss: 4.2143 corr: 122 (69120/2257759) completed in 0m 1.727s
#   loss: 3.8402 corr: 120 (69504/2257759) completed in 0m 1.676s
#   loss: 3.6857 corr: 138 (69888/2257759) completed in 0m 1.676s
#   loss: 3.4794 corr: 142 (70272/2257759) completed in 0m 1.703s
#   loss: 3.6907 corr: 147 (70656/2257759) completed in 0m 1.742s
#   loss: 3.8283 corr: 131 (71040/2257759) completed in 0m 1.765s
#   loss: 3.9717 corr: 126 (71424/2257759) completed in 0m 1.728s
#   loss: 4.0719 corr: 140 (71808/2257759) completed in 0m 1.685s
#   loss: 3.8497 corr: 121 (72192/2257759) completed in 0m 1.711s
#   loss: 3.8490 corr: 136 (72576/2257759) completed in 0m 1.727s
#   loss: 4.0704 corr: 134 (72960/2257759) completed in 0m 1.668s
#   loss: 3.6789 corr: 142 (73344/2257759) completed in 0m 1.650s
#   loss: 4.0512 corr: 130 (73728/2257759) completed in 0m 1.661s
#   loss: 3.8327 corr: 134 (74112/2257759) completed in 0m 1.717s
#   loss: 4.0602 corr: 119 (74496/2257759) completed in 0m 1.777s
#   loss: 3.9838 corr: 117 (74880/2257759) completed in 0m 1.638s
#   loss: 3.9038 corr: 133 (75264/2257759) completed in 0m 1.634s
#   loss: 3.9869 corr: 137 (75648/2257759) completed in 0m 1.610s
#   loss: 4.1505 corr: 113 (76032/2257759) completed in 0m 1.665s
#   loss: 3.9222 corr: 137 (76416/2257759) completed in 0m 1.609s
#   loss: 3.8180 corr: 131 (76800/2257759) completed in 0m 1.659s
#   loss: 3.9452 corr: 129 (77184/2257759) completed in 0m 1.625s
#   loss: 4.2066 corr: 122 (77568/2257759) completed in 0m 1.696s
#   loss: 4.1882 corr: 121 (77952/2257759) completed in 0m 1.668s
#   loss: 3.8390 corr: 118 (78336/2257759) completed in 0m 1.693s
#   loss: 4.0608 corr: 128 (78720/2257759) completed in 0m 1.729s
#   loss: 3.8880 corr: 131 (79104/2257759) completed in 0m 1.660s
#   loss: 4.2427 corr: 120 (79488/2257759) completed in 0m 1.684s
#   loss: 3.5810 corr: 137 (79872/2257759) completed in 0m 1.633s
#   loss: 3.8501 corr: 118 (80256/2257759) completed in 0m 1.664s
#   loss: 4.0129 corr: 125 (80640/2257759) completed in 0m 1.759s
#   loss: 3.8002 corr: 145 (81024/2257759) completed in 0m 1.729s
#   loss: 3.9401 corr: 126 (81408/2257759) completed in 0m 1.638s
#   loss: 3.8031 corr: 137 (81792/2257759) completed in 0m 1.666s
#   loss: 4.1415 corr: 115 (82176/2257759) completed in 0m 1.686s
#   loss: 3.8920 corr: 133 (82560/2257759) completed in 0m 1.696s
#   loss: 3.8782 corr: 122 (82944/2257759) completed in 0m 1.699s
#   loss: 3.7712 corr: 143 (83328/2257759) completed in 0m 1.653s
#   loss: 3.8339 corr: 132 (83712/2257759) completed in 0m 1.675s
#   loss: 3.7608 corr: 135 (84096/2257759) completed in 0m 1.756s
#   loss: 3.9651 corr: 131 (84480/2257759) completed in 0m 1.691s
#   loss: 4.0555 corr: 142 (84864/2257759) completed in 0m 1.702s
#   loss: 3.8970 corr: 129 (85248/2257759) completed in 0m 1.714s
#   loss: 3.9409 corr: 122 (85632/2257759) completed in 0m 1.714s
#   loss: 3.8719 corr: 136 (86016/2257759) completed in 0m 1.761s
#   loss: 3.9432 corr: 120 (86400/2257759) completed in 0m 1.735s
#   loss: 3.7089 corr: 127 (86784/2257759) completed in 0m 1.764s
#   loss: 3.9209 corr: 130 (87168/2257759) completed in 0m 1.705s
#   loss: 3.8901 corr: 135 (87552/2257759) completed in 0m 2.009s
#   loss: 3.9738 corr: 124 (87936/2257759) completed in 0m 1.741s
#   loss: 4.1263 corr: 120 (88320/2257759) completed in 0m 1.702s
#   loss: 3.8073 corr: 129 (88704/2257759) completed in 0m 1.653s
#   loss: 3.9739 corr: 138 (89088/2257759) completed in 0m 1.819s
#   loss: 4.1767 corr: 135 (89472/2257759) completed in 0m 1.674s
#   loss: 3.8240 corr: 136 (89856/2257759) completed in 0m 1.709s
#   loss: 4.0380 corr: 137 (90240/2257759) completed in 0m 1.693s
#   loss: 4.2288 corr: 118 (90624/2257759) completed in 0m 1.988s
#   loss: 4.0005 corr: 137 (91008/2257759) completed in 0m 1.686s
#   loss: 3.8319 corr: 148 (91392/2257759) completed in 0m 1.639s
#   loss: 4.1705 corr: 122 (91776/2257759) completed in 0m 1.706s
#   loss: 4.1826 corr: 116 (92160/2257759) completed in 0m 1.845s
#   loss: 3.6799 corr: 139 (92544/2257759) completed in 0m 1.731s
#   loss: 3.8303 corr: 125 (92928/2257759) completed in 0m 1.672s
#   loss: 3.8301 corr: 134 (93312/2257759) completed in 0m 1.644s
#   loss: 4.1139 corr: 141 (93696/2257759) completed in 0m 1.721s
#   loss: 4.0964 corr: 125 (94080/2257759) completed in 0m 1.737s
#   loss: 4.1152 corr: 135 (94464/2257759) completed in 0m 1.647s
#   loss: 4.2630 corr: 130 (94848/2257759) completed in 0m 1.674s
#   loss: 3.8992 corr: 139 (95232/2257759) completed in 0m 1.665s
#   loss: 4.3646 corr: 110 (95616/2257759) completed in 0m 1.737s
#   loss: 3.8315 corr: 129 (96000/2257759) completed in 0m 1.744s
#   loss: 3.8771 corr: 127 (96384/2257759) completed in 0m 1.813s
#   loss: 3.8373 corr: 128 (96768/2257759) completed in 0m 1.704s
#   loss: 3.8979 corr: 147 (97152/2257759) completed in 0m 1.709s
#   loss: 3.8048 corr: 140 (97536/2257759) completed in 0m 1.724s
#   loss: 3.6637 corr: 149 (97920/2257759) completed in 0m 1.800s
#   loss: 3.9346 corr: 125 (98304/2257759) completed in 0m 1.643s
#   loss: 4.2478 corr: 110 (98688/2257759) completed in 0m 1.704s
#   loss: 4.0894 corr: 115 (99072/2257759) completed in 0m 1.736s
#   loss: 3.8517 corr: 139 (99456/2257759) completed in 0m 1.733s
#   loss: 3.9163 corr: 135 (99840/2257759) completed in 0m 1.710s
#   loss: 3.9682 corr: 137 (100224/2257759) completed in 0m 1.742s
#   loss: 3.9130 corr: 128 (100608/2257759) completed in 0m 1.708s
#   loss: 4.0049 corr: 128 (100992/2257759) completed in 0m 1.563s
#   loss: 3.8593 corr: 142 (101376/2257759) completed in 0m 1.705s
#   loss: 3.9608 corr: 125 (101760/2257759) completed in 0m 1.683s
#   loss: 4.0884 corr: 121 (102144/2257759) completed in 0m 1.684s
#   loss: 4.0459 corr: 138 (102528/2257759) completed in 0m 1.690s
#   loss: 3.8035 corr: 134 (102912/2257759) completed in 0m 1.678s
#   loss: 3.9765 corr: 126 (103296/2257759) completed in 0m 2.094s
#   loss: 4.1642 corr: 133 (103680/2257759) completed in 0m 1.693s
#   loss: 4.5457 corr: 120 (104064/2257759) completed in 0m 1.700s
#   loss: 4.0433 corr: 120 (104448/2257759) completed in 0m 1.770s
#   loss: 4.1513 corr: 120 (104832/2257759) completed in 0m 1.643s
#   loss: 3.8296 corr: 141 (105216/2257759) completed in 0m 1.592s
#   loss: 4.1929 corr: 131 (105600/2257759) completed in 0m 1.707s
#   loss: 4.0226 corr: 123 (105984/2257759) completed in 0m 1.649s
#   loss: 4.1454 corr: 133 (106368/2257759) completed in 0m 2.080s
#   loss: 3.9190 corr: 126 (106752/2257759) completed in 0m 1.636s
#   loss: 4.3019 corr: 110 (107136/2257759) completed in 0m 1.696s
#   loss: 3.9333 corr: 133 (107520/2257759) completed in 0m 1.667s
#   loss: 3.8947 corr: 133 (107904/2257759) completed in 0m 1.826s
#   loss: 3.7097 corr: 136 (108288/2257759) completed in 0m 1.691s
#   loss: 3.9225 corr: 138 (108672/2257759) completed in 0m 1.676s
#   loss: 3.9632 corr: 135 (109056/2257759) completed in 0m 1.626s
#   loss: 3.7888 corr: 131 (109440/2257759) completed in 0m 1.766s
#   loss: 3.8715 corr: 134 (109824/2257759) completed in 0m 1.742s
#   loss: 4.0562 corr: 131 (110208/2257759) completed in 0m 1.641s
#   loss: 4.0276 corr: 133 (110592/2257759) completed in 0m 1.689s
#   loss: 3.9821 corr: 132 (110976/2257759) completed in 0m 1.746s
#   loss: 4.2110 corr: 128 (111360/2257759) completed in 0m 1.681s
#   loss: 4.0169 corr: 135 (111744/2257759) completed in 0m 1.697s
#   loss: 4.0062 corr: 123 (112128/2257759) completed in 0m 1.684s
#   loss: 3.6685 corr: 152 (112512/2257759) completed in 0m 1.719s
#   loss: 3.7266 corr: 139 (112896/2257759) completed in 0m 1.751s
#   loss: 3.7569 corr: 134 (113280/2257759) completed in 0m 1.623s
#   loss: 3.9081 corr: 128 (113664/2257759) completed in 0m 1.779s
#   loss: 3.9936 corr: 126 (114048/2257759) completed in 0m 1.735s
#   loss: 4.0078 corr: 120 (114432/2257759) completed in 0m 1.716s
#   loss: 4.2852 corr: 124 (114816/2257759) completed in 0m 1.643s
#   loss: 4.2204 corr: 123 (115200/2257759) completed in 0m 1.679s
#   loss: 3.8294 corr: 138 (115584/2257759) completed in 0m 1.811s
#   loss: 3.7884 corr: 128 (115968/2257759) completed in 0m 1.704s
#   loss: 4.2130 corr: 122 (116352/2257759) completed in 0m 1.669s
#   loss: 3.7919 corr: 133 (116736/2257759) completed in 0m 1.725s
#   loss: 3.8144 corr: 138 (117120/2257759) completed in 0m 1.725s
#   loss: 4.3517 corr: 124 (117504/2257759) completed in 0m 1.715s
#   loss: 3.9565 corr: 139 (117888/2257759) completed in 0m 1.763s
#   loss: 4.0922 corr: 134 (118272/2257759) completed in 0m 1.611s
#   loss: 4.0924 corr: 119 (118656/2257759) completed in 0m 1.655s
#   loss: 3.6838 corr: 145 (119040/2257759) completed in 0m 1.688s
#   loss: 4.2632 corr: 131 (119424/2257759) completed in 0m 1.623s
#   loss: 3.9161 corr: 140 (119808/2257759) completed in 0m 1.647s
#   loss: 3.9404 corr: 124 (120192/2257759) completed in 0m 1.692s
#   loss: 3.8739 corr: 140 (120576/2257759) completed in 0m 1.759s
#   loss: 3.8297 corr: 141 (120960/2257759) completed in 0m 1.687s
#   loss: 4.0254 corr: 131 (121344/2257759) completed in 0m 1.724s
#   loss: 3.9420 corr: 136 (121728/2257759) completed in 0m 1.679s
#   loss: 3.6079 corr: 131 (122112/2257759) completed in 0m 1.681s
#   loss: 4.1664 corr: 133 (122496/2257759) completed in 0m 1.653s
#   loss: 4.0285 corr: 134 (122880/2257759) completed in 0m 1.722s
#   loss: 3.9862 corr: 130 (123264/2257759) completed in 0m 1.747s
#   loss: 3.8649 corr: 136 (123648/2257759) completed in 0m 1.790s
#   loss: 3.9748 corr: 136 (124032/2257759) completed in 0m 1.615s
#   loss: 4.0781 corr: 139 (124416/2257759) completed in 0m 1.676s
#   loss: 3.9082 corr: 120 (124800/2257759) completed in 0m 1.696s
#   loss: 4.2071 corr: 117 (125184/2257759) completed in 0m 1.744s
#   loss: 4.0440 corr: 118 (125568/2257759) completed in 0m 1.747s
#   loss: 3.9089 corr: 126 (125952/2257759) completed in 0m 1.666s
#   loss: 4.0653 corr: 133 (126336/2257759) completed in 0m 1.689s
#   loss: 4.1226 corr: 129 (126720/2257759) completed in 0m 1.659s
#   loss: 4.1329 corr: 127 (127104/2257759) completed in 0m 1.741s
#   loss: 4.0413 corr: 137 (127488/2257759) completed in 0m 1.625s
#   loss: 3.6839 corr: 151 (127872/2257759) completed in 0m 1.669s
#   loss: 4.0534 corr: 128 (128256/2257759) completed in 0m 1.703s
#   loss: 3.9638 corr: 144 (128640/2257759) completed in 0m 1.665s
#   loss: 3.7984 corr: 134 (129024/2257759) completed in 0m 1.696s
#   loss: 3.9550 corr: 149 (129408/2257759) completed in 0m 1.814s
#   loss: 3.7128 corr: 148 (129792/2257759) completed in 0m 1.631s
#   loss: 4.0472 corr: 146 (130176/2257759) completed in 0m 1.866s
#   loss: 3.6288 corr: 142 (130560/2257759) completed in 0m 1.629s
#   loss: 3.8464 corr: 151 (130944/2257759) completed in 0m 1.647s
#   loss: 3.7630 corr: 121 (131328/2257759) completed in 0m 1.672s
#   loss: 3.7760 corr: 141 (131712/2257759) completed in 0m 1.737s
#   loss: 4.0972 corr: 127 (132096/2257759) completed in 0m 1.639s
#   loss: 3.9976 corr: 140 (132480/2257759) completed in 0m 1.893s
#   loss: 3.9313 corr: 135 (132864/2257759) completed in 0m 1.727s
#   loss: 3.8848 corr: 127 (133248/2257759) completed in 0m 1.815s
#   loss: 4.1206 corr: 125 (133632/2257759) completed in 0m 1.719s
#   loss: 3.8842 corr: 140 (134016/2257759) completed in 0m 1.710s
#   loss: 3.9310 corr: 127 (134400/2257759) completed in 0m 1.745s
#   loss: 3.9709 corr: 132 (134784/2257759) completed in 0m 1.725s
#   loss: 4.0941 corr: 138 (135168/2257759) completed in 0m 1.735s
#   loss: 4.2173 corr: 133 (135552/2257759) completed in 0m 1.837s
#   loss: 3.7691 corr: 131 (135936/2257759) completed in 0m 1.729s
#   loss: 3.9361 corr: 133 (136320/2257759) completed in 0m 1.782s
#   loss: 3.8821 corr: 143 (136704/2257759) completed in 0m 1.720s
#   loss: 3.7951 corr: 138 (137088/2257759) completed in 0m 1.662s
#   loss: 3.9163 corr: 142 (137472/2257759) completed in 0m 1.691s
#   loss: 3.6797 corr: 141 (137856/2257759) completed in 0m 1.664s
#   loss: 4.1064 corr: 137 (138240/2257759) completed in 0m 1.686s
#   loss: 4.6308 corr: 115 (138624/2257759) completed in 0m 1.658s
#   loss: 4.2506 corr: 120 (139008/2257759) completed in 0m 1.632s
#   loss: 4.0339 corr: 140 (139392/2257759) completed in 0m 1.689s
#   loss: 3.9830 corr: 142 (139776/2257759) completed in 0m 1.695s
#   loss: 4.3373 corr: 121 (140160/2257759) completed in 0m 1.744s
#   loss: 4.0132 corr: 123 (140544/2257759) completed in 0m 1.623s
#   loss: 4.0495 corr: 126 (140928/2257759) completed in 0m 1.731s
#   loss: 3.7934 corr: 129 (141312/2257759) completed in 0m 1.724s
#   loss: 3.7373 corr: 139 (141696/2257759) completed in 0m 1.724s
#   loss: 3.8220 corr: 139 (142080/2257759) completed in 0m 1.635s
#   loss: 3.9233 corr: 129 (142464/2257759) completed in 0m 1.870s
#   loss: 3.8418 corr: 137 (142848/2257759) completed in 0m 1.644s
#   loss: 3.8556 corr: 130 (143232/2257759) completed in 0m 1.724s
#   loss: 4.2104 corr: 121 (143616/2257759) completed in 0m 1.750s
#   loss: 4.1362 corr: 116 (144000/2257759) completed in 0m 1.613s
#   loss: 4.2239 corr: 123 (144384/2257759) completed in 0m 1.740s
#   loss: 4.1843 corr: 137 (144768/2257759) completed in 0m 1.834s
#   loss: 4.3803 corr: 110 (145152/2257759) completed in 0m 1.724s
#   loss: 3.6668 corr: 153 (145536/2257759) completed in 0m 1.687s
#   loss: 3.9243 corr: 133 (145920/2257759) completed in 0m 1.692s
#   loss: 3.9719 corr: 141 (146304/2257759) completed in 0m 1.668s
#   loss: 3.9832 corr: 124 (146688/2257759) completed in 0m 1.705s
#   loss: 4.0810 corr: 130 (147072/2257759) completed in 0m 1.705s
#   loss: 4.1142 corr: 131 (147456/2257759) completed in 0m 1.665s
#   loss: 3.6769 corr: 139 (147840/2257759) completed in 0m 1.678s
#   loss: 4.0948 corr: 136 (148224/2257759) completed in 0m 1.617s
#   loss: 3.9909 corr: 123 (148608/2257759) completed in 0m 1.721s
#   loss: 4.0993 corr: 135 (148992/2257759) completed in 0m 1.775s
#   loss: 3.8033 corr: 146 (149376/2257759) completed in 0m 1.669s
#   loss: 3.8058 corr: 132 (149760/2257759) completed in 0m 1.673s
#   loss: 3.8590 corr: 134 (150144/2257759) completed in 0m 1.686s
#   loss: 3.9800 corr: 136 (150528/2257759) completed in 0m 1.721s
#   loss: 4.0137 corr: 134 (150912/2257759) completed in 0m 1.665s
#   loss: 3.9701 corr: 141 (151296/2257759) completed in 0m 1.700s
#   loss: 3.6976 corr: 137 (151680/2257759) completed in 0m 1.735s
#   loss: 4.1193 corr: 117 (152064/2257759) completed in 0m 1.792s
#   loss: 3.7782 corr: 137 (152448/2257759) completed in 0m 1.691s
#   loss: 3.6813 corr: 135 (152832/2257759) completed in 0m 1.656s
#   loss: 4.1415 corr: 125 (153216/2257759) completed in 0m 1.694s
#   loss: 3.7458 corr: 144 (153600/2257759) completed in 0m 1.800s
#   loss: 3.7941 corr: 134 (153984/2257759) completed in 0m 1.728s
#   loss: 3.6406 corr: 153 (154368/2257759) completed in 0m 1.724s
#   loss: 3.5729 corr: 154 (154752/2257759) completed in 0m 1.723s
#   loss: 4.0018 corr: 131 (155136/2257759) completed in 0m 1.780s
#   loss: 3.8638 corr: 134 (155520/2257759) completed in 0m 1.674s
#   loss: 3.6509 corr: 156 (155904/2257759) completed in 0m 1.623s
#   loss: 4.2955 corr: 128 (156288/2257759) completed in 0m 1.641s
#   loss: 4.2236 corr: 130 (156672/2257759) completed in 0m 1.696s
#   loss: 3.9210 corr: 149 (157056/2257759) completed in 0m 1.697s
#   loss: 3.6354 corr: 153 (157440/2257759) completed in 0m 1.682s
#   loss: 3.9016 corr: 132 (157824/2257759) completed in 0m 1.698s
#   loss: 3.7489 corr: 135 (158208/2257759) completed in 0m 1.836s
#   loss: 3.7258 corr: 142 (158592/2257759) completed in 0m 1.649s
#   loss: 4.1854 corr: 131 (158976/2257759) completed in 0m 1.824s
#   loss: 3.9975 corr: 146 (159360/2257759) completed in 0m 1.730s
#   loss: 3.9134 corr: 139 (159744/2257759) completed in 0m 1.696s
#   loss: 3.5778 corr: 155 (160128/2257759) completed in 0m 1.706s
#   loss: 3.9468 corr: 139 (160512/2257759) completed in 0m 1.560s
#   loss: 4.0802 corr: 139 (160896/2257759) completed in 0m 1.562s
#   loss: 4.1188 corr: 140 (161280/2257759) completed in 0m 1.616s
#   loss: 3.9898 corr: 142 (161664/2257759) completed in 0m 1.688s
#   loss: 3.8290 corr: 139 (162048/2257759) completed in 0m 1.711s
#   loss: 3.8979 corr: 145 (162432/2257759) completed in 0m 1.720s
#   loss: 4.0693 corr: 131 (162816/2257759) completed in 0m 1.658s
#   loss: 3.8946 corr: 134 (163200/2257759) completed in 0m 1.739s
#   loss: 3.9312 corr: 136 (163584/2257759) completed in 0m 1.730s
#   loss: 4.1147 corr: 133 (163968/2257759) completed in 0m 1.737s
#   loss: 4.0690 corr: 137 (164352/2257759) completed in 0m 1.790s
#   loss: 3.9914 corr: 134 (164736/2257759) completed in 0m 1.557s
#   loss: 4.0567 corr: 135 (165120/2257759) completed in 0m 1.644s
#   loss: 3.8885 corr: 137 (165504/2257759) completed in 0m 1.669s
#   loss: 4.1768 corr: 119 (165888/2257759) completed in 0m 1.670s
#   loss: 3.7866 corr: 147 (166272/2257759) completed in 0m 1.704s
#   loss: 3.8435 corr: 142 (166656/2257759) completed in 0m 1.630s
#   loss: 3.8665 corr: 146 (167040/2257759) completed in 0m 1.660s
#   loss: 3.9418 corr: 146 (167424/2257759) completed in 0m 1.849s
#   loss: 3.4437 corr: 147 (167808/2257759) completed in 0m 1.658s
#   loss: 4.0603 corr: 122 (168192/2257759) completed in 0m 1.729s
#   loss: 3.5074 corr: 152 (168576/2257759) completed in 0m 1.716s
#   loss: 3.8541 corr: 136 (168960/2257759) completed in 0m 1.642s
#   loss: 3.8582 corr: 139 (169344/2257759) completed in 0m 1.668s
#   loss: 3.8934 corr: 137 (169728/2257759) completed in 0m 1.669s
#   loss: 4.1618 corr: 134 (170112/2257759) completed in 0m 1.634s
#   loss: 3.9834 corr: 136 (170496/2257759) completed in 0m 1.821s
#   loss: 3.9462 corr: 128 (170880/2257759) completed in 0m 1.745s
#   loss: 3.9863 corr: 136 (171264/2257759) completed in 0m 1.586s
#   loss: 3.7457 corr: 141 (171648/2257759) completed in 0m 1.664s
#   loss: 4.3776 corr: 123 (172032/2257759) completed in 0m 1.663s
#   loss: 3.9315 corr: 131 (172416/2257759) completed in 0m 1.624s
#   loss: 4.1684 corr: 130 (172800/2257759) completed in 0m 1.719s
#   loss: 4.2155 corr: 138 (173184/2257759) completed in 0m 1.637s
#   loss: 4.2353 corr: 126 (173568/2257759) completed in 0m 1.719s
#   loss: 4.0166 corr: 130 (173952/2257759) completed in 0m 1.836s
#   loss: 3.8823 corr: 133 (174336/2257759) completed in 0m 1.689s
#   loss: 4.1774 corr: 123 (174720/2257759) completed in 0m 1.691s
#   loss: 3.9634 corr: 142 (175104/2257759) completed in 0m 1.675s
#   loss: 3.9864 corr: 132 (175488/2257759) completed in 0m 1.689s
#   loss: 3.7885 corr: 131 (175872/2257759) completed in 0m 1.684s
#   loss: 4.1024 corr: 120 (176256/2257759) completed in 0m 1.582s
#   loss: 4.2725 corr: 130 (176640/2257759) completed in 0m 1.834s
#   loss: 4.0774 corr: 127 (177024/2257759) completed in 0m 1.638s
#   loss: 3.9805 corr: 124 (177408/2257759) completed in 0m 1.653s
#   loss: 4.0067 corr: 137 (177792/2257759) completed in 0m 1.675s
#   loss: 3.7504 corr: 143 (178176/2257759) completed in 0m 1.656s
#   loss: 4.3237 corr: 116 (178560/2257759) completed in 0m 1.748s
#   loss: 4.2080 corr: 124 (178944/2257759) completed in 0m 1.648s
#   loss: 4.0510 corr: 137 (179328/2257759) completed in 0m 1.620s
#   loss: 3.8520 corr: 127 (179712/2257759) completed in 0m 1.771s
#   loss: 3.8419 corr: 131 (180096/2257759) completed in 0m 1.735s
#   loss: 4.1233 corr: 124 (180480/2257759) completed in 0m 1.677s
#   loss: 3.9643 corr: 144 (180864/2257759) completed in 0m 1.682s
#   loss: 3.6346 corr: 145 (181248/2257759) completed in 0m 1.686s
#   loss: 3.7991 corr: 136 (181632/2257759) completed in 0m 1.665s
#   loss: 3.6240 corr: 141 (182016/2257759) completed in 0m 1.719s
#   loss: 3.8849 corr: 135 (182400/2257759) completed in 0m 1.597s
#   loss: 3.8251 corr: 147 (182784/2257759) completed in 0m 1.608s
#   loss: 3.9162 corr: 129 (183168/2257759) completed in 0m 1.629s
#   loss: 4.1267 corr: 127 (183552/2257759) completed in 0m 1.701s
#   loss: 3.8278 corr: 129 (183936/2257759) completed in 0m 1.747s
#   loss: 3.8882 corr: 137 (184320/2257759) completed in 0m 1.684s
#   loss: 4.0788 corr: 132 (184704/2257759) completed in 0m 1.669s
#   loss: 4.0438 corr: 133 (185088/2257759) completed in 0m 1.704s
#   loss: 3.7686 corr: 140 (185472/2257759) completed in 0m 1.624s
#   loss: 4.1127 corr: 126 (185856/2257759) completed in 0m 1.644s
#   loss: 4.3121 corr: 139 (186240/2257759) completed in 0m 1.720s
#   loss: 3.9997 corr: 134 (186624/2257759) completed in 0m 1.739s
#   loss: 4.2306 corr: 122 (187008/2257759) completed in 0m 1.636s
#   loss: 3.6661 corr: 142 (187392/2257759) completed in 0m 1.576s
#   loss: 4.1410 corr: 132 (187776/2257759) completed in 0m 1.686s
#   loss: 3.9151 corr: 127 (188160/2257759) completed in 0m 1.731s
#   loss: 4.1626 corr: 130 (188544/2257759) completed in 0m 1.693s
#   loss: 4.3044 corr: 135 (188928/2257759) completed in 0m 2.243s
#   loss: 3.9611 corr: 137 (189312/2257759) completed in 0m 1.709s
#   loss: 4.1607 corr: 136 (189696/2257759) completed in 0m 1.730s
#   loss: 4.2196 corr: 119 (190080/2257759) completed in 0m 1.711s
#   loss: 4.0133 corr: 134 (190464/2257759) completed in 0m 1.726s
#   loss: 3.8924 corr: 136 (190848/2257759) completed in 0m 1.693s
#   loss: 3.8418 corr: 144 (191232/2257759) completed in 0m 1.680s
#   loss: 4.0969 corr: 142 (191616/2257759) completed in 0m 1.708s
#   loss: 3.9486 corr: 135 (192000/2257759) completed in 0m 1.868s
#   loss: 4.1331 corr: 133 (192384/2257759) completed in 0m 1.707s
#   loss: 3.9315 corr: 137 (192768/2257759) completed in 0m 1.717s
#   loss: 4.0948 corr: 126 (193152/2257759) completed in 0m 1.759s
#   loss: 3.8665 corr: 142 (193536/2257759) completed in 0m 1.676s
#   loss: 4.1645 corr: 120 (193920/2257759) completed in 0m 1.697s
#   loss: 3.9521 corr: 139 (194304/2257759) completed in 0m 1.668s
#   loss: 3.8310 corr: 143 (194688/2257759) completed in 0m 2.014s
#   loss: 3.8335 corr: 153 (195072/2257759) completed in 0m 1.799s
#   loss: 3.9877 corr: 136 (195456/2257759) completed in 0m 1.703s
#   loss: 3.9150 corr: 152 (195840/2257759) completed in 0m 1.694s
#   loss: 3.9041 corr: 135 (196224/2257759) completed in 0m 1.603s
#   loss: 4.0980 corr: 133 (196608/2257759) completed in 0m 1.697s
#   loss: 3.9356 corr: 136 (196992/2257759) completed in 0m 1.640s
#   loss: 3.9264 corr: 131 (197376/2257759) completed in 0m 1.985s
#   loss: 3.8297 corr: 146 (197760/2257759) completed in 0m 1.841s
#   loss: 3.8253 corr: 133 (198144/2257759) completed in 0m 1.690s
#   loss: 3.8443 corr: 139 (198528/2257759) completed in 0m 1.731s
#   loss: 3.9875 corr: 131 (198912/2257759) completed in 0m 1.653s
#   loss: 4.1141 corr: 138 (199296/2257759) completed in 0m 1.710s
#   loss: 4.3468 corr: 127 (199680/2257759) completed in 0m 1.666s
#   loss: 4.0854 corr: 127 (200064/2257759) completed in 0m 1.706s
#   loss: 3.7575 corr: 139 (200448/2257759) completed in 0m 1.705s
#   loss: 3.9734 corr: 145 (200832/2257759) completed in 0m 1.850s
#   loss: 3.8544 corr: 124 (201216/2257759) completed in 0m 1.707s
#   loss: 4.0708 corr: 123 (201600/2257759) completed in 0m 1.678s
#   loss: 3.8646 corr: 134 (201984/2257759) completed in 0m 1.646s
#   loss: 4.1436 corr: 125 (202368/2257759) completed in 0m 1.777s
#   loss: 3.7522 corr: 137 (202752/2257759) completed in 0m 1.681s
#   loss: 3.9820 corr: 134 (203136/2257759) completed in 0m 1.701s
#   loss: 4.0625 corr: 133 (203520/2257759) completed in 0m 1.693s
#   loss: 4.0936 corr: 122 (203904/2257759) completed in 0m 1.812s
#   loss: 4.0237 corr: 141 (204288/2257759) completed in 0m 1.699s
#   loss: 4.2313 corr: 134 (204672/2257759) completed in 0m 1.653s
#   loss: 3.9427 corr: 140 (205056/2257759) completed in 0m 1.613s
#   loss: 3.8328 corr: 148 (205440/2257759) completed in 0m 1.689s
#   loss: 4.1296 corr: 134 (205824/2257759) completed in 0m 1.736s
#   loss: 3.8733 corr: 132 (206208/2257759) completed in 0m 1.715s
#   loss: 4.1117 corr: 133 (206592/2257759) completed in 0m 1.650s
#   loss: 4.0154 corr: 135 (206976/2257759) completed in 0m 1.824s
#   loss: 3.8541 corr: 144 (207360/2257759) completed in 0m 1.728s
#   loss: 3.9490 corr: 146 (207744/2257759) completed in 0m 1.701s
#   loss: 3.6234 corr: 154 (208128/2257759) completed in 0m 1.651s
#   loss: 4.1541 corr: 138 (208512/2257759) completed in 0m 1.755s
#   loss: 3.8329 corr: 129 (208896/2257759) completed in 0m 1.747s
#   loss: 3.9388 corr: 137 (209280/2257759) completed in 0m 1.674s
#   loss: 3.8916 corr: 135 (209664/2257759) completed in 0m 1.732s
#   loss: 3.8456 corr: 138 (210048/2257759) completed in 0m 1.768s
#   loss: 4.0123 corr: 139 (210432/2257759) completed in 0m 1.719s
#   loss: 4.0445 corr: 143 (210816/2257759) completed in 0m 1.682s
#   loss: 3.9826 corr: 135 (211200/2257759) completed in 0m 1.664s
#   loss: 4.0277 corr: 140 (211584/2257759) completed in 0m 1.779s
#   loss: 3.8115 corr: 133 (211968/2257759) completed in 0m 1.666s
#   loss: 4.0491 corr: 142 (212352/2257759) completed in 0m 1.738s
#   loss: 3.7122 corr: 138 (212736/2257759) completed in 0m 1.655s
#   loss: 3.7883 corr: 138 (213120/2257759) completed in 0m 1.824s
#   loss: 3.9445 corr: 133 (213504/2257759) completed in 0m 1.669s
#   loss: 4.1236 corr: 117 (213888/2257759) completed in 0m 1.687s
#   loss: 4.0256 corr: 149 (214272/2257759) completed in 0m 1.683s
#   loss: 3.8766 corr: 134 (214656/2257759) completed in 0m 1.669s
#   loss: 3.9916 corr: 145 (215040/2257759) completed in 0m 1.730s
#   loss: 4.1302 corr: 132 (215424/2257759) completed in 0m 1.757s
#   loss: 3.8402 corr: 125 (215808/2257759) completed in 0m 1.719s
#   loss: 3.8929 corr: 150 (216192/2257759) completed in 0m 1.756s
#   loss: 3.7698 corr: 123 (216576/2257759) completed in 0m 1.717s
#   loss: 3.6508 corr: 147 (216960/2257759) completed in 0m 1.682s
#   loss: 3.5866 corr: 149 (217344/2257759) completed in 0m 1.705s
#   loss: 3.8487 corr: 136 (217728/2257759) completed in 0m 1.679s
#   loss: 4.1684 corr: 130 (218112/2257759) completed in 0m 1.718s
#   loss: 3.9980 corr: 140 (218496/2257759) completed in 0m 1.665s
#   loss: 4.2147 corr: 130 (218880/2257759) completed in 0m 1.692s
#   loss: 3.8900 corr: 149 (219264/2257759) completed in 0m 1.782s
#   loss: 3.8934 corr: 124 (219648/2257759) completed in 0m 1.727s
#   loss: 3.6136 corr: 145 (220032/2257759) completed in 0m 1.655s
#   loss: 3.6574 corr: 150 (220416/2257759) completed in 0m 1.706s
#   loss: 4.0235 corr: 130 (220800/2257759) completed in 0m 1.570s
#   loss: 3.9611 corr: 144 (221184/2257759) completed in 0m 1.708s
#   loss: 3.8017 corr: 132 (221568/2257759) completed in 0m 1.750s
#   loss: 3.9407 corr: 134 (221952/2257759) completed in 0m 1.703s
#   loss: 3.9485 corr: 138 (222336/2257759) completed in 0m 1.678s
#   loss: 3.9210 corr: 146 (222720/2257759) completed in 0m 1.812s
#   loss: 3.8163 corr: 148 (223104/2257759) completed in 0m 1.653s
#   loss: 3.8863 corr: 138 (223488/2257759) completed in 0m 1.713s
#   loss: 3.8970 corr: 142 (223872/2257759) completed in 0m 1.668s
#   loss: 3.7419 corr: 133 (224256/2257759) completed in 0m 1.733s
#   loss: 4.0099 corr: 133 (224640/2257759) completed in 0m 1.672s
#   loss: 3.9432 corr: 147 (225024/2257759) completed in 0m 1.732s
#   loss: 3.8535 corr: 130 (225408/2257759) completed in 0m 1.686s
#   loss: 4.1793 corr: 141 (225792/2257759) completed in 0m 1.780s
#   loss: 3.9412 corr: 128 (226176/2257759) completed in 0m 1.719s
#   loss: 3.9303 corr: 146 (226560/2257759) completed in 0m 1.734s
#   loss: 4.0157 corr: 132 (226944/2257759) completed in 0m 1.690s
#   loss: 4.1285 corr: 122 (227328/2257759) completed in 0m 1.652s
#   loss: 4.4103 corr: 126 (227712/2257759) completed in 0m 1.712s
#   loss: 4.1662 corr: 132 (228096/2257759) completed in 0m 1.709s
#   loss: 4.0438 corr: 129 (228480/2257759) completed in 0m 1.722s
#   loss: 4.0705 corr: 132 (228864/2257759) completed in 0m 1.813s
#   loss: 4.0552 corr: 131 (229248/2257759) completed in 0m 1.700s
#   loss: 4.1739 corr: 129 (229632/2257759) completed in 0m 1.669s
#   loss: 4.0939 corr: 118 (230016/2257759) completed in 0m 1.658s
#   loss: 4.2841 corr: 124 (230400/2257759) completed in 0m 1.746s
#   loss: 3.7541 corr: 153 (230784/2257759) completed in 0m 1.698s
#   loss: 3.9771 corr: 139 (231168/2257759) completed in 0m 1.699s
#   loss: 3.8049 corr: 147 (231552/2257759) completed in 0m 1.726s
#   loss: 4.2181 corr: 125 (231936/2257759) completed in 0m 1.837s
#   loss: 3.6684 corr: 137 (232320/2257759) completed in 0m 1.802s
#   loss: 4.1146 corr: 135 (232704/2257759) completed in 0m 1.751s
#   loss: 3.8810 corr: 134 (233088/2257759) completed in 0m 1.702s
#   loss: 3.7449 corr: 144 (233472/2257759) completed in 0m 1.676s
#   loss: 3.8463 corr: 134 (233856/2257759) completed in 0m 1.709s
#   loss: 3.5760 corr: 145 (234240/2257759) completed in 0m 1.710s
#   loss: 3.9208 corr: 130 (234624/2257759) completed in 0m 1.778s
#   loss: 4.0441 corr: 129 (235008/2257759) completed in 0m 1.704s
#   loss: 4.2408 corr: 127 (235392/2257759) completed in 0m 1.677s
#   loss: 3.8169 corr: 136 (235776/2257759) completed in 0m 1.680s
#   loss: 3.9135 corr: 153 (236160/2257759) completed in 0m 1.701s
#   loss: 3.9175 corr: 140 (236544/2257759) completed in 0m 1.657s
#   loss: 3.3650 corr: 150 (236928/2257759) completed in 0m 1.663s
#   loss: 4.2751 corr: 141 (237312/2257759) completed in 0m 1.738s
#   loss: 3.7330 corr: 143 (237696/2257759) completed in 0m 1.816s
#   loss: 3.9080 corr: 152 (238080/2257759) completed in 0m 1.724s
#   loss: 3.9582 corr: 146 (238464/2257759) completed in 0m 1.697s
#   loss: 4.2761 corr: 132 (238848/2257759) completed in 0m 1.775s
#   loss: 3.7992 corr: 133 (239232/2257759) completed in 0m 1.665s
#   loss: 4.0764 corr: 122 (239616/2257759) completed in 0m 1.712s
#   loss: 3.6950 corr: 134 (240000/2257759) completed in 0m 1.692s
#   loss: 3.9815 corr: 139 (240384/2257759) completed in 0m 1.741s
#   loss: 3.5570 corr: 148 (240768/2257759) completed in 0m 1.871s
#   loss: 3.8538 corr: 136 (241152/2257759) completed in 0m 1.661s
#   loss: 3.7509 corr: 140 (241536/2257759) completed in 0m 1.773s
#   loss: 4.1430 corr: 137 (241920/2257759) completed in 0m 1.719s
#   loss: 3.9751 corr: 148 (242304/2257759) completed in 0m 1.690s
#   loss: 4.1306 corr: 128 (242688/2257759) completed in 0m 1.727s
#   loss: 4.0670 corr: 128 (243072/2257759) completed in 0m 1.732s
#   loss: 3.8083 corr: 140 (243456/2257759) completed in 0m 1.668s
#   loss: 3.9605 corr: 142 (243840/2257759) completed in 0m 1.794s
#   loss: 3.8203 corr: 147 (244224/2257759) completed in 0m 1.609s
#   loss: 3.8304 corr: 141 (244608/2257759) completed in 0m 1.608s
#   loss: 3.7810 corr: 149 (244992/2257759) completed in 0m 1.680s
#   loss: 4.0184 corr: 130 (245376/2257759) completed in 0m 1.654s
#   loss: 4.2567 corr: 130 (245760/2257759) completed in 0m 1.634s
#   loss: 3.8122 corr: 136 (246144/2257759) completed in 0m 1.775s
#   loss: 3.6835 corr: 153 (246528/2257759) completed in 0m 1.711s
#   loss: 4.2467 corr: 133 (246912/2257759) completed in 0m 1.876s
#   loss: 4.1730 corr: 136 (247296/2257759) completed in 0m 1.665s
#   loss: 4.1487 corr: 128 (247680/2257759) completed in 0m 1.713s
#   loss: 3.8039 corr: 152 (248064/2257759) completed in 0m 1.669s
#   loss: 4.1524 corr: 129 (248448/2257759) completed in 0m 1.714s
#   loss: 4.1778 corr: 127 (248832/2257759) completed in 0m 1.699s
#   loss: 4.4718 corr: 133 (249216/2257759) completed in 0m 1.633s
#   loss: 3.9515 corr: 147 (249600/2257759) completed in 0m 1.680s
#   loss: 3.8353 corr: 152 (249984/2257759) completed in 0m 1.823s
#   loss: 4.0425 corr: 120 (250368/2257759) completed in 0m 1.643s
#   loss: 3.7991 corr: 139 (250752/2257759) completed in 0m 1.585s
#   loss: 4.0851 corr: 128 (251136/2257759) completed in 0m 1.690s
#   loss: 3.8747 corr: 126 (251520/2257759) completed in 0m 1.746s
#   loss: 3.9650 corr: 131 (251904/2257759) completed in 0m 1.720s
#   loss: 3.8535 corr: 142 (252288/2257759) completed in 0m 1.693s
#   loss: 4.0267 corr: 140 (252672/2257759) completed in 0m 1.661s
#   loss: 3.8751 corr: 148 (253056/2257759) completed in 0m 1.835s
#   loss: 3.8523 corr: 148 (253440/2257759) completed in 0m 1.753s
#   loss: 3.7986 corr: 136 (253824/2257759) completed in 0m 1.627s
#   loss: 3.9519 corr: 117 (254208/2257759) completed in 0m 1.743s
#   loss: 3.9094 corr: 148 (254592/2257759) completed in 0m 1.756s
#   loss: 3.7783 corr: 151 (254976/2257759) completed in 0m 1.680s
#   loss: 3.7180 corr: 136 (255360/2257759) completed in 0m 1.708s
#   loss: 3.8411 corr: 136 (255744/2257759) completed in 0m 1.733s
#   loss: 3.8474 corr: 147 (256128/2257759) completed in 0m 1.765s
#   loss: 4.1201 corr: 127 (256512/2257759) completed in 0m 1.588s
#   loss: 3.8400 corr: 148 (256896/2257759) completed in 0m 1.630s
#   loss: 3.8510 corr: 137 (257280/2257759) completed in 0m 1.663s
#   loss: 3.7869 corr: 139 (257664/2257759) completed in 0m 1.749s
#   loss: 3.7695 corr: 156 (258048/2257759) completed in 0m 1.652s
#   loss: 4.1720 corr: 129 (258432/2257759) completed in 0m 1.700s
#   loss: 4.1665 corr: 143 (258816/2257759) completed in 0m 1.719s
#   loss: 3.9181 corr: 131 (259200/2257759) completed in 0m 1.830s
#   loss: 4.0212 corr: 138 (259584/2257759) completed in 0m 1.681s
#   loss: 3.4213 corr: 158 (259968/2257759) completed in 0m 1.645s
#   loss: 3.7974 corr: 140 (260352/2257759) completed in 0m 1.705s
#   loss: 4.2531 corr: 134 (260736/2257759) completed in 0m 1.553s
#   loss: 4.1310 corr: 130 (261120/2257759) completed in 0m 1.706s
#   loss: 4.0365 corr: 119 (261504/2257759) completed in 0m 1.690s
#   loss: 4.0159 corr: 141 (261888/2257759) completed in 0m 1.699s
#   loss: 3.7134 corr: 139 (262272/2257759) completed in 0m 1.853s
#   loss: 3.9122 corr: 138 (262656/2257759) completed in 0m 1.701s
#   loss: 4.2285 corr: 141 (263040/2257759) completed in 0m 1.753s
#   loss: 4.0019 corr: 145 (263424/2257759) completed in 0m 1.710s
#   loss: 4.1574 corr: 142 (263808/2257759) completed in 0m 1.660s
#   loss: 3.8485 corr: 137 (264192/2257759) completed in 0m 1.592s
#   loss: 3.9643 corr: 138 (264576/2257759) completed in 0m 1.722s
#   loss: 3.9070 corr: 137 (264960/2257759) completed in 0m 1.763s
#   loss: 3.9333 corr: 137 (265344/2257759) completed in 0m 1.814s
#   loss: 3.5625 corr: 152 (265728/2257759) completed in 0m 1.704s
#   loss: 3.8165 corr: 140 (266112/2257759) completed in 0m 1.759s
#   loss: 4.0086 corr: 137 (266496/2257759) completed in 0m 1.563s
#   loss: 4.1430 corr: 132 (266880/2257759) completed in 0m 1.719s
#   loss: 3.7162 corr: 139 (267264/2257759) completed in 0m 1.617s
#   loss: 3.9149 corr: 131 (267648/2257759) completed in 0m 1.981s
#   loss: 3.9893 corr: 144 (268032/2257759) completed in 0m 1.624s
#   loss: 3.4777 corr: 146 (268416/2257759) completed in 0m 1.767s
#   loss: 4.0260 corr: 128 (268800/2257759) completed in 0m 1.678s
#   loss: 4.1056 corr: 133 (269184/2257759) completed in 0m 1.683s
#   loss: 3.7766 corr: 133 (269568/2257759) completed in 0m 1.699s
#   loss: 3.9130 corr: 142 (269952/2257759) completed in 0m 1.650s
#   loss: 3.9852 corr: 141 (270336/2257759) completed in 0m 1.702s
#   loss: 4.1873 corr: 143 (270720/2257759) completed in 0m 1.842s
#   loss: 3.9184 corr: 136 (271104/2257759) completed in 0m 1.621s
#   loss: 4.2894 corr: 126 (271488/2257759) completed in 0m 1.812s
#   loss: 4.2829 corr: 149 (271872/2257759) completed in 0m 1.679s
#   loss: 3.6874 corr: 138 (272256/2257759) completed in 0m 1.738s
#   loss: 3.8464 corr: 140 (272640/2257759) completed in 0m 1.627s
#   loss: 3.9000 corr: 136 (273024/2257759) completed in 0m 1.711s
#   loss: 3.9125 corr: 145 (273408/2257759) completed in 0m 1.712s
#   loss: 3.7998 corr: 143 (273792/2257759) completed in 0m 1.915s
#   loss: 3.7900 corr: 131 (274176/2257759) completed in 0m 1.700s
#   loss: 3.9480 corr: 139 (274560/2257759) completed in 0m 1.561s
#   loss: 3.9249 corr: 144 (274944/2257759) completed in 0m 1.797s
#   loss: 3.8387 corr: 149 (275328/2257759) completed in 0m 1.698s
#   loss: 3.7511 corr: 140 (275712/2257759) completed in 0m 1.666s
#   loss: 3.7098 corr: 130 (276096/2257759) completed in 0m 1.718s
#   loss: 4.2389 corr: 130 (276480/2257759) completed in 0m 1.644s
#   loss: 4.2572 corr: 128 (276864/2257759) completed in 0m 1.671s
#   loss: 3.6640 corr: 132 (277248/2257759) completed in 0m 1.606s
#   loss: 3.8806 corr: 145 (277632/2257759) completed in 0m 1.676s
#   loss: 3.9618 corr: 141 (278016/2257759) completed in 0m 1.845s
#   loss: 4.2275 corr: 126 (278400/2257759) completed in 0m 1.685s
#   loss: 3.7834 corr: 142 (278784/2257759) completed in 0m 1.733s
#   loss: 3.9690 corr: 123 (279168/2257759) completed in 0m 1.684s
#   loss: 3.8249 corr: 127 (279552/2257759) completed in 0m 1.690s
#   loss: 3.6440 corr: 147 (279936/2257759) completed in 0m 1.694s
#   loss: 4.2127 corr: 126 (280320/2257759) completed in 0m 1.617s
#   loss: 3.8191 corr: 145 (280704/2257759) completed in 0m 1.670s
#   loss: 3.6663 corr: 140 (281088/2257759) completed in 0m 1.805s
#   loss: 3.6630 corr: 150 (281472/2257759) completed in 0m 1.712s
#   loss: 3.7386 corr: 141 (281856/2257759) completed in 0m 1.646s
#   loss: 4.3265 corr: 117 (282240/2257759) completed in 0m 1.640s
#   loss: 3.8901 corr: 155 (282624/2257759) completed in 0m 1.680s
#   loss: 3.9530 corr: 126 (283008/2257759) completed in 0m 1.684s
#   loss: 3.6169 corr: 155 (283392/2257759) completed in 0m 1.708s
#   loss: 3.7050 corr: 144 (283776/2257759) completed in 0m 1.678s
#   loss: 3.9716 corr: 141 (284160/2257759) completed in 0m 1.795s
#   loss: 3.8131 corr: 138 (284544/2257759) completed in 0m 1.724s
#   loss: 3.9989 corr: 130 (284928/2257759) completed in 0m 1.658s
# ...
#   loss: 2.3844 corr: 196 (2166144/2257759) completed in 0m 1.654s
#   loss: 2.5641 corr: 191 (2166528/2257759) completed in 0m 1.720s
#   loss: 2.3007 corr: 220 (2166912/2257759) completed in 0m 1.654s
#   loss: 2.5442 corr: 186 (2167296/2257759) completed in 0m 1.743s
#   loss: 2.6353 corr: 189 (2167680/2257759) completed in 0m 1.677s
#   loss: 2.6484 corr: 198 (2168064/2257759) completed in 0m 1.618s
#   loss: 2.8422 corr: 201 (2168448/2257759) completed in 0m 1.875s
#   loss: 2.6134 corr: 197 (2168832/2257759) completed in 0m 1.708s
#   loss: 2.6230 corr: 200 (2169216/2257759) completed in 0m 1.671s
#   loss: 2.4817 corr: 202 (2169600/2257759) completed in 0m 1.658s
#   loss: 2.3917 corr: 208 (2169984/2257759) completed in 0m 1.668s
#   loss: 2.5023 corr: 185 (2170368/2257759) completed in 0m 1.716s
#   loss: 2.4485 corr: 204 (2170752/2257759) completed in 0m 1.712s
#   loss: 2.3112 corr: 202 (2171136/2257759) completed in 0m 1.702s
#   loss: 2.6733 corr: 195 (2171520/2257759) completed in 0m 1.740s
#   loss: 2.4551 corr: 192 (2171904/2257759) completed in 0m 1.679s
#   loss: 2.4286 corr: 204 (2172288/2257759) completed in 0m 1.661s
#   loss: 2.6559 corr: 187 (2172672/2257759) completed in 0m 1.687s
#   loss: 2.5098 corr: 205 (2173056/2257759) completed in 0m 1.713s
#   loss: 2.6761 corr: 202 (2173440/2257759) completed in 0m 1.657s
#   loss: 2.5512 corr: 199 (2173824/2257759) completed in 0m 1.667s
#   loss: 2.4494 corr: 191 (2174208/2257759) completed in 0m 1.713s
#   loss: 2.5357 corr: 194 (2174592/2257759) completed in 0m 1.702s
#   loss: 2.4752 corr: 198 (2174976/2257759) completed in 0m 1.746s
#   loss: 2.2949 corr: 215 (2175360/2257759) completed in 0m 1.637s
#   loss: 2.3885 corr: 208 (2175744/2257759) completed in 0m 1.692s
#   loss: 2.6682 corr: 191 (2176128/2257759) completed in 0m 1.677s
#   loss: 2.5255 corr: 209 (2176512/2257759) completed in 0m 1.641s
#   loss: 2.6707 corr: 207 (2176896/2257759) completed in 0m 1.662s
#   loss: 2.4045 corr: 201 (2177280/2257759) completed in 0m 1.636s
#   loss: 2.5684 corr: 185 (2177664/2257759) completed in 0m 1.791s
#   loss: 2.4647 corr: 211 (2178048/2257759) completed in 0m 1.688s
#   loss: 2.6241 corr: 186 (2178432/2257759) completed in 0m 1.604s
#   loss: 2.4436 corr: 190 (2178816/2257759) completed in 0m 1.718s
#   loss: 2.4196 corr: 205 (2179200/2257759) completed in 0m 1.653s
#   loss: 2.2490 corr: 205 (2179584/2257759) completed in 0m 1.681s
#   loss: 2.2746 corr: 215 (2179968/2257759) completed in 0m 1.700s
#   loss: 2.6599 corr: 198 (2180352/2257759) completed in 0m 1.728s
#   loss: 2.4013 corr: 208 (2180736/2257759) completed in 0m 1.659s
#   loss: 2.6555 corr: 182 (2181120/2257759) completed in 0m 1.750s
#   loss: 2.4627 corr: 202 (2181504/2257759) completed in 0m 1.674s
#   loss: 2.3615 corr: 196 (2181888/2257759) completed in 0m 1.691s
#   loss: 2.4114 corr: 215 (2182272/2257759) completed in 0m 1.735s
#   loss: 2.7569 corr: 194 (2182656/2257759) completed in 0m 1.703s
#   loss: 2.7240 corr: 190 (2183040/2257759) completed in 0m 1.662s
#   loss: 2.4529 corr: 199 (2183424/2257759) completed in 0m 1.677s
#   loss: 2.4235 corr: 206 (2183808/2257759) completed in 0m 1.676s
#   loss: 2.5479 corr: 204 (2184192/2257759) completed in 0m 1.696s
#   loss: 2.6006 corr: 198 (2184576/2257759) completed in 0m 1.644s
#   loss: 2.3823 corr: 199 (2184960/2257759) completed in 0m 1.656s
#   loss: 2.5627 corr: 198 (2185344/2257759) completed in 0m 1.758s
#   loss: 2.2156 corr: 203 (2185728/2257759) completed in 0m 1.694s
#   loss: 2.5294 corr: 202 (2186112/2257759) completed in 0m 1.723s
#   loss: 2.5301 corr: 195 (2186496/2257759) completed in 0m 1.634s
#   loss: 2.4936 corr: 193 (2186880/2257759) completed in 0m 1.664s
#   loss: 2.2597 corr: 210 (2187264/2257759) completed in 0m 1.679s
#   loss: 2.3828 corr: 195 (2187648/2257759) completed in 0m 1.724s
#   loss: 2.3847 corr: 195 (2188032/2257759) completed in 0m 1.708s
#   loss: 2.5893 corr: 192 (2188416/2257759) completed in 0m 1.658s
#   loss: 2.3858 corr: 199 (2188800/2257759) completed in 0m 1.643s
#   loss: 2.6501 corr: 199 (2189184/2257759) completed in 0m 1.678s
#   loss: 2.5074 corr: 203 (2189568/2257759) completed in 0m 1.683s
#   loss: 2.4946 corr: 213 (2189952/2257759) completed in 0m 1.773s
#   loss: 2.6339 corr: 187 (2190336/2257759) completed in 0m 1.591s
#   loss: 2.5865 corr: 192 (2190720/2257759) completed in 0m 1.710s
#   loss: 2.4935 corr: 200 (2191104/2257759) completed in 0m 1.737s
#   loss: 2.2847 corr: 214 (2191488/2257759) completed in 0m 1.600s
#   loss: 2.7635 corr: 179 (2191872/2257759) completed in 0m 1.737s
#   loss: 2.4347 corr: 202 (2192256/2257759) completed in 0m 1.724s
#   loss: 2.3167 corr: 213 (2192640/2257759) completed in 0m 1.703s
#   loss: 2.5192 corr: 195 (2193024/2257759) completed in 0m 1.627s
#   loss: 2.9269 corr: 187 (2193408/2257759) completed in 0m 1.675s
#   loss: 2.4303 corr: 197 (2193792/2257759) completed in 0m 1.612s
#   loss: 2.0428 corr: 204 (2194176/2257759) completed in 0m 1.820s
#   loss: 2.3556 corr: 198 (2194560/2257759) completed in 0m 1.724s
#   loss: 2.5925 corr: 190 (2194944/2257759) completed in 0m 1.736s
#   loss: 2.6295 corr: 195 (2195328/2257759) completed in 0m 1.631s
#   loss: 2.5477 corr: 199 (2195712/2257759) completed in 0m 1.737s
#   loss: 2.7573 corr: 191 (2196096/2257759) completed in 0m 1.635s
#   loss: 2.5885 corr: 199 (2196480/2257759) completed in 0m 1.660s
#   loss: 2.2559 corr: 206 (2196864/2257759) completed in 0m 1.650s
#   loss: 2.7213 corr: 189 (2197248/2257759) completed in 0m 1.683s
#   loss: 2.5916 corr: 189 (2197632/2257759) completed in 0m 1.658s
#   loss: 2.4049 corr: 193 (2198016/2257759) completed in 0m 1.702s
#   loss: 2.3346 corr: 203 (2198400/2257759) completed in 0m 1.674s
#   loss: 2.3543 corr: 219 (2198784/2257759) completed in 0m 1.690s
#   loss: 2.4367 corr: 213 (2199168/2257759) completed in 0m 2.043s
#   loss: 2.2396 corr: 189 (2199552/2257759) completed in 0m 1.648s
#   loss: 2.7571 corr: 188 (2199936/2257759) completed in 0m 1.745s
#   loss: 2.2513 corr: 192 (2200320/2257759) completed in 0m 1.768s
#   loss: 2.9745 corr: 187 (2200704/2257759) completed in 0m 1.665s
#   loss: 2.4794 corr: 197 (2201088/2257759) completed in 0m 1.786s
#   loss: 2.5034 corr: 210 (2201472/2257759) completed in 0m 1.664s
#   loss: 2.4218 corr: 204 (2201856/2257759) completed in 0m 1.694s
#   loss: 2.5206 corr: 190 (2202240/2257759) completed in 0m 1.892s
#   loss: 2.4732 corr: 199 (2202624/2257759) completed in 0m 1.741s
#   loss: 2.3502 corr: 216 (2203008/2257759) completed in 0m 1.643s
#   loss: 2.6135 corr: 197 (2203392/2257759) completed in 0m 1.720s
#   loss: 2.6231 corr: 201 (2203776/2257759) completed in 0m 1.672s
#   loss: 2.4568 corr: 207 (2204160/2257759) completed in 0m 1.677s
#   loss: 2.2764 corr: 206 (2204544/2257759) completed in 0m 1.694s
#   loss: 2.6090 corr: 196 (2204928/2257759) completed in 0m 1.667s
#   loss: 2.5959 corr: 203 (2205312/2257759) completed in 0m 1.823s
#   loss: 2.5022 corr: 203 (2205696/2257759) completed in 0m 1.644s
#   loss: 2.6294 corr: 193 (2206080/2257759) completed in 0m 2.038s
#   loss: 2.5047 corr: 195 (2206464/2257759) completed in 0m 1.727s
#   loss: 2.5552 corr: 186 (2206848/2257759) completed in 0m 1.574s
#   loss: 2.6482 corr: 185 (2207232/2257759) completed in 0m 1.676s
#   loss: 2.2645 corr: 206 (2207616/2257759) completed in 0m 1.705s
#   loss: 2.8217 corr: 195 (2208000/2257759) completed in 0m 1.616s
#   loss: 2.4606 corr: 194 (2208384/2257759) completed in 0m 1.680s
#   loss: 2.6680 corr: 185 (2208768/2257759) completed in 0m 1.652s
#   loss: 2.6375 corr: 200 (2209152/2257759) completed in 0m 2.079s
#   loss: 2.7335 corr: 200 (2209536/2257759) completed in 0m 1.706s
#   loss: 2.7458 corr: 186 (2209920/2257759) completed in 0m 1.723s
#   loss: 2.5557 corr: 193 (2210304/2257759) completed in 0m 1.672s
#   loss: 2.2816 corr: 208 (2210688/2257759) completed in 0m 1.729s
#   loss: 2.4570 corr: 184 (2211072/2257759) completed in 0m 1.637s
#   loss: 2.8879 corr: 182 (2211456/2257759) completed in 0m 1.860s
#   loss: 2.7107 corr: 185 (2211840/2257759) completed in 0m 1.593s
#   loss: 2.5923 corr: 194 (2212224/2257759) completed in 0m 2.068s
#   loss: 2.5365 corr: 187 (2212608/2257759) completed in 0m 1.663s
#   loss: 2.5222 corr: 216 (2212992/2257759) completed in 0m 1.681s
#   loss: 2.2112 corr: 213 (2213376/2257759) completed in 0m 1.705s
#   loss: 2.3386 corr: 210 (2213760/2257759) completed in 0m 1.711s
#   loss: 2.8132 corr: 181 (2214144/2257759) completed in 0m 1.710s
#   loss: 2.5649 corr: 197 (2214528/2257759) completed in 0m 1.882s
#   loss: 2.5919 corr: 204 (2214912/2257759) completed in 0m 1.692s
#   loss: 2.5282 corr: 204 (2215296/2257759) completed in 0m 2.031s
#   loss: 2.5217 corr: 207 (2215680/2257759) completed in 0m 1.695s
#   loss: 2.3809 corr: 206 (2216064/2257759) completed in 0m 1.713s
#   loss: 2.7220 corr: 184 (2216448/2257759) completed in 0m 1.670s
#   loss: 2.6387 corr: 191 (2216832/2257759) completed in 0m 1.730s
#   loss: 2.1610 corr: 215 (2217216/2257759) completed in 0m 1.730s
#   loss: 2.5821 corr: 202 (2217600/2257759) completed in 0m 1.816s
#   loss: 2.4668 corr: 207 (2217984/2257759) completed in 0m 1.715s
#   loss: 2.6666 corr: 199 (2218368/2257759) completed in 0m 1.863s
#   loss: 2.6354 corr: 197 (2218752/2257759) completed in 0m 1.660s
#   loss: 2.4866 corr: 196 (2219136/2257759) completed in 0m 1.689s
#   loss: 2.1988 corr: 209 (2219520/2257759) completed in 0m 1.690s
#   loss: 2.3695 corr: 203 (2219904/2257759) completed in 0m 1.927s
#   loss: 2.8021 corr: 178 (2220288/2257759) completed in 0m 1.778s
#   loss: 2.6959 corr: 200 (2220672/2257759) completed in 0m 1.868s
#   loss: 2.4280 corr: 208 (2221056/2257759) completed in 0m 1.700s
#   loss: 2.2767 corr: 213 (2221440/2257759) completed in 0m 1.711s
#   loss: 2.6030 corr: 195 (2221824/2257759) completed in 0m 1.727s
#   loss: 2.5668 corr: 184 (2222208/2257759) completed in 0m 1.642s
#   loss: 2.5583 corr: 183 (2222592/2257759) completed in 0m 1.750s
#   loss: 2.6225 corr: 190 (2222976/2257759) completed in 0m 1.766s
#   loss: 2.5456 corr: 205 (2223360/2257759) completed in 0m 1.715s
#   loss: 2.5902 corr: 177 (2223744/2257759) completed in 0m 1.885s
#   loss: 2.5837 corr: 191 (2224128/2257759) completed in 0m 1.661s
#   loss: 2.4087 corr: 205 (2224512/2257759) completed in 0m 1.752s
#   loss: 2.3706 corr: 216 (2224896/2257759) completed in 0m 1.724s
#   loss: 2.5676 corr: 192 (2225280/2257759) completed in 0m 1.730s
#   loss: 2.8306 corr: 183 (2225664/2257759) completed in 0m 1.710s
#   loss: 2.5609 corr: 190 (2226048/2257759) completed in 0m 1.827s
#   loss: 2.5228 corr: 195 (2226432/2257759) completed in 0m 1.676s
#   loss: 2.7877 corr: 195 (2226816/2257759) completed in 0m 1.881s
#   loss: 2.4380 corr: 203 (2227200/2257759) completed in 0m 1.756s
#   loss: 2.5970 corr: 189 (2227584/2257759) completed in 0m 1.667s
#   loss: 2.5350 corr: 197 (2227968/2257759) completed in 0m 1.672s
#   loss: 2.4136 corr: 205 (2228352/2257759) completed in 0m 1.636s
#   loss: 2.7543 corr: 188 (2228736/2257759) completed in 0m 1.601s
#   loss: 2.7057 corr: 191 (2229120/2257759) completed in 0m 1.845s
#   loss: 2.4276 corr: 192 (2229504/2257759) completed in 0m 1.716s
#   loss: 2.3839 corr: 202 (2229888/2257759) completed in 0m 1.867s
#   loss: 2.3852 corr: 197 (2230272/2257759) completed in 0m 1.738s
#   loss: 2.3726 corr: 200 (2230656/2257759) completed in 0m 1.734s
#   loss: 2.7295 corr: 192 (2231040/2257759) completed in 0m 1.686s
#   loss: 2.4448 corr: 194 (2231424/2257759) completed in 0m 1.694s
#   loss: 2.4077 corr: 219 (2231808/2257759) completed in 0m 1.666s
#   loss: 2.6978 corr: 204 (2232192/2257759) completed in 0m 1.784s
#   loss: 2.5209 corr: 193 (2232576/2257759) completed in 0m 1.708s
#   loss: 2.5751 corr: 190 (2232960/2257759) completed in 0m 1.837s
#   loss: 2.3967 corr: 189 (2233344/2257759) completed in 0m 1.740s
#   loss: 2.6910 corr: 199 (2233728/2257759) completed in 0m 1.662s
#   loss: 2.4851 corr: 190 (2234112/2257759) completed in 0m 1.660s
#   loss: 2.8304 corr: 182 (2234496/2257759) completed in 0m 1.626s
#   loss: 2.2416 corr: 224 (2234880/2257759) completed in 0m 1.756s
#   loss: 2.4024 corr: 217 (2235264/2257759) completed in 0m 1.817s
#   loss: 2.6441 corr: 187 (2235648/2257759) completed in 0m 1.680s
#   loss: 2.5054 corr: 198 (2236032/2257759) completed in 0m 1.857s
#   loss: 2.4893 corr: 206 (2236416/2257759) completed in 0m 1.691s
#   loss: 2.3863 corr: 196 (2236800/2257759) completed in 0m 1.742s
#   loss: 2.4440 corr: 206 (2237184/2257759) completed in 0m 1.701s
#   loss: 2.3124 corr: 202 (2237568/2257759) completed in 0m 1.624s
#   loss: 2.4132 corr: 193 (2237952/2257759) completed in 0m 1.650s
#   loss: 2.2680 corr: 198 (2238336/2257759) completed in 0m 1.814s
#   loss: 2.5433 corr: 188 (2238720/2257759) completed in 0m 1.731s
#   loss: 2.5925 corr: 199 (2239104/2257759) completed in 0m 1.832s
#   loss: 2.5753 corr: 199 (2239488/2257759) completed in 0m 1.695s
#   loss: 2.5464 corr: 189 (2239872/2257759) completed in 0m 1.652s
#   loss: 2.4183 corr: 193 (2240256/2257759) completed in 0m 1.661s
#   loss: 2.3935 corr: 196 (2240640/2257759) completed in 0m 1.734s
#   loss: 2.6227 corr: 190 (2241024/2257759) completed in 0m 1.613s
#   loss: 2.3882 corr: 212 (2241408/2257759) completed in 0m 1.659s
#   loss: 2.6642 corr: 190 (2241792/2257759) completed in 0m 1.686s
#   loss: 2.3454 corr: 220 (2242176/2257759) completed in 0m 1.840s
#   loss: 2.6692 corr: 177 (2242560/2257759) completed in 0m 1.689s
#   loss: 2.5399 corr: 203 (2242944/2257759) completed in 0m 1.765s
#   loss: 2.4201 corr: 200 (2243328/2257759) completed in 0m 1.699s
#   loss: 2.5241 corr: 189 (2243712/2257759) completed in 0m 1.765s
#   loss: 2.3741 corr: 200 (2244096/2257759) completed in 0m 1.679s
#   loss: 2.7217 corr: 217 (2244480/2257759) completed in 0m 1.753s
#   loss: 2.5985 corr: 200 (2244864/2257759) completed in 0m 1.699s
#   loss: 2.7460 corr: 181 (2245248/2257759) completed in 0m 1.787s
#   loss: 2.3399 corr: 201 (2245632/2257759) completed in 0m 1.728s
#   loss: 2.2682 corr: 205 (2246016/2257759) completed in 0m 1.687s
#   loss: 2.8025 corr: 194 (2246400/2257759) completed in 0m 1.627s
#   loss: 2.5015 corr: 192 (2246784/2257759) completed in 0m 1.639s
#   loss: 2.5536 corr: 193 (2247168/2257759) completed in 0m 1.717s
#   loss: 2.7937 corr: 199 (2247552/2257759) completed in 0m 1.785s
#   loss: 2.1253 corr: 218 (2247936/2257759) completed in 0m 1.737s
#   loss: 2.4970 corr: 205 (2248320/2257759) completed in 0m 1.829s
#   loss: 2.4934 corr: 208 (2248704/2257759) completed in 0m 1.693s
#   loss: 2.3733 corr: 198 (2249088/2257759) completed in 0m 1.712s
#   loss: 2.4160 corr: 194 (2249472/2257759) completed in 0m 1.675s
#   loss: 2.3969 corr: 205 (2249856/2257759) completed in 0m 1.655s
#   loss: 2.7274 corr: 177 (2250240/2257759) completed in 0m 1.673s
#   loss: 2.6063 corr: 192 (2250624/2257759) completed in 0m 1.810s
#   loss: 2.5072 corr: 189 (2251008/2257759) completed in 0m 1.711s
#   loss: 2.6054 corr: 192 (2251392/2257759) completed in 0m 1.778s
#   loss: 2.3035 corr: 207 (2251776/2257759) completed in 0m 1.737s
#   loss: 2.1861 corr: 199 (2252160/2257759) completed in 0m 1.702s
#   loss: 2.6223 corr: 186 (2252544/2257759) completed in 0m 1.578s
#   loss: 2.2364 corr: 221 (2252928/2257759) completed in 0m 1.716s
#   loss: 2.5778 corr: 178 (2253312/2257759) completed in 0m 1.714s
#   loss: 2.4514 corr: 212 (2253696/2257759) completed in 0m 1.642s
#   loss: 2.6242 corr: 189 (2254080/2257759) completed in 0m 1.682s
#   loss: 2.4464 corr: 208 (2254464/2257759) completed in 0m 1.912s
#   loss: 2.7652 corr: 196 (2254848/2257759) completed in 0m 1.778s
#   loss: 2.5216 corr: 200 (2255232/2257759) completed in 0m 1.775s
#   loss: 2.3711 corr: 203 (2255616/2257759) completed in 0m 1.738s
#   loss: 2.4281 corr: 205 (2256000/2257759) completed in 0m 1.617s
#   loss: 2.6701 corr: 196 (2256384/2257759) completed in 0m 1.711s
#   loss: 2.9182 corr: 180 (2256768/2257759) completed in 0m 1.593s
#   loss: 2.4407 corr: 193 (2257152/2257759) completed in 0m 1.524s
#   loss: 2.4831 corr: 202 (2257536/2257759) completed in 0m 1.528s
#   loss: 2.8807 corr: 106 (2257920/2257759) completed in 0m 0.913s
# /kaggle/working/ResNet34_run-02.pth
# Loss: 3.1264 Acc: 0.4369
#
# Loss: 3.1264 Acc: 0.4369
# Training complete in 407m 7.936s

# %% [markdown]
# ## Inference

# %%
model.eval()
model.to(DEVICE)

predictions = np.zeros((len(test_dataset)))

for i,images in tqdm.tqdm(enumerate(test_loader)):
    images = images.to(DEVICE)
    with torch.no_grad():
        y_predictions = model(images)

    predictions[i*BATCH_EVAL:(i+1)*BATCH_EVAL] = y_predictions.to(DEVICE).cpu().numpy().argmax(1)
# Out:
# 633it [41:33,  3.94s/it]

# %% [markdown]
# ## Submit

# %%
test_df["preds"] = predictions.astype(int)
submission = sample_submission.merge(
    test_df.rename(columns = {"id":"Id"})[["Id","preds"]],on="Id"
).drop(columns="Predicted")
submission["Predicted"] = submission["preds"].map(class_map)
submission = submission.drop(columns="preds")
submission.to_csv("submission.csv",index=False)
submission.head()
# Out:
#    Id  Predicted
# 0   0      45270
# 1   1      49681
# 2   2      35602
# 3   3      54434
# 4   4       4753
