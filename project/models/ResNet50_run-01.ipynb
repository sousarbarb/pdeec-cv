# %% [markdown]
# # Herbarium 2021 - Half-Earth Challenge - FGVC8 - ResNet
#
# The main goal of this work is to identify plant species of the Americas, Oceania, and the Pacific from herbarium specimens. The dataset that is used in this work - _The Herbarium 2021: Half-Earth Challenge_ - includes more than 2.5M images representing nearly 65.000 species from the Americas and Oceania. These images have been aligned to a standardized plant list ([LCVP v1.0.2](https://www.nature.com/articles/s41597-020-00702-z)).
#
# The model used in this notebook for classifying the images is ResNet ([arXiv:1512.03385](https://arxiv.org/abs/1512.03385)). ResNet makes it possible to train up to hundreds or even thousands of layers and still achieves compelling performance. Taking advantage of its powerful representational ability, the performance of many computer vision applications other than image classification have been bosted. As a classification model, it is considered to be a state-of-the-art method.

# %% [markdown]
# ## Setup
#
# ### Load libraries

# %%
# Math and Image
import numpy as np               # Math
import matplotlib.pyplot as plt  # Plot
import cv2                       # OpenCV
import PIL                       # Data Augmentation
import albumentations            # Data Augmentation
from albumentations.pytorch import ToTensorV2
# Operating System
import os
import time
import copy
# Utilities
import pandas as pd  # Handling CSV files
import random
import json
import tqdm          # Testing
import sklearn       # label encoding and metrics
from sklearn import preprocessing
# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
# TensorFlow
import tensorflow as tf

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets
# preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved
# outside of the current session will list all files under the input directory

print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.7.0
# Torchvision Version:  0.8.1

# %% [markdown]
# ### PC Configuration

# %%
# CPU Details - Number & Model
# !lscpu | grep "CPU(s):"
# !lscpu | grep Hz
# Total Memory
# !cat /proc/meminfo | grep MemTotal
# CUDA Check
print("Is CUDA Available?",
      torch.cuda.is_available())
if torch.cuda.is_available() == True: 
    print("Current CUDA device:",
        torch.cuda.get_device_name(0))

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: ",DEVICE)
# Out:
# CPU(s):              2
# NUMA node0 CPU(s):   0,1
# Model name:          Intel(R) Xeon(R) CPU @ 2.00GHz
# CPU MHz:             2000.190
# MemTotal:       16402016 kB
# Is CUDA Available? True
# Current CUDA device: Tesla P100-PCIE-16GB
# Device:  cuda

# %% [markdown]
# ### Ramdom seed
#
# The goal is to fix the random seed. For making the environment statically, fixing the random seed is needed. Also, it is essential to reproduce the experimental results.

# %%
def seed_fix(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_fix()
print("Seed fixed")
# Out:
# Seed fixed

# %% [markdown]
# ### Configuration

# %%
ROOT_DATA   = "/kaggle/input/herbarium-2021-fgvc8/"
DATA_TRAIN  = ROOT_DATA + "train/"
DATA_TEST   = ROOT_DATA + "test/"
ROOT_OUTPUT = "/kaggle/working/"
META        = "metadata.json"
BATCH_SIZE  = 128    # number of training examples utilized in one iteration
BATCH_EVAL  = 128
SHUFFLE     = True
EPOCHS      = 1
LEARN_RATE  = 4e-4
IMG_HEIGHT  = 224
IMG_WIDTH   = 224
NUM_CLASSES = None   # define below
NUM_WORKERS = 4
PRE_TRAINED = False

PATH_SAVE_MODEL = "/kaggle/working/ResNet50_run-01.pth"

ESTIMATED_MAX_TRAINING_TIME = 480 # hours (8h * 60 = 480min, leaving 1h to the test time)

print(ROOT_DATA)
# Out:
# /kaggle/input/herbarium-2021-fgvc8/

# %% [markdown]
# ## Create dataset

# %% [markdown]
# ### Generic information

# %%
# Training dataset
with open(os.path.join(DATA_TRAIN,META),"r",encoding="ISO-8859-1") as file:
    meta_train = json.load(file)
    print("Number of images (training dataset): ",
          len(meta_train["images"]),)
    for i in list(meta_train.keys()):
        print("  - sample and number of elements in category {}: ".format(i),
              len(list(meta_train[i])),)
        print("\t[0] ",
              list(meta_train[i])[0], end="\n")

NUM_CLASSES   = len(meta_train["categories"])
NUM_IMG_TRAIN = len(meta_train["annotations"])

# Validation dataset
with open(os.path.join(DATA_TEST,META),"r",encoding="ISO-8859-1") as file:
    meta_test = json.load(file)
    print("\nNumber of images (training dataset): ",
          len(meta_test["images"]),)
    for i in list(meta_test.keys()):
        print("  - sample and number of elements in category {}: ".format(i),
              len(list(meta_test[i])),)
        print("\t[0] ",
              list(meta_test[i])[0], end="\n")

NUM_IMG_TEST  = len(meta_test["images"]) 

# Print variables
print("\n\n"
      "Number of images for training: ",NUM_IMG_TRAIN)
print("Number of images for testing : ",NUM_IMG_TEST)
print("Number of classes            : ",NUM_CLASSES)
# Out:
# Number of images (training dataset):  2257759
#   - sample and number of elements in category annotations:  2257759
# 	[0]  {'category_id': 60492, 'id': 1814367, 'image_id': 1814367, 'institution_id': 0}
#   - sample and number of elements in category categories:  64500
# 	[0]  {'family': 'Orchidaceae', 'order': 'Asparagales', 'name': 'Aa calceata (Rchb.f.) Schltr.', 'id': 0}
#   - sample and number of elements in category images:  2257759
# 	[0]  {'file_name': 'images/604/92/1814367.jpg', 'height': 1000, 'id': 1814367, 'license': 0, 'width': 678}
#   - sample and number of elements in category info:  6
# 	[0]  contributor
#   - sample and number of elements in category licenses:  3
# 	[0]  {'id': 0, 'name': 'Public Domain Dedication', 'url': 'http://creativecommons.org/publicdomain/zero/1.0/'}
#   - sample and number of elements in category institutions:  5
# 	[0]  {'id': 0, 'name': 'New York Botanical Garden'}
#
# Number of images (training dataset):  243020
#   - sample and number of elements in category images:  243020
# 	[0]  {'file_name': 'images/000/0.jpg', 'height': 1000, 'id': 0, 'license': 0, 'width': 680}
#   - sample and number of elements in category info:  6
# 	[0]  contributor
#   - sample and number of elements in category licenses:  3
# 	[0]  {'id': 0, 'name': 'Public Domain Dedication', 'url': 'http://creativecommons.org/publicdomain/zero/1.0/'}
#
#
# Number of images for training:  2257759
# Number of images for testing :  243020
# Number of classes            :  64500

# %% [markdown]
# ### Process training and evaluation metadata
#
# Merge training images and annotations as a dataframe. The database-based joint operation merge is performed on the ids "image_id" (from images dataframe) and "id" (from annotations dataframe).
#
# The problem with the validation data is that the `.json` does not provide the labels to check if the model is classifying correctly or not the validation images.

# %%
# Process metadata json for training images into a DataFrame
train_img = pd.DataFrame(meta_train["images"])
train_ann = pd.DataFrame(meta_train["annotations"]).drop(columns="image_id")
train_df  = train_img.merge(train_ann,on="id") # Performs a database-style joint

# Check number of classes
print("Number of classes (expected): ",NUM_CLASSES)
print("Number of classes (computed): ",
      train_df["category_id"].max() - train_df["category_id"].min()+1)
print("\nShape training dataframe    :",train_df.shape)

# Process metadata json for test images into a DataFrame
test_df = pd.DataFrame(meta_test["images"])
# Out:
# Number of classes (expected):  64500
# Number of classes (computed):  64500
#
# Shape training dataframe    : (2257759, 7)

# %%
# Print the first 5 elements of the tables
train_df.head(n=5)
# Out:
#                    file_name  height       id  license  width  category_id  \
# 0  images/604/92/1814367.jpg    1000  1814367        0    678        60492
# 1  images/108/24/1308257.jpg    1000  1308257        0    666        10824
# 2  images/330/76/1270453.jpg    1000  1270453        0    739        33076
# 3  images/247/99/1123834.jpg    1000  1123834        0    672        24799
# 4  images/170/18/1042410.jpg    1000  1042410        0    675        17018
#
#    institution_id
# 0               0
# 1               0
# 2               3
# 3               0
# 4               0

# %%
# Print the first 5 elements of the tables
test_df.head(n=5)
# Out:
#           file_name  height  id  license  width
# 0  images/000/0.jpg    1000   0        0    680
# 1  images/000/1.jpg    1000   1        0    681
# 2  images/000/2.jpg    1000   2        0    676
# 3  images/000/3.jpg    1000   3        0    666
# 4  images/000/4.jpg    1000   4        0    676

# %% [markdown]
# ### Checkout samples

# %%
im = PIL.Image.open(DATA_TRAIN + train_df.file_name[0])
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=678x1000 at 0x7F33C5B503D0>

# %%
size_of_img = (36,36)
fig=plt.figure(figsize=(80,80))
for i in range(25):
    ax=fig.add_subplot(5,5,i+1)
    img = cv2.imread(DATA_TRAIN + meta_train["images"][i]["file_name"])
    img = cv2.resize(img,size_of_img)
    ax.imshow(img)

plt.show()

# %% [markdown]
# ## Prepare Submission

# %%
sample_submission = pd.read_csv(ROOT_DATA + "sample_submission.csv")
sample_submission.head(n=5)
# Out:
#    Id  Predicted
# 0   0          0
# 1   1          0
# 2   2          0
# 3   3          0
# 4   4          0

# %% [markdown]
# ## Label Encoder

# %%
# Fit the label encoder instance
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(train_df["category_id"])

# Transform labels to normalized encoding
train_df["category_id_le"] = label_encoder.transform(train_df["category_id"])
class_map = dict(sorted(train_df[["category_id_le","category_id"]].values.tolist()))

print("Labels converted to normalized encoding")
# Out:
# Labels converted to normalized encoding

# %% [markdown]
# ### Dataloaders

# %%
class TrainDataset(torch.utils.data.Dataset):
    def __init__(self, df, labels, transform=None):
        self.df = df
        self.labels = labels
        self.transform = transform
        
    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.df["file_name"].values[idx]
        file_path = DATA_TRAIN + file_name
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        label = self.labels.values[idx]
        
        if self.transform:
            img = self.transform(image=img)["image"]
        
        return img, label

# %%
class TestDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform
        
    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.df["file_name"].values[idx]
        file_path = DATA_TEST + file_name
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        if self.transform:
            img = self.transform(image=img)["image"]
        
        return img

# %% [markdown]
# ### Image Augmentation

# %%
def get_transforms(*, data: str):
    assert data in ("train","test")
    
    if data == "train":
        return albumentations.Compose([
            albumentations.Resize(IMG_HEIGHT,IMG_WIDTH),
            albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

    elif data == "test":
        return albumentations.Compose([
            albumentations.Resize(IMG_HEIGHT,IMG_WIDTH),
            albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Training Dataset

# %%
train_df.head(n=5)
# Out:
#                    file_name  height       id  license  width  category_id  \
# 0  images/604/92/1814367.jpg    1000  1814367        0    678        60492
# 1  images/108/24/1308257.jpg    1000  1308257        0    666        10824
# 2  images/330/76/1270453.jpg    1000  1270453        0    739        33076
# 3  images/247/99/1123834.jpg    1000  1123834        0    672        24799
# 4  images/170/18/1042410.jpg    1000  1042410        0    675        17018
#
#    institution_id  category_id_le
# 0               0           60492
# 1               0           10824
# 2               3           33076
# 3               0           24799
# 4               0           17018

# %%
train_dataset = TrainDataset(
    train_df,train_df["category_id_le"],
    transform=get_transforms(data="train"))
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,shuffle=SHUFFLE,num_workers=NUM_WORKERS)
print("Train data loader created")
# Out:
# Train data loader created

# %% [markdown]
# ### Test Dataset

# %%
test_df.head(n=5)
# Out:
#           file_name  height  id  license  width
# 0  images/000/0.jpg    1000   0        0    680
# 1  images/000/1.jpg    1000   1        0    681
# 2  images/000/2.jpg    1000   2        0    676
# 3  images/000/3.jpg    1000   3        0    666
# 4  images/000/4.jpg    1000   4        0    676

# %%
test_dataset = TestDataset(
    test_df,
    transform=get_transforms(data="test"))
test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=BATCH_EVAL,shuffle=False,num_workers=NUM_WORKERS)
print("Test data loader created")
# Out:
# Test data loader created

# %% [markdown]
# ## Model

# %%
def train_model(model,dataloader,criterion,optimizer,num_epochs=1):
    since = time.time()
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        model.train()
        
        running_loss = 0.0
        running_corrects = 0
        
        #for inputs, labels in tqdm.tqdm(enumerate(dataloader)):
        i = 0
        len_dataset = len(dataloader.dataset)
        for inputs, labels in dataloader:
            since_tmp = time.time()
            
            inputs = inputs.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                loss = criterion(outputs,labels)
                
                _,preds = torch.max(outputs,1)
                
                loss.backward()
                optimizer.step()
              
            loss_tmp = loss.item()
            pred_tmp = torch.sum(preds == labels.data)
            
            running_loss += loss_tmp * inputs.size(0)
            running_corrects += pred_tmp
            
            time_elapsed_tmp = time.time() - since_tmp
            
            print('  loss: {:.04f} corr: {:d} ({:d}/{:d}) completed in {:.0f}m {:.03f}s'.format(
                loss_tmp, pred_tmp,(i+1)*BATCH_SIZE,len_dataset,
                time_elapsed_tmp // 60, time_elapsed_tmp % 60))
            
            if ((time.time() - since) // 60 > ESTIMATED_MAX_TRAINING_TIME):
                break;
            
            i += 1
            
        epoch_loss = running_loss / len_dataset
        epoch_acc = running_corrects.double() / len_dataset
        
        torch.save(model.state_dict(),PATH_SAVE_MODEL)
        print(PATH_SAVE_MODEL)
        print('Loss: {:.04f} Acc: {:.04f}'.format(epoch_loss, epoch_acc))
        
        print()
            
        if ((time.time() - since) // 60 > ESTIMATED_MAX_TRAINING_TIME):
            break;
        
    time_elapsed = time.time() - since
    print('Loss: {:.04f} Acc: {:.04f}'.format(epoch_loss, epoch_acc))
    print('Training complete in {:.0f}m {:.03f}s'.format(time_elapsed // 60, time_elapsed % 60))
    
    #model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ### Construct model

# %%
model = torchvision.models.resnet50(pretrained=PRE_TRAINED)
model.avgpool = torch.nn.AdaptiveAvgPool2d(1)
model.fc = torch.nn.Linear(model.fc.in_features,NUM_CLASSES)

# %% [markdown]
# ### Use existent trained model

# %% [markdown]
# #model.load_state_dict(torch.load("../input/herbarium-2021-rbs/ResNet34_run-02.pth"))

# %% [markdown]
# ### Train

# %%
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARN_RATE, amsgrad=False)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 'min', factor=0.75, patience=5, verbose=True, eps=1e-6)

criterion = torch.nn.CrossEntropyLoss()

# %%
model = train_model(model,train_loader,criterion,optimizer,EPOCHS)
# Out:
# Epoch 0/0
# ----------
#   loss: 11.2186 corr: 0 (128/2257759) completed in 0m 2.628s
#   loss: 11.3125 corr: 0 (256/2257759) completed in 0m 0.826s
#   loss: 11.1989 corr: 0 (384/2257759) completed in 0m 0.839s
#   loss: 11.3881 corr: 0 (512/2257759) completed in 0m 0.799s
#   loss: 11.6715 corr: 0 (640/2257759) completed in 0m 0.807s
#   loss: 12.0009 corr: 0 (768/2257759) completed in 0m 0.814s
#   loss: 12.1945 corr: 0 (896/2257759) completed in 0m 0.855s
#   loss: 12.6852 corr: 0 (1024/2257759) completed in 0m 0.844s
#   loss: 13.0322 corr: 0 (1152/2257759) completed in 0m 0.816s
#   loss: 13.0173 corr: 0 (1280/2257759) completed in 0m 0.858s
#   loss: 12.5378 corr: 0 (1408/2257759) completed in 0m 0.774s
#   loss: 12.9761 corr: 0 (1536/2257759) completed in 0m 0.838s
#   loss: 12.1359 corr: 0 (1664/2257759) completed in 0m 0.874s
#   loss: 12.3926 corr: 0 (1792/2257759) completed in 0m 0.898s
#   loss: 11.7596 corr: 0 (1920/2257759) completed in 0m 0.832s
#   loss: 11.9509 corr: 0 (2048/2257759) completed in 0m 0.837s
#   loss: 11.9505 corr: 0 (2176/2257759) completed in 0m 0.843s
#   loss: 11.7528 corr: 0 (2304/2257759) completed in 0m 0.806s
#   loss: 11.6780 corr: 0 (2432/2257759) completed in 0m 0.832s
#   loss: 11.7092 corr: 0 (2560/2257759) completed in 0m 0.821s
#   loss: 11.5823 corr: 0 (2688/2257759) completed in 0m 0.776s
#   loss: 11.7287 corr: 2 (2816/2257759) completed in 0m 0.810s
#   loss: 11.4780 corr: 0 (2944/2257759) completed in 0m 0.814s
#   loss: 11.4512 corr: 0 (3072/2257759) completed in 0m 0.812s
#   loss: 11.4814 corr: 0 (3200/2257759) completed in 0m 0.867s
#   loss: 11.2386 corr: 0 (3328/2257759) completed in 0m 0.824s
#   loss: 11.2407 corr: 0 (3456/2257759) completed in 0m 0.908s
#   loss: 11.1762 corr: 0 (3584/2257759) completed in 0m 0.921s
#   loss: 11.2177 corr: 0 (3712/2257759) completed in 0m 0.838s
#   loss: 11.3312 corr: 0 (3840/2257759) completed in 0m 0.854s
#   loss: 11.1918 corr: 1 (3968/2257759) completed in 0m 0.834s
#   loss: 11.0491 corr: 0 (4096/2257759) completed in 0m 0.860s
#   loss: 10.9530 corr: 0 (4224/2257759) completed in 0m 0.871s
#   loss: 11.1796 corr: 0 (4352/2257759) completed in 0m 0.824s
#   loss: 11.1111 corr: 0 (4480/2257759) completed in 0m 0.824s
#   loss: 10.8424 corr: 0 (4608/2257759) completed in 0m 0.823s
#   loss: 11.0639 corr: 0 (4736/2257759) completed in 0m 0.856s
#   loss: 11.0368 corr: 0 (4864/2257759) completed in 0m 0.840s
#   loss: 11.0274 corr: 0 (4992/2257759) completed in 0m 0.905s
#   loss: 11.0182 corr: 0 (5120/2257759) completed in 0m 0.872s
#   loss: 10.7529 corr: 0 (5248/2257759) completed in 0m 0.810s
#   loss: 11.0191 corr: 0 (5376/2257759) completed in 0m 0.828s
#   loss: 10.8973 corr: 0 (5504/2257759) completed in 0m 0.845s
#   loss: 10.9233 corr: 1 (5632/2257759) completed in 0m 0.831s
#   loss: 10.8418 corr: 0 (5760/2257759) completed in 0m 0.778s
#   loss: 10.9635 corr: 0 (5888/2257759) completed in 0m 0.890s
#   loss: 10.8758 corr: 1 (6016/2257759) completed in 0m 0.878s
#   loss: 10.9169 corr: 0 (6144/2257759) completed in 0m 0.802s
#   loss: 10.8704 corr: 0 (6272/2257759) completed in 0m 0.826s
#   loss: 10.9742 corr: 1 (6400/2257759) completed in 0m 0.822s
#   loss: 11.0188 corr: 0 (6528/2257759) completed in 0m 0.856s
#   loss: 11.0644 corr: 0 (6656/2257759) completed in 0m 0.853s
#   loss: 10.7390 corr: 0 (6784/2257759) completed in 0m 0.886s
#   loss: 10.8366 corr: 0 (6912/2257759) completed in 0m 0.842s
#   loss: 10.8831 corr: 0 (7040/2257759) completed in 0m 0.858s
#   loss: 10.9079 corr: 0 (7168/2257759) completed in 0m 0.821s
#   loss: 10.8229 corr: 0 (7296/2257759) completed in 0m 0.834s
#   loss: 10.9126 corr: 1 (7424/2257759) completed in 0m 0.861s
#   loss: 10.7767 corr: 0 (7552/2257759) completed in 0m 0.825s
#   loss: 11.0227 corr: 0 (7680/2257759) completed in 0m 0.869s
#   loss: 10.8370 corr: 0 (7808/2257759) completed in 0m 0.810s
#   loss: 10.7689 corr: 0 (7936/2257759) completed in 0m 0.833s
#   loss: 10.8656 corr: 0 (8064/2257759) completed in 0m 0.802s
#   loss: 10.7517 corr: 0 (8192/2257759) completed in 0m 0.838s
#   loss: 10.7069 corr: 0 (8320/2257759) completed in 0m 0.815s
#   loss: 10.9290 corr: 0 (8448/2257759) completed in 0m 0.869s
#   loss: 10.7490 corr: 0 (8576/2257759) completed in 0m 0.816s
#   loss: 10.8758 corr: 0 (8704/2257759) completed in 0m 0.837s
#   loss: 10.8714 corr: 0 (8832/2257759) completed in 0m 0.774s
#   loss: 10.8329 corr: 0 (8960/2257759) completed in 0m 0.811s
#   loss: 10.9138 corr: 0 (9088/2257759) completed in 0m 0.811s
#   loss: 10.8002 corr: 0 (9216/2257759) completed in 0m 0.786s
#   loss: 10.9112 corr: 0 (9344/2257759) completed in 0m 0.814s
#   loss: 10.7508 corr: 1 (9472/2257759) completed in 0m 0.864s
#   loss: 10.7321 corr: 1 (9600/2257759) completed in 0m 0.861s
#   loss: 10.6810 corr: 0 (9728/2257759) completed in 0m 0.843s
#   loss: 10.7759 corr: 0 (9856/2257759) completed in 0m 0.830s
#   loss: 10.6389 corr: 0 (9984/2257759) completed in 0m 0.806s
#   loss: 10.9325 corr: 0 (10112/2257759) completed in 0m 0.796s
#   loss: 10.7789 corr: 0 (10240/2257759) completed in 0m 0.892s
#   loss: 10.6719 corr: 1 (10368/2257759) completed in 0m 0.816s
#   loss: 10.7463 corr: 1 (10496/2257759) completed in 0m 0.866s
#   loss: 10.8592 corr: 1 (10624/2257759) completed in 0m 0.852s
#   loss: 10.7829 corr: 0 (10752/2257759) completed in 0m 0.821s
#   loss: 10.7327 corr: 1 (10880/2257759) completed in 0m 0.822s
#   loss: 10.7843 corr: 0 (11008/2257759) completed in 0m 0.828s
#   loss: 10.9593 corr: 0 (11136/2257759) completed in 0m 0.807s
#   loss: 10.8619 corr: 0 (11264/2257759) completed in 0m 0.777s
#   loss: 10.7545 corr: 0 (11392/2257759) completed in 0m 0.835s
#   loss: 10.7598 corr: 0 (11520/2257759) completed in 0m 0.826s
#   loss: 10.6711 corr: 0 (11648/2257759) completed in 0m 0.843s
#   loss: 10.8129 corr: 0 (11776/2257759) completed in 0m 0.850s
#   loss: 10.8038 corr: 0 (11904/2257759) completed in 0m 0.845s
#   loss: 10.8497 corr: 0 (12032/2257759) completed in 0m 0.831s
#   loss: 10.6918 corr: 0 (12160/2257759) completed in 0m 0.853s
#   loss: 10.7206 corr: 0 (12288/2257759) completed in 0m 0.844s
#   loss: 10.8176 corr: 0 (12416/2257759) completed in 0m 0.845s
#   loss: 10.5044 corr: 1 (12544/2257759) completed in 0m 0.821s
#   loss: 10.7246 corr: 0 (12672/2257759) completed in 0m 0.865s
#   loss: 10.6791 corr: 0 (12800/2257759) completed in 0m 0.918s
#   loss: 10.5663 corr: 1 (12928/2257759) completed in 0m 0.855s
#   loss: 10.6282 corr: 0 (13056/2257759) completed in 0m 0.851s
#   loss: 10.4291 corr: 0 (13184/2257759) completed in 0m 0.835s
#   loss: 10.7478 corr: 0 (13312/2257759) completed in 0m 0.790s
#   loss: 10.7649 corr: 1 (13440/2257759) completed in 0m 0.854s
#   loss: 10.8331 corr: 0 (13568/2257759) completed in 0m 0.847s
#   loss: 10.7225 corr: 0 (13696/2257759) completed in 0m 0.852s
#   loss: 10.7438 corr: 0 (13824/2257759) completed in 0m 0.811s
#   loss: 10.7358 corr: 0 (13952/2257759) completed in 0m 0.837s
#   loss: 10.9121 corr: 0 (14080/2257759) completed in 0m 0.882s
#   loss: 10.7874 corr: 1 (14208/2257759) completed in 0m 0.837s
#   loss: 10.6791 corr: 0 (14336/2257759) completed in 0m 0.817s
#   loss: 10.7273 corr: 0 (14464/2257759) completed in 0m 0.864s
#   loss: 10.7104 corr: 0 (14592/2257759) completed in 0m 0.825s
#   loss: 10.5913 corr: 0 (14720/2257759) completed in 0m 0.844s
#   loss: 10.8053 corr: 0 (14848/2257759) completed in 0m 0.884s
#   loss: 10.6766 corr: 0 (14976/2257759) completed in 0m 0.788s
#   loss: 10.6050 corr: 0 (15104/2257759) completed in 0m 0.822s
#   loss: 10.7558 corr: 0 (15232/2257759) completed in 0m 0.832s
#   loss: 10.5721 corr: 0 (15360/2257759) completed in 0m 0.893s
#   loss: 10.7862 corr: 0 (15488/2257759) completed in 0m 0.826s
#   loss: 10.7460 corr: 0 (15616/2257759) completed in 0m 0.826s
#   loss: 10.7135 corr: 0 (15744/2257759) completed in 0m 0.857s
#   loss: 10.6812 corr: 0 (15872/2257759) completed in 0m 0.810s
#   loss: 10.6094 corr: 0 (16000/2257759) completed in 0m 0.833s
#   loss: 10.7375 corr: 0 (16128/2257759) completed in 0m 0.775s
#   loss: 10.6268 corr: 1 (16256/2257759) completed in 0m 0.826s
#   loss: 10.6384 corr: 0 (16384/2257759) completed in 0m 0.809s
#   loss: 10.5736 corr: 0 (16512/2257759) completed in 0m 0.836s
#   loss: 10.7892 corr: 0 (16640/2257759) completed in 0m 0.802s
#   loss: 10.7356 corr: 1 (16768/2257759) completed in 0m 0.812s
#   loss: 10.7810 corr: 2 (16896/2257759) completed in 0m 0.848s
#   loss: 10.4982 corr: 0 (17024/2257759) completed in 0m 0.837s
#   loss: 10.6992 corr: 0 (17152/2257759) completed in 0m 0.845s
#   loss: 10.6494 corr: 0 (17280/2257759) completed in 0m 0.817s
#   loss: 10.4728 corr: 1 (17408/2257759) completed in 0m 0.819s
#   loss: 10.6757 corr: 0 (17536/2257759) completed in 0m 0.828s
#   loss: 10.9904 corr: 0 (17664/2257759) completed in 0m 0.782s
#   loss: 10.6416 corr: 0 (17792/2257759) completed in 0m 0.826s
#   loss: 10.8348 corr: 0 (17920/2257759) completed in 0m 0.902s
#   loss: 10.4856 corr: 0 (18048/2257759) completed in 0m 0.838s
#   loss: 10.6622 corr: 0 (18176/2257759) completed in 0m 0.819s
#   loss: 10.5476 corr: 1 (18304/2257759) completed in 0m 0.824s
#   loss: 10.6421 corr: 0 (18432/2257759) completed in 0m 0.842s
#   loss: 10.8802 corr: 0 (18560/2257759) completed in 0m 0.798s
#   loss: 10.6726 corr: 0 (18688/2257759) completed in 0m 0.937s
#   loss: 10.4522 corr: 0 (18816/2257759) completed in 0m 0.826s
#   loss: 10.6758 corr: 0 (18944/2257759) completed in 0m 0.867s
#   loss: 10.6274 corr: 0 (19072/2257759) completed in 0m 0.828s
#   loss: 10.4786 corr: 0 (19200/2257759) completed in 0m 0.827s
#   loss: 10.7603 corr: 0 (19328/2257759) completed in 0m 0.825s
#   loss: 10.5160 corr: 0 (19456/2257759) completed in 0m 0.864s
#   loss: 10.7711 corr: 0 (19584/2257759) completed in 0m 0.849s
#   loss: 10.5847 corr: 0 (19712/2257759) completed in 0m 0.800s
#   loss: 10.5515 corr: 0 (19840/2257759) completed in 0m 0.814s
#   loss: 10.6572 corr: 0 (19968/2257759) completed in 0m 0.846s
#   loss: 10.5524 corr: 0 (20096/2257759) completed in 0m 0.839s
#   loss: 10.4435 corr: 0 (20224/2257759) completed in 0m 0.840s
#   loss: 10.4103 corr: 0 (20352/2257759) completed in 0m 0.844s
#   loss: 10.5796 corr: 0 (20480/2257759) completed in 0m 0.816s
#   loss: 10.6344 corr: 0 (20608/2257759) completed in 0m 0.826s
#   loss: 10.7243 corr: 0 (20736/2257759) completed in 0m 0.853s
#   loss: 10.5934 corr: 0 (20864/2257759) completed in 0m 0.815s
#   loss: 10.6180 corr: 0 (20992/2257759) completed in 0m 0.857s
#   loss: 10.5905 corr: 0 (21120/2257759) completed in 0m 0.866s
#   loss: 10.4692 corr: 0 (21248/2257759) completed in 0m 0.964s
#   loss: 10.4009 corr: 0 (21376/2257759) completed in 0m 0.884s
#   loss: 10.5597 corr: 0 (21504/2257759) completed in 0m 0.853s
#   loss: 10.5135 corr: 0 (21632/2257759) completed in 0m 0.867s
#   loss: 10.4931 corr: 0 (21760/2257759) completed in 0m 0.826s
#   loss: 10.6825 corr: 0 (21888/2257759) completed in 0m 0.895s
#   loss: 10.4093 corr: 0 (22016/2257759) completed in 0m 0.880s
#   loss: 10.5229 corr: 1 (22144/2257759) completed in 0m 0.882s
#   loss: 10.6999 corr: 0 (22272/2257759) completed in 0m 0.841s
#   loss: 10.7186 corr: 0 (22400/2257759) completed in 0m 0.810s
#   loss: 10.7353 corr: 0 (22528/2257759) completed in 0m 0.861s
#   loss: 10.4933 corr: 0 (22656/2257759) completed in 0m 0.822s
#   loss: 10.7666 corr: 0 (22784/2257759) completed in 0m 0.844s
#   loss: 10.4984 corr: 0 (22912/2257759) completed in 0m 0.871s
#   loss: 10.7034 corr: 0 (23040/2257759) completed in 0m 0.827s
#   loss: 10.6761 corr: 0 (23168/2257759) completed in 0m 0.790s
#   loss: 10.5168 corr: 0 (23296/2257759) completed in 0m 0.841s
#   loss: 10.5877 corr: 0 (23424/2257759) completed in 0m 0.820s
#   loss: 10.5782 corr: 0 (23552/2257759) completed in 0m 0.837s
#   loss: 11.7492 corr: 0 (23680/2257759) completed in 0m 0.861s
#   loss: 10.6330 corr: 1 (23808/2257759) completed in 0m 0.893s
#   loss: 10.8942 corr: 0 (23936/2257759) completed in 0m 0.890s
#   loss: 10.5235 corr: 0 (24064/2257759) completed in 0m 0.852s
#   loss: 10.5633 corr: 0 (24192/2257759) completed in 0m 0.840s
#   loss: 10.4103 corr: 0 (24320/2257759) completed in 0m 0.859s
#   loss: 10.6592 corr: 0 (24448/2257759) completed in 0m 0.833s
#   loss: 10.8333 corr: 0 (24576/2257759) completed in 0m 0.862s
#   loss: 10.6785 corr: 0 (24704/2257759) completed in 0m 0.818s
#   loss: 10.8377 corr: 0 (24832/2257759) completed in 0m 0.827s
#   loss: 10.5609 corr: 0 (24960/2257759) completed in 0m 0.806s
#   loss: 10.4481 corr: 0 (25088/2257759) completed in 0m 0.771s
#   loss: 10.6347 corr: 1 (25216/2257759) completed in 0m 0.854s
#   loss: 10.6919 corr: 0 (25344/2257759) completed in 0m 0.843s
#   loss: 10.5575 corr: 0 (25472/2257759) completed in 0m 0.807s
#   loss: 10.6677 corr: 0 (25600/2257759) completed in 0m 0.872s
#   loss: 10.5735 corr: 1 (25728/2257759) completed in 0m 0.841s
#   loss: 10.6384 corr: 0 (25856/2257759) completed in 0m 0.768s
#   loss: 10.6098 corr: 0 (25984/2257759) completed in 0m 0.827s
#   loss: 10.6239 corr: 0 (26112/2257759) completed in 0m 0.821s
#   loss: 10.7273 corr: 0 (26240/2257759) completed in 0m 0.841s
#   loss: 10.3597 corr: 0 (26368/2257759) completed in 0m 0.898s
#   loss: 10.6574 corr: 1 (26496/2257759) completed in 0m 0.792s
#   loss: 10.5151 corr: 1 (26624/2257759) completed in 0m 0.821s
#   loss: 10.5112 corr: 0 (26752/2257759) completed in 0m 0.842s
#   loss: 10.5865 corr: 0 (26880/2257759) completed in 0m 0.918s
#   loss: 10.3999 corr: 0 (27008/2257759) completed in 0m 0.815s
#   loss: 10.6538 corr: 0 (27136/2257759) completed in 0m 0.842s
#   loss: 10.7513 corr: 0 (27264/2257759) completed in 0m 0.844s
#   loss: 10.5064 corr: 0 (27392/2257759) completed in 0m 0.782s
#   loss: 10.5475 corr: 1 (27520/2257759) completed in 0m 0.810s
#   loss: 10.6934 corr: 0 (27648/2257759) completed in 0m 0.817s
#   loss: 10.5456 corr: 1 (27776/2257759) completed in 0m 0.817s
#   loss: 10.2954 corr: 0 (27904/2257759) completed in 0m 0.802s
#   loss: 10.5210 corr: 0 (28032/2257759) completed in 0m 0.831s
#   loss: 10.6898 corr: 0 (28160/2257759) completed in 0m 0.851s
#   loss: 10.2372 corr: 0 (28288/2257759) completed in 0m 0.798s
#   loss: 10.4656 corr: 0 (28416/2257759) completed in 0m 0.800s
#   loss: 11.0091 corr: 0 (28544/2257759) completed in 0m 0.820s
#   loss: 10.3932 corr: 2 (28672/2257759) completed in 0m 0.807s
#   loss: 10.5211 corr: 0 (28800/2257759) completed in 0m 0.860s
#   loss: 10.3532 corr: 0 (28928/2257759) completed in 0m 0.895s
#   loss: 10.4218 corr: 0 (29056/2257759) completed in 0m 0.878s
#   loss: 10.4773 corr: 0 (29184/2257759) completed in 0m 0.844s
#   loss: 10.4951 corr: 0 (29312/2257759) completed in 0m 0.780s
#   loss: 10.5005 corr: 0 (29440/2257759) completed in 0m 0.820s
#   loss: 10.6482 corr: 0 (29568/2257759) completed in 0m 0.857s
#   loss: 10.4608 corr: 0 (29696/2257759) completed in 0m 0.845s
#   loss: 10.5831 corr: 0 (29824/2257759) completed in 0m 0.812s
#   loss: 10.4083 corr: 0 (29952/2257759) completed in 0m 0.822s
#   loss: 10.5041 corr: 0 (30080/2257759) completed in 0m 0.808s
#   loss: 10.3576 corr: 0 (30208/2257759) completed in 0m 0.837s
#   loss: 10.8137 corr: 0 (30336/2257759) completed in 0m 0.841s
#   loss: 10.5429 corr: 0 (30464/2257759) completed in 0m 0.845s
#   loss: 10.5270 corr: 0 (30592/2257759) completed in 0m 0.885s
#   loss: 10.6728 corr: 0 (30720/2257759) completed in 0m 0.786s
#   loss: 10.4692 corr: 1 (30848/2257759) completed in 0m 0.850s
#   loss: 10.6492 corr: 1 (30976/2257759) completed in 0m 0.857s
#   loss: 10.5014 corr: 0 (31104/2257759) completed in 0m 0.837s
#   loss: 10.4765 corr: 0 (31232/2257759) completed in 0m 0.857s
#   loss: 10.3222 corr: 0 (31360/2257759) completed in 0m 0.900s
#   loss: 10.5172 corr: 0 (31488/2257759) completed in 0m 0.864s
#   loss: 10.4101 corr: 1 (31616/2257759) completed in 0m 0.843s
#   loss: 10.3151 corr: 0 (31744/2257759) completed in 0m 0.797s
#   loss: 10.5773 corr: 0 (31872/2257759) completed in 0m 0.814s
#   loss: 10.7181 corr: 1 (32000/2257759) completed in 0m 0.840s
#   loss: 10.7727 corr: 0 (32128/2257759) completed in 0m 0.851s
#   loss: 10.5175 corr: 0 (32256/2257759) completed in 0m 0.827s
#   loss: 10.3646 corr: 0 (32384/2257759) completed in 0m 0.814s
#   loss: 10.5635 corr: 0 (32512/2257759) completed in 0m 0.839s
#   loss: 10.4536 corr: 0 (32640/2257759) completed in 0m 0.816s
#   loss: 10.5601 corr: 1 (32768/2257759) completed in 0m 0.995s
#   loss: 10.5959 corr: 0 (32896/2257759) completed in 0m 0.852s
#   loss: 10.4470 corr: 0 (33024/2257759) completed in 0m 0.832s
#   loss: 10.7126 corr: 0 (33152/2257759) completed in 0m 0.845s
#   loss: 10.4431 corr: 0 (33280/2257759) completed in 0m 0.838s
#   loss: 10.4789 corr: 0 (33408/2257759) completed in 0m 0.818s
#   loss: 10.3428 corr: 0 (33536/2257759) completed in 0m 0.894s
#   loss: 10.3720 corr: 0 (33664/2257759) completed in 0m 0.844s
#   loss: 10.4283 corr: 0 (33792/2257759) completed in 0m 0.808s
#   loss: 10.4439 corr: 1 (33920/2257759) completed in 0m 0.832s
#   loss: 10.4303 corr: 0 (34048/2257759) completed in 0m 0.892s
#   loss: 10.5449 corr: 0 (34176/2257759) completed in 0m 0.841s
#   loss: 10.8356 corr: 0 (34304/2257759) completed in 0m 0.775s
#   loss: 10.5165 corr: 0 (34432/2257759) completed in 0m 0.852s
#   loss: 10.7980 corr: 0 (34560/2257759) completed in 0m 0.860s
#   loss: 10.4625 corr: 1 (34688/2257759) completed in 0m 0.829s
#   loss: 10.4304 corr: 0 (34816/2257759) completed in 0m 0.831s
#   loss: 10.4663 corr: 0 (34944/2257759) completed in 0m 0.818s
#   loss: 10.5456 corr: 0 (35072/2257759) completed in 0m 0.858s
#   loss: 10.5059 corr: 1 (35200/2257759) completed in 0m 0.779s
#   loss: 10.3047 corr: 0 (35328/2257759) completed in 0m 0.828s
#   loss: 10.5102 corr: 0 (35456/2257759) completed in 0m 0.845s
#   loss: 10.5995 corr: 0 (35584/2257759) completed in 0m 0.852s
#   loss: 10.4125 corr: 0 (35712/2257759) completed in 0m 0.862s
#   loss: 10.3371 corr: 0 (35840/2257759) completed in 0m 0.863s
#   loss: 10.3327 corr: 0 (35968/2257759) completed in 0m 0.831s
#   loss: 10.4817 corr: 0 (36096/2257759) completed in 0m 0.848s
#   loss: 10.2068 corr: 1 (36224/2257759) completed in 0m 0.816s
#   loss: 10.4630 corr: 2 (36352/2257759) completed in 0m 0.833s
#   loss: 10.3499 corr: 0 (36480/2257759) completed in 0m 0.823s
#   loss: 10.3230 corr: 1 (36608/2257759) completed in 0m 0.932s
#   loss: 10.4492 corr: 0 (36736/2257759) completed in 0m 0.860s
#   loss: 10.2990 corr: 0 (36864/2257759) completed in 0m 0.837s
#   loss: 10.3750 corr: 0 (36992/2257759) completed in 0m 0.860s
#   loss: 10.4392 corr: 1 (37120/2257759) completed in 0m 0.810s
#   loss: 10.3492 corr: 0 (37248/2257759) completed in 0m 0.829s
#   loss: 10.3394 corr: 0 (37376/2257759) completed in 0m 0.836s
#   loss: 10.5151 corr: 0 (37504/2257759) completed in 0m 0.846s
#   loss: 10.6477 corr: 0 (37632/2257759) completed in 0m 0.844s
#   loss: 10.4057 corr: 0 (37760/2257759) completed in 0m 0.871s
#   loss: 10.4127 corr: 0 (37888/2257759) completed in 0m 0.815s
#   loss: 10.6214 corr: 1 (38016/2257759) completed in 0m 0.824s
#   loss: 10.3138 corr: 0 (38144/2257759) completed in 0m 0.797s
#   loss: 10.5599 corr: 1 (38272/2257759) completed in 0m 0.829s
#   loss: 10.5349 corr: 0 (38400/2257759) completed in 0m 0.813s
#   loss: 10.3532 corr: 0 (38528/2257759) completed in 0m 0.845s
#   loss: 10.5265 corr: 0 (38656/2257759) completed in 0m 0.803s
#   loss: 10.5445 corr: 0 (38784/2257759) completed in 0m 0.868s
#   loss: 10.4480 corr: 0 (38912/2257759) completed in 0m 0.908s
#   loss: 10.4842 corr: 0 (39040/2257759) completed in 0m 0.908s
#   loss: 10.3990 corr: 0 (39168/2257759) completed in 0m 0.870s
#   loss: 10.5056 corr: 0 (39296/2257759) completed in 0m 0.825s
#   loss: 10.4941 corr: 0 (39424/2257759) completed in 0m 0.827s
#   loss: 10.4942 corr: 1 (39552/2257759) completed in 0m 0.811s
#   loss: 10.3242 corr: 0 (39680/2257759) completed in 0m 0.853s
#   loss: 10.4336 corr: 0 (39808/2257759) completed in 0m 0.880s
#   loss: 10.6877 corr: 0 (39936/2257759) completed in 0m 0.840s
#   loss: 10.5868 corr: 0 (40064/2257759) completed in 0m 0.849s
#   loss: 10.3144 corr: 0 (40192/2257759) completed in 0m 0.829s
#   loss: 10.6023 corr: 0 (40320/2257759) completed in 0m 0.842s
#   loss: 10.5699 corr: 0 (40448/2257759) completed in 0m 0.875s
#   loss: 10.3984 corr: 0 (40576/2257759) completed in 0m 0.859s
#   loss: 10.3675 corr: 0 (40704/2257759) completed in 0m 0.835s
#   loss: 10.4930 corr: 0 (40832/2257759) completed in 0m 0.848s
#   loss: 10.6175 corr: 1 (40960/2257759) completed in 0m 0.882s
#   loss: 10.5054 corr: 0 (41088/2257759) completed in 0m 0.814s
#   loss: 10.5688 corr: 0 (41216/2257759) completed in 0m 0.833s
#   loss: 10.4498 corr: 0 (41344/2257759) completed in 0m 0.817s
#   loss: 10.7153 corr: 0 (41472/2257759) completed in 0m 0.888s
#   loss: 10.4866 corr: 0 (41600/2257759) completed in 0m 0.798s
#   loss: 10.2415 corr: 0 (41728/2257759) completed in 0m 0.828s
#   loss: 10.4019 corr: 0 (41856/2257759) completed in 0m 0.876s
#   loss: 10.3273 corr: 1 (41984/2257759) completed in 0m 0.847s
#   loss: 10.4684 corr: 0 (42112/2257759) completed in 0m 0.841s
#   loss: 10.2820 corr: 1 (42240/2257759) completed in 0m 0.867s
#   loss: 10.4681 corr: 0 (42368/2257759) completed in 0m 0.819s
#   loss: 10.6355 corr: 0 (42496/2257759) completed in 0m 0.891s
#   loss: 10.3700 corr: 0 (42624/2257759) completed in 0m 0.962s
#   loss: 10.3870 corr: 2 (42752/2257759) completed in 0m 0.833s
#   loss: 10.3935 corr: 0 (42880/2257759) completed in 0m 0.820s
#   loss: 10.5315 corr: 0 (43008/2257759) completed in 0m 0.849s
#   loss: 10.4784 corr: 0 (43136/2257759) completed in 0m 0.851s
#   loss: 10.3025 corr: 0 (43264/2257759) completed in 0m 0.849s
#   loss: 10.4504 corr: 0 (43392/2257759) completed in 0m 0.841s
#   loss: 10.4671 corr: 0 (43520/2257759) completed in 0m 0.862s
#   loss: 10.2767 corr: 0 (43648/2257759) completed in 0m 0.812s
#   loss: 10.3331 corr: 0 (43776/2257759) completed in 0m 0.829s
#   loss: 10.2780 corr: 0 (43904/2257759) completed in 0m 0.840s
#   loss: 10.4287 corr: 0 (44032/2257759) completed in 0m 0.829s
#   loss: 10.1910 corr: 0 (44160/2257759) completed in 0m 0.790s
#   loss: 10.5898 corr: 0 (44288/2257759) completed in 0m 0.824s
#   loss: 10.2553 corr: 0 (44416/2257759) completed in 0m 0.833s
#   loss: 11.6684 corr: 1 (44544/2257759) completed in 0m 0.867s
#   loss: 10.5080 corr: 0 (44672/2257759) completed in 0m 0.847s
#   loss: 10.5442 corr: 0 (44800/2257759) completed in 0m 0.859s
#   loss: 10.2884 corr: 0 (44928/2257759) completed in 0m 0.805s
#   loss: 10.2934 corr: 0 (45056/2257759) completed in 0m 0.802s
#   loss: 10.5083 corr: 0 (45184/2257759) completed in 0m 0.847s
#   loss: 10.1565 corr: 0 (45312/2257759) completed in 0m 0.829s
#   loss: 10.3151 corr: 0 (45440/2257759) completed in 0m 0.893s
#   loss: 10.2713 corr: 0 (45568/2257759) completed in 0m 0.849s
#   loss: 10.5787 corr: 0 (45696/2257759) completed in 0m 0.850s
#   loss: 10.4663 corr: 0 (45824/2257759) completed in 0m 0.852s
#   loss: 10.2698 corr: 0 (45952/2257759) completed in 0m 0.839s
#   loss: 10.6157 corr: 0 (46080/2257759) completed in 0m 0.853s
#   loss: 10.5099 corr: 0 (46208/2257759) completed in 0m 0.812s
#   loss: 10.3348 corr: 0 (46336/2257759) completed in 0m 0.874s
#   loss: 10.4095 corr: 0 (46464/2257759) completed in 0m 0.836s
#   loss: 10.1811 corr: 0 (46592/2257759) completed in 0m 0.814s
#   loss: 10.2616 corr: 0 (46720/2257759) completed in 0m 0.838s
#   loss: 10.2817 corr: 0 (46848/2257759) completed in 0m 0.771s
#   loss: 10.2695 corr: 0 (46976/2257759) completed in 0m 0.869s
#   loss: 10.2799 corr: 0 (47104/2257759) completed in 0m 0.888s
#   loss: 10.4329 corr: 0 (47232/2257759) completed in 0m 0.817s
#   loss: 10.5328 corr: 0 (47360/2257759) completed in 0m 0.828s
#   loss: 10.3755 corr: 0 (47488/2257759) completed in 0m 0.840s
#   loss: 10.4652 corr: 0 (47616/2257759) completed in 0m 0.859s
#   loss: 10.5442 corr: 0 (47744/2257759) completed in 0m 0.828s
#   loss: 10.3848 corr: 1 (47872/2257759) completed in 0m 0.804s
#   loss: 10.3648 corr: 0 (48000/2257759) completed in 0m 0.775s
#   loss: 10.3287 corr: 0 (48128/2257759) completed in 0m 0.813s
#   loss: 10.3259 corr: 0 (48256/2257759) completed in 0m 0.784s
#   loss: 10.4132 corr: 0 (48384/2257759) completed in 0m 0.982s
#   loss: 10.3213 corr: 0 (48512/2257759) completed in 0m 0.946s
#   loss: 10.4025 corr: 0 (48640/2257759) completed in 0m 0.820s
#   loss: 10.3100 corr: 0 (48768/2257759) completed in 0m 0.823s
#   loss: 10.3353 corr: 0 (48896/2257759) completed in 0m 0.814s
#   loss: 10.3699 corr: 0 (49024/2257759) completed in 0m 0.868s
#   loss: 10.6273 corr: 1 (49152/2257759) completed in 0m 0.832s
#   loss: 10.3498 corr: 0 (49280/2257759) completed in 0m 0.843s
#   loss: 10.4081 corr: 1 (49408/2257759) completed in 0m 0.841s
#   loss: 10.5390 corr: 0 (49536/2257759) completed in 0m 0.859s
#   loss: 10.4589 corr: 1 (49664/2257759) completed in 0m 0.845s
#   loss: 10.4390 corr: 0 (49792/2257759) completed in 0m 0.858s
#   loss: 10.3711 corr: 0 (49920/2257759) completed in 0m 0.859s
#   loss: 10.2596 corr: 1 (50048/2257759) completed in 0m 0.844s
#   loss: 10.3947 corr: 0 (50176/2257759) completed in 0m 0.828s
#   loss: 10.2521 corr: 0 (50304/2257759) completed in 0m 0.844s
#   loss: 10.2220 corr: 0 (50432/2257759) completed in 0m 0.918s
#   loss: 10.3211 corr: 1 (50560/2257759) completed in 0m 0.811s
#   loss: 10.5439 corr: 0 (50688/2257759) completed in 0m 0.822s
#   loss: 10.4237 corr: 1 (50816/2257759) completed in 0m 0.847s
#   loss: 10.4468 corr: 1 (50944/2257759) completed in 0m 0.951s
#   loss: 10.3781 corr: 2 (51072/2257759) completed in 0m 0.828s
#   loss: 10.3309 corr: 0 (51200/2257759) completed in 0m 0.831s
#   loss: 10.1839 corr: 0 (51328/2257759) completed in 0m 0.877s
#   loss: 10.3120 corr: 0 (51456/2257759) completed in 0m 0.829s
#   loss: 10.2111 corr: 0 (51584/2257759) completed in 0m 0.845s
#   loss: 10.5438 corr: 0 (51712/2257759) completed in 0m 0.777s
#   loss: 10.4075 corr: 0 (51840/2257759) completed in 0m 0.826s
#   loss: 10.4508 corr: 0 (51968/2257759) completed in 0m 0.882s
#   loss: 10.4781 corr: 0 (52096/2257759) completed in 0m 0.828s
#   loss: 10.1386 corr: 0 (52224/2257759) completed in 0m 0.902s
#   loss: 10.2690 corr: 0 (52352/2257759) completed in 0m 0.829s
#   loss: 10.3227 corr: 0 (52480/2257759) completed in 0m 0.860s
#   loss: 10.2663 corr: 0 (52608/2257759) completed in 0m 0.828s
#   loss: 10.1283 corr: 1 (52736/2257759) completed in 0m 0.822s
#   loss: 10.5673 corr: 1 (52864/2257759) completed in 0m 0.814s
#   loss: 10.1172 corr: 0 (52992/2257759) completed in 0m 0.821s
#   loss: 10.2778 corr: 0 (53120/2257759) completed in 0m 0.788s
#   loss: 10.2813 corr: 0 (53248/2257759) completed in 0m 0.824s
#   loss: 10.1961 corr: 0 (53376/2257759) completed in 0m 0.811s
#   loss: 10.1526 corr: 1 (53504/2257759) completed in 0m 0.860s
#   loss: 10.3697 corr: 0 (53632/2257759) completed in 0m 0.903s
#   loss: 10.1721 corr: 1 (53760/2257759) completed in 0m 0.826s
#   loss: 10.3307 corr: 0 (53888/2257759) completed in 0m 0.934s
#   loss: 10.3537 corr: 0 (54016/2257759) completed in 0m 0.847s
#   loss: 10.1826 corr: 0 (54144/2257759) completed in 0m 0.866s
#   loss: 10.1916 corr: 0 (54272/2257759) completed in 0m 0.835s
#   loss: 10.0705 corr: 0 (54400/2257759) completed in 0m 0.845s
#   loss: 10.3704 corr: 0 (54528/2257759) completed in 0m 0.778s
#   loss: 10.0877 corr: 2 (54656/2257759) completed in 0m 0.864s
#   loss: 10.3885 corr: 1 (54784/2257759) completed in 0m 0.849s
#   loss: 10.3768 corr: 0 (54912/2257759) completed in 0m 0.838s
#   loss: 10.3011 corr: 0 (55040/2257759) completed in 0m 0.838s
#   loss: 10.1013 corr: 0 (55168/2257759) completed in 0m 0.830s
#   loss: 10.1891 corr: 0 (55296/2257759) completed in 0m 0.809s
#   loss: 10.5489 corr: 0 (55424/2257759) completed in 0m 0.895s
#   loss: 10.3418 corr: 0 (55552/2257759) completed in 0m 0.835s
#   loss: 10.3983 corr: 1 (55680/2257759) completed in 0m 0.877s
#   loss: 10.4671 corr: 0 (55808/2257759) completed in 0m 0.794s
#   loss: 10.2876 corr: 0 (55936/2257759) completed in 0m 0.817s
#   loss: 10.0908 corr: 0 (56064/2257759) completed in 0m 0.819s
#   loss: 10.1734 corr: 0 (56192/2257759) completed in 0m 0.962s
#   loss: 10.4182 corr: 0 (56320/2257759) completed in 0m 0.872s
#   loss: 10.3907 corr: 0 (56448/2257759) completed in 0m 0.829s
#   loss: 10.4967 corr: 0 (56576/2257759) completed in 0m 0.822s
#   loss: 10.0501 corr: 1 (56704/2257759) completed in 0m 0.827s
#   loss: 10.3643 corr: 0 (56832/2257759) completed in 0m 0.861s
#   loss: 10.4401 corr: 0 (56960/2257759) completed in 0m 0.850s
#   loss: 10.1841 corr: 0 (57088/2257759) completed in 0m 0.834s
#   loss: 10.3060 corr: 1 (57216/2257759) completed in 0m 0.877s
#   loss: 10.3874 corr: 0 (57344/2257759) completed in 0m 0.792s
#   loss: 10.1441 corr: 0 (57472/2257759) completed in 0m 0.827s
#   loss: 10.2416 corr: 0 (57600/2257759) completed in 0m 0.862s
#   loss: 10.3025 corr: 0 (57728/2257759) completed in 0m 0.847s
#   loss: 10.1503 corr: 0 (57856/2257759) completed in 0m 0.822s
#   loss: 10.4029 corr: 0 (57984/2257759) completed in 0m 0.842s
#   loss: 10.1828 corr: 0 (58112/2257759) completed in 0m 0.815s
#   loss: 10.3831 corr: 0 (58240/2257759) completed in 0m 0.872s
#   loss: 10.1636 corr: 0 (58368/2257759) completed in 0m 0.848s
#   loss: 10.3169 corr: 0 (58496/2257759) completed in 0m 0.834s
#   loss: 10.3208 corr: 0 (58624/2257759) completed in 0m 0.839s
#   loss: 9.9935 corr: 0 (58752/2257759) completed in 0m 0.881s
#   loss: 10.5510 corr: 0 (58880/2257759) completed in 0m 0.816s
#   loss: 10.2639 corr: 0 (59008/2257759) completed in 0m 0.825s
#   loss: 9.8118 corr: 1 (59136/2257759) completed in 0m 0.842s
#   loss: 10.3615 corr: 0 (59264/2257759) completed in 0m 0.813s
#   loss: 10.3843 corr: 0 (59392/2257759) completed in 0m 0.795s
#   loss: 10.1295 corr: 1 (59520/2257759) completed in 0m 0.835s
#   loss: 10.3861 corr: 0 (59648/2257759) completed in 0m 0.876s
#   loss: 10.1239 corr: 1 (59776/2257759) completed in 0m 0.852s
#   loss: 10.1326 corr: 0 (59904/2257759) completed in 0m 0.779s
#   loss: 10.1133 corr: 0 (60032/2257759) completed in 0m 0.874s
#   loss: 10.2202 corr: 0 (60160/2257759) completed in 0m 0.772s
#   loss: 10.3246 corr: 0 (60288/2257759) completed in 0m 0.809s
#   loss: 10.1785 corr: 0 (60416/2257759) completed in 0m 0.834s
#   loss: 10.0813 corr: 0 (60544/2257759) completed in 0m 0.840s
#   loss: 10.3506 corr: 0 (60672/2257759) completed in 0m 0.799s
#   loss: 10.2356 corr: 0 (60800/2257759) completed in 0m 0.890s
#   loss: 10.5442 corr: 1 (60928/2257759) completed in 0m 0.903s
#   loss: 10.2232 corr: 0 (61056/2257759) completed in 0m 0.849s
#   loss: 10.1730 corr: 0 (61184/2257759) completed in 0m 0.835s
#   loss: 10.0679 corr: 1 (61312/2257759) completed in 0m 0.859s
#   loss: 10.2742 corr: 1 (61440/2257759) completed in 0m 0.876s
#   loss: 10.0126 corr: 1 (61568/2257759) completed in 0m 0.837s
#   loss: 10.1439 corr: 0 (61696/2257759) completed in 0m 0.840s
#   loss: 10.0248 corr: 0 (61824/2257759) completed in 0m 0.849s
#   loss: 10.3487 corr: 0 (61952/2257759) completed in 0m 0.834s
#   loss: 10.2821 corr: 1 (62080/2257759) completed in 0m 0.849s
#   loss: 10.3903 corr: 1 (62208/2257759) completed in 0m 0.855s
#   loss: 10.2014 corr: 0 (62336/2257759) completed in 0m 0.851s
#   loss: 10.1235 corr: 0 (62464/2257759) completed in 0m 0.837s
#   loss: 9.9369 corr: 0 (62592/2257759) completed in 0m 0.791s
#   loss: 10.1601 corr: 0 (62720/2257759) completed in 0m 0.811s
#   loss: 10.0507 corr: 0 (62848/2257759) completed in 0m 0.829s
#   loss: 10.2447 corr: 2 (62976/2257759) completed in 0m 0.838s
#   loss: 10.3158 corr: 0 (63104/2257759) completed in 0m 0.867s
#   loss: 10.4167 corr: 1 (63232/2257759) completed in 0m 0.841s
#   loss: 10.0185 corr: 0 (63360/2257759) completed in 0m 0.879s
#   loss: 10.2622 corr: 0 (63488/2257759) completed in 0m 0.903s
#   loss: 10.2174 corr: 0 (63616/2257759) completed in 0m 0.886s
#   loss: 10.3542 corr: 1 (63744/2257759) completed in 0m 0.870s
#   loss: 10.1818 corr: 0 (63872/2257759) completed in 0m 0.771s
#   loss: 10.2777 corr: 1 (64000/2257759) completed in 0m 0.817s
#   loss: 10.1368 corr: 0 (64128/2257759) completed in 0m 0.865s
#   loss: 10.1422 corr: 0 (64256/2257759) completed in 0m 0.890s
#   loss: 10.1513 corr: 1 (64384/2257759) completed in 0m 0.841s
#   loss: 10.1316 corr: 0 (64512/2257759) completed in 0m 0.782s
#   loss: 10.2547 corr: 0 (64640/2257759) completed in 0m 0.774s
#   loss: 10.4148 corr: 0 (64768/2257759) completed in 0m 0.936s
#   loss: 10.1419 corr: 0 (64896/2257759) completed in 0m 0.835s
#   loss: 10.2221 corr: 0 (65024/2257759) completed in 0m 0.824s
#   loss: 10.3031 corr: 0 (65152/2257759) completed in 0m 0.860s
#   loss: 10.3597 corr: 1 (65280/2257759) completed in 0m 0.832s
#   loss: 10.2360 corr: 0 (65408/2257759) completed in 0m 0.859s
#   loss: 10.1893 corr: 0 (65536/2257759) completed in 0m 0.852s
#   loss: 10.2835 corr: 0 (65664/2257759) completed in 0m 0.804s
#   loss: 10.2726 corr: 0 (65792/2257759) completed in 0m 0.868s
#   loss: 10.2188 corr: 0 (65920/2257759) completed in 0m 0.798s
#   loss: 10.2368 corr: 0 (66048/2257759) completed in 0m 0.943s
#   loss: 10.2823 corr: 0 (66176/2257759) completed in 0m 0.862s
#   loss: 10.3734 corr: 0 (66304/2257759) completed in 0m 0.845s
#   loss: 10.0790 corr: 2 (66432/2257759) completed in 0m 0.844s
#   loss: 10.1670 corr: 0 (66560/2257759) completed in 0m 0.827s
#   loss: 10.2959 corr: 1 (66688/2257759) completed in 0m 0.864s
#   loss: 10.1436 corr: 0 (66816/2257759) completed in 0m 0.829s
#   loss: 10.2105 corr: 0 (66944/2257759) completed in 0m 0.840s
#   loss: 10.1528 corr: 0 (67072/2257759) completed in 0m 0.816s
#   loss: 10.3486 corr: 0 (67200/2257759) completed in 0m 0.843s
#   loss: 9.9697 corr: 0 (67328/2257759) completed in 0m 0.867s
#   loss: 10.1213 corr: 0 (67456/2257759) completed in 0m 0.827s
#   loss: 10.0571 corr: 0 (67584/2257759) completed in 0m 0.829s
#   loss: 9.9890 corr: 0 (67712/2257759) completed in 0m 0.850s
#   loss: 10.5189 corr: 0 (67840/2257759) completed in 0m 0.898s
#   loss: 9.9072 corr: 2 (67968/2257759) completed in 0m 0.779s
#   loss: 10.2932 corr: 0 (68096/2257759) completed in 0m 0.863s
#   loss: 10.0276 corr: 1 (68224/2257759) completed in 0m 0.834s
#   loss: 10.2517 corr: 0 (68352/2257759) completed in 0m 0.853s
#   loss: 10.3560 corr: 0 (68480/2257759) completed in 0m 0.841s
#   loss: 10.2058 corr: 1 (68608/2257759) completed in 0m 0.827s
#   loss: 10.0796 corr: 1 (68736/2257759) completed in 0m 0.840s
#   loss: 10.3172 corr: 0 (68864/2257759) completed in 0m 0.864s
#   loss: 10.0840 corr: 0 (68992/2257759) completed in 0m 0.826s
#   loss: 10.0437 corr: 0 (69120/2257759) completed in 0m 0.834s
#   loss: 10.0539 corr: 0 (69248/2257759) completed in 0m 0.812s
#   loss: 10.1193 corr: 0 (69376/2257759) completed in 0m 0.832s
#   loss: 10.1459 corr: 0 (69504/2257759) completed in 0m 0.889s
#   loss: 10.4607 corr: 0 (69632/2257759) completed in 0m 0.777s
#   loss: 10.0523 corr: 0 (69760/2257759) completed in 0m 0.830s
#   loss: 10.2732 corr: 1 (69888/2257759) completed in 0m 0.884s
#   loss: 9.9638 corr: 2 (70016/2257759) completed in 0m 0.882s
#   loss: 10.3673 corr: 0 (70144/2257759) completed in 0m 0.822s
#   loss: 10.1488 corr: 0 (70272/2257759) completed in 0m 0.822s
#   loss: 10.2747 corr: 0 (70400/2257759) completed in 0m 0.941s
#   loss: 10.1950 corr: 0 (70528/2257759) completed in 0m 0.841s
#   loss: 10.1423 corr: 0 (70656/2257759) completed in 0m 0.864s
#   loss: 10.2360 corr: 0 (70784/2257759) completed in 0m 0.861s
#   loss: 10.0961 corr: 0 (70912/2257759) completed in 0m 0.808s
#   loss: 10.2094 corr: 0 (71040/2257759) completed in 0m 0.881s
#   loss: 10.0075 corr: 1 (71168/2257759) completed in 0m 0.851s
#   loss: 10.1384 corr: 0 (71296/2257759) completed in 0m 0.923s
#   loss: 10.4346 corr: 0 (71424/2257759) completed in 0m 0.835s
#   loss: 10.3623 corr: 0 (71552/2257759) completed in 0m 0.769s
#   loss: 10.1257 corr: 1 (71680/2257759) completed in 0m 0.845s
#   loss: 10.2310 corr: 0 (71808/2257759) completed in 0m 0.791s
#   loss: 10.1283 corr: 0 (71936/2257759) completed in 0m 0.812s
#   loss: 10.1388 corr: 0 (72064/2257759) completed in 0m 0.847s
#   loss: 10.2390 corr: 0 (72192/2257759) completed in 0m 0.817s
#   loss: 9.9025 corr: 1 (72320/2257759) completed in 0m 0.832s
#   loss: 10.1812 corr: 0 (72448/2257759) completed in 0m 0.793s
#   loss: 10.3244 corr: 1 (72576/2257759) completed in 0m 0.828s
#   loss: 10.4000 corr: 0 (72704/2257759) completed in 0m 0.864s
#   loss: 9.9307 corr: 1 (72832/2257759) completed in 0m 0.832s
#   loss: 10.4029 corr: 0 (72960/2257759) completed in 0m 0.846s
#   loss: 10.1704 corr: 1 (73088/2257759) completed in 0m 0.856s
#   loss: 10.3568 corr: 0 (73216/2257759) completed in 0m 0.822s
#   loss: 10.1683 corr: 0 (73344/2257759) completed in 0m 0.802s
#   loss: 10.2302 corr: 0 (73472/2257759) completed in 0m 0.824s
#   loss: 10.0823 corr: 0 (73600/2257759) completed in 0m 0.837s
#   loss: 9.9880 corr: 0 (73728/2257759) completed in 0m 0.859s
#   loss: 10.1834 corr: 0 (73856/2257759) completed in 0m 0.930s
#   loss: 10.2737 corr: 0 (73984/2257759) completed in 0m 0.847s
#   loss: 9.8533 corr: 0 (74112/2257759) completed in 0m 0.843s
#   loss: 9.9011 corr: 0 (74240/2257759) completed in 0m 0.798s
#   loss: 9.9712 corr: 0 (74368/2257759) completed in 0m 0.844s
#   loss: 10.2920 corr: 1 (74496/2257759) completed in 0m 0.793s
#   loss: 9.9716 corr: 1 (74624/2257759) completed in 0m 0.829s
#   loss: 10.1732 corr: 0 (74752/2257759) completed in 0m 0.817s
#   loss: 9.9901 corr: 0 (74880/2257759) completed in 0m 0.859s
#   loss: 10.1587 corr: 0 (75008/2257759) completed in 0m 0.833s
#   loss: 10.0030 corr: 0 (75136/2257759) completed in 0m 0.843s
#   loss: 9.8748 corr: 0 (75264/2257759) completed in 0m 0.793s
#   loss: 10.1953 corr: 0 (75392/2257759) completed in 0m 0.778s
#   loss: 9.8925 corr: 0 (75520/2257759) completed in 0m 0.876s
#   loss: 10.2549 corr: 0 (75648/2257759) completed in 0m 0.851s
#   loss: 10.1413 corr: 2 (75776/2257759) completed in 0m 0.862s
#   loss: 10.0345 corr: 1 (75904/2257759) completed in 0m 0.845s
#   loss: 10.2183 corr: 0 (76032/2257759) completed in 0m 0.859s
#   loss: 10.3269 corr: 0 (76160/2257759) completed in 0m 0.889s
#   loss: 10.0256 corr: 0 (76288/2257759) completed in 0m 0.816s
#   loss: 10.2082 corr: 0 (76416/2257759) completed in 0m 0.983s
#   loss: 9.9516 corr: 0 (76544/2257759) completed in 0m 0.833s
#   loss: 10.2929 corr: 0 (76672/2257759) completed in 0m 0.837s
#   loss: 10.1704 corr: 0 (76800/2257759) completed in 0m 0.814s
#   loss: 10.1431 corr: 0 (76928/2257759) completed in 0m 0.873s
#   loss: 10.1524 corr: 1 (77056/2257759) completed in 0m 0.815s
#   loss: 10.1287 corr: 1 (77184/2257759) completed in 0m 0.892s
#   loss: 10.2020 corr: 0 (77312/2257759) completed in 0m 0.871s
#   loss: 9.9900 corr: 1 (77440/2257759) completed in 0m 0.830s
#   loss: 10.3593 corr: 0 (77568/2257759) completed in 0m 0.838s
#   loss: 10.1055 corr: 0 (77696/2257759) completed in 0m 0.847s
#   loss: 10.2432 corr: 0 (77824/2257759) completed in 0m 0.838s
#   loss: 9.8970 corr: 0 (77952/2257759) completed in 0m 0.843s
#   loss: 10.1499 corr: 0 (78080/2257759) completed in 0m 0.779s
#   loss: 10.1618 corr: 0 (78208/2257759) completed in 0m 0.908s
#   loss: 9.9130 corr: 0 (78336/2257759) completed in 0m 0.862s
#   loss: 9.9124 corr: 0 (78464/2257759) completed in 0m 0.896s
#   loss: 10.0320 corr: 0 (78592/2257759) completed in 0m 0.861s
#   loss: 10.0451 corr: 1 (78720/2257759) completed in 0m 0.865s
#   loss: 10.0481 corr: 1 (78848/2257759) completed in 0m 0.850s
#   loss: 10.1546 corr: 0 (78976/2257759) completed in 0m 0.829s
#   loss: 10.0275 corr: 0 (79104/2257759) completed in 0m 0.892s
#   loss: 10.1965 corr: 0 (79232/2257759) completed in 0m 0.830s
#   loss: 10.1326 corr: 0 (79360/2257759) completed in 0m 0.842s
#   loss: 10.0706 corr: 0 (79488/2257759) completed in 0m 0.840s
#   loss: 9.9139 corr: 0 (79616/2257759) completed in 0m 0.813s
#   loss: 9.9631 corr: 0 (79744/2257759) completed in 0m 0.845s
#   loss: 10.0327 corr: 0 (79872/2257759) completed in 0m 0.942s
#   loss: 10.1386 corr: 1 (80000/2257759) completed in 0m 0.916s
#   loss: 10.2068 corr: 0 (80128/2257759) completed in 0m 0.862s
#   loss: 10.1778 corr: 0 (80256/2257759) completed in 0m 0.843s
#   loss: 9.9296 corr: 0 (80384/2257759) completed in 0m 0.825s
#   loss: 10.1854 corr: 1 (80512/2257759) completed in 0m 0.842s
#   loss: 10.0330 corr: 1 (80640/2257759) completed in 0m 0.843s
#   loss: 10.0595 corr: 0 (80768/2257759) completed in 0m 0.782s
#   loss: 9.9266 corr: 0 (80896/2257759) completed in 0m 0.824s
#   loss: 9.9315 corr: 0 (81024/2257759) completed in 0m 0.867s
#   loss: 9.9585 corr: 1 (81152/2257759) completed in 0m 0.887s
#   loss: 10.2356 corr: 0 (81280/2257759) completed in 0m 0.865s
#   loss: 9.9625 corr: 0 (81408/2257759) completed in 0m 0.851s
#   loss: 10.0789 corr: 0 (81536/2257759) completed in 0m 0.846s
#   loss: 10.3433 corr: 0 (81664/2257759) completed in 0m 0.866s
#   loss: 10.0495 corr: 1 (81792/2257759) completed in 0m 0.780s
#   loss: 9.8688 corr: 0 (81920/2257759) completed in 0m 0.841s
#   loss: 9.9529 corr: 0 (82048/2257759) completed in 0m 0.817s
#   loss: 9.9678 corr: 0 (82176/2257759) completed in 0m 0.842s
#   loss: 9.8778 corr: 1 (82304/2257759) completed in 0m 0.847s
#   loss: 10.0523 corr: 0 (82432/2257759) completed in 0m 0.868s
#   loss: 10.0637 corr: 0 (82560/2257759) completed in 0m 0.919s
#   loss: 10.2173 corr: 0 (82688/2257759) completed in 0m 0.797s
#   loss: 10.2754 corr: 0 (82816/2257759) completed in 0m 0.860s
#   loss: 10.1281 corr: 0 (82944/2257759) completed in 0m 0.833s
#   loss: 10.2138 corr: 1 (83072/2257759) completed in 0m 0.833s
#   loss: 10.2404 corr: 0 (83200/2257759) completed in 0m 0.841s
#   loss: 10.0834 corr: 0 (83328/2257759) completed in 0m 0.882s
#   loss: 9.8885 corr: 0 (83456/2257759) completed in 0m 0.924s
#   loss: 10.0320 corr: 2 (83584/2257759) completed in 0m 0.874s
#   loss: 9.9664 corr: 2 (83712/2257759) completed in 0m 0.893s
#   loss: 10.0194 corr: 0 (83840/2257759) completed in 0m 0.912s
#   loss: 10.1159 corr: 1 (83968/2257759) completed in 0m 0.879s
#   loss: 9.9738 corr: 0 (84096/2257759) completed in 0m 0.854s
#   loss: 10.1874 corr: 0 (84224/2257759) completed in 0m 0.939s
#   loss: 9.9358 corr: 0 (84352/2257759) completed in 0m 0.873s
#   loss: 9.8364 corr: 0 (84480/2257759) completed in 0m 0.834s
#   loss: 10.0057 corr: 2 (84608/2257759) completed in 0m 0.830s
#   loss: 9.8402 corr: 0 (84736/2257759) completed in 0m 0.826s
#   loss: 9.9170 corr: 0 (84864/2257759) completed in 0m 0.825s
#   loss: 10.1155 corr: 1 (84992/2257759) completed in 0m 0.803s
#   loss: 10.0157 corr: 1 (85120/2257759) completed in 0m 0.872s
#   loss: 9.9074 corr: 0 (85248/2257759) completed in 0m 0.881s
#   loss: 9.8070 corr: 0 (85376/2257759) completed in 0m 0.836s
#   loss: 10.1279 corr: 1 (85504/2257759) completed in 0m 0.793s
#   loss: 9.9337 corr: 0 (85632/2257759) completed in 0m 0.828s
#   loss: 9.8615 corr: 0 (85760/2257759) completed in 0m 0.818s
#   loss: 10.3446 corr: 0 (85888/2257759) completed in 0m 0.834s
#   loss: 9.8562 corr: 1 (86016/2257759) completed in 0m 0.898s
#   loss: 10.2640 corr: 0 (86144/2257759) completed in 0m 0.855s
#   loss: 10.1017 corr: 1 (86272/2257759) completed in 0m 0.889s
#   loss: 10.1377 corr: 0 (86400/2257759) completed in 0m 1.073s
#   loss: 9.9483 corr: 0 (86528/2257759) completed in 0m 0.847s
#   loss: 10.0076 corr: 1 (86656/2257759) completed in 0m 0.846s
#   loss: 9.8665 corr: 1 (86784/2257759) completed in 0m 0.806s
#   loss: 9.9501 corr: 0 (86912/2257759) completed in 0m 0.841s
#   loss: 10.1796 corr: 0 (87040/2257759) completed in 0m 0.796s
#   loss: 10.0046 corr: 0 (87168/2257759) completed in 0m 0.828s
#   loss: 10.2426 corr: 1 (87296/2257759) completed in 0m 0.824s
#   loss: 9.7936 corr: 0 (87424/2257759) completed in 0m 0.845s
#   loss: 9.8815 corr: 0 (87552/2257759) completed in 0m 0.840s
#   loss: 9.9991 corr: 0 (87680/2257759) completed in 0m 0.802s
#   loss: 9.8863 corr: 0 (87808/2257759) completed in 0m 0.830s
#   loss: 10.1924 corr: 0 (87936/2257759) completed in 0m 0.886s
#   loss: 10.2193 corr: 0 (88064/2257759) completed in 0m 0.851s
#   loss: 9.9450 corr: 1 (88192/2257759) completed in 0m 0.838s
#   loss: 10.1108 corr: 0 (88320/2257759) completed in 0m 0.865s
#   loss: 10.0372 corr: 2 (88448/2257759) completed in 0m 0.819s
#   loss: 10.1051 corr: 1 (88576/2257759) completed in 0m 0.925s
#   loss: 10.1408 corr: 0 (88704/2257759) completed in 0m 0.920s
#   loss: 9.9967 corr: 0 (88832/2257759) completed in 0m 0.862s
#   loss: 10.0991 corr: 1 (88960/2257759) completed in 0m 0.779s
#   loss: 10.4569 corr: 2 (89088/2257759) completed in 0m 0.785s
#   loss: 10.1118 corr: 1 (89216/2257759) completed in 0m 0.814s
#   loss: 10.1253 corr: 2 (89344/2257759) completed in 0m 0.837s
#   loss: 10.0878 corr: 1 (89472/2257759) completed in 0m 0.851s
#   loss: 10.2180 corr: 1 (89600/2257759) completed in 0m 0.844s
#   loss: 9.9846 corr: 1 (89728/2257759) completed in 0m 0.847s
#   loss: 9.7884 corr: 1 (89856/2257759) completed in 0m 0.829s
#   loss: 9.9956 corr: 0 (89984/2257759) completed in 0m 0.858s
#   loss: 9.9544 corr: 0 (90112/2257759) completed in 0m 0.855s
#   loss: 10.0075 corr: 0 (90240/2257759) completed in 0m 0.860s
#   loss: 10.0894 corr: 0 (90368/2257759) completed in 0m 0.859s
#   loss: 10.2842 corr: 0 (90496/2257759) completed in 0m 0.822s
#   loss: 10.0504 corr: 0 (90624/2257759) completed in 0m 0.858s
#   loss: 9.9989 corr: 1 (90752/2257759) completed in 0m 0.810s
#   loss: 10.0252 corr: 0 (90880/2257759) completed in 0m 0.834s
#   loss: 9.8500 corr: 0 (91008/2257759) completed in 0m 0.821s
#   loss: 10.0802 corr: 0 (91136/2257759) completed in 0m 0.933s
#   loss: 10.0317 corr: 0 (91264/2257759) completed in 0m 0.838s
#   loss: 10.0236 corr: 1 (91392/2257759) completed in 0m 0.839s
#   loss: 10.1593 corr: 0 (91520/2257759) completed in 0m 0.830s
#   loss: 9.9458 corr: 0 (91648/2257759) completed in 0m 0.870s
#   loss: 9.9405 corr: 1 (91776/2257759) completed in 0m 0.799s
#   loss: 9.9904 corr: 0 (91904/2257759) completed in 0m 0.861s
#   loss: 10.1999 corr: 0 (92032/2257759) completed in 0m 0.835s
#   loss: 10.1507 corr: 0 (92160/2257759) completed in 0m 0.831s
#   loss: 10.0360 corr: 0 (92288/2257759) completed in 0m 0.859s
#   loss: 10.0110 corr: 0 (92416/2257759) completed in 0m 0.828s
#   loss: 10.0910 corr: 1 (92544/2257759) completed in 0m 0.887s
#   loss: 9.9119 corr: 1 (92672/2257759) completed in 0m 0.815s
#   loss: 10.0231 corr: 0 (92800/2257759) completed in 0m 0.811s
#   loss: 9.9190 corr: 0 (92928/2257759) completed in 0m 0.868s
#   loss: 9.9551 corr: 1 (93056/2257759) completed in 0m 0.792s
#   loss: 9.8001 corr: 0 (93184/2257759) completed in 0m 0.825s
#   loss: 9.9381 corr: 0 (93312/2257759) completed in 0m 0.849s
#   loss: 9.7087 corr: 2 (93440/2257759) completed in 0m 0.834s
#   loss: 9.9130 corr: 2 (93568/2257759) completed in 0m 0.843s
#   loss: 9.9120 corr: 1 (93696/2257759) completed in 0m 0.796s
#   loss: 9.9422 corr: 2 (93824/2257759) completed in 0m 0.779s
#   loss: 10.0828 corr: 2 (93952/2257759) completed in 0m 0.824s
#   loss: 10.0852 corr: 1 (94080/2257759) completed in 0m 0.925s
#   loss: 9.8325 corr: 2 (94208/2257759) completed in 0m 0.834s
#   loss: 10.1199 corr: 0 (94336/2257759) completed in 0m 0.853s
#   loss: 10.3135 corr: 0 (94464/2257759) completed in 0m 0.817s
#   loss: 10.0699 corr: 0 (94592/2257759) completed in 0m 0.871s
#   loss: 10.0063 corr: 1 (94720/2257759) completed in 0m 0.828s
#   loss: 10.0458 corr: 0 (94848/2257759) completed in 0m 0.822s
#   loss: 9.9176 corr: 0 (94976/2257759) completed in 0m 0.830s
#   loss: 10.1597 corr: 0 (95104/2257759) completed in 0m 0.778s
#   loss: 9.9550 corr: 0 (95232/2257759) completed in 0m 0.825s
#   loss: 10.1491 corr: 0 (95360/2257759) completed in 0m 0.831s
#   loss: 9.9212 corr: 0 (95488/2257759) completed in 0m 0.884s
#   loss: 10.0597 corr: 1 (95616/2257759) completed in 0m 0.861s
#   loss: 10.0021 corr: 0 (95744/2257759) completed in 0m 0.798s
#   loss: 10.2108 corr: 0 (95872/2257759) completed in 0m 0.815s
#   loss: 10.0004 corr: 0 (96000/2257759) completed in 0m 0.829s
#   loss: 9.9997 corr: 1 (96128/2257759) completed in 0m 0.830s
#   loss: 9.9941 corr: 0 (96256/2257759) completed in 0m 0.815s
#   loss: 9.8121 corr: 0 (96384/2257759) completed in 0m 0.864s
#   loss: 10.1679 corr: 0 (96512/2257759) completed in 0m 0.846s
#   loss: 10.0006 corr: 0 (96640/2257759) completed in 0m 0.839s
#   loss: 9.9725 corr: 0 (96768/2257759) completed in 0m 0.793s
#   loss: 10.0113 corr: 0 (96896/2257759) completed in 0m 0.801s
#   loss: 9.8612 corr: 0 (97024/2257759) completed in 0m 0.830s
#   loss: 9.9943 corr: 0 (97152/2257759) completed in 0m 0.814s
#   loss: 9.8766 corr: 0 (97280/2257759) completed in 0m 0.804s
#   loss: 10.0270 corr: 0 (97408/2257759) completed in 0m 0.830s
#   loss: 9.8200 corr: 1 (97536/2257759) completed in 0m 0.825s
#   loss: 10.1262 corr: 1 (97664/2257759) completed in 0m 0.880s
#   loss: 10.0729 corr: 0 (97792/2257759) completed in 0m 0.837s
# ...
#   loss: 3.9251 corr: 51 (2189568/2257759) completed in 0m 0.875s
#   loss: 3.2597 corr: 45 (2189696/2257759) completed in 0m 0.894s
#   loss: 3.4921 corr: 45 (2189824/2257759) completed in 0m 0.794s
#   loss: 3.8800 corr: 46 (2189952/2257759) completed in 0m 0.865s
#   loss: 4.0635 corr: 45 (2190080/2257759) completed in 0m 0.834s
#   loss: 3.9349 corr: 53 (2190208/2257759) completed in 0m 0.831s
#   loss: 3.9958 corr: 42 (2190336/2257759) completed in 0m 0.872s
#   loss: 3.6265 corr: 48 (2190464/2257759) completed in 0m 0.855s
#   loss: 4.0626 corr: 47 (2190592/2257759) completed in 0m 0.887s
#   loss: 3.7021 corr: 45 (2190720/2257759) completed in 0m 0.891s
#   loss: 4.7045 corr: 39 (2190848/2257759) completed in 0m 0.819s
#   loss: 3.8570 corr: 47 (2190976/2257759) completed in 0m 0.829s
#   loss: 3.6795 corr: 50 (2191104/2257759) completed in 0m 0.833s
#   loss: 3.7605 corr: 46 (2191232/2257759) completed in 0m 0.912s
#   loss: 3.9581 corr: 54 (2191360/2257759) completed in 0m 0.917s
#   loss: 3.5816 corr: 54 (2191488/2257759) completed in 0m 0.819s
#   loss: 3.3983 corr: 48 (2191616/2257759) completed in 0m 0.827s
#   loss: 4.4169 corr: 42 (2191744/2257759) completed in 0m 0.845s
#   loss: 4.3233 corr: 46 (2191872/2257759) completed in 0m 0.876s
#   loss: 3.7391 corr: 45 (2192000/2257759) completed in 0m 0.865s
#   loss: 4.7542 corr: 37 (2192128/2257759) completed in 0m 0.874s
#   loss: 3.8753 corr: 51 (2192256/2257759) completed in 0m 0.839s
#   loss: 3.2599 corr: 47 (2192384/2257759) completed in 0m 0.908s
#   loss: 3.8394 corr: 44 (2192512/2257759) completed in 0m 0.868s
#   loss: 3.4624 corr: 49 (2192640/2257759) completed in 0m 0.840s
#   loss: 3.9393 corr: 46 (2192768/2257759) completed in 0m 0.863s
#   loss: 3.9287 corr: 49 (2192896/2257759) completed in 0m 0.874s
#   loss: 4.1426 corr: 47 (2193024/2257759) completed in 0m 0.866s
#   loss: 3.9734 corr: 44 (2193152/2257759) completed in 0m 0.914s
#   loss: 3.5868 corr: 46 (2193280/2257759) completed in 0m 0.881s
#   loss: 4.1246 corr: 45 (2193408/2257759) completed in 0m 0.852s
#   loss: 3.7635 corr: 49 (2193536/2257759) completed in 0m 0.884s
#   loss: 3.6403 corr: 48 (2193664/2257759) completed in 0m 0.883s
#   loss: 4.3787 corr: 48 (2193792/2257759) completed in 0m 0.958s
#   loss: 3.1915 corr: 57 (2193920/2257759) completed in 0m 0.842s
#   loss: 3.8382 corr: 44 (2194048/2257759) completed in 0m 0.830s
#   loss: 3.3866 corr: 49 (2194176/2257759) completed in 0m 0.846s
#   loss: 3.7089 corr: 58 (2194304/2257759) completed in 0m 0.897s
#   loss: 3.1083 corr: 50 (2194432/2257759) completed in 0m 0.886s
#   loss: 4.0389 corr: 42 (2194560/2257759) completed in 0m 0.865s
#   loss: 4.1498 corr: 40 (2194688/2257759) completed in 0m 0.863s
#   loss: 4.6306 corr: 35 (2194816/2257759) completed in 0m 0.890s
#   loss: 3.5817 corr: 41 (2194944/2257759) completed in 0m 0.856s
#   loss: 2.9664 corr: 51 (2195072/2257759) completed in 0m 0.871s
#   loss: 3.7931 corr: 48 (2195200/2257759) completed in 0m 0.849s
#   loss: 3.3164 corr: 49 (2195328/2257759) completed in 0m 0.864s
#   loss: 3.5097 corr: 48 (2195456/2257759) completed in 0m 0.842s
#   loss: 3.7494 corr: 47 (2195584/2257759) completed in 0m 0.919s
#   loss: 4.1069 corr: 38 (2195712/2257759) completed in 0m 0.853s
#   loss: 3.6844 corr: 50 (2195840/2257759) completed in 0m 0.863s
#   loss: 3.4862 corr: 55 (2195968/2257759) completed in 0m 0.863s
#   loss: 3.6239 corr: 50 (2196096/2257759) completed in 0m 0.861s
#   loss: 3.6826 corr: 50 (2196224/2257759) completed in 0m 0.846s
#   loss: 3.7450 corr: 37 (2196352/2257759) completed in 0m 0.807s
#   loss: 3.4407 corr: 54 (2196480/2257759) completed in 0m 0.851s
#   loss: 3.0402 corr: 57 (2196608/2257759) completed in 0m 0.867s
#   loss: 3.5751 corr: 42 (2196736/2257759) completed in 0m 0.827s
#   loss: 4.1823 corr: 45 (2196864/2257759) completed in 0m 0.846s
#   loss: 3.6330 corr: 53 (2196992/2257759) completed in 0m 0.925s
#   loss: 3.6940 corr: 43 (2197120/2257759) completed in 0m 0.828s
#   loss: 3.8149 corr: 39 (2197248/2257759) completed in 0m 0.885s
#   loss: 3.7751 corr: 54 (2197376/2257759) completed in 0m 0.834s
#   loss: 3.8423 corr: 45 (2197504/2257759) completed in 0m 0.866s
#   loss: 3.5745 corr: 53 (2197632/2257759) completed in 0m 0.847s
#   loss: 3.1637 corr: 53 (2197760/2257759) completed in 0m 0.839s
#   loss: 3.4319 corr: 50 (2197888/2257759) completed in 0m 0.869s
#   loss: 3.5773 corr: 43 (2198016/2257759) completed in 0m 0.871s
#   loss: 3.3935 corr: 50 (2198144/2257759) completed in 0m 0.877s
#   loss: 2.7497 corr: 65 (2198272/2257759) completed in 0m 0.836s
#   loss: 3.3664 corr: 46 (2198400/2257759) completed in 0m 0.795s
#   loss: 3.3037 corr: 51 (2198528/2257759) completed in 0m 0.878s
#   loss: 3.6732 corr: 56 (2198656/2257759) completed in 0m 0.862s
#   loss: 3.6276 corr: 50 (2198784/2257759) completed in 0m 0.848s
#   loss: 3.4019 corr: 50 (2198912/2257759) completed in 0m 0.827s
#   loss: 4.0754 corr: 50 (2199040/2257759) completed in 0m 0.889s
#   loss: 3.2905 corr: 54 (2199168/2257759) completed in 0m 0.837s
#   loss: 3.6333 corr: 47 (2199296/2257759) completed in 0m 0.877s
#   loss: 3.4483 corr: 48 (2199424/2257759) completed in 0m 0.870s
#   loss: 3.6972 corr: 40 (2199552/2257759) completed in 0m 0.847s
#   loss: 3.5342 corr: 50 (2199680/2257759) completed in 0m 0.920s
#   loss: 3.8765 corr: 48 (2199808/2257759) completed in 0m 0.989s
#   loss: 3.8765 corr: 48 (2199936/2257759) completed in 0m 0.882s
#   loss: 3.7445 corr: 50 (2200064/2257759) completed in 0m 0.888s
#   loss: 3.8900 corr: 37 (2200192/2257759) completed in 0m 0.838s
#   loss: 3.5381 corr: 41 (2200320/2257759) completed in 0m 0.859s
#   loss: 3.9159 corr: 47 (2200448/2257759) completed in 0m 0.847s
#   loss: 3.6560 corr: 52 (2200576/2257759) completed in 0m 0.870s
#   loss: 3.8353 corr: 40 (2200704/2257759) completed in 0m 0.816s
#   loss: 3.7390 corr: 42 (2200832/2257759) completed in 0m 0.858s
#   loss: 4.0102 corr: 48 (2200960/2257759) completed in 0m 0.816s
#   loss: 3.5571 corr: 42 (2201088/2257759) completed in 0m 0.836s
#   loss: 3.6206 corr: 42 (2201216/2257759) completed in 0m 0.880s
#   loss: 4.2686 corr: 41 (2201344/2257759) completed in 0m 0.877s
#   loss: 3.7357 corr: 48 (2201472/2257759) completed in 0m 0.900s
#   loss: 4.0834 corr: 46 (2201600/2257759) completed in 0m 0.829s
#   loss: 4.2996 corr: 42 (2201728/2257759) completed in 0m 0.872s
#   loss: 4.3616 corr: 47 (2201856/2257759) completed in 0m 0.862s
#   loss: 4.6614 corr: 42 (2201984/2257759) completed in 0m 0.843s
#   loss: 3.0703 corr: 57 (2202112/2257759) completed in 0m 0.875s
#   loss: 3.2562 corr: 54 (2202240/2257759) completed in 0m 0.867s
#   loss: 3.5697 corr: 44 (2202368/2257759) completed in 0m 0.929s
#   loss: 3.4514 corr: 49 (2202496/2257759) completed in 0m 0.858s
#   loss: 3.8464 corr: 44 (2202624/2257759) completed in 0m 0.878s
#   loss: 2.9971 corr: 60 (2202752/2257759) completed in 0m 0.897s
#   loss: 4.5243 corr: 38 (2202880/2257759) completed in 0m 0.854s
#   loss: 3.7299 corr: 39 (2203008/2257759) completed in 0m 0.917s
#   loss: 4.7006 corr: 41 (2203136/2257759) completed in 0m 0.874s
#   loss: 3.9070 corr: 50 (2203264/2257759) completed in 0m 0.866s
#   loss: 3.9881 corr: 48 (2203392/2257759) completed in 0m 0.871s
#   loss: 3.2976 corr: 47 (2203520/2257759) completed in 0m 0.865s
#   loss: 3.9659 corr: 49 (2203648/2257759) completed in 0m 0.879s
#   loss: 3.9058 corr: 39 (2203776/2257759) completed in 0m 0.820s
#   loss: 4.0314 corr: 46 (2203904/2257759) completed in 0m 0.925s
#   loss: 3.5972 corr: 53 (2204032/2257759) completed in 0m 0.780s
#   loss: 3.7491 corr: 53 (2204160/2257759) completed in 0m 0.831s
#   loss: 3.4770 corr: 55 (2204288/2257759) completed in 0m 0.792s
#   loss: 3.5942 corr: 50 (2204416/2257759) completed in 0m 0.892s
#   loss: 3.2887 corr: 49 (2204544/2257759) completed in 0m 0.871s
#   loss: 3.6173 corr: 57 (2204672/2257759) completed in 0m 0.922s
#   loss: 3.8946 corr: 46 (2204800/2257759) completed in 0m 1.144s
#   loss: 3.5232 corr: 49 (2204928/2257759) completed in 0m 0.872s
#   loss: 3.8150 corr: 42 (2205056/2257759) completed in 0m 0.845s
#   loss: 4.2087 corr: 35 (2205184/2257759) completed in 0m 0.891s
#   loss: 3.9626 corr: 44 (2205312/2257759) completed in 0m 0.857s
#   loss: 3.0869 corr: 48 (2205440/2257759) completed in 0m 0.833s
#   loss: 3.7772 corr: 39 (2205568/2257759) completed in 0m 0.926s
#   loss: 3.9017 corr: 39 (2205696/2257759) completed in 0m 0.836s
#   loss: 3.8028 corr: 46 (2205824/2257759) completed in 0m 0.865s
#   loss: 3.5233 corr: 54 (2205952/2257759) completed in 0m 0.850s
#   loss: 3.5973 corr: 51 (2206080/2257759) completed in 0m 0.848s
#   loss: 3.8978 corr: 54 (2206208/2257759) completed in 0m 0.885s
#   loss: 3.6457 corr: 43 (2206336/2257759) completed in 0m 0.796s
#   loss: 3.6817 corr: 45 (2206464/2257759) completed in 0m 0.904s
#   loss: 3.5694 corr: 44 (2206592/2257759) completed in 0m 0.868s
#   loss: 3.8649 corr: 46 (2206720/2257759) completed in 0m 0.864s
#   loss: 3.6970 corr: 54 (2206848/2257759) completed in 0m 0.891s
#   loss: 3.2289 corr: 64 (2206976/2257759) completed in 0m 0.867s
#   loss: 3.6448 corr: 45 (2207104/2257759) completed in 0m 0.847s
#   loss: 3.5042 corr: 50 (2207232/2257759) completed in 0m 0.908s
#   loss: 3.5119 corr: 48 (2207360/2257759) completed in 0m 0.916s
#   loss: 3.7578 corr: 53 (2207488/2257759) completed in 0m 0.859s
#   loss: 3.2465 corr: 56 (2207616/2257759) completed in 0m 0.876s
#   loss: 3.9120 corr: 51 (2207744/2257759) completed in 0m 0.849s
#   loss: 4.0247 corr: 48 (2207872/2257759) completed in 0m 0.869s
#   loss: 3.5894 corr: 45 (2208000/2257759) completed in 0m 0.869s
#   loss: 4.2854 corr: 38 (2208128/2257759) completed in 0m 0.896s
#   loss: 3.5604 corr: 48 (2208256/2257759) completed in 0m 0.858s
#   loss: 3.9121 corr: 42 (2208384/2257759) completed in 0m 0.830s
#   loss: 3.3153 corr: 48 (2208512/2257759) completed in 0m 0.857s
#   loss: 3.1907 corr: 55 (2208640/2257759) completed in 0m 0.860s
#   loss: 4.1010 corr: 46 (2208768/2257759) completed in 0m 0.838s
#   loss: 4.2063 corr: 45 (2208896/2257759) completed in 0m 0.842s
#   loss: 3.6830 corr: 46 (2209024/2257759) completed in 0m 0.875s
#   loss: 3.8395 corr: 48 (2209152/2257759) completed in 0m 0.883s
#   loss: 4.3332 corr: 35 (2209280/2257759) completed in 0m 0.896s
#   loss: 3.9044 corr: 48 (2209408/2257759) completed in 0m 0.844s
#   loss: 3.8759 corr: 46 (2209536/2257759) completed in 0m 0.839s
#   loss: 3.9994 corr: 50 (2209664/2257759) completed in 0m 0.867s
#   loss: 3.4849 corr: 47 (2209792/2257759) completed in 0m 0.889s
#   loss: 3.3307 corr: 58 (2209920/2257759) completed in 0m 0.843s
#   loss: 3.7597 corr: 50 (2210048/2257759) completed in 0m 0.908s
#   loss: 3.3157 corr: 46 (2210176/2257759) completed in 0m 0.824s
#   loss: 3.6318 corr: 54 (2210304/2257759) completed in 0m 0.838s
#   loss: 3.6551 corr: 45 (2210432/2257759) completed in 0m 0.855s
#   loss: 3.7899 corr: 44 (2210560/2257759) completed in 0m 0.993s
#   loss: 3.6462 corr: 51 (2210688/2257759) completed in 0m 0.924s
#   loss: 4.5853 corr: 44 (2210816/2257759) completed in 0m 0.876s
#   loss: 3.3255 corr: 51 (2210944/2257759) completed in 0m 0.842s
#   loss: 3.6530 corr: 48 (2211072/2257759) completed in 0m 0.858s
#   loss: 3.1287 corr: 53 (2211200/2257759) completed in 0m 0.833s
#   loss: 3.8147 corr: 48 (2211328/2257759) completed in 0m 0.849s
#   loss: 4.0915 corr: 39 (2211456/2257759) completed in 0m 0.942s
#   loss: 3.3410 corr: 52 (2211584/2257759) completed in 0m 0.850s
#   loss: 4.1424 corr: 44 (2211712/2257759) completed in 0m 0.874s
#   loss: 3.7510 corr: 40 (2211840/2257759) completed in 0m 0.867s
#   loss: 3.7635 corr: 46 (2211968/2257759) completed in 0m 0.871s
#   loss: 4.6954 corr: 40 (2212096/2257759) completed in 0m 0.847s
#   loss: 3.6040 corr: 49 (2212224/2257759) completed in 0m 0.775s
#   loss: 3.3586 corr: 47 (2212352/2257759) completed in 0m 0.835s
#   loss: 3.6239 corr: 42 (2212480/2257759) completed in 0m 0.833s
#   loss: 3.5096 corr: 50 (2212608/2257759) completed in 0m 0.865s
#   loss: 3.7528 corr: 46 (2212736/2257759) completed in 0m 0.847s
#   loss: 3.5849 corr: 51 (2212864/2257759) completed in 0m 0.825s
#   loss: 3.8978 corr: 51 (2212992/2257759) completed in 0m 0.846s
#   loss: 3.3278 corr: 51 (2213120/2257759) completed in 0m 0.897s
#   loss: 3.3356 corr: 49 (2213248/2257759) completed in 0m 0.807s
#   loss: 3.6131 corr: 45 (2213376/2257759) completed in 0m 0.910s
#   loss: 3.5732 corr: 48 (2213504/2257759) completed in 0m 0.843s
#   loss: 3.9568 corr: 46 (2213632/2257759) completed in 0m 0.860s
#   loss: 4.1034 corr: 47 (2213760/2257759) completed in 0m 0.911s
#   loss: 3.8218 corr: 41 (2213888/2257759) completed in 0m 0.829s
#   loss: 3.6391 corr: 44 (2214016/2257759) completed in 0m 0.908s
#   loss: 3.1586 corr: 47 (2214144/2257759) completed in 0m 0.830s
#   loss: 3.9973 corr: 52 (2214272/2257759) completed in 0m 0.896s
#   loss: 3.8554 corr: 46 (2214400/2257759) completed in 0m 0.844s
#   loss: 4.2830 corr: 45 (2214528/2257759) completed in 0m 0.836s
#   loss: 3.4562 corr: 48 (2214656/2257759) completed in 0m 0.850s
#   loss: 3.7993 corr: 38 (2214784/2257759) completed in 0m 0.871s
#   loss: 3.7351 corr: 43 (2214912/2257759) completed in 0m 0.830s
#   loss: 3.4255 corr: 46 (2215040/2257759) completed in 0m 0.792s
#   loss: 3.6096 corr: 53 (2215168/2257759) completed in 0m 0.864s
#   loss: 3.5983 corr: 47 (2215296/2257759) completed in 0m 0.812s
#   loss: 4.0479 corr: 40 (2215424/2257759) completed in 0m 0.894s
#   loss: 3.3524 corr: 49 (2215552/2257759) completed in 0m 0.842s
#   loss: 3.8048 corr: 42 (2215680/2257759) completed in 0m 0.935s
#   loss: 4.1421 corr: 46 (2215808/2257759) completed in 0m 0.934s
#   loss: 3.5908 corr: 54 (2215936/2257759) completed in 0m 0.792s
#   loss: 3.7002 corr: 37 (2216064/2257759) completed in 0m 0.819s
#   loss: 3.5745 corr: 50 (2216192/2257759) completed in 0m 0.835s
#   loss: 3.9748 corr: 46 (2216320/2257759) completed in 0m 0.851s
#   loss: 3.3654 corr: 54 (2216448/2257759) completed in 0m 0.835s
#   loss: 3.4624 corr: 51 (2216576/2257759) completed in 0m 0.877s
#   loss: 4.1960 corr: 44 (2216704/2257759) completed in 0m 0.841s
#   loss: 3.5695 corr: 46 (2216832/2257759) completed in 0m 0.795s
#   loss: 4.0559 corr: 51 (2216960/2257759) completed in 0m 0.836s
#   loss: 3.2829 corr: 53 (2217088/2257759) completed in 0m 0.862s
#   loss: 3.8894 corr: 38 (2217216/2257759) completed in 0m 0.857s
#   loss: 3.4795 corr: 47 (2217344/2257759) completed in 0m 0.823s
#   loss: 3.7653 corr: 40 (2217472/2257759) completed in 0m 0.835s
#   loss: 3.9251 corr: 42 (2217600/2257759) completed in 0m 0.888s
#   loss: 3.6268 corr: 48 (2217728/2257759) completed in 0m 0.890s
#   loss: 4.0151 corr: 45 (2217856/2257759) completed in 0m 0.846s
#   loss: 3.9012 corr: 43 (2217984/2257759) completed in 0m 0.814s
#   loss: 4.0445 corr: 45 (2218112/2257759) completed in 0m 0.811s
#   loss: 3.4142 corr: 45 (2218240/2257759) completed in 0m 0.915s
#   loss: 3.5515 corr: 54 (2218368/2257759) completed in 0m 0.905s
#   loss: 3.8561 corr: 51 (2218496/2257759) completed in 0m 0.877s
#   loss: 4.0406 corr: 34 (2218624/2257759) completed in 0m 0.831s
#   loss: 4.0266 corr: 49 (2218752/2257759) completed in 0m 0.850s
#   loss: 3.7762 corr: 51 (2218880/2257759) completed in 0m 0.825s
#   loss: 3.3769 corr: 50 (2219008/2257759) completed in 0m 0.834s
#   loss: 3.9003 corr: 45 (2219136/2257759) completed in 0m 0.990s
#   loss: 3.2983 corr: 51 (2219264/2257759) completed in 0m 0.820s
#   loss: 3.9788 corr: 48 (2219392/2257759) completed in 0m 0.816s
#   loss: 3.5650 corr: 49 (2219520/2257759) completed in 0m 0.845s
#   loss: 3.4349 corr: 49 (2219648/2257759) completed in 0m 0.847s
#   loss: 4.1634 corr: 42 (2219776/2257759) completed in 0m 0.857s
#   loss: 3.5029 corr: 51 (2219904/2257759) completed in 0m 0.932s
#   loss: 3.3678 corr: 61 (2220032/2257759) completed in 0m 0.847s
#   loss: 3.5281 corr: 42 (2220160/2257759) completed in 0m 0.870s
#   loss: 3.7680 corr: 37 (2220288/2257759) completed in 0m 0.878s
#   loss: 3.3605 corr: 49 (2220416/2257759) completed in 0m 0.849s
#   loss: 3.7199 corr: 49 (2220544/2257759) completed in 0m 0.842s
#   loss: 3.9474 corr: 44 (2220672/2257759) completed in 0m 0.817s
# /kaggle/working/ResNet50_run-01.pth
# Loss: 6.3501 Acc: 0.1549
#
# Loss: 6.3501 Acc: 0.1549
# Training complete in 481m 7.257s

# %% [markdown]
# ## Inference

# %%
model.eval()
model.to(DEVICE)

predictions = np.zeros((len(test_dataset)))

for i,images in tqdm.tqdm(enumerate(test_loader)):
    images = images.to(DEVICE)
    with torch.no_grad():
        y_predictions = model(images)

    predictions[i*BATCH_EVAL:(i+1)*BATCH_EVAL] = y_predictions.to(DEVICE).cpu().numpy().argmax(1)
# Out:
# 1899it [49:00,  1.55s/it]

# %% [markdown]
# ## Submit

# %%
test_df["preds"] = predictions.astype(int)
submission = sample_submission.merge(
    test_df.rename(columns = {"id":"Id"})[["Id","preds"]],on="Id"
).drop(columns="Predicted")
submission["Predicted"] = submission["preds"].map(class_map)
submission = submission.drop(columns="preds")
submission.to_csv("submission.csv",index=False)
submission.head()
# Out:
#    Id  Predicted
# 0   0      22633
# 1   1      49681
# 2   2      35602
# 3   3      38896
# 4   4      25670
