# %% [markdown]
# # Herbarium 2021 - Half-Earth Challenge - FGVC8 - ResNet
#
# The main goal of this work is to identify plant species of the Americas, Oceania, and the Pacific from herbarium specimens. The dataset that is used in this work - _The Herbarium 2021: Half-Earth Challenge_ - includes more than 2.5M images representing nearly 65.000 species from the Americas and Oceania. These images have been aligned to a standardized plant list ([LCVP v1.0.2](https://www.nature.com/articles/s41597-020-00702-z)).
#
# The model used in this notebook for classifying the images is ResNet ([arXiv:1512.03385](https://arxiv.org/abs/1512.03385)). ResNet makes it possible to train up to hundreds or even thousands of layers and still achieves compelling performance. Taking advantage of its powerful representational ability, the performance of many computer vision applications other than image classification have been bosted. As a classification model, it is considered to be a state-of-the-art method.

# %% [markdown]
# ## Setup
#
# ### Load libraries

# %%
# Math and Image
import numpy as np               # Math
import matplotlib.pyplot as plt  # Plot
import cv2                       # OpenCV
import PIL                       # Data Augmentation
import albumentations            # Data Augmentation
from albumentations.pytorch import ToTensorV2
# Operating System
import os
import time
import copy
# Utilities
import pandas as pd  # Handling CSV files
import random
import json
import tqdm          # Testing
import sklearn       # label encoding and metrics
from sklearn import preprocessing
# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
# TensorFlow
import tensorflow as tf

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets
# preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved
# outside of the current session will list all files under the input directory

print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.7.0
# Torchvision Version:  0.8.1

# %% [markdown]
# ### PC Configuration

# %%
# CPU Details - Number & Model
# !lscpu | grep "CPU(s):"
# !lscpu | grep Hz
# Total Memory
# !cat /proc/meminfo | grep MemTotal
# CUDA Check
print("Is CUDA Available?",
      torch.cuda.is_available())
if torch.cuda.is_available() == True: 
    print("Current CUDA device:",
        torch.cuda.get_device_name(0))

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: ",DEVICE)
# Out:
# CPU(s):              2
# NUMA node0 CPU(s):   0,1
# Model name:          Intel(R) Xeon(R) CPU @ 2.00GHz
# CPU MHz:             2000.158
# MemTotal:       16402016 kB
# Is CUDA Available? True
# Current CUDA device: Tesla P100-PCIE-16GB
# Device:  cuda

# %% [markdown]
# ### Ramdom seed
#
# The goal is to fix the random seed. For making the environment statically, fixing the random seed is needed. Also, it is essential to reproduce the experimental results.

# %%
def seed_fix(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_fix()
print("Seed fixed")
# Out:
# Seed fixed

# %% [markdown]
# ### Configuration

# %%
ROOT_DATA   = "/kaggle/input/herbarium-2021-fgvc8/"
DATA_TRAIN  = ROOT_DATA + "train/"
DATA_TEST   = ROOT_DATA + "test/"
ROOT_OUTPUT = "/kaggle/working/"
META        = "metadata.json"
BATCH_SIZE  = 128    # number of training examples utilized in one iteration
BATCH_EVAL  = 128
SHUFFLE     = True
EPOCHS      = 1
LEARN_RATE  = 4e-4
IMG_HEIGHT  = 224
IMG_WIDTH   = 224
NUM_CLASSES = None   # define below
NUM_WORKERS = 4
PRE_TRAINED = False

PATH_SAVE_MODEL = "/kaggle/working/ResNet50_run-03.pth"

ESTIMATED_MAX_TRAINING_TIME = 480 # hours (8h * 60 = 480min, leaving 1h to the test time)

print(ROOT_DATA)
# Out:
# /kaggle/input/herbarium-2021-fgvc8/

# %% [markdown]
# ## Create dataset

# %% [markdown]
# ### Generic information

# %%
# Training dataset
with open(os.path.join(DATA_TRAIN,META),"r",encoding="ISO-8859-1") as file:
    meta_train = json.load(file)
    print("Number of images (training dataset): ",
          len(meta_train["images"]),)
    for i in list(meta_train.keys()):
        print("  - sample and number of elements in category {}: ".format(i),
              len(list(meta_train[i])),)
        print("\t[0] ",
              list(meta_train[i])[0], end="\n")

NUM_CLASSES   = len(meta_train["categories"])
NUM_IMG_TRAIN = len(meta_train["annotations"])

# Validation dataset
with open(os.path.join(DATA_TEST,META),"r",encoding="ISO-8859-1") as file:
    meta_test = json.load(file)
    print("\nNumber of images (training dataset): ",
          len(meta_test["images"]),)
    for i in list(meta_test.keys()):
        print("  - sample and number of elements in category {}: ".format(i),
              len(list(meta_test[i])),)
        print("\t[0] ",
              list(meta_test[i])[0], end="\n")

NUM_IMG_TEST  = len(meta_test["images"]) 

# Print variables
print("\n\n"
      "Number of images for training: ",NUM_IMG_TRAIN)
print("Number of images for testing : ",NUM_IMG_TEST)
print("Number of classes            : ",NUM_CLASSES)
# Out:
# Number of images (training dataset):  2257759
#   - sample and number of elements in category annotations:  2257759
# 	[0]  {'category_id': 60492, 'id': 1814367, 'image_id': 1814367, 'institution_id': 0}
#   - sample and number of elements in category categories:  64500
# 	[0]  {'family': 'Orchidaceae', 'order': 'Asparagales', 'name': 'Aa calceata (Rchb.f.) Schltr.', 'id': 0}
#   - sample and number of elements in category images:  2257759
# 	[0]  {'file_name': 'images/604/92/1814367.jpg', 'height': 1000, 'id': 1814367, 'license': 0, 'width': 678}
#   - sample and number of elements in category info:  6
# 	[0]  contributor
#   - sample and number of elements in category licenses:  3
# 	[0]  {'id': 0, 'name': 'Public Domain Dedication', 'url': 'http://creativecommons.org/publicdomain/zero/1.0/'}
#   - sample and number of elements in category institutions:  5
# 	[0]  {'id': 0, 'name': 'New York Botanical Garden'}
#
# Number of images (training dataset):  243020
#   - sample and number of elements in category images:  243020
# 	[0]  {'file_name': 'images/000/0.jpg', 'height': 1000, 'id': 0, 'license': 0, 'width': 680}
#   - sample and number of elements in category info:  6
# 	[0]  contributor
#   - sample and number of elements in category licenses:  3
# 	[0]  {'id': 0, 'name': 'Public Domain Dedication', 'url': 'http://creativecommons.org/publicdomain/zero/1.0/'}
#
#
# Number of images for training:  2257759
# Number of images for testing :  243020
# Number of classes            :  64500

# %% [markdown]
# ### Process training and evaluation metadata
#
# Merge training images and annotations as a dataframe. The database-based joint operation merge is performed on the ids "image_id" (from images dataframe) and "id" (from annotations dataframe).
#
# The problem with the validation data is that the `.json` does not provide the labels to check if the model is classifying correctly or not the validation images.

# %%
# Process metadata json for training images into a DataFrame
train_img = pd.DataFrame(meta_train["images"])
train_ann = pd.DataFrame(meta_train["annotations"]).drop(columns="image_id")
train_df  = train_img.merge(train_ann,on="id") # Performs a database-style joint

# Check number of classes
print("Number of classes (expected): ",NUM_CLASSES)
print("Number of classes (computed): ",
      train_df["category_id"].max() - train_df["category_id"].min()+1)
print("\nShape training dataframe    :",train_df.shape)

# Process metadata json for test images into a DataFrame
test_df = pd.DataFrame(meta_test["images"])
# Out:
# Number of classes (expected):  64500
# Number of classes (computed):  64500
#
# Shape training dataframe    : (2257759, 7)

# %%
# Print the first 5 elements of the tables
train_df.head(n=5)
# Out:
#                    file_name  height       id  license  width  category_id  \
# 0  images/604/92/1814367.jpg    1000  1814367        0    678        60492
# 1  images/108/24/1308257.jpg    1000  1308257        0    666        10824
# 2  images/330/76/1270453.jpg    1000  1270453        0    739        33076
# 3  images/247/99/1123834.jpg    1000  1123834        0    672        24799
# 4  images/170/18/1042410.jpg    1000  1042410        0    675        17018
#
#    institution_id
# 0               0
# 1               0
# 2               3
# 3               0
# 4               0

# %%
# Print the first 5 elements of the tables
test_df.head(n=5)
# Out:
#           file_name  height  id  license  width
# 0  images/000/0.jpg    1000   0        0    680
# 1  images/000/1.jpg    1000   1        0    681
# 2  images/000/2.jpg    1000   2        0    676
# 3  images/000/3.jpg    1000   3        0    666
# 4  images/000/4.jpg    1000   4        0    676

# %% [markdown]
# ### Checkout samples

# %%
im = PIL.Image.open(DATA_TRAIN + train_df.file_name[0])
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=678x1000 at 0x7F6B75B513D0>

# %%
size_of_img = (36,36)
fig=plt.figure(figsize=(80,80))
for i in range(25):
    ax=fig.add_subplot(5,5,i+1)
    img = cv2.imread(DATA_TRAIN + meta_train["images"][i]["file_name"])
    img = cv2.resize(img,size_of_img)
    ax.imshow(img)

plt.show()

# %% [markdown]
# ## Prepare Submission

# %%
sample_submission = pd.read_csv(ROOT_DATA + "sample_submission.csv")
sample_submission.head(n=5)
# Out:
#    Id  Predicted
# 0   0          0
# 1   1          0
# 2   2          0
# 3   3          0
# 4   4          0

# %% [markdown]
# ## Label Encoder

# %%
# Fit the label encoder instance
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(train_df["category_id"])

# Transform labels to normalized encoding
train_df["category_id_le"] = label_encoder.transform(train_df["category_id"])
class_map = dict(sorted(train_df[["category_id_le","category_id"]].values.tolist()))

print("Labels converted to normalized encoding")
# Out:
# Labels converted to normalized encoding

# %% [markdown]
# ### Dataloaders

# %%
class TrainDataset(torch.utils.data.Dataset):
    def __init__(self, df, labels, transform=None):
        self.df = df
        self.labels = labels
        self.transform = transform
        
    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.df["file_name"].values[idx]
        file_path = DATA_TRAIN + file_name
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        label = self.labels.values[idx]
        
        if self.transform:
            img = self.transform(image=img)["image"]
        
        return img, label

# %%
class TestDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform
        
    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.df["file_name"].values[idx]
        file_path = DATA_TEST + file_name
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        if self.transform:
            img = self.transform(image=img)["image"]
        
        return img

# %% [markdown]
# ### Image Augmentation

# %%
def get_transforms(*, data: str):
    assert data in ("train","test")
    
    if data == "train":
        return albumentations.Compose([
            albumentations.Resize(IMG_HEIGHT,IMG_WIDTH),
            albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

    elif data == "test":
        return albumentations.Compose([
            albumentations.Resize(IMG_HEIGHT,IMG_WIDTH),
            albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Training Dataset

# %%
train_df.head(n=5)
# Out:
#                    file_name  height       id  license  width  category_id  \
# 0  images/604/92/1814367.jpg    1000  1814367        0    678        60492
# 1  images/108/24/1308257.jpg    1000  1308257        0    666        10824
# 2  images/330/76/1270453.jpg    1000  1270453        0    739        33076
# 3  images/247/99/1123834.jpg    1000  1123834        0    672        24799
# 4  images/170/18/1042410.jpg    1000  1042410        0    675        17018
#
#    institution_id  category_id_le
# 0               0           60492
# 1               0           10824
# 2               3           33076
# 3               0           24799
# 4               0           17018

# %%
train_dataset = TrainDataset(
    train_df,train_df["category_id_le"],
    transform=get_transforms(data="train"))
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,shuffle=SHUFFLE,num_workers=NUM_WORKERS)
print("Train data loader created")
# Out:
# Train data loader created

# %% [markdown]
# ### Test Dataset

# %%
test_df.head(n=5)
# Out:
#           file_name  height  id  license  width
# 0  images/000/0.jpg    1000   0        0    680
# 1  images/000/1.jpg    1000   1        0    681
# 2  images/000/2.jpg    1000   2        0    676
# 3  images/000/3.jpg    1000   3        0    666
# 4  images/000/4.jpg    1000   4        0    676

# %%
test_dataset = TestDataset(
    test_df,
    transform=get_transforms(data="test"))
test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=BATCH_EVAL,shuffle=False,num_workers=NUM_WORKERS)
print("Test data loader created")
# Out:
# Test data loader created

# %% [markdown]
# ## Model

# %%
def train_model(model,dataloader,criterion,optimizer,num_epochs=1):
    since = time.time()
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        model.train()
        
        running_loss = 0.0
        running_corrects = 0
        
        #for inputs, labels in tqdm.tqdm(enumerate(dataloader)):
        i = 0
        len_dataset = len(dataloader.dataset)
        for inputs, labels in dataloader:
            since_tmp = time.time()
            
            inputs = inputs.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                loss = criterion(outputs,labels)
                
                _,preds = torch.max(outputs,1)
                
                loss.backward()
                optimizer.step()
              
            loss_tmp = loss.item()
            pred_tmp = torch.sum(preds == labels.data)
            
            running_loss += loss_tmp * inputs.size(0)
            running_corrects += pred_tmp
            
            time_elapsed_tmp = time.time() - since_tmp
            
            print('  loss: {:.04f} corr: {:d} ({:d}/{:d}) completed in {:.0f}m {:.03f}s'.format(
                loss_tmp, pred_tmp,(i+1)*BATCH_SIZE,len_dataset,
                time_elapsed_tmp // 60, time_elapsed_tmp % 60))
            
            if ((time.time() - since) // 60 > ESTIMATED_MAX_TRAINING_TIME):
                break;
            
            i += 1
            
        epoch_loss = running_loss / len_dataset
        epoch_acc = running_corrects.double() / len_dataset
        
        torch.save(model.state_dict(),PATH_SAVE_MODEL)
        print(PATH_SAVE_MODEL)
        print('Loss: {:.04f} Acc: {:.04f}'.format(epoch_loss, epoch_acc))
        
        print()
            
        if ((time.time() - since) // 60 > ESTIMATED_MAX_TRAINING_TIME):
            break;
        
    time_elapsed = time.time() - since
    print('Loss: {:.04f} Acc: {:.04f}'.format(epoch_loss, epoch_acc))
    print('Training complete in {:.0f}m {:.03f}s'.format(time_elapsed // 60, time_elapsed % 60))
    
    #model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ### Construct model

# %%
model = torchvision.models.resnet50(pretrained=PRE_TRAINED)
model.avgpool = torch.nn.AdaptiveAvgPool2d(1)
model.fc = torch.nn.Linear(model.fc.in_features,NUM_CLASSES)

# %% [markdown]
# ### Use existent trained model

# %%
model.load_state_dict(torch.load("../input/herbarium-2021-rbs/ResNet50_run-02.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Train

# %%
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARN_RATE, amsgrad=False)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 'min', factor=0.75, patience=5, verbose=True, eps=1e-6)

criterion = torch.nn.CrossEntropyLoss()

# %%
model = train_model(model,train_loader,criterion,optimizer,EPOCHS)
# Out:
# Epoch 0/0
# ----------
#   loss: 2.3585 corr: 64 (128/2257759) completed in 0m 2.500s
#   loss: 1.8980 corr: 72 (256/2257759) completed in 0m 0.913s
#   loss: 1.7695 corr: 78 (384/2257759) completed in 0m 0.848s
#   loss: 2.1413 corr: 75 (512/2257759) completed in 0m 0.857s
#   loss: 1.5940 corr: 74 (640/2257759) completed in 0m 0.819s
#   loss: 1.6964 corr: 74 (768/2257759) completed in 0m 0.779s
#   loss: 1.7749 corr: 73 (896/2257759) completed in 0m 0.853s
#   loss: 1.7770 corr: 79 (1024/2257759) completed in 0m 0.826s
#   loss: 1.3736 corr: 86 (1152/2257759) completed in 0m 0.823s
#   loss: 1.6700 corr: 82 (1280/2257759) completed in 0m 0.872s
#   loss: 1.6836 corr: 82 (1408/2257759) completed in 0m 0.862s
#   loss: 1.6762 corr: 82 (1536/2257759) completed in 0m 0.810s
#   loss: 1.7157 corr: 77 (1664/2257759) completed in 0m 0.834s
#   loss: 1.6654 corr: 78 (1792/2257759) completed in 0m 0.831s
#   loss: 1.6753 corr: 76 (1920/2257759) completed in 0m 0.823s
#   loss: 1.2766 corr: 90 (2048/2257759) completed in 0m 0.843s
#   loss: 1.4457 corr: 85 (2176/2257759) completed in 0m 0.926s
#   loss: 1.6128 corr: 74 (2304/2257759) completed in 0m 1.008s
#   loss: 1.5081 corr: 78 (2432/2257759) completed in 0m 0.825s
#   loss: 1.5767 corr: 81 (2560/2257759) completed in 0m 0.821s
#   loss: 1.5761 corr: 81 (2688/2257759) completed in 0m 0.811s
#   loss: 1.5350 corr: 76 (2816/2257759) completed in 0m 0.780s
#   loss: 1.4335 corr: 82 (2944/2257759) completed in 0m 0.847s
#   loss: 1.7159 corr: 74 (3072/2257759) completed in 0m 0.795s
#   loss: 1.3716 corr: 83 (3200/2257759) completed in 0m 0.829s
#   loss: 1.5804 corr: 79 (3328/2257759) completed in 0m 0.836s
#   loss: 1.4721 corr: 89 (3456/2257759) completed in 0m 0.875s
#   loss: 1.6262 corr: 77 (3584/2257759) completed in 0m 0.844s
#   loss: 1.2389 corr: 84 (3712/2257759) completed in 0m 0.822s
#   loss: 1.8439 corr: 71 (3840/2257759) completed in 0m 0.840s
#   loss: 1.7418 corr: 74 (3968/2257759) completed in 0m 0.861s
#   loss: 1.5420 corr: 83 (4096/2257759) completed in 0m 0.793s
#   loss: 1.2552 corr: 91 (4224/2257759) completed in 0m 0.821s
#   loss: 1.6642 corr: 78 (4352/2257759) completed in 0m 0.813s
#   loss: 1.5390 corr: 75 (4480/2257759) completed in 0m 0.771s
#   loss: 1.3559 corr: 81 (4608/2257759) completed in 0m 0.833s
#   loss: 1.3760 corr: 86 (4736/2257759) completed in 0m 0.790s
#   loss: 1.4255 corr: 86 (4864/2257759) completed in 0m 0.797s
#   loss: 1.7344 corr: 75 (4992/2257759) completed in 0m 0.812s
#   loss: 1.4341 corr: 73 (5120/2257759) completed in 0m 0.798s
#   loss: 1.4396 corr: 89 (5248/2257759) completed in 0m 0.802s
#   loss: 1.3963 corr: 84 (5376/2257759) completed in 0m 0.825s
#   loss: 1.5708 corr: 78 (5504/2257759) completed in 0m 0.821s
#   loss: 1.4545 corr: 81 (5632/2257759) completed in 0m 0.849s
#   loss: 1.5628 corr: 82 (5760/2257759) completed in 0m 0.808s
#   loss: 1.7724 corr: 67 (5888/2257759) completed in 0m 0.847s
#   loss: 1.3000 corr: 87 (6016/2257759) completed in 0m 0.822s
#   loss: 1.1772 corr: 95 (6144/2257759) completed in 0m 0.830s
#   loss: 1.2911 corr: 87 (6272/2257759) completed in 0m 0.826s
#   loss: 1.3737 corr: 88 (6400/2257759) completed in 0m 0.812s
#   loss: 1.5030 corr: 79 (6528/2257759) completed in 0m 0.847s
#   loss: 1.6847 corr: 75 (6656/2257759) completed in 0m 0.835s
#   loss: 1.3746 corr: 78 (6784/2257759) completed in 0m 0.821s
#   loss: 1.5799 corr: 80 (6912/2257759) completed in 0m 0.850s
#   loss: 1.5464 corr: 78 (7040/2257759) completed in 0m 0.844s
#   loss: 1.7732 corr: 72 (7168/2257759) completed in 0m 0.839s
#   loss: 1.5618 corr: 75 (7296/2257759) completed in 0m 0.835s
#   loss: 1.5587 corr: 79 (7424/2257759) completed in 0m 0.792s
#   loss: 1.4691 corr: 82 (7552/2257759) completed in 0m 0.854s
#   loss: 1.8562 corr: 77 (7680/2257759) completed in 0m 0.807s
#   loss: 1.6322 corr: 70 (7808/2257759) completed in 0m 0.819s
#   loss: 1.4367 corr: 85 (7936/2257759) completed in 0m 0.808s
#   loss: 1.5564 corr: 80 (8064/2257759) completed in 0m 0.812s
#   loss: 1.2949 corr: 83 (8192/2257759) completed in 0m 0.904s
#   loss: 1.3604 corr: 86 (8320/2257759) completed in 0m 0.819s
#   loss: 1.6855 corr: 65 (8448/2257759) completed in 0m 0.808s
#   loss: 1.4815 corr: 82 (8576/2257759) completed in 0m 0.831s
#   loss: 1.5888 corr: 77 (8704/2257759) completed in 0m 0.824s
#   loss: 1.3075 corr: 75 (8832/2257759) completed in 0m 0.869s
#   loss: 1.3901 corr: 74 (8960/2257759) completed in 0m 0.938s
#   loss: 1.5344 corr: 78 (9088/2257759) completed in 0m 0.876s
#   loss: 1.3073 corr: 90 (9216/2257759) completed in 0m 0.799s
#   loss: 1.3961 corr: 79 (9344/2257759) completed in 0m 0.825s
#   loss: 1.1329 corr: 85 (9472/2257759) completed in 0m 0.812s
#   loss: 1.3483 corr: 81 (9600/2257759) completed in 0m 0.794s
#   loss: 1.3369 corr: 82 (9728/2257759) completed in 0m 0.803s
#   loss: 1.3088 corr: 80 (9856/2257759) completed in 0m 0.816s
#   loss: 1.2303 corr: 85 (9984/2257759) completed in 0m 0.868s
#   loss: 1.7714 corr: 73 (10112/2257759) completed in 0m 0.886s
#   loss: 1.3214 corr: 87 (10240/2257759) completed in 0m 0.805s
#   loss: 1.4342 corr: 83 (10368/2257759) completed in 0m 0.843s
#   loss: 1.3054 corr: 79 (10496/2257759) completed in 0m 0.828s
#   loss: 1.6887 corr: 69 (10624/2257759) completed in 0m 0.857s
#   loss: 1.1311 corr: 87 (10752/2257759) completed in 0m 0.821s
#   loss: 1.4624 corr: 79 (10880/2257759) completed in 0m 0.876s
#   loss: 1.3252 corr: 77 (11008/2257759) completed in 0m 0.897s
#   loss: 1.7581 corr: 79 (11136/2257759) completed in 0m 0.816s
#   loss: 1.5945 corr: 74 (11264/2257759) completed in 0m 0.821s
#   loss: 1.6368 corr: 74 (11392/2257759) completed in 0m 0.806s
#   loss: 1.3224 corr: 83 (11520/2257759) completed in 0m 0.796s
#   loss: 1.4503 corr: 78 (11648/2257759) completed in 0m 0.914s
#   loss: 1.5271 corr: 87 (11776/2257759) completed in 0m 0.881s
#   loss: 1.4219 corr: 84 (11904/2257759) completed in 0m 0.825s
#   loss: 1.5167 corr: 82 (12032/2257759) completed in 0m 0.810s
#   loss: 1.2345 corr: 85 (12160/2257759) completed in 0m 0.845s
#   loss: 1.3994 corr: 83 (12288/2257759) completed in 0m 0.876s
#   loss: 1.8041 corr: 73 (12416/2257759) completed in 0m 0.816s
#   loss: 1.1341 corr: 84 (12544/2257759) completed in 0m 0.837s
#   loss: 1.3692 corr: 80 (12672/2257759) completed in 0m 0.808s
#   loss: 1.4065 corr: 78 (12800/2257759) completed in 0m 0.813s
#   loss: 1.3610 corr: 82 (12928/2257759) completed in 0m 0.841s
#   loss: 1.7738 corr: 74 (13056/2257759) completed in 0m 0.823s
#   loss: 1.7334 corr: 73 (13184/2257759) completed in 0m 0.831s
#   loss: 1.4623 corr: 74 (13312/2257759) completed in 0m 0.808s
#   loss: 1.5172 corr: 78 (13440/2257759) completed in 0m 0.843s
#   loss: 1.8502 corr: 74 (13568/2257759) completed in 0m 0.844s
#   loss: 1.4897 corr: 86 (13696/2257759) completed in 0m 0.828s
#   loss: 1.5552 corr: 81 (13824/2257759) completed in 0m 0.839s
#   loss: 1.3878 corr: 82 (13952/2257759) completed in 0m 0.806s
#   loss: 1.5203 corr: 76 (14080/2257759) completed in 0m 0.795s
#   loss: 1.6189 corr: 70 (14208/2257759) completed in 0m 0.826s
#   loss: 1.3708 corr: 78 (14336/2257759) completed in 0m 0.812s
#   loss: 1.4920 corr: 78 (14464/2257759) completed in 0m 0.951s
#   loss: 1.7205 corr: 78 (14592/2257759) completed in 0m 0.821s
#   loss: 1.3363 corr: 87 (14720/2257759) completed in 0m 0.814s
#   loss: 1.7020 corr: 64 (14848/2257759) completed in 0m 0.835s
#   loss: 1.4736 corr: 75 (14976/2257759) completed in 0m 0.838s
#   loss: 1.2753 corr: 87 (15104/2257759) completed in 0m 0.833s
#   loss: 1.5494 corr: 75 (15232/2257759) completed in 0m 0.823s
#   loss: 1.2138 corr: 86 (15360/2257759) completed in 0m 0.820s
#   loss: 1.4715 corr: 74 (15488/2257759) completed in 0m 0.780s
#   loss: 1.3314 corr: 80 (15616/2257759) completed in 0m 0.836s
#   loss: 1.7492 corr: 70 (15744/2257759) completed in 0m 0.898s
#   loss: 1.5643 corr: 81 (15872/2257759) completed in 0m 0.878s
#   loss: 1.4464 corr: 86 (16000/2257759) completed in 0m 0.802s
#   loss: 1.3670 corr: 80 (16128/2257759) completed in 0m 0.836s
#   loss: 1.4713 corr: 80 (16256/2257759) completed in 0m 0.786s
#   loss: 1.5514 corr: 78 (16384/2257759) completed in 0m 0.848s
#   loss: 1.5015 corr: 82 (16512/2257759) completed in 0m 0.808s
#   loss: 1.5521 corr: 74 (16640/2257759) completed in 0m 0.910s
#   loss: 1.3664 corr: 77 (16768/2257759) completed in 0m 0.866s
#   loss: 1.5351 corr: 81 (16896/2257759) completed in 0m 0.819s
#   loss: 1.2711 corr: 83 (17024/2257759) completed in 0m 0.856s
#   loss: 1.4378 corr: 80 (17152/2257759) completed in 0m 0.803s
#   loss: 1.6189 corr: 75 (17280/2257759) completed in 0m 0.864s
#   loss: 1.4315 corr: 83 (17408/2257759) completed in 0m 0.898s
#   loss: 1.1655 corr: 88 (17536/2257759) completed in 0m 0.829s
#   loss: 1.4755 corr: 81 (17664/2257759) completed in 0m 0.833s
#   loss: 1.4930 corr: 86 (17792/2257759) completed in 0m 0.871s
#   loss: 1.6279 corr: 79 (17920/2257759) completed in 0m 0.836s
#   loss: 1.2599 corr: 82 (18048/2257759) completed in 0m 0.819s
#   loss: 1.6316 corr: 81 (18176/2257759) completed in 0m 0.804s
#   loss: 1.5821 corr: 75 (18304/2257759) completed in 0m 0.845s
#   loss: 1.3301 corr: 77 (18432/2257759) completed in 0m 0.814s
#   loss: 1.4646 corr: 81 (18560/2257759) completed in 0m 0.824s
#   loss: 1.3887 corr: 81 (18688/2257759) completed in 0m 0.833s
#   loss: 1.4320 corr: 82 (18816/2257759) completed in 0m 0.833s
#   loss: 1.6001 corr: 73 (18944/2257759) completed in 0m 0.817s
#   loss: 1.4824 corr: 75 (19072/2257759) completed in 0m 0.834s
#   loss: 1.3413 corr: 85 (19200/2257759) completed in 0m 0.821s
#   loss: 1.8319 corr: 65 (19328/2257759) completed in 0m 0.841s
#   loss: 1.3797 corr: 84 (19456/2257759) completed in 0m 0.829s
#   loss: 1.2677 corr: 80 (19584/2257759) completed in 0m 0.858s
#   loss: 1.1761 corr: 91 (19712/2257759) completed in 0m 0.862s
#   loss: 1.2929 corr: 81 (19840/2257759) completed in 0m 0.817s
#   loss: 1.5851 corr: 85 (19968/2257759) completed in 0m 0.822s
#   loss: 1.8229 corr: 73 (20096/2257759) completed in 0m 0.946s
#   loss: 1.4094 corr: 79 (20224/2257759) completed in 0m 0.806s
#   loss: 1.5836 corr: 75 (20352/2257759) completed in 0m 0.844s
#   loss: 1.1889 corr: 86 (20480/2257759) completed in 0m 0.797s
#   loss: 1.5097 corr: 76 (20608/2257759) completed in 0m 0.823s
#   loss: 1.6170 corr: 75 (20736/2257759) completed in 0m 0.794s
#   loss: 1.7256 corr: 81 (20864/2257759) completed in 0m 0.803s
#   loss: 1.4030 corr: 87 (20992/2257759) completed in 0m 0.815s
#   loss: 1.3455 corr: 88 (21120/2257759) completed in 0m 0.847s
#   loss: 1.5485 corr: 85 (21248/2257759) completed in 0m 0.846s
#   loss: 1.2284 corr: 86 (21376/2257759) completed in 0m 0.828s
#   loss: 1.7317 corr: 74 (21504/2257759) completed in 0m 0.878s
#   loss: 1.3884 corr: 77 (21632/2257759) completed in 0m 0.830s
#   loss: 1.3927 corr: 88 (21760/2257759) completed in 0m 0.815s
#   loss: 1.7256 corr: 74 (21888/2257759) completed in 0m 0.819s
#   loss: 1.5290 corr: 79 (22016/2257759) completed in 0m 0.773s
#   loss: 1.4987 corr: 80 (22144/2257759) completed in 0m 0.839s
#   loss: 1.4021 corr: 79 (22272/2257759) completed in 0m 0.829s
#   loss: 1.4834 corr: 81 (22400/2257759) completed in 0m 0.947s
#   loss: 1.8401 corr: 72 (22528/2257759) completed in 0m 0.906s
#   loss: 1.3986 corr: 75 (22656/2257759) completed in 0m 0.825s
#   loss: 1.7374 corr: 73 (22784/2257759) completed in 0m 0.834s
#   loss: 1.7389 corr: 76 (22912/2257759) completed in 0m 0.817s
#   loss: 1.6291 corr: 75 (23040/2257759) completed in 0m 0.857s
#   loss: 1.8582 corr: 73 (23168/2257759) completed in 0m 0.861s
#   loss: 1.5520 corr: 81 (23296/2257759) completed in 0m 0.873s
#   loss: 1.3551 corr: 81 (23424/2257759) completed in 0m 0.879s
#   loss: 1.4919 corr: 80 (23552/2257759) completed in 0m 0.843s
#   loss: 1.6164 corr: 78 (23680/2257759) completed in 0m 0.830s
#   loss: 1.6495 corr: 72 (23808/2257759) completed in 0m 0.818s
#   loss: 1.8034 corr: 72 (23936/2257759) completed in 0m 0.843s
#   loss: 1.7013 corr: 74 (24064/2257759) completed in 0m 0.816s
#   loss: 1.4888 corr: 78 (24192/2257759) completed in 0m 0.841s
#   loss: 1.5591 corr: 78 (24320/2257759) completed in 0m 0.877s
#   loss: 1.3767 corr: 82 (24448/2257759) completed in 0m 0.822s
#   loss: 1.5749 corr: 76 (24576/2257759) completed in 0m 0.825s
#   loss: 1.3971 corr: 77 (24704/2257759) completed in 0m 0.846s
#   loss: 1.7823 corr: 70 (24832/2257759) completed in 0m 0.817s
#   loss: 1.5949 corr: 74 (24960/2257759) completed in 0m 0.836s
#   loss: 1.5147 corr: 73 (25088/2257759) completed in 0m 0.801s
#   loss: 1.3549 corr: 79 (25216/2257759) completed in 0m 0.858s
#   loss: 1.5577 corr: 74 (25344/2257759) completed in 0m 0.813s
#   loss: 1.6269 corr: 73 (25472/2257759) completed in 0m 0.839s
#   loss: 1.6121 corr: 76 (25600/2257759) completed in 0m 0.808s
#   loss: 1.2262 corr: 86 (25728/2257759) completed in 0m 0.952s
#   loss: 1.4900 corr: 77 (25856/2257759) completed in 0m 1.000s
#   loss: 1.4494 corr: 79 (25984/2257759) completed in 0m 0.881s
#   loss: 1.5513 corr: 84 (26112/2257759) completed in 0m 0.848s
#   loss: 1.8818 corr: 74 (26240/2257759) completed in 0m 0.805s
#   loss: 1.3320 corr: 83 (26368/2257759) completed in 0m 0.837s
#   loss: 1.5169 corr: 83 (26496/2257759) completed in 0m 0.851s
#   loss: 1.9781 corr: 66 (26624/2257759) completed in 0m 0.840s
#   loss: 1.4675 corr: 85 (26752/2257759) completed in 0m 0.816s
#   loss: 1.4779 corr: 70 (26880/2257759) completed in 0m 0.821s
#   loss: 1.5171 corr: 80 (27008/2257759) completed in 0m 0.835s
#   loss: 1.5179 corr: 73 (27136/2257759) completed in 0m 0.869s
#   loss: 1.7546 corr: 77 (27264/2257759) completed in 0m 0.831s
#   loss: 1.7036 corr: 76 (27392/2257759) completed in 0m 0.812s
#   loss: 1.1701 corr: 93 (27520/2257759) completed in 0m 0.801s
#   loss: 1.6870 corr: 79 (27648/2257759) completed in 0m 0.853s
#   loss: 1.4778 corr: 73 (27776/2257759) completed in 0m 0.829s
#   loss: 1.6524 corr: 79 (27904/2257759) completed in 0m 0.796s
#   loss: 1.8439 corr: 76 (28032/2257759) completed in 0m 0.770s
#   loss: 1.4944 corr: 84 (28160/2257759) completed in 0m 0.850s
#   loss: 1.3477 corr: 83 (28288/2257759) completed in 0m 0.782s
#   loss: 1.7699 corr: 70 (28416/2257759) completed in 0m 0.806s
#   loss: 1.8330 corr: 76 (28544/2257759) completed in 0m 0.923s
#   loss: 1.4705 corr: 78 (28672/2257759) completed in 0m 0.980s
#   loss: 1.4814 corr: 83 (28800/2257759) completed in 0m 0.852s
#   loss: 1.2631 corr: 85 (28928/2257759) completed in 0m 0.848s
#   loss: 1.5411 corr: 72 (29056/2257759) completed in 0m 0.858s
#   loss: 1.6408 corr: 81 (29184/2257759) completed in 0m 0.828s
#   loss: 1.2393 corr: 88 (29312/2257759) completed in 0m 0.815s
#   loss: 1.7039 corr: 78 (29440/2257759) completed in 0m 0.833s
#   loss: 1.7194 corr: 71 (29568/2257759) completed in 0m 0.821s
#   loss: 1.4984 corr: 83 (29696/2257759) completed in 0m 0.829s
#   loss: 1.8007 corr: 65 (29824/2257759) completed in 0m 0.842s
#   loss: 1.5490 corr: 78 (29952/2257759) completed in 0m 0.825s
#   loss: 1.7037 corr: 77 (30080/2257759) completed in 0m 0.882s
#   loss: 1.2373 corr: 87 (30208/2257759) completed in 0m 0.854s
#   loss: 2.0182 corr: 68 (30336/2257759) completed in 0m 0.812s
#   loss: 1.3788 corr: 84 (30464/2257759) completed in 0m 0.825s
#   loss: 1.4888 corr: 76 (30592/2257759) completed in 0m 0.868s
#   loss: 1.5769 corr: 73 (30720/2257759) completed in 0m 0.830s
#   loss: 1.7371 corr: 74 (30848/2257759) completed in 0m 0.808s
#   loss: 1.5660 corr: 76 (30976/2257759) completed in 0m 0.893s
#   loss: 1.5097 corr: 77 (31104/2257759) completed in 0m 0.882s
#   loss: 1.5675 corr: 75 (31232/2257759) completed in 0m 0.807s
#   loss: 1.4140 corr: 83 (31360/2257759) completed in 0m 0.972s
#   loss: 1.6951 corr: 72 (31488/2257759) completed in 0m 0.790s
#   loss: 1.5230 corr: 79 (31616/2257759) completed in 0m 0.829s
#   loss: 1.9493 corr: 70 (31744/2257759) completed in 0m 0.858s
#   loss: 1.3190 corr: 88 (31872/2257759) completed in 0m 0.900s
#   loss: 1.4057 corr: 80 (32000/2257759) completed in 0m 0.865s
#   loss: 1.6656 corr: 78 (32128/2257759) completed in 0m 0.816s
#   loss: 1.4257 corr: 77 (32256/2257759) completed in 0m 0.778s
#   loss: 1.4332 corr: 87 (32384/2257759) completed in 0m 0.813s
#   loss: 1.2981 corr: 86 (32512/2257759) completed in 0m 0.842s
#   loss: 1.4970 corr: 76 (32640/2257759) completed in 0m 0.827s
#   loss: 1.4606 corr: 78 (32768/2257759) completed in 0m 0.837s
#   loss: 1.6871 corr: 77 (32896/2257759) completed in 0m 0.926s
#   loss: 1.6513 corr: 74 (33024/2257759) completed in 0m 0.824s
#   loss: 1.4923 corr: 81 (33152/2257759) completed in 0m 0.819s
#   loss: 1.4204 corr: 79 (33280/2257759) completed in 0m 0.860s
#   loss: 1.3494 corr: 85 (33408/2257759) completed in 0m 0.826s
#   loss: 1.8653 corr: 76 (33536/2257759) completed in 0m 0.820s
#   loss: 1.4910 corr: 80 (33664/2257759) completed in 0m 0.848s
#   loss: 1.3537 corr: 87 (33792/2257759) completed in 0m 0.862s
#   loss: 1.5257 corr: 84 (33920/2257759) completed in 0m 0.854s
#   loss: 1.5241 corr: 80 (34048/2257759) completed in 0m 0.882s
#   loss: 1.5419 corr: 82 (34176/2257759) completed in 0m 0.825s
#   loss: 1.6009 corr: 75 (34304/2257759) completed in 0m 0.809s
#   loss: 1.6957 corr: 75 (34432/2257759) completed in 0m 0.808s
#   loss: 1.7060 corr: 72 (34560/2257759) completed in 0m 0.768s
#   loss: 1.6650 corr: 76 (34688/2257759) completed in 0m 0.826s
#   loss: 1.3384 corr: 84 (34816/2257759) completed in 0m 0.859s
#   loss: 1.7938 corr: 71 (34944/2257759) completed in 0m 0.845s
#   loss: 1.7921 corr: 69 (35072/2257759) completed in 0m 0.820s
#   loss: 1.4808 corr: 82 (35200/2257759) completed in 0m 0.811s
#   loss: 1.8250 corr: 78 (35328/2257759) completed in 0m 0.781s
#   loss: 1.2247 corr: 82 (35456/2257759) completed in 0m 0.812s
#   loss: 1.7072 corr: 74 (35584/2257759) completed in 0m 0.832s
#   loss: 1.4439 corr: 80 (35712/2257759) completed in 0m 0.818s
#   loss: 1.3138 corr: 82 (35840/2257759) completed in 0m 0.859s
#   loss: 1.5190 corr: 77 (35968/2257759) completed in 0m 0.851s
#   loss: 1.6315 corr: 75 (36096/2257759) completed in 0m 0.802s
#   loss: 1.6701 corr: 77 (36224/2257759) completed in 0m 0.845s
#   loss: 1.7381 corr: 73 (36352/2257759) completed in 0m 0.827s
#   loss: 1.3600 corr: 83 (36480/2257759) completed in 0m 0.870s
#   loss: 1.3848 corr: 85 (36608/2257759) completed in 0m 0.832s
#   loss: 1.3672 corr: 82 (36736/2257759) completed in 0m 0.838s
#   loss: 1.3510 corr: 86 (36864/2257759) completed in 0m 0.783s
#   loss: 1.0466 corr: 90 (36992/2257759) completed in 0m 0.829s
#   loss: 1.3899 corr: 86 (37120/2257759) completed in 0m 0.833s
#   loss: 1.3937 corr: 87 (37248/2257759) completed in 0m 0.790s
#   loss: 1.5318 corr: 85 (37376/2257759) completed in 0m 0.811s
#   loss: 1.7244 corr: 76 (37504/2257759) completed in 0m 0.854s
#   loss: 1.4022 corr: 84 (37632/2257759) completed in 0m 0.777s
#   loss: 1.7486 corr: 74 (37760/2257759) completed in 0m 0.833s
#   loss: 1.3873 corr: 87 (37888/2257759) completed in 0m 0.823s
#   loss: 1.5530 corr: 80 (38016/2257759) completed in 0m 0.809s
#   loss: 1.4055 corr: 80 (38144/2257759) completed in 0m 0.770s
#   loss: 1.1277 corr: 87 (38272/2257759) completed in 0m 0.846s
#   loss: 1.4895 corr: 80 (38400/2257759) completed in 0m 0.824s
#   loss: 1.5426 corr: 75 (38528/2257759) completed in 0m 0.817s
#   loss: 1.4739 corr: 86 (38656/2257759) completed in 0m 0.844s
#   loss: 1.8868 corr: 80 (38784/2257759) completed in 0m 0.855s
#   loss: 1.3927 corr: 84 (38912/2257759) completed in 0m 0.825s
#   loss: 1.5243 corr: 80 (39040/2257759) completed in 0m 0.838s
#   loss: 2.1801 corr: 67 (39168/2257759) completed in 0m 0.801s
#   loss: 1.4793 corr: 83 (39296/2257759) completed in 0m 0.822s
#   loss: 1.7373 corr: 77 (39424/2257759) completed in 0m 0.844s
#   loss: 1.5608 corr: 74 (39552/2257759) completed in 0m 0.809s
#   loss: 1.3503 corr: 90 (39680/2257759) completed in 0m 0.813s
#   loss: 1.6409 corr: 80 (39808/2257759) completed in 0m 0.863s
#   loss: 1.9205 corr: 67 (39936/2257759) completed in 0m 0.828s
#   loss: 1.5995 corr: 75 (40064/2257759) completed in 0m 0.833s
#   loss: 1.6182 corr: 81 (40192/2257759) completed in 0m 0.836s
#   loss: 1.6310 corr: 72 (40320/2257759) completed in 0m 0.830s
#   loss: 1.2783 corr: 83 (40448/2257759) completed in 0m 1.023s
#   loss: 1.6100 corr: 79 (40576/2257759) completed in 0m 0.821s
#   loss: 1.5958 corr: 85 (40704/2257759) completed in 0m 0.817s
#   loss: 1.2898 corr: 92 (40832/2257759) completed in 0m 0.891s
#   loss: 1.9786 corr: 69 (40960/2257759) completed in 0m 0.935s
#   loss: 1.5571 corr: 76 (41088/2257759) completed in 0m 0.850s
#   loss: 1.3622 corr: 86 (41216/2257759) completed in 0m 0.789s
#   loss: 1.6900 corr: 75 (41344/2257759) completed in 0m 0.775s
#   loss: 1.7500 corr: 77 (41472/2257759) completed in 0m 0.838s
#   loss: 1.6498 corr: 79 (41600/2257759) completed in 0m 0.873s
#   loss: 1.4165 corr: 80 (41728/2257759) completed in 0m 0.863s
#   loss: 1.7885 corr: 68 (41856/2257759) completed in 0m 0.935s
#   loss: 1.6824 corr: 74 (41984/2257759) completed in 0m 0.878s
#   loss: 1.8675 corr: 72 (42112/2257759) completed in 0m 0.815s
#   loss: 1.6561 corr: 76 (42240/2257759) completed in 0m 0.794s
#   loss: 1.9352 corr: 75 (42368/2257759) completed in 0m 0.877s
#   loss: 1.5864 corr: 86 (42496/2257759) completed in 0m 0.865s
#   loss: 2.0381 corr: 73 (42624/2257759) completed in 0m 0.850s
#   loss: 1.8821 corr: 64 (42752/2257759) completed in 0m 0.905s
#   loss: 1.8759 corr: 73 (42880/2257759) completed in 0m 0.882s
#   loss: 1.5343 corr: 76 (43008/2257759) completed in 0m 0.794s
#   loss: 1.7740 corr: 78 (43136/2257759) completed in 0m 0.972s
#   loss: 1.5338 corr: 77 (43264/2257759) completed in 0m 0.833s
#   loss: 1.3692 corr: 90 (43392/2257759) completed in 0m 0.793s
#   loss: 1.4953 corr: 77 (43520/2257759) completed in 0m 0.828s
#   loss: 1.6625 corr: 77 (43648/2257759) completed in 0m 0.897s
#   loss: 1.9061 corr: 69 (43776/2257759) completed in 0m 0.854s
#   loss: 1.4051 corr: 81 (43904/2257759) completed in 0m 0.857s
#   loss: 1.7685 corr: 75 (44032/2257759) completed in 0m 0.784s
#   loss: 1.4581 corr: 84 (44160/2257759) completed in 0m 0.833s
#   loss: 1.4965 corr: 82 (44288/2257759) completed in 0m 0.853s
#   loss: 1.8368 corr: 73 (44416/2257759) completed in 0m 0.813s
#   loss: 1.3011 corr: 83 (44544/2257759) completed in 0m 0.834s
#   loss: 1.7638 corr: 79 (44672/2257759) completed in 0m 0.839s
#   loss: 1.5595 corr: 74 (44800/2257759) completed in 0m 0.818s
#   loss: 1.1749 corr: 88 (44928/2257759) completed in 0m 0.822s
#   loss: 1.4601 corr: 81 (45056/2257759) completed in 0m 0.819s
#   loss: 1.6585 corr: 78 (45184/2257759) completed in 0m 0.847s
#   loss: 1.4843 corr: 80 (45312/2257759) completed in 0m 0.845s
#   loss: 1.5782 corr: 78 (45440/2257759) completed in 0m 0.842s
#   loss: 1.4371 corr: 81 (45568/2257759) completed in 0m 0.872s
#   loss: 1.6780 corr: 73 (45696/2257759) completed in 0m 0.808s
#   loss: 1.9360 corr: 68 (45824/2257759) completed in 0m 0.802s
#   loss: 1.5646 corr: 81 (45952/2257759) completed in 0m 0.834s
#   loss: 2.0165 corr: 68 (46080/2257759) completed in 0m 0.924s
#   loss: 1.6812 corr: 73 (46208/2257759) completed in 0m 0.836s
#   loss: 2.0032 corr: 74 (46336/2257759) completed in 0m 0.791s
#   loss: 1.4495 corr: 83 (46464/2257759) completed in 0m 0.784s
#   loss: 1.5956 corr: 74 (46592/2257759) completed in 0m 0.844s
#   loss: 1.6579 corr: 75 (46720/2257759) completed in 0m 0.819s
#   loss: 1.4377 corr: 81 (46848/2257759) completed in 0m 0.854s
#   loss: 1.9289 corr: 74 (46976/2257759) completed in 0m 0.838s
#   loss: 1.4945 corr: 85 (47104/2257759) completed in 0m 0.811s
#   loss: 1.6602 corr: 76 (47232/2257759) completed in 0m 0.842s
#   loss: 1.7197 corr: 78 (47360/2257759) completed in 0m 0.824s
#   loss: 1.7468 corr: 77 (47488/2257759) completed in 0m 0.852s
#   loss: 1.7220 corr: 74 (47616/2257759) completed in 0m 0.892s
#   loss: 1.8724 corr: 67 (47744/2257759) completed in 0m 0.847s
#   loss: 1.7295 corr: 76 (47872/2257759) completed in 0m 0.793s
#   loss: 1.7536 corr: 75 (48000/2257759) completed in 0m 0.791s
#   loss: 1.6077 corr: 79 (48128/2257759) completed in 0m 0.823s
#   loss: 1.5696 corr: 80 (48256/2257759) completed in 0m 0.851s
#   loss: 1.8676 corr: 72 (48384/2257759) completed in 0m 0.834s
#   loss: 1.8533 corr: 71 (48512/2257759) completed in 0m 0.891s
#   loss: 1.6286 corr: 81 (48640/2257759) completed in 0m 0.870s
#   loss: 1.6703 corr: 67 (48768/2257759) completed in 0m 0.838s
#   loss: 1.6521 corr: 70 (48896/2257759) completed in 0m 0.864s
#   loss: 1.4675 corr: 82 (49024/2257759) completed in 0m 0.897s
#   loss: 1.8161 corr: 75 (49152/2257759) completed in 0m 0.843s
#   loss: 1.3122 corr: 80 (49280/2257759) completed in 0m 0.875s
#   loss: 1.5848 corr: 77 (49408/2257759) completed in 0m 0.855s
#   loss: 1.5455 corr: 78 (49536/2257759) completed in 0m 0.888s
#   loss: 1.9625 corr: 68 (49664/2257759) completed in 0m 0.856s
#   loss: 1.8575 corr: 73 (49792/2257759) completed in 0m 0.846s
#   loss: 1.5934 corr: 74 (49920/2257759) completed in 0m 0.824s
#   loss: 1.3165 corr: 84 (50048/2257759) completed in 0m 0.839s
#   loss: 1.8089 corr: 75 (50176/2257759) completed in 0m 0.779s
#   loss: 1.6209 corr: 77 (50304/2257759) completed in 0m 0.838s
#   loss: 1.9978 corr: 64 (50432/2257759) completed in 0m 0.837s
#   loss: 1.7661 corr: 81 (50560/2257759) completed in 0m 0.903s
#   loss: 1.7930 corr: 71 (50688/2257759) completed in 0m 0.815s
#   loss: 1.7260 corr: 79 (50816/2257759) completed in 0m 0.832s
#   loss: 1.9226 corr: 71 (50944/2257759) completed in 0m 0.836s
#   loss: 1.9090 corr: 75 (51072/2257759) completed in 0m 0.807s
#   loss: 1.5300 corr: 71 (51200/2257759) completed in 0m 0.839s
#   loss: 1.6223 corr: 76 (51328/2257759) completed in 0m 0.835s
#   loss: 1.7102 corr: 74 (51456/2257759) completed in 0m 0.913s
#   loss: 1.7081 corr: 76 (51584/2257759) completed in 0m 0.881s
#   loss: 1.9025 corr: 71 (51712/2257759) completed in 0m 0.865s
#   loss: 1.8727 corr: 75 (51840/2257759) completed in 0m 0.984s
#   loss: 1.9366 corr: 73 (51968/2257759) completed in 0m 0.824s
#   loss: 1.8772 corr: 72 (52096/2257759) completed in 0m 0.809s
#   loss: 1.7672 corr: 78 (52224/2257759) completed in 0m 0.854s
#   loss: 1.6185 corr: 81 (52352/2257759) completed in 0m 0.877s
#   loss: 1.7171 corr: 75 (52480/2257759) completed in 0m 0.794s
#   loss: 1.7777 corr: 75 (52608/2257759) completed in 0m 0.847s
#   loss: 1.5130 corr: 80 (52736/2257759) completed in 0m 0.887s
#   loss: 1.9151 corr: 76 (52864/2257759) completed in 0m 0.825s
#   loss: 1.4866 corr: 79 (52992/2257759) completed in 0m 0.819s
#   loss: 1.6351 corr: 80 (53120/2257759) completed in 0m 0.794s
#   loss: 1.6550 corr: 75 (53248/2257759) completed in 0m 0.834s
#   loss: 1.6593 corr: 73 (53376/2257759) completed in 0m 0.907s
#   loss: 1.5693 corr: 78 (53504/2257759) completed in 0m 0.852s
#   loss: 1.6150 corr: 72 (53632/2257759) completed in 0m 0.857s
#   loss: 1.4597 corr: 78 (53760/2257759) completed in 0m 0.827s
#   loss: 1.8560 corr: 75 (53888/2257759) completed in 0m 0.829s
#   loss: 1.7666 corr: 77 (54016/2257759) completed in 0m 0.846s
#   loss: 1.6190 corr: 77 (54144/2257759) completed in 0m 0.819s
#   loss: 1.5222 corr: 87 (54272/2257759) completed in 0m 0.828s
#   loss: 1.4065 corr: 81 (54400/2257759) completed in 0m 0.858s
#   loss: 1.8132 corr: 76 (54528/2257759) completed in 0m 0.835s
#   loss: 1.4608 corr: 88 (54656/2257759) completed in 0m 0.810s
#   loss: 1.4995 corr: 84 (54784/2257759) completed in 0m 0.828s
#   loss: 1.3517 corr: 88 (54912/2257759) completed in 0m 0.862s
#   loss: 1.6035 corr: 79 (55040/2257759) completed in 0m 0.855s
#   loss: 1.6366 corr: 81 (55168/2257759) completed in 0m 0.872s
#   loss: 1.5654 corr: 88 (55296/2257759) completed in 0m 0.810s
#   loss: 1.8796 corr: 67 (55424/2257759) completed in 0m 0.816s
#   loss: 1.9300 corr: 66 (55552/2257759) completed in 0m 0.820s
#   loss: 1.5688 corr: 74 (55680/2257759) completed in 0m 0.837s
#   loss: 1.6821 corr: 74 (55808/2257759) completed in 0m 0.837s
#   loss: 1.9500 corr: 75 (55936/2257759) completed in 0m 0.856s
#   loss: 1.4663 corr: 85 (56064/2257759) completed in 0m 0.793s
#   loss: 1.4920 corr: 76 (56192/2257759) completed in 0m 0.825s
#   loss: 1.6716 corr: 75 (56320/2257759) completed in 0m 0.837s
#   loss: 1.6588 corr: 76 (56448/2257759) completed in 0m 0.846s
#   loss: 1.7626 corr: 77 (56576/2257759) completed in 0m 0.806s
#   loss: 1.6036 corr: 77 (56704/2257759) completed in 0m 0.815s
#   loss: 1.7209 corr: 78 (56832/2257759) completed in 0m 0.843s
#   loss: 1.5000 corr: 76 (56960/2257759) completed in 0m 0.865s
#   loss: 1.7305 corr: 73 (57088/2257759) completed in 0m 0.819s
#   loss: 1.6814 corr: 78 (57216/2257759) completed in 0m 0.817s
#   loss: 1.7541 corr: 86 (57344/2257759) completed in 0m 0.837s
#   loss: 1.3042 corr: 78 (57472/2257759) completed in 0m 0.867s
#   loss: 1.7153 corr: 78 (57600/2257759) completed in 0m 0.775s
#   loss: 2.0249 corr: 66 (57728/2257759) completed in 0m 0.865s
#   loss: 1.8700 corr: 70 (57856/2257759) completed in 0m 0.870s
#   loss: 1.8906 corr: 76 (57984/2257759) completed in 0m 0.848s
#   loss: 1.7501 corr: 77 (58112/2257759) completed in 0m 0.802s
#   loss: 1.6398 corr: 80 (58240/2257759) completed in 0m 0.825s
#   loss: 1.6165 corr: 79 (58368/2257759) completed in 0m 0.873s
#   loss: 2.2376 corr: 69 (58496/2257759) completed in 0m 0.839s
#   loss: 1.9724 corr: 69 (58624/2257759) completed in 0m 0.790s
#   loss: 1.9393 corr: 68 (58752/2257759) completed in 0m 0.768s
#   loss: 1.4689 corr: 84 (58880/2257759) completed in 0m 0.855s
#   loss: 1.3311 corr: 79 (59008/2257759) completed in 0m 0.775s
#   loss: 1.5124 corr: 78 (59136/2257759) completed in 0m 0.800s
#   loss: 1.5751 corr: 84 (59264/2257759) completed in 0m 0.803s
#   loss: 1.7832 corr: 74 (59392/2257759) completed in 0m 0.859s
#   loss: 1.5658 corr: 80 (59520/2257759) completed in 0m 0.864s
#   loss: 2.1881 corr: 60 (59648/2257759) completed in 0m 0.817s
#   loss: 1.5802 corr: 83 (59776/2257759) completed in 0m 0.839s
#   loss: 1.6752 corr: 78 (59904/2257759) completed in 0m 0.850s
#   loss: 1.3791 corr: 88 (60032/2257759) completed in 0m 0.979s
#   loss: 1.2900 corr: 87 (60160/2257759) completed in 0m 0.915s
#   loss: 1.9090 corr: 68 (60288/2257759) completed in 0m 0.848s
#   loss: 1.2649 corr: 86 (60416/2257759) completed in 0m 0.776s
#   loss: 1.6461 corr: 74 (60544/2257759) completed in 0m 0.845s
#   loss: 1.5926 corr: 74 (60672/2257759) completed in 0m 0.834s
#   loss: 1.8283 corr: 78 (60800/2257759) completed in 0m 0.843s
#   loss: 1.7914 corr: 78 (60928/2257759) completed in 0m 0.780s
#   loss: 1.2914 corr: 90 (61056/2257759) completed in 0m 0.774s
#   loss: 1.9340 corr: 62 (61184/2257759) completed in 0m 0.801s
#   loss: 1.4504 corr: 84 (61312/2257759) completed in 0m 0.778s
#   loss: 1.6350 corr: 78 (61440/2257759) completed in 0m 0.769s
#   loss: 1.6709 corr: 77 (61568/2257759) completed in 0m 0.835s
#   loss: 1.4453 corr: 82 (61696/2257759) completed in 0m 0.832s
#   loss: 1.8275 corr: 78 (61824/2257759) completed in 0m 0.896s
#   loss: 2.1768 corr: 69 (61952/2257759) completed in 0m 0.824s
#   loss: 1.8026 corr: 72 (62080/2257759) completed in 0m 0.875s
#   loss: 1.6843 corr: 78 (62208/2257759) completed in 0m 0.810s
#   loss: 1.9808 corr: 67 (62336/2257759) completed in 0m 0.858s
#   loss: 2.0108 corr: 73 (62464/2257759) completed in 0m 0.850s
#   loss: 1.4582 corr: 81 (62592/2257759) completed in 0m 0.822s
#   loss: 1.6449 corr: 80 (62720/2257759) completed in 0m 0.945s
#   loss: 1.7209 corr: 69 (62848/2257759) completed in 0m 0.902s
#   loss: 1.8544 corr: 72 (62976/2257759) completed in 0m 0.834s
#   loss: 1.5920 corr: 78 (63104/2257759) completed in 0m 0.834s
#   loss: 1.7403 corr: 83 (63232/2257759) completed in 0m 0.846s
#   loss: 1.6055 corr: 77 (63360/2257759) completed in 0m 0.818s
#   loss: 1.6992 corr: 83 (63488/2257759) completed in 0m 0.809s
#   loss: 1.9961 corr: 67 (63616/2257759) completed in 0m 0.844s
#   loss: 1.6652 corr: 78 (63744/2257759) completed in 0m 0.864s
#   loss: 1.8439 corr: 75 (63872/2257759) completed in 0m 0.923s
#   loss: 1.8356 corr: 70 (64000/2257759) completed in 0m 0.927s
#   loss: 1.5826 corr: 73 (64128/2257759) completed in 0m 0.823s
#   loss: 1.3263 corr: 81 (64256/2257759) completed in 0m 0.797s
#   loss: 1.6915 corr: 74 (64384/2257759) completed in 0m 0.788s
#   loss: 1.7321 corr: 79 (64512/2257759) completed in 0m 0.841s
#   loss: 1.8031 corr: 76 (64640/2257759) completed in 0m 0.863s
#   loss: 1.7352 corr: 68 (64768/2257759) completed in 0m 0.845s
#   loss: 1.7607 corr: 80 (64896/2257759) completed in 0m 0.825s
#   loss: 1.6845 corr: 76 (65024/2257759) completed in 0m 0.850s
#   loss: 1.7026 corr: 81 (65152/2257759) completed in 0m 0.829s
#   loss: 1.7493 corr: 75 (65280/2257759) completed in 0m 0.851s
#   loss: 2.0056 corr: 70 (65408/2257759) completed in 0m 0.810s
#   loss: 1.6704 corr: 70 (65536/2257759) completed in 0m 0.827s
#   loss: 1.5368 corr: 75 (65664/2257759) completed in 0m 0.862s
#   loss: 1.8848 corr: 76 (65792/2257759) completed in 0m 0.838s
#   loss: 1.7595 corr: 78 (65920/2257759) completed in 0m 0.798s
#   loss: 1.7595 corr: 76 (66048/2257759) completed in 0m 0.874s
#   loss: 1.6450 corr: 78 (66176/2257759) completed in 0m 0.817s
#   loss: 1.7582 corr: 81 (66304/2257759) completed in 0m 0.842s
#   loss: 1.8712 corr: 76 (66432/2257759) completed in 0m 0.805s
#   loss: 1.5163 corr: 78 (66560/2257759) completed in 0m 0.855s
#   loss: 1.9329 corr: 73 (66688/2257759) completed in 0m 0.860s
#   loss: 1.8172 corr: 75 (66816/2257759) completed in 0m 0.803s
#   loss: 1.7693 corr: 76 (66944/2257759) completed in 0m 0.821s
#   loss: 1.4609 corr: 76 (67072/2257759) completed in 0m 0.861s
#   loss: 1.6472 corr: 76 (67200/2257759) completed in 0m 0.835s
#   loss: 1.2664 corr: 87 (67328/2257759) completed in 0m 0.792s
#   loss: 1.6597 corr: 72 (67456/2257759) completed in 0m 0.839s
#   loss: 1.8096 corr: 79 (67584/2257759) completed in 0m 0.857s
#   loss: 1.5782 corr: 82 (67712/2257759) completed in 0m 0.846s
#   loss: 2.1679 corr: 67 (67840/2257759) completed in 0m 0.832s
#   loss: 1.3783 corr: 80 (67968/2257759) completed in 0m 0.816s
#   loss: 1.9610 corr: 76 (68096/2257759) completed in 0m 0.828s
#   loss: 1.6423 corr: 83 (68224/2257759) completed in 0m 0.803s
#   loss: 1.7824 corr: 65 (68352/2257759) completed in 0m 0.816s
#   loss: 1.6483 corr: 74 (68480/2257759) completed in 0m 0.828s
#   loss: 1.8334 corr: 79 (68608/2257759) completed in 0m 0.812s
#   loss: 1.4942 corr: 85 (68736/2257759) completed in 0m 0.767s
#   loss: 1.7573 corr: 71 (68864/2257759) completed in 0m 0.804s
#   loss: 1.6103 corr: 82 (68992/2257759) completed in 0m 0.823s
#   loss: 1.5942 corr: 85 (69120/2257759) completed in 0m 0.818s
#   loss: 1.5994 corr: 78 (69248/2257759) completed in 0m 0.882s
#   loss: 1.2695 corr: 86 (69376/2257759) completed in 0m 0.833s
#   loss: 1.7104 corr: 71 (69504/2257759) completed in 0m 0.810s
#   loss: 1.7115 corr: 74 (69632/2257759) completed in 0m 0.863s
#   loss: 1.5713 corr: 76 (69760/2257759) completed in 0m 0.821s
#   loss: 1.7349 corr: 75 (69888/2257759) completed in 0m 0.827s
#   loss: 1.7887 corr: 70 (70016/2257759) completed in 0m 0.831s
#   loss: 1.8624 corr: 73 (70144/2257759) completed in 0m 0.834s
#   loss: 1.5762 corr: 80 (70272/2257759) completed in 0m 0.816s
#   loss: 1.5980 corr: 76 (70400/2257759) completed in 0m 0.826s
#   loss: 1.4316 corr: 85 (70528/2257759) completed in 0m 0.828s
#   loss: 1.8384 corr: 70 (70656/2257759) completed in 0m 0.894s
#   loss: 1.7529 corr: 69 (70784/2257759) completed in 0m 0.828s
#   loss: 1.6457 corr: 68 (70912/2257759) completed in 0m 0.841s
#   loss: 1.7318 corr: 79 (71040/2257759) completed in 0m 0.836s
#   loss: 1.7501 corr: 78 (71168/2257759) completed in 0m 0.853s
#   loss: 1.7019 corr: 81 (71296/2257759) completed in 0m 0.848s
#   loss: 2.0374 corr: 69 (71424/2257759) completed in 0m 0.844s
#   loss: 1.6162 corr: 79 (71552/2257759) completed in 0m 0.786s
#   loss: 1.6274 corr: 76 (71680/2257759) completed in 0m 0.873s
#   loss: 2.0840 corr: 68 (71808/2257759) completed in 0m 0.891s
#   loss: 1.6511 corr: 81 (71936/2257759) completed in 0m 0.811s
#   loss: 1.7493 corr: 77 (72064/2257759) completed in 0m 0.829s
#   loss: 1.6901 corr: 77 (72192/2257759) completed in 0m 0.817s
#   loss: 1.5166 corr: 83 (72320/2257759) completed in 0m 0.814s
#   loss: 1.6492 corr: 88 (72448/2257759) completed in 0m 0.857s
#   loss: 1.9686 corr: 68 (72576/2257759) completed in 0m 0.947s
#   loss: 1.9216 corr: 67 (72704/2257759) completed in 0m 0.850s
#   loss: 1.4688 corr: 84 (72832/2257759) completed in 0m 0.858s
#   loss: 1.5156 corr: 81 (72960/2257759) completed in 0m 0.838s
#   loss: 1.8129 corr: 75 (73088/2257759) completed in 0m 0.831s
#   loss: 1.8901 corr: 68 (73216/2257759) completed in 0m 0.858s
#   loss: 1.4796 corr: 79 (73344/2257759) completed in 0m 0.850s
#   loss: 1.4922 corr: 78 (73472/2257759) completed in 0m 0.858s
#   loss: 1.5345 corr: 83 (73600/2257759) completed in 0m 0.879s
#   loss: 1.3422 corr: 79 (73728/2257759) completed in 0m 0.855s
#   loss: 1.5478 corr: 78 (73856/2257759) completed in 0m 0.848s
#   loss: 1.8462 corr: 78 (73984/2257759) completed in 0m 0.860s
#   loss: 1.6719 corr: 78 (74112/2257759) completed in 0m 0.824s
#   loss: 1.6812 corr: 78 (74240/2257759) completed in 0m 0.841s
#   loss: 1.2614 corr: 85 (74368/2257759) completed in 0m 0.859s
#   loss: 1.7133 corr: 81 (74496/2257759) completed in 0m 0.894s
#   loss: 1.5447 corr: 81 (74624/2257759) completed in 0m 0.898s
#   loss: 1.8243 corr: 75 (74752/2257759) completed in 0m 0.839s
#   loss: 1.6812 corr: 84 (74880/2257759) completed in 0m 0.788s
#   loss: 1.7004 corr: 81 (75008/2257759) completed in 0m 0.845s
#   loss: 2.0246 corr: 66 (75136/2257759) completed in 0m 0.846s
#   loss: 1.4817 corr: 80 (75264/2257759) completed in 0m 0.814s
#   loss: 1.9083 corr: 76 (75392/2257759) completed in 0m 0.854s
#   loss: 1.7439 corr: 76 (75520/2257759) completed in 0m 0.971s
#   loss: 1.6547 corr: 72 (75648/2257759) completed in 0m 0.916s
#   loss: 1.6537 corr: 75 (75776/2257759) completed in 0m 0.852s
#   loss: 1.6757 corr: 80 (75904/2257759) completed in 0m 0.842s
#   loss: 1.8714 corr: 71 (76032/2257759) completed in 0m 0.817s
#   loss: 1.8789 corr: 78 (76160/2257759) completed in 0m 0.832s
#   loss: 1.4207 corr: 85 (76288/2257759) completed in 0m 0.836s
#   loss: 1.6080 corr: 71 (76416/2257759) completed in 0m 0.906s
#   loss: 1.6195 corr: 76 (76544/2257759) completed in 0m 0.849s
#   loss: 1.7691 corr: 76 (76672/2257759) completed in 0m 0.776s
#   loss: 1.5737 corr: 76 (76800/2257759) completed in 0m 0.824s
#   loss: 1.6157 corr: 81 (76928/2257759) completed in 0m 0.861s
#   loss: 1.6436 corr: 73 (77056/2257759) completed in 0m 0.864s
#   loss: 1.9802 corr: 71 (77184/2257759) completed in 0m 0.844s
#   loss: 1.9476 corr: 65 (77312/2257759) completed in 0m 0.854s
#   loss: 1.5002 corr: 83 (77440/2257759) completed in 0m 0.873s
#   loss: 1.9177 corr: 69 (77568/2257759) completed in 0m 0.875s
#   loss: 1.6175 corr: 77 (77696/2257759) completed in 0m 0.871s
#   loss: 1.6993 corr: 72 (77824/2257759) completed in 0m 0.827s
#   loss: 1.6651 corr: 71 (77952/2257759) completed in 0m 0.789s
#   loss: 1.7571 corr: 79 (78080/2257759) completed in 0m 0.775s
#   loss: 1.9041 corr: 65 (78208/2257759) completed in 0m 0.844s
#   loss: 1.5703 corr: 78 (78336/2257759) completed in 0m 0.815s
#   loss: 1.6416 corr: 75 (78464/2257759) completed in 0m 0.850s
#   loss: 1.5828 corr: 81 (78592/2257759) completed in 0m 0.881s
#   loss: 1.4216 corr: 79 (78720/2257759) completed in 0m 0.818s
#   loss: 1.7529 corr: 73 (78848/2257759) completed in 0m 0.830s
#   loss: 2.1467 corr: 68 (78976/2257759) completed in 0m 0.855s
#   loss: 1.7763 corr: 71 (79104/2257759) completed in 0m 0.848s
#   loss: 1.3672 corr: 82 (79232/2257759) completed in 0m 0.796s
#   loss: 2.0205 corr: 77 (79360/2257759) completed in 0m 0.849s
#   loss: 1.8612 corr: 70 (79488/2257759) completed in 0m 0.806s
#   loss: 1.4303 corr: 86 (79616/2257759) completed in 0m 0.830s
#   loss: 1.4711 corr: 82 (79744/2257759) completed in 0m 0.827s
#   loss: 1.8757 corr: 76 (79872/2257759) completed in 0m 0.891s
#   loss: 1.3054 corr: 85 (80000/2257759) completed in 0m 0.811s
#   loss: 1.7875 corr: 73 (80128/2257759) completed in 0m 0.770s
#   loss: 1.9192 corr: 74 (80256/2257759) completed in 0m 0.813s
#   loss: 1.7169 corr: 78 (80384/2257759) completed in 0m 0.816s
#   loss: 1.5892 corr: 76 (80512/2257759) completed in 0m 0.822s
#   loss: 1.8053 corr: 78 (80640/2257759) completed in 0m 0.855s
#   loss: 1.4881 corr: 82 (80768/2257759) completed in 0m 0.814s
#   loss: 1.5234 corr: 82 (80896/2257759) completed in 0m 0.823s
#   loss: 1.5203 corr: 76 (81024/2257759) completed in 0m 0.838s
#   loss: 1.4898 corr: 83 (81152/2257759) completed in 0m 0.827s
#   loss: 1.7830 corr: 70 (81280/2257759) completed in 0m 0.815s
#   loss: 1.5839 corr: 81 (81408/2257759) completed in 0m 0.920s
#   loss: 1.7699 corr: 79 (81536/2257759) completed in 0m 0.807s
#   loss: 1.6075 corr: 74 (81664/2257759) completed in 0m 0.800s
#   loss: 1.8212 corr: 64 (81792/2257759) completed in 0m 0.817s
#   loss: 1.9663 corr: 78 (81920/2257759) completed in 0m 0.812s
#   loss: 1.7409 corr: 70 (82048/2257759) completed in 0m 0.830s
#   loss: 1.4693 corr: 84 (82176/2257759) completed in 0m 0.864s
#   loss: 1.5313 corr: 82 (82304/2257759) completed in 0m 0.829s
#   loss: 1.4240 corr: 76 (82432/2257759) completed in 0m 0.815s
#   loss: 1.9079 corr: 73 (82560/2257759) completed in 0m 0.823s
#   loss: 1.7059 corr: 76 (82688/2257759) completed in 0m 0.810s
#   loss: 1.7936 corr: 76 (82816/2257759) completed in 0m 0.820s
#   loss: 1.6249 corr: 79 (82944/2257759) completed in 0m 0.808s
#   loss: 1.7379 corr: 83 (83072/2257759) completed in 0m 0.864s
#   loss: 1.8352 corr: 67 (83200/2257759) completed in 0m 0.811s
#   loss: 1.5065 corr: 88 (83328/2257759) completed in 0m 0.795s
#   loss: 1.8546 corr: 71 (83456/2257759) completed in 0m 0.811s
#   loss: 1.5792 corr: 83 (83584/2257759) completed in 0m 0.809s
#   loss: 1.5935 corr: 78 (83712/2257759) completed in 0m 0.798s
#   loss: 1.8654 corr: 67 (83840/2257759) completed in 0m 0.813s
#   loss: 1.6283 corr: 86 (83968/2257759) completed in 0m 0.874s
#   loss: 1.6974 corr: 74 (84096/2257759) completed in 0m 0.850s
#   loss: 1.9688 corr: 71 (84224/2257759) completed in 0m 0.899s
#   loss: 1.6599 corr: 78 (84352/2257759) completed in 0m 1.022s
#   loss: 1.7263 corr: 83 (84480/2257759) completed in 0m 0.855s
#   loss: 1.6472 corr: 80 (84608/2257759) completed in 0m 0.833s
#   loss: 1.5078 corr: 79 (84736/2257759) completed in 0m 0.836s
#   loss: 1.5710 corr: 82 (84864/2257759) completed in 0m 0.775s
#   loss: 1.6779 corr: 76 (84992/2257759) completed in 0m 0.854s
#   loss: 1.6000 corr: 79 (85120/2257759) completed in 0m 0.846s
#   loss: 1.8239 corr: 73 (85248/2257759) completed in 0m 0.814s
#   loss: 1.9308 corr: 77 (85376/2257759) completed in 0m 0.868s
#   loss: 1.9436 corr: 63 (85504/2257759) completed in 0m 0.828s
#   loss: 1.6674 corr: 77 (85632/2257759) completed in 0m 0.803s
#   loss: 1.8491 corr: 67 (85760/2257759) completed in 0m 0.822s
#   loss: 1.8197 corr: 85 (85888/2257759) completed in 0m 0.797s
#   loss: 1.3166 corr: 87 (86016/2257759) completed in 0m 0.845s
#   loss: 2.2037 corr: 72 (86144/2257759) completed in 0m 0.845s
#   loss: 1.6164 corr: 79 (86272/2257759) completed in 0m 0.791s
#   loss: 1.8576 corr: 66 (86400/2257759) completed in 0m 0.853s
#   loss: 1.3422 corr: 85 (86528/2257759) completed in 0m 0.852s
#   loss: 1.7566 corr: 74 (86656/2257759) completed in 0m 0.814s
#   loss: 2.0040 corr: 72 (86784/2257759) completed in 0m 0.826s
#   loss: 1.4819 corr: 89 (86912/2257759) completed in 0m 0.826s
#   loss: 1.9120 corr: 67 (87040/2257759) completed in 0m 0.847s
#   loss: 1.5348 corr: 83 (87168/2257759) completed in 0m 0.844s
#   loss: 1.7776 corr: 71 (87296/2257759) completed in 0m 0.797s
#   loss: 1.8668 corr: 75 (87424/2257759) completed in 0m 0.835s
#   loss: 1.6547 corr: 82 (87552/2257759) completed in 0m 0.807s
#   loss: 1.8584 corr: 72 (87680/2257759) completed in 0m 0.879s
#   loss: 1.7026 corr: 78 (87808/2257759) completed in 0m 0.831s
#   loss: 2.0830 corr: 68 (87936/2257759) completed in 0m 0.775s
#   loss: 1.8947 corr: 69 (88064/2257759) completed in 0m 0.939s
#   loss: 1.7213 corr: 80 (88192/2257759) completed in 0m 0.828s
#   loss: 1.9092 corr: 79 (88320/2257759) completed in 0m 0.838s
#   loss: 1.4105 corr: 83 (88448/2257759) completed in 0m 0.808s
#   loss: 1.8268 corr: 73 (88576/2257759) completed in 0m 0.800s
#   loss: 1.4474 corr: 83 (88704/2257759) completed in 0m 0.823s
#   loss: 1.6543 corr: 80 (88832/2257759) completed in 0m 0.825s
#   loss: 1.6065 corr: 80 (88960/2257759) completed in 0m 0.794s
#   loss: 1.7414 corr: 80 (89088/2257759) completed in 0m 0.889s
#   loss: 1.7056 corr: 77 (89216/2257759) completed in 0m 0.842s
#   loss: 1.5396 corr: 81 (89344/2257759) completed in 0m 0.828s
#   loss: 1.6172 corr: 77 (89472/2257759) completed in 0m 0.833s
#   loss: 1.6489 corr: 77 (89600/2257759) completed in 0m 0.799s
#   loss: 1.3912 corr: 80 (89728/2257759) completed in 0m 0.853s
#   loss: 1.4474 corr: 80 (89856/2257759) completed in 0m 0.812s
#   loss: 1.5854 corr: 85 (89984/2257759) completed in 0m 0.812s
#   loss: 1.6362 corr: 76 (90112/2257759) completed in 0m 0.887s
#   loss: 1.3241 corr: 83 (90240/2257759) completed in 0m 0.828s
#   loss: 1.9731 corr: 73 (90368/2257759) completed in 0m 0.849s
#   loss: 1.6775 corr: 77 (90496/2257759) completed in 0m 0.823s
#   loss: 1.7449 corr: 75 (90624/2257759) completed in 0m 0.810s
#   loss: 2.0115 corr: 67 (90752/2257759) completed in 0m 0.851s
#   loss: 1.6776 corr: 77 (90880/2257759) completed in 0m 0.858s
#   loss: 1.6289 corr: 74 (91008/2257759) completed in 0m 0.880s
#   loss: 2.0297 corr: 68 (91136/2257759) completed in 0m 0.860s
#   loss: 1.6104 corr: 83 (91264/2257759) completed in 0m 0.812s
#   loss: 1.7130 corr: 75 (91392/2257759) completed in 0m 0.812s
#   loss: 1.8752 corr: 70 (91520/2257759) completed in 0m 0.846s
#   loss: 1.5655 corr: 74 (91648/2257759) completed in 0m 0.821s
#   loss: 1.9925 corr: 68 (91776/2257759) completed in 0m 0.826s
#   loss: 1.8778 corr: 68 (91904/2257759) completed in 0m 0.854s
#   loss: 1.8462 corr: 76 (92032/2257759) completed in 0m 0.847s
#   loss: 1.6596 corr: 78 (92160/2257759) completed in 0m 0.842s
#   loss: 1.9515 corr: 76 (92288/2257759) completed in 0m 0.854s
#   loss: 1.4892 corr: 80 (92416/2257759) completed in 0m 0.827s
#   loss: 1.6477 corr: 80 (92544/2257759) completed in 0m 0.807s
#   loss: 2.0082 corr: 76 (92672/2257759) completed in 0m 0.836s
#   loss: 1.7810 corr: 74 (92800/2257759) completed in 0m 0.768s
#   loss: 1.3316 corr: 82 (92928/2257759) completed in 0m 0.914s
#   loss: 1.8446 corr: 73 (93056/2257759) completed in 0m 0.852s
#   loss: 1.4603 corr: 80 (93184/2257759) completed in 0m 0.804s
#   loss: 1.7068 corr: 79 (93312/2257759) completed in 0m 0.827s
#   loss: 1.6933 corr: 79 (93440/2257759) completed in 0m 0.813s
#   loss: 1.5329 corr: 77 (93568/2257759) completed in 0m 0.786s
#   loss: 1.3273 corr: 87 (93696/2257759) completed in 0m 0.809s
#   loss: 1.8534 corr: 79 (93824/2257759) completed in 0m 0.830s
#   loss: 1.8291 corr: 71 (93952/2257759) completed in 0m 0.832s
#   loss: 1.6967 corr: 80 (94080/2257759) completed in 0m 0.862s
#   loss: 1.6585 corr: 77 (94208/2257759) completed in 0m 0.812s
#   loss: 1.8810 corr: 72 (94336/2257759) completed in 0m 0.766s
#   loss: 1.8901 corr: 72 (94464/2257759) completed in 0m 0.823s
#   loss: 1.3805 corr: 79 (94592/2257759) completed in 0m 0.856s
#   loss: 1.5062 corr: 79 (94720/2257759) completed in 0m 0.823s
#   loss: 1.9151 corr: 70 (94848/2257759) completed in 0m 0.786s
#   loss: 1.7490 corr: 79 (94976/2257759) completed in 0m 0.823s
#   loss: 1.4963 corr: 86 (95104/2257759) completed in 0m 0.892s
#   loss: 1.4726 corr: 79 (95232/2257759) completed in 0m 0.860s
#   loss: 1.5913 corr: 82 (95360/2257759) completed in 0m 0.838s
#   loss: 1.8417 corr: 78 (95488/2257759) completed in 0m 0.866s
#   loss: 1.8083 corr: 71 (95616/2257759) completed in 0m 0.850s
#   loss: 1.6319 corr: 81 (95744/2257759) completed in 0m 0.846s
#   loss: 1.8063 corr: 74 (95872/2257759) completed in 0m 0.889s
#   loss: 2.0967 corr: 74 (96000/2257759) completed in 0m 0.870s
#   loss: 1.9337 corr: 68 (96128/2257759) completed in 0m 0.819s
#   loss: 1.8145 corr: 78 (96256/2257759) completed in 0m 0.808s
#   loss: 1.5494 corr: 75 (96384/2257759) completed in 0m 0.823s
#   loss: 1.5093 corr: 86 (96512/2257759) completed in 0m 0.841s
#   loss: 1.6514 corr: 81 (96640/2257759) completed in 0m 0.811s
#   loss: 1.8900 corr: 80 (96768/2257759) completed in 0m 0.831s
#   loss: 1.8566 corr: 74 (96896/2257759) completed in 0m 0.874s
#   loss: 1.4686 corr: 84 (97024/2257759) completed in 0m 0.872s
#   loss: 1.6315 corr: 72 (97152/2257759) completed in 0m 0.812s
#   loss: 1.5306 corr: 76 (97280/2257759) completed in 0m 0.829s
#   loss: 1.7267 corr: 70 (97408/2257759) completed in 0m 0.815s
#   loss: 1.4900 corr: 77 (97536/2257759) completed in 0m 0.800s
# ...
#   loss: 1.7807 corr: 89 (2226688/2257759) completed in 0m 0.835s
#   loss: 1.3563 corr: 84 (2226816/2257759) completed in 0m 0.828s
#   loss: 2.1040 corr: 80 (2226944/2257759) completed in 0m 0.833s
#   loss: 1.6536 corr: 85 (2227072/2257759) completed in 0m 0.837s
#   loss: 1.9615 corr: 81 (2227200/2257759) completed in 0m 0.848s
#   loss: 1.6193 corr: 81 (2227328/2257759) completed in 0m 0.875s
#   loss: 1.9861 corr: 83 (2227456/2257759) completed in 0m 0.820s
#   loss: 2.0965 corr: 75 (2227584/2257759) completed in 0m 0.852s
#   loss: 1.8771 corr: 82 (2227712/2257759) completed in 0m 0.801s
#   loss: 1.8414 corr: 83 (2227840/2257759) completed in 0m 0.855s
#   loss: 1.6571 corr: 86 (2227968/2257759) completed in 0m 0.840s
#   loss: 1.7037 corr: 81 (2228096/2257759) completed in 0m 0.855s
#   loss: 1.9849 corr: 80 (2228224/2257759) completed in 0m 0.864s
#   loss: 1.7859 corr: 78 (2228352/2257759) completed in 0m 0.914s
#   loss: 1.5456 corr: 87 (2228480/2257759) completed in 0m 0.838s
#   loss: 1.7694 corr: 79 (2228608/2257759) completed in 0m 0.868s
#   loss: 1.6707 corr: 92 (2228736/2257759) completed in 0m 0.778s
#   loss: 1.6844 corr: 81 (2228864/2257759) completed in 0m 0.879s
#   loss: 2.0090 corr: 77 (2228992/2257759) completed in 0m 0.826s
#   loss: 1.9698 corr: 82 (2229120/2257759) completed in 0m 0.869s
#   loss: 2.0394 corr: 84 (2229248/2257759) completed in 0m 0.870s
#   loss: 2.2984 corr: 75 (2229376/2257759) completed in 0m 0.815s
#   loss: 1.8629 corr: 75 (2229504/2257759) completed in 0m 0.841s
#   loss: 1.7680 corr: 81 (2229632/2257759) completed in 0m 0.846s
#   loss: 1.6012 corr: 80 (2229760/2257759) completed in 0m 0.862s
#   loss: 1.5789 corr: 84 (2229888/2257759) completed in 0m 0.849s
#   loss: 1.7945 corr: 87 (2230016/2257759) completed in 0m 0.840s
#   loss: 2.1247 corr: 77 (2230144/2257759) completed in 0m 0.802s
#   loss: 1.3694 corr: 87 (2230272/2257759) completed in 0m 0.879s
#   loss: 1.8132 corr: 75 (2230400/2257759) completed in 0m 0.839s
#   loss: 1.4467 corr: 92 (2230528/2257759) completed in 0m 0.858s
#   loss: 1.6480 corr: 85 (2230656/2257759) completed in 0m 0.865s
#   loss: 1.9450 corr: 78 (2230784/2257759) completed in 0m 0.820s
#   loss: 1.5458 corr: 92 (2230912/2257759) completed in 0m 0.845s
#   loss: 1.8040 corr: 78 (2231040/2257759) completed in 0m 0.836s
#   loss: 2.1858 corr: 78 (2231168/2257759) completed in 0m 0.815s
#   loss: 1.6800 corr: 87 (2231296/2257759) completed in 0m 0.953s
#   loss: 1.8121 corr: 82 (2231424/2257759) completed in 0m 0.887s
#   loss: 1.4363 corr: 90 (2231552/2257759) completed in 0m 0.848s
#   loss: 1.5726 corr: 81 (2231680/2257759) completed in 0m 0.834s
#   loss: 1.7613 corr: 82 (2231808/2257759) completed in 0m 0.844s
#   loss: 1.9946 corr: 71 (2231936/2257759) completed in 0m 0.854s
#   loss: 1.6134 corr: 84 (2232064/2257759) completed in 0m 0.830s
#   loss: 1.8211 corr: 77 (2232192/2257759) completed in 0m 0.922s
#   loss: 1.3078 corr: 89 (2232320/2257759) completed in 0m 0.907s
#   loss: 1.7526 corr: 82 (2232448/2257759) completed in 0m 0.847s
#   loss: 1.6022 corr: 83 (2232576/2257759) completed in 0m 0.859s
#   loss: 1.8279 corr: 83 (2232704/2257759) completed in 0m 0.819s
#   loss: 1.9522 corr: 82 (2232832/2257759) completed in 0m 0.841s
#   loss: 2.0994 corr: 79 (2232960/2257759) completed in 0m 0.849s
#   loss: 1.8606 corr: 76 (2233088/2257759) completed in 0m 0.804s
#   loss: 1.8254 corr: 80 (2233216/2257759) completed in 0m 0.851s
#   loss: 1.8413 corr: 81 (2233344/2257759) completed in 0m 0.874s
#   loss: 1.8276 corr: 79 (2233472/2257759) completed in 0m 0.861s
#   loss: 1.7828 corr: 85 (2233600/2257759) completed in 0m 0.855s
#   loss: 1.5196 corr: 84 (2233728/2257759) completed in 0m 0.820s
#   loss: 1.5077 corr: 86 (2233856/2257759) completed in 0m 0.820s
#   loss: 2.0999 corr: 82 (2233984/2257759) completed in 0m 0.813s
#   loss: 1.4660 corr: 90 (2234112/2257759) completed in 0m 0.828s
#   loss: 1.9415 corr: 79 (2234240/2257759) completed in 0m 0.984s
#   loss: 1.1768 corr: 94 (2234368/2257759) completed in 0m 1.067s
#   loss: 2.1078 corr: 74 (2234496/2257759) completed in 0m 0.840s
#   loss: 1.8728 corr: 81 (2234624/2257759) completed in 0m 0.850s
#   loss: 1.7473 corr: 80 (2234752/2257759) completed in 0m 0.832s
#   loss: 1.5679 corr: 84 (2234880/2257759) completed in 0m 0.836s
#   loss: 1.8750 corr: 79 (2235008/2257759) completed in 0m 0.862s
#   loss: 2.0488 corr: 68 (2235136/2257759) completed in 0m 0.775s
#   loss: 1.2809 corr: 85 (2235264/2257759) completed in 0m 0.870s
#   loss: 1.9863 corr: 84 (2235392/2257759) completed in 0m 0.820s
#   loss: 2.0553 corr: 86 (2235520/2257759) completed in 0m 0.866s
#   loss: 1.7623 corr: 86 (2235648/2257759) completed in 0m 0.839s
#   loss: 1.9478 corr: 83 (2235776/2257759) completed in 0m 0.851s
#   loss: 1.4511 corr: 85 (2235904/2257759) completed in 0m 0.786s
#   loss: 1.2383 corr: 86 (2236032/2257759) completed in 0m 0.806s
#   loss: 1.5148 corr: 83 (2236160/2257759) completed in 0m 0.829s
#   loss: 1.7290 corr: 85 (2236288/2257759) completed in 0m 0.877s
#   loss: 1.6921 corr: 86 (2236416/2257759) completed in 0m 0.871s
#   loss: 1.4718 corr: 91 (2236544/2257759) completed in 0m 0.825s
#   loss: 1.8201 corr: 76 (2236672/2257759) completed in 0m 0.824s
#   loss: 1.4348 corr: 84 (2236800/2257759) completed in 0m 0.820s
#   loss: 1.6562 corr: 79 (2236928/2257759) completed in 0m 0.802s
#   loss: 2.4690 corr: 80 (2237056/2257759) completed in 0m 0.825s
#   loss: 1.2561 corr: 90 (2237184/2257759) completed in 0m 0.833s
#   loss: 1.5675 corr: 85 (2237312/2257759) completed in 0m 0.947s
#   loss: 1.5918 corr: 93 (2237440/2257759) completed in 0m 0.934s
#   loss: 1.8582 corr: 75 (2237568/2257759) completed in 0m 0.816s
#   loss: 1.5699 corr: 87 (2237696/2257759) completed in 0m 0.832s
#   loss: 1.4504 corr: 91 (2237824/2257759) completed in 0m 0.839s
#   loss: 1.6391 corr: 90 (2237952/2257759) completed in 0m 0.795s
#   loss: 2.1506 corr: 82 (2238080/2257759) completed in 0m 0.805s
#   loss: 1.8801 corr: 85 (2238208/2257759) completed in 0m 0.817s
#   loss: 1.7723 corr: 84 (2238336/2257759) completed in 0m 0.832s
#   loss: 1.8940 corr: 79 (2238464/2257759) completed in 0m 0.829s
#   loss: 2.3243 corr: 70 (2238592/2257759) completed in 0m 0.820s
#   loss: 1.6648 corr: 84 (2238720/2257759) completed in 0m 0.846s
#   loss: 1.7197 corr: 72 (2238848/2257759) completed in 0m 0.827s
#   loss: 2.1512 corr: 79 (2238976/2257759) completed in 0m 0.814s
#   loss: 1.6952 corr: 88 (2239104/2257759) completed in 0m 0.818s
#   loss: 1.4701 corr: 84 (2239232/2257759) completed in 0m 0.871s
#   loss: 2.1645 corr: 73 (2239360/2257759) completed in 0m 0.817s
#   loss: 1.9005 corr: 76 (2239488/2257759) completed in 0m 0.831s
#   loss: 1.3904 corr: 88 (2239616/2257759) completed in 0m 0.860s
#   loss: 2.0639 corr: 81 (2239744/2257759) completed in 0m 0.843s
#   loss: 1.3601 corr: 93 (2239872/2257759) completed in 0m 0.819s
#   loss: 2.5632 corr: 71 (2240000/2257759) completed in 0m 0.828s
#   loss: 1.7721 corr: 87 (2240128/2257759) completed in 0m 0.831s
#   loss: 1.7746 corr: 83 (2240256/2257759) completed in 0m 0.857s
#   loss: 2.0786 corr: 79 (2240384/2257759) completed in 0m 0.851s
#   loss: 2.1365 corr: 78 (2240512/2257759) completed in 0m 0.816s
#   loss: 1.6011 corr: 87 (2240640/2257759) completed in 0m 0.890s
#   loss: 1.7993 corr: 85 (2240768/2257759) completed in 0m 0.833s
#   loss: 1.6894 corr: 80 (2240896/2257759) completed in 0m 0.846s
#   loss: 1.9148 corr: 79 (2241024/2257759) completed in 0m 0.781s
#   loss: 1.6785 corr: 87 (2241152/2257759) completed in 0m 0.852s
#   loss: 1.8096 corr: 80 (2241280/2257759) completed in 0m 0.840s
#   loss: 1.9826 corr: 71 (2241408/2257759) completed in 0m 0.852s
#   loss: 1.7406 corr: 84 (2241536/2257759) completed in 0m 0.815s
#   loss: 1.5346 corr: 91 (2241664/2257759) completed in 0m 0.813s
#   loss: 1.4362 corr: 86 (2241792/2257759) completed in 0m 0.832s
#   loss: 1.9483 corr: 80 (2241920/2257759) completed in 0m 0.835s
#   loss: 1.8717 corr: 86 (2242048/2257759) completed in 0m 0.854s
#   loss: 1.8671 corr: 88 (2242176/2257759) completed in 0m 0.827s
#   loss: 1.9211 corr: 79 (2242304/2257759) completed in 0m 0.846s
#   loss: 1.8028 corr: 79 (2242432/2257759) completed in 0m 0.820s
#   loss: 1.5039 corr: 86 (2242560/2257759) completed in 0m 0.771s
#   loss: 2.0702 corr: 84 (2242688/2257759) completed in 0m 0.818s
#   loss: 1.8252 corr: 85 (2242816/2257759) completed in 0m 0.853s
#   loss: 1.7538 corr: 75 (2242944/2257759) completed in 0m 0.799s
#   loss: 2.0231 corr: 80 (2243072/2257759) completed in 0m 0.830s
#   loss: 1.4422 corr: 87 (2243200/2257759) completed in 0m 0.852s
#   loss: 2.0443 corr: 73 (2243328/2257759) completed in 0m 0.862s
#   loss: 1.6677 corr: 90 (2243456/2257759) completed in 0m 0.816s
#   loss: 1.7950 corr: 88 (2243584/2257759) completed in 0m 0.836s
#   loss: 1.5469 corr: 81 (2243712/2257759) completed in 0m 0.792s
#   loss: 1.8403 corr: 74 (2243840/2257759) completed in 0m 0.833s
#   loss: 1.9014 corr: 84 (2243968/2257759) completed in 0m 0.868s
#   loss: 1.9468 corr: 78 (2244096/2257759) completed in 0m 0.828s
#   loss: 1.8588 corr: 80 (2244224/2257759) completed in 0m 0.837s
#   loss: 1.9155 corr: 78 (2244352/2257759) completed in 0m 0.834s
#   loss: 1.8192 corr: 81 (2244480/2257759) completed in 0m 0.823s
#   loss: 1.3625 corr: 82 (2244608/2257759) completed in 0m 0.837s
#   loss: 1.9273 corr: 83 (2244736/2257759) completed in 0m 0.817s
#   loss: 1.9361 corr: 74 (2244864/2257759) completed in 0m 0.809s
#   loss: 2.2685 corr: 73 (2244992/2257759) completed in 0m 0.842s
#   loss: 2.1377 corr: 78 (2245120/2257759) completed in 0m 0.833s
#   loss: 1.8302 corr: 77 (2245248/2257759) completed in 0m 0.886s
#   loss: 1.8078 corr: 79 (2245376/2257759) completed in 0m 0.869s
#   loss: 1.5671 corr: 89 (2245504/2257759) completed in 0m 0.821s
#   loss: 1.4040 corr: 93 (2245632/2257759) completed in 0m 0.835s
#   loss: 1.8655 corr: 77 (2245760/2257759) completed in 0m 0.822s
#   loss: 1.6080 corr: 81 (2245888/2257759) completed in 0m 0.847s
#   loss: 1.9818 corr: 77 (2246016/2257759) completed in 0m 0.866s
#   loss: 1.4117 corr: 88 (2246144/2257759) completed in 0m 0.796s
#   loss: 1.2704 corr: 96 (2246272/2257759) completed in 0m 0.845s
#   loss: 1.7683 corr: 84 (2246400/2257759) completed in 0m 0.912s
#   loss: 1.6304 corr: 85 (2246528/2257759) completed in 0m 0.840s
#   loss: 1.7032 corr: 81 (2246656/2257759) completed in 0m 0.853s
#   loss: 1.4354 corr: 90 (2246784/2257759) completed in 0m 0.822s
#   loss: 1.7579 corr: 83 (2246912/2257759) completed in 0m 0.834s
#   loss: 1.7000 corr: 82 (2247040/2257759) completed in 0m 0.839s
#   loss: 1.4727 corr: 87 (2247168/2257759) completed in 0m 0.854s
#   loss: 1.9831 corr: 81 (2247296/2257759) completed in 0m 0.858s
#   loss: 1.4426 corr: 86 (2247424/2257759) completed in 0m 0.868s
#   loss: 1.6617 corr: 86 (2247552/2257759) completed in 0m 0.821s
#   loss: 1.8657 corr: 81 (2247680/2257759) completed in 0m 0.786s
#   loss: 2.1147 corr: 71 (2247808/2257759) completed in 0m 0.823s
#   loss: 1.8498 corr: 75 (2247936/2257759) completed in 0m 0.861s
#   loss: 1.8350 corr: 82 (2248064/2257759) completed in 0m 0.817s
#   loss: 2.0283 corr: 69 (2248192/2257759) completed in 0m 0.834s
#   loss: 1.6902 corr: 81 (2248320/2257759) completed in 0m 0.917s
#   loss: 1.8399 corr: 74 (2248448/2257759) completed in 0m 0.841s
#   loss: 1.8206 corr: 87 (2248576/2257759) completed in 0m 0.816s
#   loss: 1.1526 corr: 94 (2248704/2257759) completed in 0m 0.804s
#   loss: 1.5070 corr: 91 (2248832/2257759) completed in 0m 0.829s
#   loss: 1.8672 corr: 76 (2248960/2257759) completed in 0m 0.822s
#   loss: 2.1926 corr: 69 (2249088/2257759) completed in 0m 0.818s
#   loss: 1.2999 corr: 85 (2249216/2257759) completed in 0m 0.815s
#   loss: 1.3922 corr: 92 (2249344/2257759) completed in 0m 0.876s
#   loss: 1.4081 corr: 89 (2249472/2257759) completed in 0m 0.850s
#   loss: 2.1602 corr: 79 (2249600/2257759) completed in 0m 0.830s
#   loss: 1.6276 corr: 81 (2249728/2257759) completed in 0m 0.851s
#   loss: 2.1145 corr: 81 (2249856/2257759) completed in 0m 0.797s
#   loss: 1.6643 corr: 87 (2249984/2257759) completed in 0m 0.820s
#   loss: 1.7914 corr: 81 (2250112/2257759) completed in 0m 0.847s
#   loss: 1.5440 corr: 88 (2250240/2257759) completed in 0m 0.841s
#   loss: 1.3462 corr: 89 (2250368/2257759) completed in 0m 0.810s
#   loss: 1.7327 corr: 81 (2250496/2257759) completed in 0m 0.878s
#   loss: 1.6795 corr: 85 (2250624/2257759) completed in 0m 0.847s
#   loss: 1.5259 corr: 79 (2250752/2257759) completed in 0m 0.834s
#   loss: 2.3134 corr: 74 (2250880/2257759) completed in 0m 0.823s
#   loss: 1.9254 corr: 77 (2251008/2257759) completed in 0m 0.857s
#   loss: 1.6487 corr: 79 (2251136/2257759) completed in 0m 0.770s
#   loss: 1.5561 corr: 88 (2251264/2257759) completed in 0m 0.824s
#   loss: 1.4261 corr: 84 (2251392/2257759) completed in 0m 0.838s
#   loss: 1.8331 corr: 77 (2251520/2257759) completed in 0m 0.800s
#   loss: 2.1003 corr: 77 (2251648/2257759) completed in 0m 0.833s
#   loss: 1.5106 corr: 83 (2251776/2257759) completed in 0m 0.807s
#   loss: 1.6226 corr: 82 (2251904/2257759) completed in 0m 0.844s
#   loss: 1.3035 corr: 87 (2252032/2257759) completed in 0m 0.841s
#   loss: 1.4899 corr: 82 (2252160/2257759) completed in 0m 0.995s
#   loss: 1.7109 corr: 80 (2252288/2257759) completed in 0m 0.907s
#   loss: 1.4105 corr: 93 (2252416/2257759) completed in 0m 0.825s
#   loss: 1.5988 corr: 88 (2252544/2257759) completed in 0m 0.841s
#   loss: 1.9959 corr: 79 (2252672/2257759) completed in 0m 0.857s
#   loss: 1.4730 corr: 84 (2252800/2257759) completed in 0m 0.824s
#   loss: 2.0396 corr: 76 (2252928/2257759) completed in 0m 0.855s
#   loss: 1.7532 corr: 79 (2253056/2257759) completed in 0m 0.863s
#   loss: 2.4587 corr: 70 (2253184/2257759) completed in 0m 0.918s
#   loss: 1.9283 corr: 78 (2253312/2257759) completed in 0m 0.892s
#   loss: 1.7730 corr: 80 (2253440/2257759) completed in 0m 0.852s
#   loss: 1.5773 corr: 81 (2253568/2257759) completed in 0m 0.840s
#   loss: 1.8449 corr: 86 (2253696/2257759) completed in 0m 0.830s
#   loss: 1.8892 corr: 82 (2253824/2257759) completed in 0m 0.812s
#   loss: 1.8021 corr: 80 (2253952/2257759) completed in 0m 0.856s
#   loss: 1.9897 corr: 75 (2254080/2257759) completed in 0m 0.833s
#   loss: 1.5559 corr: 85 (2254208/2257759) completed in 0m 0.895s
#   loss: 1.6214 corr: 91 (2254336/2257759) completed in 0m 0.842s
#   loss: 1.6242 corr: 86 (2254464/2257759) completed in 0m 0.829s
#   loss: 2.0370 corr: 76 (2254592/2257759) completed in 0m 0.863s
#   loss: 1.9191 corr: 76 (2254720/2257759) completed in 0m 0.819s
#   loss: 1.8618 corr: 79 (2254848/2257759) completed in 0m 0.828s
#   loss: 1.7223 corr: 79 (2254976/2257759) completed in 0m 0.870s
#   loss: 1.9770 corr: 78 (2255104/2257759) completed in 0m 0.819s
#   loss: 1.5988 corr: 88 (2255232/2257759) completed in 0m 0.852s
#   loss: 1.5707 corr: 84 (2255360/2257759) completed in 0m 0.881s
#   loss: 2.0695 corr: 72 (2255488/2257759) completed in 0m 0.808s
#   loss: 1.7520 corr: 77 (2255616/2257759) completed in 0m 0.846s
#   loss: 1.4784 corr: 85 (2255744/2257759) completed in 0m 0.804s
#   loss: 1.8379 corr: 77 (2255872/2257759) completed in 0m 0.821s
#   loss: 2.1800 corr: 72 (2256000/2257759) completed in 0m 0.823s
#   loss: 1.5075 corr: 90 (2256128/2257759) completed in 0m 0.828s
#   loss: 1.9137 corr: 77 (2256256/2257759) completed in 0m 0.861s
#   loss: 1.4704 corr: 88 (2256384/2257759) completed in 0m 0.854s
#   loss: 1.6058 corr: 81 (2256512/2257759) completed in 0m 0.866s
#   loss: 2.1365 corr: 78 (2256640/2257759) completed in 0m 0.811s
#   loss: 1.3776 corr: 84 (2256768/2257759) completed in 0m 0.852s
#   loss: 1.5326 corr: 85 (2256896/2257759) completed in 0m 0.837s
#   loss: 1.7835 corr: 85 (2257024/2257759) completed in 0m 0.846s
#   loss: 1.7220 corr: 83 (2257152/2257759) completed in 0m 0.938s
#   loss: 1.9097 corr: 82 (2257280/2257759) completed in 0m 0.783s
#   loss: 1.8606 corr: 81 (2257408/2257759) completed in 0m 0.781s
#   loss: 2.2166 corr: 70 (2257536/2257759) completed in 0m 0.792s
#   loss: 1.8713 corr: 79 (2257664/2257759) completed in 0m 0.762s
#   loss: 2.4606 corr: 51 (2257792/2257759) completed in 0m 0.583s
# /kaggle/working/ResNet50_run-03.pth
# Loss: 1.5133 Acc: 0.6478
#
# Loss: 1.5133 Acc: 0.6478
# Training complete in 417m 17.580s

# %% [markdown]
# ## Inference

# %%
model.eval()
model.to(DEVICE)

predictions = np.zeros((len(test_dataset)))

for i,images in tqdm.tqdm(enumerate(test_loader)):
    images = images.to(DEVICE)
    with torch.no_grad():
        y_predictions = model(images)

    predictions[i*BATCH_EVAL:(i+1)*BATCH_EVAL] = y_predictions.to(DEVICE).cpu().numpy().argmax(1)
# Out:
# 1899it [42:47,  1.35s/it]

# %% [markdown]
# ## Submit

# %%
test_df["preds"] = predictions.astype(int)
submission = sample_submission.merge(
    test_df.rename(columns = {"id":"Id"})[["Id","preds"]],on="Id"
).drop(columns="Predicted")
submission["Predicted"] = submission["preds"].map(class_map)
submission = submission.drop(columns="preds")
submission.to_csv("submission.csv",index=False)
submission.head()
# Out:
#    Id  Predicted
# 0   0      45270
# 1   1      49681
# 2   2      35602
# 3   3      38896
# 4   4       4753
