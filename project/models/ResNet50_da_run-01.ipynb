# %% [markdown]
# # Herbarium 2021 - Half-Earth Challenge - FGVC8 - ResNet
#
# The main goal of this work is to identify plant species of the Americas, Oceania, and the Pacific from herbarium specimens. The dataset that is used in this work - _The Herbarium 2021: Half-Earth Challenge_ - includes more than 2.5M images representing nearly 65.000 species from the Americas and Oceania. These images have been aligned to a standardized plant list ([LCVP v1.0.2](https://www.nature.com/articles/s41597-020-00702-z)).
#
# The model used in this notebook for classifying the images is ResNet ([arXiv:1512.03385](https://arxiv.org/abs/1512.03385)). ResNet makes it possible to train up to hundreds or even thousands of layers and still achieves compelling performance. Taking advantage of its powerful representational ability, the performance of many computer vision applications other than image classification have been bosted. As a classification model, it is considered to be a state-of-the-art method.

# %% [markdown]
# ## Setup
#
# ### Load libraries

# %%
# Math and Image
import numpy as np               # Math
import matplotlib.pyplot as plt  # Plot
import cv2                       # OpenCV
import PIL                       # Data Augmentation
import albumentations            # Data Augmentation
from albumentations.pytorch import ToTensorV2
# Operating System
import os
import time
import copy
# Utilities
import pandas as pd  # Handling CSV files
import random
import json
import tqdm          # Testing
import sklearn       # label encoding and metrics
from sklearn import preprocessing
# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
# TensorFlow
import tensorflow as tf

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets
# preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved
# outside of the current session will list all files under the input directory

print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.7.0
# Torchvision Version:  0.8.1

# %% [markdown]
# ### PC Configuration

# %%
# CPU Details - Number & Model
# !lscpu | grep "CPU(s):"
# !lscpu | grep Hz
# Total Memory
# !cat /proc/meminfo | grep MemTotal
# CUDA Check
print("Is CUDA Available?",
      torch.cuda.is_available())
if torch.cuda.is_available() == True: 
    print("Current CUDA device:",
        torch.cuda.get_device_name(0))

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: ",DEVICE)
# Out:
# CPU(s):              2
# NUMA node0 CPU(s):   0,1
# Model name:          Intel(R) Xeon(R) CPU @ 2.00GHz
# CPU MHz:             2000.144
# MemTotal:       16402016 kB
# Is CUDA Available? True
# Current CUDA device: Tesla P100-PCIE-16GB
# Device:  cuda

# %% [markdown]
# ### Configuration

# %%
ROOT_DATA   = "/kaggle/input/herbarium-2021-fgvc8/"
DATA_TRAIN  = ROOT_DATA + "train/"
DATA_TEST   = ROOT_DATA + "test/"
ROOT_OUTPUT = "/kaggle/working/"
META        = "metadata.json"
BATCH_SIZE  = 128    # number of training examples utilized in one iteration
BATCH_EVAL  = 128
SHUFFLE     = True
EPOCHS      = 1
LEARN_RATE  = 4e-4
IMG_HEIGHT  = 224
IMG_WIDTH   = 224
NUM_CLASSES = None   # define below
NUM_WORKERS = 4
PRE_TRAINED = False

PATH_SAVE_MODEL = "/kaggle/working/ResNet50_da_run-01.pth"

ESTIMATED_MAX_TRAINING_TIME = 480 # hours (8h * 60 = 480min, leaving 1h to the test time)

print(ROOT_DATA)
# Out:
# /kaggle/input/herbarium-2021-fgvc8/

# %% [markdown]
# ## Create dataset

# %% [markdown]
# ### Generic information

# %%
# Training dataset
with open(os.path.join(DATA_TRAIN,META),"r",encoding="ISO-8859-1") as file:
    meta_train = json.load(file)
    print("Number of images (training dataset): ",
          len(meta_train["images"]),)
    for i in list(meta_train.keys()):
        print("  - sample and number of elements in category {}: ".format(i),
              len(list(meta_train[i])),)
        print("\t[0] ",
              list(meta_train[i])[0], end="\n")

NUM_CLASSES   = len(meta_train["categories"])
NUM_IMG_TRAIN = len(meta_train["annotations"])

# Validation dataset
with open(os.path.join(DATA_TEST,META),"r",encoding="ISO-8859-1") as file:
    meta_test = json.load(file)
    print("\nNumber of images (training dataset): ",
          len(meta_test["images"]),)
    for i in list(meta_test.keys()):
        print("  - sample and number of elements in category {}: ".format(i),
              len(list(meta_test[i])),)
        print("\t[0] ",
              list(meta_test[i])[0], end="\n")

NUM_IMG_TEST  = len(meta_test["images"]) 

# Print variables
print("\n\n"
      "Number of images for training: ",NUM_IMG_TRAIN)
print("Number of images for testing : ",NUM_IMG_TEST)
print("Number of classes            : ",NUM_CLASSES)
# Out:
# Number of images (training dataset):  2257759
#   - sample and number of elements in category annotations:  2257759
# 	[0]  {'category_id': 60492, 'id': 1814367, 'image_id': 1814367, 'institution_id': 0}
#   - sample and number of elements in category categories:  64500
# 	[0]  {'family': 'Orchidaceae', 'order': 'Asparagales', 'name': 'Aa calceata (Rchb.f.) Schltr.', 'id': 0}
#   - sample and number of elements in category images:  2257759
# 	[0]  {'file_name': 'images/604/92/1814367.jpg', 'height': 1000, 'id': 1814367, 'license': 0, 'width': 678}
#   - sample and number of elements in category info:  6
# 	[0]  contributor
#   - sample and number of elements in category licenses:  3
# 	[0]  {'id': 0, 'name': 'Public Domain Dedication', 'url': 'http://creativecommons.org/publicdomain/zero/1.0/'}
#   - sample and number of elements in category institutions:  5
# 	[0]  {'id': 0, 'name': 'New York Botanical Garden'}
#
# Number of images (training dataset):  243020
#   - sample and number of elements in category images:  243020
# 	[0]  {'file_name': 'images/000/0.jpg', 'height': 1000, 'id': 0, 'license': 0, 'width': 680}
#   - sample and number of elements in category info:  6
# 	[0]  contributor
#   - sample and number of elements in category licenses:  3
# 	[0]  {'id': 0, 'name': 'Public Domain Dedication', 'url': 'http://creativecommons.org/publicdomain/zero/1.0/'}
#
#
# Number of images for training:  2257759
# Number of images for testing :  243020
# Number of classes            :  64500

# %% [markdown]
# ### Process training and evaluation metadata
#
# Merge training images and annotations as a dataframe. The database-based joint operation merge is performed on the ids "image_id" (from images dataframe) and "id" (from annotations dataframe).
#
# The problem with the validation data is that the `.json` does not provide the labels to check if the model is classifying correctly or not the validation images.

# %%
# Process metadata json for training images into a DataFrame
train_img = pd.DataFrame(meta_train["images"])
train_ann = pd.DataFrame(meta_train["annotations"]).drop(columns="image_id")
train_df  = train_img.merge(train_ann,on="id") # Performs a database-style joint

# Check number of classes
print("Number of classes (expected): ",NUM_CLASSES)
print("Number of classes (computed): ",
      train_df["category_id"].max() - train_df["category_id"].min()+1)
print("\nShape training dataframe    :",train_df.shape)

# Process metadata json for test images into a DataFrame
test_df = pd.DataFrame(meta_test["images"])
# Out:
# Number of classes (expected):  64500
# Number of classes (computed):  64500
#
# Shape training dataframe    : (2257759, 7)

# %% [markdown]
# ## Prepare Submission

# %%
sample_submission = pd.read_csv(ROOT_DATA + "sample_submission.csv")

# %% [markdown]
# ## Label Encoder

# %%
# Fit the label encoder instance
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(train_df["category_id"])

# Transform labels to normalized encoding
train_df["category_id_le"] = label_encoder.transform(train_df["category_id"])
class_map = dict(sorted(train_df[["category_id_le","category_id"]].values.tolist()))

print("Labels converted to normalized encoding")
# Out:
# Labels converted to normalized encoding

# %% [markdown]
# ### Dataloaders

# %%
class TrainDataset(torch.utils.data.Dataset):
    def __init__(self, df, labels, transform=None):
        self.df = df
        self.labels = labels
        self.transform = transform
        
    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.df["file_name"].values[idx]
        file_path = DATA_TRAIN + file_name
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        label = self.labels.values[idx]
        
        if self.transform:
            img = self.transform(image=img)["image"]
        
        return img, label

# %%
class TestDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform
        
    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.df["file_name"].values[idx]
        file_path = DATA_TEST + file_name
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        if self.transform:
            img = self.transform(image=img)["image"]
        
        return img

# %% [markdown]
# ### Image Augmentation

# %%
def get_transforms(*, data: str):
    assert data in ("train","test")
    
    if data == "train":
        return albumentations.Compose([
            albumentations.Resize(IMG_HEIGHT,IMG_WIDTH),
            albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            albumentations.HorizontalFlip(p=0.25),
            albumentations.VerticalFlip(p=0.25),
            albumentations.Rotate(limit=10,p=0.05),
            ToTensorV2(),
        ])

    elif data == "test":
        return albumentations.Compose([
            albumentations.Resize(IMG_HEIGHT,IMG_WIDTH),
            albumentations.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

# %% [markdown]
# ## Datasets
#
# ### Training Dataset

# %%
train_dataset = TrainDataset(
    train_df,train_df["category_id_le"],
    transform=get_transforms(data="train"))
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,shuffle=SHUFFLE,num_workers=NUM_WORKERS)
print("Train data loader created")
# Out:
# Train data loader created

# %% [markdown]
# ### Test Dataset

# %%
test_df.head(n=5)
# Out:
#           file_name  height  id  license  width
# 0  images/000/0.jpg    1000   0        0    680
# 1  images/000/1.jpg    1000   1        0    681
# 2  images/000/2.jpg    1000   2        0    676
# 3  images/000/3.jpg    1000   3        0    666
# 4  images/000/4.jpg    1000   4        0    676

# %%
test_dataset = TestDataset(
    test_df,
    transform=get_transforms(data="test"))
test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=BATCH_EVAL,shuffle=False,num_workers=NUM_WORKERS)
print("Test data loader created")
# Out:
# Test data loader created

# %% [markdown]
# ## Model

# %%
def train_model(model,dataloader,criterion,optimizer,num_epochs=1):
    since = time.time()
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        model.train()
        
        running_loss = 0.0
        running_corrects = 0
        
        #for inputs, labels in tqdm.tqdm(enumerate(dataloader)):
        i = 0
        len_dataset = len(dataloader.dataset)
        for inputs, labels in dataloader:
            since_tmp = time.time()
            
            inputs = inputs.to(DEVICE)
            labels = labels.to(DEVICE)
            
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                loss = criterion(outputs,labels)
                
                _,preds = torch.max(outputs,1)
                
                loss.backward()
                optimizer.step()
              
            loss_tmp = loss.item()
            pred_tmp = torch.sum(preds == labels.data)
            
            running_loss += loss_tmp * inputs.size(0)
            running_corrects += pred_tmp
            
            time_elapsed_tmp = time.time() - since_tmp
            
            print('  loss: {:.04f} corr: {:d} ({:d}/{:d}) completed in {:.0f}m {:.03f}s'.format(
                loss_tmp, pred_tmp,(i+1)*BATCH_SIZE,len_dataset,
                time_elapsed_tmp // 60, time_elapsed_tmp % 60))
            
            if ((time.time() - since) // 60 > ESTIMATED_MAX_TRAINING_TIME):
                break;
            
            i += 1
            
        epoch_loss = running_loss / len_dataset
        epoch_acc = running_corrects.double() / len_dataset
        
        torch.save(model.state_dict(),PATH_SAVE_MODEL)
        print(PATH_SAVE_MODEL)
        print('Loss: {:.04f} Acc: {:.04f}'.format(epoch_loss, epoch_acc))
        
        print()
            
        if ((time.time() - since) // 60 > ESTIMATED_MAX_TRAINING_TIME):
            break;
        
    time_elapsed = time.time() - since
    print('Loss: {:.04f} Acc: {:.04f}'.format(epoch_loss, epoch_acc))
    print('Training complete in {:.0f}m {:.03f}s'.format(time_elapsed // 60, time_elapsed % 60))
    
    #model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ### Construct model

# %%
model = torchvision.models.resnet50(pretrained=PRE_TRAINED)
model.avgpool = torch.nn.AdaptiveAvgPool2d(1)
model.fc = torch.nn.Linear(model.fc.in_features,NUM_CLASSES)

# %% [markdown]
# ### Use existent trained model

# %% [markdown]
# model.load_state_dict(torch.load("../input/herbarium-2021-rbs/ResNet50_run-02.pth"))

# %% [markdown]
# ### Train

# %%
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARN_RATE, amsgrad=False)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 'min', factor=0.75, patience=5, verbose=True, eps=1e-6)

criterion = torch.nn.CrossEntropyLoss()

# %%
model = train_model(model,train_loader,criterion,optimizer,EPOCHS)
# Out:
# Epoch 0/0
# ----------
#   loss: 11.2625 corr: 0 (128/2257759) completed in 0m 2.204s
#   loss: 11.2229 corr: 0 (256/2257759) completed in 0m 0.822s
#   loss: 11.3983 corr: 0 (384/2257759) completed in 0m 0.777s
#   loss: 11.3737 corr: 0 (512/2257759) completed in 0m 0.752s
#   loss: 11.5797 corr: 0 (640/2257759) completed in 0m 0.740s
#   loss: 11.8724 corr: 0 (768/2257759) completed in 0m 0.739s
#   loss: 12.1520 corr: 0 (896/2257759) completed in 0m 0.745s
#   loss: 12.3239 corr: 0 (1024/2257759) completed in 0m 0.719s
#   loss: 12.2871 corr: 0 (1152/2257759) completed in 0m 0.709s
#   loss: 12.3580 corr: 0 (1280/2257759) completed in 0m 0.743s
#   loss: 11.7266 corr: 0 (1408/2257759) completed in 0m 0.774s
#   loss: 11.8960 corr: 0 (1536/2257759) completed in 0m 0.812s
#   loss: 11.7259 corr: 0 (1664/2257759) completed in 0m 0.701s
#   loss: 11.5916 corr: 0 (1792/2257759) completed in 0m 0.756s
#   loss: 11.6144 corr: 0 (1920/2257759) completed in 0m 0.752s
#   loss: 11.4922 corr: 0 (2048/2257759) completed in 0m 0.729s
#   loss: 11.4602 corr: 0 (2176/2257759) completed in 0m 0.779s
#   loss: 11.4721 corr: 0 (2304/2257759) completed in 0m 0.864s
#   loss: 11.5432 corr: 0 (2432/2257759) completed in 0m 0.811s
#   loss: 11.6235 corr: 0 (2560/2257759) completed in 0m 0.736s
#   loss: 11.4522 corr: 0 (2688/2257759) completed in 0m 0.748s
#   loss: 11.4047 corr: 0 (2816/2257759) completed in 0m 0.730s
#   loss: 11.1691 corr: 1 (2944/2257759) completed in 0m 0.716s
#   loss: 11.1600 corr: 0 (3072/2257759) completed in 0m 0.727s
#   loss: 11.2472 corr: 0 (3200/2257759) completed in 0m 0.801s
#   loss: 11.1585 corr: 0 (3328/2257759) completed in 0m 0.809s
#   loss: 11.1415 corr: 0 (3456/2257759) completed in 0m 0.934s
#   loss: 11.0156 corr: 0 (3584/2257759) completed in 0m 0.888s
#   loss: 11.1202 corr: 0 (3712/2257759) completed in 0m 0.773s
#   loss: 11.0788 corr: 0 (3840/2257759) completed in 0m 0.774s
#   loss: 11.0111 corr: 0 (3968/2257759) completed in 0m 0.733s
#   loss: 11.0203 corr: 1 (4096/2257759) completed in 0m 0.708s
#   loss: 11.0060 corr: 0 (4224/2257759) completed in 0m 0.773s
#   loss: 11.2251 corr: 0 (4352/2257759) completed in 0m 0.715s
#   loss: 11.0114 corr: 0 (4480/2257759) completed in 0m 0.707s
#   loss: 11.1306 corr: 0 (4608/2257759) completed in 0m 0.778s
#   loss: 10.9712 corr: 0 (4736/2257759) completed in 0m 0.732s
#   loss: 10.9160 corr: 0 (4864/2257759) completed in 0m 0.739s
#   loss: 10.8771 corr: 0 (4992/2257759) completed in 0m 0.726s
#   loss: 10.8428 corr: 0 (5120/2257759) completed in 0m 0.765s
#   loss: 11.0539 corr: 0 (5248/2257759) completed in 0m 0.764s
#   loss: 11.0667 corr: 0 (5376/2257759) completed in 0m 0.711s
#   loss: 10.8765 corr: 0 (5504/2257759) completed in 0m 0.707s
#   loss: 11.1443 corr: 0 (5632/2257759) completed in 0m 0.741s
#   loss: 11.0089 corr: 0 (5760/2257759) completed in 0m 0.759s
#   loss: 10.9701 corr: 0 (5888/2257759) completed in 0m 0.763s
#   loss: 11.0506 corr: 0 (6016/2257759) completed in 0m 0.774s
#   loss: 10.9216 corr: 0 (6144/2257759) completed in 0m 0.768s
#   loss: 10.8598 corr: 0 (6272/2257759) completed in 0m 0.803s
#   loss: 11.0062 corr: 1 (6400/2257759) completed in 0m 0.797s
#   loss: 10.9320 corr: 0 (6528/2257759) completed in 0m 0.748s
#   loss: 10.8847 corr: 0 (6656/2257759) completed in 0m 0.733s
#   loss: 10.9574 corr: 0 (6784/2257759) completed in 0m 0.778s
#   loss: 10.8697 corr: 0 (6912/2257759) completed in 0m 0.903s
#   loss: 10.9686 corr: 0 (7040/2257759) completed in 0m 0.775s
#   loss: 10.8551 corr: 0 (7168/2257759) completed in 0m 0.748s
#   loss: 10.9236 corr: 0 (7296/2257759) completed in 0m 0.759s
#   loss: 10.8485 corr: 0 (7424/2257759) completed in 0m 0.738s
#   loss: 10.8444 corr: 0 (7552/2257759) completed in 0m 0.726s
#   loss: 10.8776 corr: 0 (7680/2257759) completed in 0m 0.762s
#   loss: 10.6556 corr: 0 (7808/2257759) completed in 0m 0.756s
#   loss: 10.9421 corr: 0 (7936/2257759) completed in 0m 0.739s
#   loss: 10.8048 corr: 0 (8064/2257759) completed in 0m 0.744s
#   loss: 10.8911 corr: 1 (8192/2257759) completed in 0m 0.756s
#   loss: 10.7678 corr: 0 (8320/2257759) completed in 0m 0.750s
#   loss: 10.8643 corr: 0 (8448/2257759) completed in 0m 0.727s
#   loss: 10.8484 corr: 0 (8576/2257759) completed in 0m 0.721s
#   loss: 10.7613 corr: 0 (8704/2257759) completed in 0m 0.718s
#   loss: 10.6548 corr: 0 (8832/2257759) completed in 0m 0.768s
#   loss: 10.9143 corr: 0 (8960/2257759) completed in 0m 0.765s
#   loss: 10.7246 corr: 0 (9088/2257759) completed in 0m 0.770s
#   loss: 10.7816 corr: 0 (9216/2257759) completed in 0m 0.741s
#   loss: 10.7295 corr: 0 (9344/2257759) completed in 0m 0.725s
#   loss: 10.7115 corr: 0 (9472/2257759) completed in 0m 0.736s
#   loss: 10.8604 corr: 0 (9600/2257759) completed in 0m 0.730s
#   loss: 10.7059 corr: 1 (9728/2257759) completed in 0m 0.770s
#   loss: 10.6350 corr: 0 (9856/2257759) completed in 0m 0.734s
#   loss: 10.7752 corr: 0 (9984/2257759) completed in 0m 0.770s
#   loss: 10.7669 corr: 0 (10112/2257759) completed in 0m 0.737s
#   loss: 10.7012 corr: 0 (10240/2257759) completed in 0m 0.723s
#   loss: 10.7594 corr: 0 (10368/2257759) completed in 0m 0.714s
#   loss: 10.7714 corr: 0 (10496/2257759) completed in 0m 0.726s
#   loss: 10.6697 corr: 0 (10624/2257759) completed in 0m 0.727s
#   loss: 10.7430 corr: 0 (10752/2257759) completed in 0m 0.806s
#   loss: 10.8449 corr: 0 (10880/2257759) completed in 0m 0.760s
#   loss: 10.6900 corr: 1 (11008/2257759) completed in 0m 0.732s
#   loss: 10.8536 corr: 0 (11136/2257759) completed in 0m 0.751s
#   loss: 10.6500 corr: 1 (11264/2257759) completed in 0m 0.718s
#   loss: 10.6544 corr: 0 (11392/2257759) completed in 0m 0.754s
#   loss: 10.8365 corr: 0 (11520/2257759) completed in 0m 0.826s
#   loss: 10.7988 corr: 0 (11648/2257759) completed in 0m 0.810s
#   loss: 10.9512 corr: 0 (11776/2257759) completed in 0m 0.924s
#   loss: 10.7479 corr: 0 (11904/2257759) completed in 0m 0.739s
#   loss: 10.6746 corr: 0 (12032/2257759) completed in 0m 0.745s
#   loss: 10.5502 corr: 1 (12160/2257759) completed in 0m 0.788s
#   loss: 10.8099 corr: 0 (12288/2257759) completed in 0m 0.715s
#   loss: 10.6672 corr: 0 (12416/2257759) completed in 0m 0.755s
#   loss: 10.5442 corr: 0 (12544/2257759) completed in 0m 0.822s
#   loss: 10.8391 corr: 0 (12672/2257759) completed in 0m 0.749s
#   loss: 10.5745 corr: 0 (12800/2257759) completed in 0m 0.745s
#   loss: 10.7201 corr: 0 (12928/2257759) completed in 0m 0.724s
#   loss: 10.8770 corr: 0 (13056/2257759) completed in 0m 0.737s
#   loss: 10.8864 corr: 0 (13184/2257759) completed in 0m 0.709s
#   loss: 10.7052 corr: 0 (13312/2257759) completed in 0m 0.745s
#   loss: 10.6429 corr: 0 (13440/2257759) completed in 0m 0.756s
#   loss: 10.7879 corr: 0 (13568/2257759) completed in 0m 0.741s
#   loss: 10.5971 corr: 0 (13696/2257759) completed in 0m 0.737s
#   loss: 10.6225 corr: 1 (13824/2257759) completed in 0m 0.765s
#   loss: 10.7546 corr: 0 (13952/2257759) completed in 0m 0.733s
#   loss: 10.6460 corr: 0 (14080/2257759) completed in 0m 0.771s
#   loss: 10.6967 corr: 0 (14208/2257759) completed in 0m 0.760s
#   loss: 10.7291 corr: 1 (14336/2257759) completed in 0m 0.702s
#   loss: 10.8349 corr: 0 (14464/2257759) completed in 0m 0.747s
#   loss: 10.7544 corr: 0 (14592/2257759) completed in 0m 0.744s
#   loss: 10.5243 corr: 1 (14720/2257759) completed in 0m 0.715s
#   loss: 10.5838 corr: 0 (14848/2257759) completed in 0m 0.729s
#   loss: 10.8322 corr: 0 (14976/2257759) completed in 0m 0.757s
#   loss: 10.7329 corr: 0 (15104/2257759) completed in 0m 0.732s
#   loss: 10.5912 corr: 0 (15232/2257759) completed in 0m 0.761s
#   loss: 10.6228 corr: 0 (15360/2257759) completed in 0m 0.847s
#   loss: 10.6010 corr: 1 (15488/2257759) completed in 0m 0.744s
#   loss: 10.8208 corr: 0 (15616/2257759) completed in 0m 0.715s
#   loss: 10.6341 corr: 0 (15744/2257759) completed in 0m 0.745s
#   loss: 10.5371 corr: 0 (15872/2257759) completed in 0m 0.744s
#   loss: 10.7316 corr: 0 (16000/2257759) completed in 0m 0.731s
#   loss: 10.6378 corr: 0 (16128/2257759) completed in 0m 0.762s
#   loss: 10.6328 corr: 0 (16256/2257759) completed in 0m 0.846s
#   loss: 10.6502 corr: 1 (16384/2257759) completed in 0m 0.803s
#   loss: 10.5254 corr: 0 (16512/2257759) completed in 0m 0.686s
#   loss: 10.6883 corr: 0 (16640/2257759) completed in 0m 0.773s
#   loss: 10.4598 corr: 0 (16768/2257759) completed in 0m 0.761s
#   loss: 10.4983 corr: 0 (16896/2257759) completed in 0m 0.750s
#   loss: 10.4745 corr: 0 (17024/2257759) completed in 0m 0.866s
#   loss: 10.5970 corr: 0 (17152/2257759) completed in 0m 0.924s
#   loss: 10.5722 corr: 1 (17280/2257759) completed in 0m 0.695s
#   loss: 10.4651 corr: 2 (17408/2257759) completed in 0m 0.736s
#   loss: 10.6910 corr: 0 (17536/2257759) completed in 0m 0.788s
#   loss: 10.5020 corr: 1 (17664/2257759) completed in 0m 0.765s
#   loss: 10.6206 corr: 0 (17792/2257759) completed in 0m 0.687s
#   loss: 10.4988 corr: 0 (17920/2257759) completed in 0m 0.759s
#   loss: 10.5019 corr: 0 (18048/2257759) completed in 0m 0.744s
#   loss: 10.3321 corr: 0 (18176/2257759) completed in 0m 0.773s
#   loss: 10.5415 corr: 0 (18304/2257759) completed in 0m 0.769s
#   loss: 10.4662 corr: 0 (18432/2257759) completed in 0m 0.745s
#   loss: 10.6332 corr: 0 (18560/2257759) completed in 0m 0.750s
#   loss: 10.6309 corr: 0 (18688/2257759) completed in 0m 0.768s
#   loss: 10.6347 corr: 0 (18816/2257759) completed in 0m 0.723s
#   loss: 10.6157 corr: 1 (18944/2257759) completed in 0m 0.741s
#   loss: 10.3856 corr: 0 (19072/2257759) completed in 0m 0.755s
#   loss: 10.6934 corr: 0 (19200/2257759) completed in 0m 0.730s
#   loss: 10.5906 corr: 0 (19328/2257759) completed in 0m 0.755s
#   loss: 10.5539 corr: 0 (19456/2257759) completed in 0m 0.737s
#   loss: 10.7299 corr: 0 (19584/2257759) completed in 0m 0.762s
#   loss: 10.6685 corr: 0 (19712/2257759) completed in 0m 0.705s
#   loss: 10.5477 corr: 1 (19840/2257759) completed in 0m 0.766s
#   loss: 10.2917 corr: 0 (19968/2257759) completed in 0m 0.924s
#   loss: 10.6992 corr: 0 (20096/2257759) completed in 0m 0.754s
#   loss: 10.5055 corr: 0 (20224/2257759) completed in 0m 0.804s
#   loss: 10.5869 corr: 0 (20352/2257759) completed in 0m 0.742s
#   loss: 10.5516 corr: 0 (20480/2257759) completed in 0m 0.778s
#   loss: 10.5690 corr: 0 (20608/2257759) completed in 0m 0.778s
#   loss: 10.5224 corr: 0 (20736/2257759) completed in 0m 0.772s
#   loss: 10.5457 corr: 0 (20864/2257759) completed in 0m 0.761s
#   loss: 10.6787 corr: 0 (20992/2257759) completed in 0m 0.799s
#   loss: 10.5747 corr: 0 (21120/2257759) completed in 0m 0.744s
#   loss: 10.5095 corr: 0 (21248/2257759) completed in 0m 0.736s
#   loss: 10.4752 corr: 0 (21376/2257759) completed in 0m 0.743s
#   loss: 10.4948 corr: 0 (21504/2257759) completed in 0m 0.708s
#   loss: 10.6286 corr: 0 (21632/2257759) completed in 0m 0.753s
#   loss: 10.6724 corr: 1 (21760/2257759) completed in 0m 0.751s
#   loss: 10.5673 corr: 0 (21888/2257759) completed in 0m 0.837s
#   loss: 10.4675 corr: 0 (22016/2257759) completed in 0m 0.802s
#   loss: 10.6325 corr: 0 (22144/2257759) completed in 0m 0.756s
#   loss: 10.7040 corr: 0 (22272/2257759) completed in 0m 0.768s
#   loss: 10.8310 corr: 0 (22400/2257759) completed in 0m 0.725s
#   loss: 10.4561 corr: 0 (22528/2257759) completed in 0m 0.759s
#   loss: 10.4611 corr: 0 (22656/2257759) completed in 0m 0.820s
#   loss: 10.3770 corr: 0 (22784/2257759) completed in 0m 0.776s
#   loss: 10.5271 corr: 0 (22912/2257759) completed in 0m 0.752s
#   loss: 10.5379 corr: 0 (23040/2257759) completed in 0m 0.766s
#   loss: 10.5956 corr: 0 (23168/2257759) completed in 0m 0.762s
#   loss: 10.7375 corr: 0 (23296/2257759) completed in 0m 0.725s
#   loss: 10.4768 corr: 0 (23424/2257759) completed in 0m 0.683s
#   loss: 10.5702 corr: 0 (23552/2257759) completed in 0m 0.736s
#   loss: 10.4653 corr: 0 (23680/2257759) completed in 0m 0.782s
#   loss: 10.6029 corr: 0 (23808/2257759) completed in 0m 0.768s
#   loss: 10.5626 corr: 0 (23936/2257759) completed in 0m 0.746s
#   loss: 10.3652 corr: 0 (24064/2257759) completed in 0m 0.776s
#   loss: 10.6397 corr: 0 (24192/2257759) completed in 0m 0.745s
#   loss: 10.5224 corr: 0 (24320/2257759) completed in 0m 0.746s
#   loss: 10.4779 corr: 0 (24448/2257759) completed in 0m 0.767s
#   loss: 10.3964 corr: 0 (24576/2257759) completed in 0m 0.759s
#   loss: 10.7219 corr: 0 (24704/2257759) completed in 0m 0.720s
#   loss: 10.5402 corr: 0 (24832/2257759) completed in 0m 0.753s
#   loss: 10.6405 corr: 0 (24960/2257759) completed in 0m 0.776s
#   loss: 10.5656 corr: 0 (25088/2257759) completed in 0m 0.711s
#   loss: 10.4991 corr: 0 (25216/2257759) completed in 0m 0.768s
#   loss: 10.4169 corr: 0 (25344/2257759) completed in 0m 0.821s
#   loss: 10.5407 corr: 0 (25472/2257759) completed in 0m 0.962s
#   loss: 10.6016 corr: 0 (25600/2257759) completed in 0m 0.829s
#   loss: 10.5579 corr: 0 (25728/2257759) completed in 0m 0.735s
#   loss: 10.6662 corr: 0 (25856/2257759) completed in 0m 0.760s
#   loss: 10.5671 corr: 0 (25984/2257759) completed in 0m 0.780s
#   loss: 10.7786 corr: 0 (26112/2257759) completed in 0m 0.778s
#   loss: 10.4868 corr: 0 (26240/2257759) completed in 0m 0.795s
#   loss: 10.4156 corr: 0 (26368/2257759) completed in 0m 0.819s
#   loss: 10.5476 corr: 0 (26496/2257759) completed in 0m 0.755s
#   loss: 10.4723 corr: 0 (26624/2257759) completed in 0m 0.722s
#   loss: 10.4153 corr: 0 (26752/2257759) completed in 0m 0.728s
#   loss: 10.4835 corr: 0 (26880/2257759) completed in 0m 0.755s
#   loss: 10.7629 corr: 0 (27008/2257759) completed in 0m 0.683s
#   loss: 10.6005 corr: 0 (27136/2257759) completed in 0m 0.760s
#   loss: 10.5295 corr: 0 (27264/2257759) completed in 0m 0.697s
#   loss: 10.4950 corr: 0 (27392/2257759) completed in 0m 0.731s
#   loss: 10.5138 corr: 0 (27520/2257759) completed in 0m 0.719s
#   loss: 10.4301 corr: 0 (27648/2257759) completed in 0m 0.741s
#   loss: 10.4893 corr: 1 (27776/2257759) completed in 0m 0.770s
#   loss: 10.6998 corr: 0 (27904/2257759) completed in 0m 0.763s
#   loss: 10.5231 corr: 0 (28032/2257759) completed in 0m 0.778s
#   loss: 10.4942 corr: 0 (28160/2257759) completed in 0m 0.713s
#   loss: 10.5887 corr: 1 (28288/2257759) completed in 0m 0.756s
#   loss: 10.5252 corr: 0 (28416/2257759) completed in 0m 0.739s
#   loss: 10.4077 corr: 0 (28544/2257759) completed in 0m 0.746s
#   loss: 10.5709 corr: 0 (28672/2257759) completed in 0m 0.720s
#   loss: 10.2365 corr: 0 (28800/2257759) completed in 0m 0.736s
#   loss: 10.6734 corr: 0 (28928/2257759) completed in 0m 0.727s
#   loss: 10.5587 corr: 0 (29056/2257759) completed in 0m 0.757s
#   loss: 10.4796 corr: 0 (29184/2257759) completed in 0m 0.752s
#   loss: 10.3389 corr: 0 (29312/2257759) completed in 0m 0.781s
#   loss: 10.3752 corr: 0 (29440/2257759) completed in 0m 0.756s
#   loss: 10.2675 corr: 0 (29568/2257759) completed in 0m 0.756s
#   loss: 10.5146 corr: 0 (29696/2257759) completed in 0m 0.738s
#   loss: 10.5026 corr: 0 (29824/2257759) completed in 0m 0.751s
#   loss: 10.4520 corr: 0 (29952/2257759) completed in 0m 0.721s
#   loss: 10.3858 corr: 1 (30080/2257759) completed in 0m 0.719s
#   loss: 10.3662 corr: 0 (30208/2257759) completed in 0m 0.782s
#   loss: 10.3582 corr: 0 (30336/2257759) completed in 0m 0.727s
#   loss: 10.8186 corr: 0 (30464/2257759) completed in 0m 0.756s
#   loss: 10.5757 corr: 0 (30592/2257759) completed in 0m 0.760s
#   loss: 10.5815 corr: 1 (30720/2257759) completed in 0m 0.724s
#   loss: 10.4515 corr: 0 (30848/2257759) completed in 0m 0.869s
#   loss: 10.4841 corr: 0 (30976/2257759) completed in 0m 0.820s
#   loss: 10.1081 corr: 0 (31104/2257759) completed in 0m 0.841s
#   loss: 10.3808 corr: 0 (31232/2257759) completed in 0m 0.768s
#   loss: 10.4819 corr: 0 (31360/2257759) completed in 0m 0.758s
#   loss: 10.6694 corr: 0 (31488/2257759) completed in 0m 0.778s
#   loss: 10.5162 corr: 1 (31616/2257759) completed in 0m 0.708s
#   loss: 10.3854 corr: 0 (31744/2257759) completed in 0m 0.752s
#   loss: 10.2958 corr: 0 (31872/2257759) completed in 0m 0.780s
#   loss: 10.5325 corr: 0 (32000/2257759) completed in 0m 0.749s
#   loss: 10.4150 corr: 1 (32128/2257759) completed in 0m 0.736s
#   loss: 10.4295 corr: 0 (32256/2257759) completed in 0m 0.746s
#   loss: 10.4820 corr: 0 (32384/2257759) completed in 0m 0.741s
#   loss: 10.4472 corr: 0 (32512/2257759) completed in 0m 0.729s
#   loss: 10.4146 corr: 0 (32640/2257759) completed in 0m 0.789s
#   loss: 10.5946 corr: 0 (32768/2257759) completed in 0m 0.750s
#   loss: 10.4168 corr: 0 (32896/2257759) completed in 0m 0.755s
#   loss: 10.2477 corr: 0 (33024/2257759) completed in 0m 0.736s
#   loss: 10.7416 corr: 0 (33152/2257759) completed in 0m 0.755s
#   loss: 10.5634 corr: 0 (33280/2257759) completed in 0m 0.718s
#   loss: 10.3825 corr: 0 (33408/2257759) completed in 0m 0.764s
#   loss: 10.4042 corr: 0 (33536/2257759) completed in 0m 0.732s
#   loss: 10.2362 corr: 0 (33664/2257759) completed in 0m 0.686s
#   loss: 10.7003 corr: 0 (33792/2257759) completed in 0m 0.736s
#   loss: 10.5176 corr: 0 (33920/2257759) completed in 0m 0.773s
#   loss: 10.4542 corr: 0 (34048/2257759) completed in 0m 0.769s
#   loss: 10.5461 corr: 0 (34176/2257759) completed in 0m 0.746s
#   loss: 10.4789 corr: 0 (34304/2257759) completed in 0m 0.771s
#   loss: 10.3436 corr: 0 (34432/2257759) completed in 0m 0.758s
#   loss: 10.5474 corr: 1 (34560/2257759) completed in 0m 0.747s
#   loss: 10.3180 corr: 1 (34688/2257759) completed in 0m 0.770s
#   loss: 10.5308 corr: 0 (34816/2257759) completed in 0m 0.775s
#   loss: 10.3234 corr: 0 (34944/2257759) completed in 0m 0.786s
#   loss: 10.5241 corr: 0 (35072/2257759) completed in 0m 0.753s
#   loss: 10.4067 corr: 0 (35200/2257759) completed in 0m 0.768s
#   loss: 10.3478 corr: 0 (35328/2257759) completed in 0m 0.698s
#   loss: 10.3027 corr: 0 (35456/2257759) completed in 0m 0.754s
#   loss: 10.3857 corr: 0 (35584/2257759) completed in 0m 0.740s
#   loss: 10.6263 corr: 0 (35712/2257759) completed in 0m 0.765s
#   loss: 10.4407 corr: 0 (35840/2257759) completed in 0m 0.789s
#   loss: 10.6113 corr: 0 (35968/2257759) completed in 0m 0.750s
#   loss: 10.4219 corr: 1 (36096/2257759) completed in 0m 0.717s
#   loss: 10.3503 corr: 0 (36224/2257759) completed in 0m 0.738s
#   loss: 10.4507 corr: 0 (36352/2257759) completed in 0m 0.760s
#   loss: 10.5178 corr: 0 (36480/2257759) completed in 0m 0.795s
#   loss: 10.5131 corr: 0 (36608/2257759) completed in 0m 0.796s
#   loss: 10.4793 corr: 0 (36736/2257759) completed in 0m 0.721s
#   loss: 10.4395 corr: 0 (36864/2257759) completed in 0m 0.746s
#   loss: 10.5243 corr: 0 (36992/2257759) completed in 0m 0.748s
#   loss: 10.2383 corr: 0 (37120/2257759) completed in 0m 0.738s
#   loss: 10.3762 corr: 0 (37248/2257759) completed in 0m 0.757s
#   loss: 10.3857 corr: 0 (37376/2257759) completed in 0m 0.740s
#   loss: 10.3427 corr: 0 (37504/2257759) completed in 0m 0.777s
#   loss: 10.6468 corr: 0 (37632/2257759) completed in 0m 0.739s
#   loss: 10.3218 corr: 0 (37760/2257759) completed in 0m 0.742s
#   loss: 10.3598 corr: 0 (37888/2257759) completed in 0m 0.719s
#   loss: 10.2295 corr: 0 (38016/2257759) completed in 0m 0.756s
#   loss: 10.3441 corr: 0 (38144/2257759) completed in 0m 0.757s
#   loss: 10.2424 corr: 0 (38272/2257759) completed in 0m 0.768s
#   loss: 10.7350 corr: 0 (38400/2257759) completed in 0m 0.729s
#   loss: 10.2813 corr: 0 (38528/2257759) completed in 0m 0.686s
#   loss: 10.5484 corr: 0 (38656/2257759) completed in 0m 0.725s
#   loss: 10.3713 corr: 0 (38784/2257759) completed in 0m 0.745s
#   loss: 10.3752 corr: 0 (38912/2257759) completed in 0m 0.741s
#   loss: 10.4747 corr: 0 (39040/2257759) completed in 0m 0.754s
#   loss: 10.3711 corr: 0 (39168/2257759) completed in 0m 0.692s
#   loss: 10.3001 corr: 0 (39296/2257759) completed in 0m 0.777s
#   loss: 10.1807 corr: 0 (39424/2257759) completed in 0m 0.909s
#   loss: 10.4775 corr: 0 (39552/2257759) completed in 0m 0.746s
#   loss: 10.5483 corr: 0 (39680/2257759) completed in 0m 0.717s
#   loss: 10.4490 corr: 0 (39808/2257759) completed in 0m 0.723s
#   loss: 10.6622 corr: 0 (39936/2257759) completed in 0m 0.710s
#   loss: 10.5097 corr: 0 (40064/2257759) completed in 0m 0.760s
#   loss: 10.2747 corr: 0 (40192/2257759) completed in 0m 0.719s
#   loss: 10.4408 corr: 0 (40320/2257759) completed in 0m 0.810s
#   loss: 10.3979 corr: 1 (40448/2257759) completed in 0m 0.840s
#   loss: 10.4829 corr: 0 (40576/2257759) completed in 0m 0.740s
#   loss: 10.4495 corr: 0 (40704/2257759) completed in 0m 0.691s
#   loss: 10.4068 corr: 1 (40832/2257759) completed in 0m 0.740s
#   loss: 10.0773 corr: 0 (40960/2257759) completed in 0m 0.783s
#   loss: 10.2063 corr: 0 (41088/2257759) completed in 0m 0.769s
#   loss: 10.6662 corr: 0 (41216/2257759) completed in 0m 0.722s
#   loss: 10.3548 corr: 0 (41344/2257759) completed in 0m 0.740s
#   loss: 10.1661 corr: 1 (41472/2257759) completed in 0m 0.728s
#   loss: 10.4842 corr: 0 (41600/2257759) completed in 0m 0.751s
#   loss: 10.3706 corr: 0 (41728/2257759) completed in 0m 0.740s
#   loss: 10.4715 corr: 0 (41856/2257759) completed in 0m 0.764s
#   loss: 10.4237 corr: 0 (41984/2257759) completed in 0m 0.753s
#   loss: 10.2443 corr: 0 (42112/2257759) completed in 0m 0.848s
#   loss: 10.1897 corr: 0 (42240/2257759) completed in 0m 0.766s
#   loss: 10.3769 corr: 0 (42368/2257759) completed in 0m 0.756s
#   loss: 10.3900 corr: 0 (42496/2257759) completed in 0m 0.752s
#   loss: 10.3150 corr: 1 (42624/2257759) completed in 0m 0.745s
#   loss: 10.2538 corr: 0 (42752/2257759) completed in 0m 0.760s
#   loss: 10.1480 corr: 0 (42880/2257759) completed in 0m 0.693s
#   loss: 10.4769 corr: 0 (43008/2257759) completed in 0m 0.776s
#   loss: 10.2472 corr: 0 (43136/2257759) completed in 0m 0.736s
#   loss: 10.2472 corr: 0 (43264/2257759) completed in 0m 0.746s
#   loss: 10.2330 corr: 1 (43392/2257759) completed in 0m 0.762s
#   loss: 10.6327 corr: 0 (43520/2257759) completed in 0m 0.713s
#   loss: 10.4200 corr: 0 (43648/2257759) completed in 0m 0.736s
#   loss: 10.2644 corr: 0 (43776/2257759) completed in 0m 0.765s
#   loss: 10.2652 corr: 0 (43904/2257759) completed in 0m 0.748s
#   loss: 10.4641 corr: 0 (44032/2257759) completed in 0m 0.746s
#   loss: 10.3251 corr: 0 (44160/2257759) completed in 0m 0.745s
#   loss: 10.3719 corr: 0 (44288/2257759) completed in 0m 0.729s
#   loss: 10.4887 corr: 0 (44416/2257759) completed in 0m 0.728s
#   loss: 10.1992 corr: 0 (44544/2257759) completed in 0m 0.726s
#   loss: 10.3666 corr: 0 (44672/2257759) completed in 0m 0.754s
#   loss: 10.2667 corr: 0 (44800/2257759) completed in 0m 0.739s
#   loss: 10.4261 corr: 0 (44928/2257759) completed in 0m 0.819s
#   loss: 10.3160 corr: 0 (45056/2257759) completed in 0m 0.791s
#   loss: 10.3597 corr: 0 (45184/2257759) completed in 0m 0.768s
#   loss: 10.1790 corr: 0 (45312/2257759) completed in 0m 0.746s
#   loss: 10.4597 corr: 0 (45440/2257759) completed in 0m 0.793s
#   loss: 10.4662 corr: 0 (45568/2257759) completed in 0m 0.779s
#   loss: 10.2859 corr: 0 (45696/2257759) completed in 0m 0.727s
#   loss: 10.3502 corr: 0 (45824/2257759) completed in 0m 0.775s
#   loss: 10.1361 corr: 0 (45952/2257759) completed in 0m 0.722s
#   loss: 10.5811 corr: 0 (46080/2257759) completed in 0m 0.820s
#   loss: 10.2118 corr: 0 (46208/2257759) completed in 0m 0.743s
#   loss: 10.0909 corr: 0 (46336/2257759) completed in 0m 0.778s
#   loss: 10.4021 corr: 0 (46464/2257759) completed in 0m 0.768s
#   loss: 10.4162 corr: 0 (46592/2257759) completed in 0m 0.776s
#   loss: 10.2100 corr: 0 (46720/2257759) completed in 0m 0.771s
#   loss: 10.0809 corr: 1 (46848/2257759) completed in 0m 0.807s
#   loss: 10.1579 corr: 0 (46976/2257759) completed in 0m 0.798s
#   loss: 10.6381 corr: 0 (47104/2257759) completed in 0m 0.729s
#   loss: 10.1940 corr: 1 (47232/2257759) completed in 0m 0.720s
#   loss: 10.4448 corr: 1 (47360/2257759) completed in 0m 0.762s
#   loss: 10.2741 corr: 0 (47488/2257759) completed in 0m 0.763s
#   loss: 10.2798 corr: 0 (47616/2257759) completed in 0m 0.749s
#   loss: 10.1164 corr: 0 (47744/2257759) completed in 0m 0.723s
#   loss: 10.4124 corr: 1 (47872/2257759) completed in 0m 0.761s
#   loss: 10.2879 corr: 0 (48000/2257759) completed in 0m 0.783s
#   loss: 10.3386 corr: 0 (48128/2257759) completed in 0m 0.779s
#   loss: 10.3955 corr: 0 (48256/2257759) completed in 0m 0.743s
#   loss: 10.1184 corr: 0 (48384/2257759) completed in 0m 0.745s
#   loss: 10.2834 corr: 0 (48512/2257759) completed in 0m 0.739s
#   loss: 10.4734 corr: 0 (48640/2257759) completed in 0m 0.739s
#   loss: 10.3032 corr: 0 (48768/2257759) completed in 0m 0.698s
#   loss: 10.2816 corr: 0 (48896/2257759) completed in 0m 0.751s
#   loss: 10.2323 corr: 0 (49024/2257759) completed in 0m 0.735s
#   loss: 10.3584 corr: 0 (49152/2257759) completed in 0m 0.730s
#   loss: 10.1678 corr: 0 (49280/2257759) completed in 0m 0.791s
#   loss: 10.0718 corr: 0 (49408/2257759) completed in 0m 0.776s
#   loss: 10.3667 corr: 0 (49536/2257759) completed in 0m 0.739s
#   loss: 10.3057 corr: 0 (49664/2257759) completed in 0m 0.760s
#   loss: 10.2792 corr: 0 (49792/2257759) completed in 0m 0.757s
#   loss: 10.3363 corr: 0 (49920/2257759) completed in 0m 0.768s
#   loss: 10.3191 corr: 0 (50048/2257759) completed in 0m 0.740s
#   loss: 10.3806 corr: 0 (50176/2257759) completed in 0m 0.725s
#   loss: 10.1631 corr: 0 (50304/2257759) completed in 0m 0.799s
#   loss: 10.1885 corr: 1 (50432/2257759) completed in 0m 0.935s
#   loss: 10.0913 corr: 0 (50560/2257759) completed in 0m 0.922s
#   loss: 10.3862 corr: 0 (50688/2257759) completed in 0m 0.831s
#   loss: 10.2695 corr: 0 (50816/2257759) completed in 0m 0.743s
#   loss: 10.2710 corr: 0 (50944/2257759) completed in 0m 0.794s
#   loss: 10.2334 corr: 0 (51072/2257759) completed in 0m 0.760s
#   loss: 10.1504 corr: 0 (51200/2257759) completed in 0m 0.742s
#   loss: 10.4256 corr: 1 (51328/2257759) completed in 0m 0.772s
#   loss: 10.2368 corr: 0 (51456/2257759) completed in 0m 0.840s
#   loss: 10.3378 corr: 0 (51584/2257759) completed in 0m 0.790s
#   loss: 10.2487 corr: 1 (51712/2257759) completed in 0m 0.737s
#   loss: 10.1907 corr: 0 (51840/2257759) completed in 0m 0.762s
#   loss: 10.3814 corr: 1 (51968/2257759) completed in 0m 0.722s
#   loss: 10.2254 corr: 0 (52096/2257759) completed in 0m 0.757s
#   loss: 10.1805 corr: 1 (52224/2257759) completed in 0m 0.738s
#   loss: 10.3230 corr: 0 (52352/2257759) completed in 0m 0.803s
#   loss: 9.9645 corr: 0 (52480/2257759) completed in 0m 0.756s
#   loss: 9.9656 corr: 0 (52608/2257759) completed in 0m 0.794s
#   loss: 10.2442 corr: 0 (52736/2257759) completed in 0m 0.775s
#   loss: 10.1714 corr: 0 (52864/2257759) completed in 0m 0.761s
#   loss: 10.5970 corr: 0 (52992/2257759) completed in 0m 0.715s
#   loss: 10.3018 corr: 0 (53120/2257759) completed in 0m 0.759s
#   loss: 10.1094 corr: 0 (53248/2257759) completed in 0m 0.752s
#   loss: 10.0949 corr: 1 (53376/2257759) completed in 0m 0.767s
#   loss: 10.1622 corr: 0 (53504/2257759) completed in 0m 0.727s
#   loss: 10.0720 corr: 0 (53632/2257759) completed in 0m 0.765s
#   loss: 10.1501 corr: 0 (53760/2257759) completed in 0m 0.747s
#   loss: 10.4369 corr: 0 (53888/2257759) completed in 0m 0.763s
#   loss: 10.3866 corr: 0 (54016/2257759) completed in 0m 0.734s
#   loss: 10.4471 corr: 0 (54144/2257759) completed in 0m 0.697s
#   loss: 10.3187 corr: 2 (54272/2257759) completed in 0m 0.770s
#   loss: 10.3173 corr: 0 (54400/2257759) completed in 0m 0.760s
#   loss: 10.2401 corr: 0 (54528/2257759) completed in 0m 0.766s
#   loss: 10.2004 corr: 0 (54656/2257759) completed in 0m 0.686s
#   loss: 10.1471 corr: 1 (54784/2257759) completed in 0m 0.749s
#   loss: 10.2828 corr: 0 (54912/2257759) completed in 0m 0.733s
#   loss: 10.3756 corr: 0 (55040/2257759) completed in 0m 0.692s
#   loss: 10.4417 corr: 0 (55168/2257759) completed in 0m 0.772s
#   loss: 10.1810 corr: 0 (55296/2257759) completed in 0m 0.795s
#   loss: 10.1057 corr: 0 (55424/2257759) completed in 0m 0.775s
#   loss: 10.3395 corr: 0 (55552/2257759) completed in 0m 0.711s
#   loss: 9.9546 corr: 0 (55680/2257759) completed in 0m 0.765s
#   loss: 10.2467 corr: 0 (55808/2257759) completed in 0m 0.782s
#   loss: 10.3460 corr: 2 (55936/2257759) completed in 0m 0.801s
#   loss: 10.0427 corr: 0 (56064/2257759) completed in 0m 0.767s
#   loss: 10.2605 corr: 1 (56192/2257759) completed in 0m 0.756s
#   loss: 10.1703 corr: 0 (56320/2257759) completed in 0m 0.733s
#   loss: 10.1763 corr: 0 (56448/2257759) completed in 0m 0.734s
#   loss: 10.1942 corr: 0 (56576/2257759) completed in 0m 0.705s
#   loss: 10.2371 corr: 0 (56704/2257759) completed in 0m 0.786s
#   loss: 10.1244 corr: 0 (56832/2257759) completed in 0m 0.783s
#   loss: 10.2837 corr: 0 (56960/2257759) completed in 0m 0.773s
#   loss: 10.2670 corr: 0 (57088/2257759) completed in 0m 0.742s
#   loss: 10.2995 corr: 0 (57216/2257759) completed in 0m 0.698s
#   loss: 10.0031 corr: 0 (57344/2257759) completed in 0m 0.761s
#   loss: 10.0115 corr: 0 (57472/2257759) completed in 0m 0.716s
#   loss: 10.4348 corr: 0 (57600/2257759) completed in 0m 0.771s
#   loss: 10.0898 corr: 0 (57728/2257759) completed in 0m 0.757s
#   loss: 10.2409 corr: 1 (57856/2257759) completed in 0m 0.735s
#   loss: 10.2565 corr: 1 (57984/2257759) completed in 0m 0.753s
#   loss: 10.2592 corr: 0 (58112/2257759) completed in 0m 0.749s
#   loss: 10.2691 corr: 0 (58240/2257759) completed in 0m 0.730s
#   loss: 10.3164 corr: 0 (58368/2257759) completed in 0m 0.715s
#   loss: 10.1995 corr: 0 (58496/2257759) completed in 0m 0.768s
#   loss: 10.3799 corr: 0 (58624/2257759) completed in 0m 0.749s
#   loss: 10.0851 corr: 0 (58752/2257759) completed in 0m 0.705s
#   loss: 10.2387 corr: 0 (58880/2257759) completed in 0m 0.734s
#   loss: 10.1184 corr: 2 (59008/2257759) completed in 0m 0.737s
#   loss: 10.2166 corr: 0 (59136/2257759) completed in 0m 0.714s
#   loss: 10.4482 corr: 0 (59264/2257759) completed in 0m 0.712s
#   loss: 10.1654 corr: 0 (59392/2257759) completed in 0m 0.733s
#   loss: 10.2297 corr: 0 (59520/2257759) completed in 0m 0.784s
#   loss: 10.1028 corr: 1 (59648/2257759) completed in 0m 0.735s
#   loss: 10.1613 corr: 0 (59776/2257759) completed in 0m 0.768s
#   loss: 10.2197 corr: 0 (59904/2257759) completed in 0m 0.729s
#   loss: 10.1180 corr: 0 (60032/2257759) completed in 0m 0.703s
#   loss: 10.0657 corr: 0 (60160/2257759) completed in 0m 0.741s
#   loss: 10.1244 corr: 0 (60288/2257759) completed in 0m 0.730s
#   loss: 9.9313 corr: 0 (60416/2257759) completed in 0m 0.728s
#   loss: 10.1649 corr: 0 (60544/2257759) completed in 0m 0.783s
#   loss: 10.2671 corr: 1 (60672/2257759) completed in 0m 0.820s
#   loss: 10.0142 corr: 0 (60800/2257759) completed in 0m 0.840s
#   loss: 10.0051 corr: 0 (60928/2257759) completed in 0m 0.683s
#   loss: 10.4171 corr: 0 (61056/2257759) completed in 0m 0.741s
#   loss: 10.2173 corr: 0 (61184/2257759) completed in 0m 0.852s
#   loss: 10.0161 corr: 0 (61312/2257759) completed in 0m 0.918s
#   loss: 10.0299 corr: 0 (61440/2257759) completed in 0m 0.766s
#   loss: 10.0533 corr: 2 (61568/2257759) completed in 0m 0.736s
#   loss: 10.3682 corr: 0 (61696/2257759) completed in 0m 0.724s
#   loss: 10.1757 corr: 0 (61824/2257759) completed in 0m 0.772s
#   loss: 10.1093 corr: 0 (61952/2257759) completed in 0m 0.762s
#   loss: 10.1212 corr: 0 (62080/2257759) completed in 0m 0.769s
#   loss: 10.1403 corr: 0 (62208/2257759) completed in 0m 0.717s
#   loss: 10.3565 corr: 1 (62336/2257759) completed in 0m 0.788s
#   loss: 10.1609 corr: 1 (62464/2257759) completed in 0m 0.785s
#   loss: 10.1236 corr: 3 (62592/2257759) completed in 0m 0.736s
#   loss: 10.1210 corr: 0 (62720/2257759) completed in 0m 0.789s
#   loss: 10.0819 corr: 0 (62848/2257759) completed in 0m 0.717s
#   loss: 10.2758 corr: 0 (62976/2257759) completed in 0m 0.729s
#   loss: 10.1672 corr: 0 (63104/2257759) completed in 0m 0.785s
#   loss: 10.0395 corr: 0 (63232/2257759) completed in 0m 0.692s
#   loss: 10.1499 corr: 0 (63360/2257759) completed in 0m 0.746s
#   loss: 10.0207 corr: 0 (63488/2257759) completed in 0m 0.746s
#   loss: 10.0431 corr: 0 (63616/2257759) completed in 0m 0.758s
#   loss: 10.1148 corr: 0 (63744/2257759) completed in 0m 0.723s
#   loss: 10.1443 corr: 0 (63872/2257759) completed in 0m 0.770s
#   loss: 9.9118 corr: 0 (64000/2257759) completed in 0m 0.747s
#   loss: 10.0698 corr: 0 (64128/2257759) completed in 0m 0.742s
#   loss: 10.0283 corr: 0 (64256/2257759) completed in 0m 0.765s
#   loss: 10.1084 corr: 0 (64384/2257759) completed in 0m 0.754s
#   loss: 10.4766 corr: 0 (64512/2257759) completed in 0m 0.767s
#   loss: 9.9801 corr: 0 (64640/2257759) completed in 0m 0.760s
#   loss: 10.1160 corr: 0 (64768/2257759) completed in 0m 0.728s
#   loss: 10.1450 corr: 0 (64896/2257759) completed in 0m 0.785s
#   loss: 10.3579 corr: 1 (65024/2257759) completed in 0m 0.727s
#   loss: 10.3024 corr: 0 (65152/2257759) completed in 0m 0.753s
#   loss: 10.0753 corr: 0 (65280/2257759) completed in 0m 0.756s
#   loss: 10.0831 corr: 0 (65408/2257759) completed in 0m 0.791s
#   loss: 10.3614 corr: 0 (65536/2257759) completed in 0m 0.804s
#   loss: 10.0762 corr: 1 (65664/2257759) completed in 0m 0.741s
#   loss: 10.0717 corr: 0 (65792/2257759) completed in 0m 0.764s
#   loss: 9.8249 corr: 0 (65920/2257759) completed in 0m 0.787s
#   loss: 9.8931 corr: 0 (66048/2257759) completed in 0m 0.738s
#   loss: 10.1873 corr: 0 (66176/2257759) completed in 0m 0.749s
#   loss: 10.2254 corr: 0 (66304/2257759) completed in 0m 0.755s
#   loss: 10.1753 corr: 0 (66432/2257759) completed in 0m 0.782s
#   loss: 10.1220 corr: 0 (66560/2257759) completed in 0m 0.791s
#   loss: 10.0947 corr: 0 (66688/2257759) completed in 0m 0.865s
#   loss: 10.0223 corr: 0 (66816/2257759) completed in 0m 0.773s
#   loss: 10.1961 corr: 0 (66944/2257759) completed in 0m 0.799s
#   loss: 10.0646 corr: 0 (67072/2257759) completed in 0m 0.731s
#   loss: 9.9887 corr: 2 (67200/2257759) completed in 0m 0.760s
#   loss: 10.3474 corr: 0 (67328/2257759) completed in 0m 0.760s
#   loss: 9.9389 corr: 1 (67456/2257759) completed in 0m 0.718s
#   loss: 10.2153 corr: 0 (67584/2257759) completed in 0m 0.736s
#   loss: 10.2300 corr: 0 (67712/2257759) completed in 0m 0.768s
#   loss: 10.1990 corr: 0 (67840/2257759) completed in 0m 0.777s
#   loss: 10.0146 corr: 0 (67968/2257759) completed in 0m 0.684s
#   loss: 10.0165 corr: 0 (68096/2257759) completed in 0m 0.731s
#   loss: 10.1807 corr: 0 (68224/2257759) completed in 0m 0.769s
#   loss: 10.1638 corr: 0 (68352/2257759) completed in 0m 0.772s
#   loss: 10.1694 corr: 0 (68480/2257759) completed in 0m 0.717s
#   loss: 10.1400 corr: 0 (68608/2257759) completed in 0m 0.755s
#   loss: 10.0532 corr: 0 (68736/2257759) completed in 0m 0.745s
#   loss: 9.8758 corr: 0 (68864/2257759) completed in 0m 0.723s
#   loss: 10.4295 corr: 0 (68992/2257759) completed in 0m 0.717s
#   loss: 10.4157 corr: 0 (69120/2257759) completed in 0m 0.771s
#   loss: 10.2618 corr: 0 (69248/2257759) completed in 0m 0.763s
#   loss: 10.1103 corr: 0 (69376/2257759) completed in 0m 0.714s
#   loss: 10.1275 corr: 0 (69504/2257759) completed in 0m 0.806s
#   loss: 10.0681 corr: 0 (69632/2257759) completed in 0m 0.862s
#   loss: 9.9854 corr: 0 (69760/2257759) completed in 0m 0.730s
#   loss: 9.8922 corr: 0 (69888/2257759) completed in 0m 0.756s
#   loss: 9.9386 corr: 0 (70016/2257759) completed in 0m 0.807s
#   loss: 10.1355 corr: 0 (70144/2257759) completed in 0m 0.793s
#   loss: 10.1356 corr: 0 (70272/2257759) completed in 0m 0.738s
#   loss: 9.6473 corr: 1 (70400/2257759) completed in 0m 0.727s
#   loss: 10.1571 corr: 0 (70528/2257759) completed in 0m 0.756s
#   loss: 10.2630 corr: 0 (70656/2257759) completed in 0m 0.735s
#   loss: 10.0382 corr: 1 (70784/2257759) completed in 0m 0.791s
#   loss: 10.0933 corr: 1 (70912/2257759) completed in 0m 0.886s
#   loss: 10.0348 corr: 0 (71040/2257759) completed in 0m 0.804s
#   loss: 10.1053 corr: 1 (71168/2257759) completed in 0m 0.710s
#   loss: 10.1070 corr: 0 (71296/2257759) completed in 0m 0.739s
#   loss: 10.1053 corr: 0 (71424/2257759) completed in 0m 0.760s
#   loss: 10.1255 corr: 1 (71552/2257759) completed in 0m 0.815s
#   loss: 9.8015 corr: 1 (71680/2257759) completed in 0m 0.762s
#   loss: 10.2099 corr: 0 (71808/2257759) completed in 0m 0.776s
#   loss: 10.2057 corr: 0 (71936/2257759) completed in 0m 0.765s
#   loss: 10.2487 corr: 0 (72064/2257759) completed in 0m 0.794s
#   loss: 10.1038 corr: 0 (72192/2257759) completed in 0m 0.743s
#   loss: 9.9311 corr: 1 (72320/2257759) completed in 0m 0.681s
#   loss: 10.0709 corr: 0 (72448/2257759) completed in 0m 0.755s
#   loss: 10.1764 corr: 0 (72576/2257759) completed in 0m 0.692s
#   loss: 10.0092 corr: 0 (72704/2257759) completed in 0m 0.777s
#   loss: 10.0246 corr: 0 (72832/2257759) completed in 0m 0.807s
#   loss: 10.0328 corr: 1 (72960/2257759) completed in 0m 0.695s
#   loss: 10.3564 corr: 0 (73088/2257759) completed in 0m 0.703s
#   loss: 10.0885 corr: 1 (73216/2257759) completed in 0m 0.728s
#   loss: 10.1228 corr: 0 (73344/2257759) completed in 0m 0.717s
#   loss: 10.2145 corr: 0 (73472/2257759) completed in 0m 0.738s
#   loss: 10.0336 corr: 1 (73600/2257759) completed in 0m 0.718s
#   loss: 10.2159 corr: 0 (73728/2257759) completed in 0m 0.774s
#   loss: 9.9870 corr: 0 (73856/2257759) completed in 0m 0.765s
#   loss: 10.0255 corr: 0 (73984/2257759) completed in 0m 0.792s
#   loss: 9.9991 corr: 0 (74112/2257759) completed in 0m 0.735s
#   loss: 10.1690 corr: 0 (74240/2257759) completed in 0m 0.772s
#   loss: 10.1536 corr: 0 (74368/2257759) completed in 0m 0.731s
#   loss: 9.9965 corr: 0 (74496/2257759) completed in 0m 0.744s
#   loss: 10.0025 corr: 0 (74624/2257759) completed in 0m 0.736s
#   loss: 10.0841 corr: 0 (74752/2257759) completed in 0m 0.771s
#   loss: 10.2280 corr: 0 (74880/2257759) completed in 0m 0.768s
#   loss: 10.0912 corr: 0 (75008/2257759) completed in 0m 0.839s
#   loss: 10.1380 corr: 0 (75136/2257759) completed in 0m 0.923s
#   loss: 9.9837 corr: 0 (75264/2257759) completed in 0m 0.749s
#   loss: 10.0743 corr: 0 (75392/2257759) completed in 0m 0.735s
#   loss: 10.1469 corr: 1 (75520/2257759) completed in 0m 0.733s
#   loss: 10.1852 corr: 0 (75648/2257759) completed in 0m 0.741s
#   loss: 9.9268 corr: 0 (75776/2257759) completed in 0m 0.798s
#   loss: 10.1338 corr: 0 (75904/2257759) completed in 0m 0.772s
#   loss: 9.9443 corr: 1 (76032/2257759) completed in 0m 0.753s
#   loss: 10.0696 corr: 0 (76160/2257759) completed in 0m 0.722s
#   loss: 10.3191 corr: 0 (76288/2257759) completed in 0m 0.738s
#   loss: 9.9240 corr: 0 (76416/2257759) completed in 0m 0.760s
#   loss: 10.2117 corr: 0 (76544/2257759) completed in 0m 0.746s
#   loss: 10.1458 corr: 1 (76672/2257759) completed in 0m 0.800s
#   loss: 10.1236 corr: 0 (76800/2257759) completed in 0m 0.771s
#   loss: 10.2100 corr: 0 (76928/2257759) completed in 0m 0.789s
#   loss: 10.1474 corr: 0 (77056/2257759) completed in 0m 0.790s
#   loss: 10.1285 corr: 0 (77184/2257759) completed in 0m 0.741s
#   loss: 10.1278 corr: 0 (77312/2257759) completed in 0m 0.716s
#   loss: 10.0412 corr: 0 (77440/2257759) completed in 0m 0.756s
#   loss: 10.0658 corr: 0 (77568/2257759) completed in 0m 0.805s
#   loss: 9.9647 corr: 1 (77696/2257759) completed in 0m 0.776s
#   loss: 10.0341 corr: 0 (77824/2257759) completed in 0m 0.767s
#   loss: 9.9854 corr: 0 (77952/2257759) completed in 0m 0.739s
#   loss: 10.0613 corr: 0 (78080/2257759) completed in 0m 0.737s
#   loss: 10.3407 corr: 0 (78208/2257759) completed in 0m 0.735s
#   loss: 10.2401 corr: 0 (78336/2257759) completed in 0m 0.754s
#   loss: 10.2022 corr: 0 (78464/2257759) completed in 0m 0.817s
#   loss: 9.9227 corr: 0 (78592/2257759) completed in 0m 0.762s
#   loss: 10.1753 corr: 0 (78720/2257759) completed in 0m 0.727s
#   loss: 10.0521 corr: 0 (78848/2257759) completed in 0m 0.743s
#   loss: 9.8484 corr: 1 (78976/2257759) completed in 0m 0.718s
#   loss: 9.9494 corr: 0 (79104/2257759) completed in 0m 0.735s
#   loss: 10.1102 corr: 0 (79232/2257759) completed in 0m 0.736s
#   loss: 9.8309 corr: 0 (79360/2257759) completed in 0m 0.760s
#   loss: 10.2809 corr: 0 (79488/2257759) completed in 0m 0.742s
#   loss: 9.8356 corr: 0 (79616/2257759) completed in 0m 0.813s
#   loss: 10.1989 corr: 0 (79744/2257759) completed in 0m 0.786s
#   loss: 9.8425 corr: 0 (79872/2257759) completed in 0m 0.765s
#   loss: 10.2131 corr: 0 (80000/2257759) completed in 0m 0.738s
#   loss: 10.0228 corr: 0 (80128/2257759) completed in 0m 0.764s
#   loss: 10.1459 corr: 0 (80256/2257759) completed in 0m 0.790s
#   loss: 10.0921 corr: 0 (80384/2257759) completed in 0m 0.714s
#   loss: 10.1570 corr: 0 (80512/2257759) completed in 0m 0.801s
#   loss: 9.9960 corr: 0 (80640/2257759) completed in 0m 0.743s
#   loss: 9.9378 corr: 0 (80768/2257759) completed in 0m 0.764s
#   loss: 10.2395 corr: 1 (80896/2257759) completed in 0m 0.812s
#   loss: 10.2080 corr: 1 (81024/2257759) completed in 0m 0.751s
#   loss: 9.9464 corr: 0 (81152/2257759) completed in 0m 0.753s
#   loss: 10.0401 corr: 0 (81280/2257759) completed in 0m 0.753s
#   loss: 10.2518 corr: 0 (81408/2257759) completed in 0m 0.799s
#   loss: 10.2964 corr: 0 (81536/2257759) completed in 0m 0.783s
#   loss: 9.9070 corr: 0 (81664/2257759) completed in 0m 0.679s
#   loss: 10.2539 corr: 0 (81792/2257759) completed in 0m 0.740s
#   loss: 10.1334 corr: 0 (81920/2257759) completed in 0m 0.730s
#   loss: 10.0303 corr: 0 (82048/2257759) completed in 0m 0.706s
#   loss: 10.2589 corr: 0 (82176/2257759) completed in 0m 0.853s
#   loss: 9.9815 corr: 0 (82304/2257759) completed in 0m 0.789s
#   loss: 10.1558 corr: 0 (82432/2257759) completed in 0m 0.760s
#   loss: 10.0995 corr: 0 (82560/2257759) completed in 0m 0.746s
#   loss: 10.1292 corr: 0 (82688/2257759) completed in 0m 0.744s
#   loss: 9.8986 corr: 0 (82816/2257759) completed in 0m 0.781s
#   loss: 9.9776 corr: 1 (82944/2257759) completed in 0m 0.749s
#   loss: 9.8399 corr: 0 (83072/2257759) completed in 0m 0.763s
#   loss: 10.3835 corr: 0 (83200/2257759) completed in 0m 0.874s
#   loss: 9.9312 corr: 1 (83328/2257759) completed in 0m 0.875s
#   loss: 10.2763 corr: 0 (83456/2257759) completed in 0m 0.700s
#   loss: 10.1848 corr: 0 (83584/2257759) completed in 0m 0.738s
#   loss: 9.7517 corr: 0 (83712/2257759) completed in 0m 0.753s
#   loss: 10.1663 corr: 0 (83840/2257759) completed in 0m 0.753s
#   loss: 10.0955 corr: 0 (83968/2257759) completed in 0m 0.780s
#   loss: 9.8634 corr: 1 (84096/2257759) completed in 0m 0.789s
#   loss: 10.1225 corr: 0 (84224/2257759) completed in 0m 0.776s
#   loss: 9.8818 corr: 0 (84352/2257759) completed in 0m 0.750s
#   loss: 9.9444 corr: 2 (84480/2257759) completed in 0m 0.755s
#   loss: 9.9580 corr: 1 (84608/2257759) completed in 0m 0.734s
#   loss: 10.2009 corr: 0 (84736/2257759) completed in 0m 0.735s
#   loss: 9.6527 corr: 0 (84864/2257759) completed in 0m 0.723s
#   loss: 9.7918 corr: 0 (84992/2257759) completed in 0m 0.762s
#   loss: 10.3196 corr: 0 (85120/2257759) completed in 0m 0.768s
#   loss: 10.0152 corr: 0 (85248/2257759) completed in 0m 0.756s
#   loss: 9.7806 corr: 0 (85376/2257759) completed in 0m 0.752s
#   loss: 10.0103 corr: 2 (85504/2257759) completed in 0m 0.726s
#   loss: 10.0070 corr: 0 (85632/2257759) completed in 0m 0.734s
#   loss: 9.9448 corr: 0 (85760/2257759) completed in 0m 0.808s
#   loss: 9.7247 corr: 0 (85888/2257759) completed in 0m 0.853s
#   loss: 10.0809 corr: 2 (86016/2257759) completed in 0m 0.844s
#   loss: 9.9786 corr: 0 (86144/2257759) completed in 0m 0.779s
#   loss: 10.0198 corr: 1 (86272/2257759) completed in 0m 0.777s
#   loss: 10.0877 corr: 0 (86400/2257759) completed in 0m 0.691s
#   loss: 10.0569 corr: 1 (86528/2257759) completed in 0m 0.749s
#   loss: 9.9674 corr: 0 (86656/2257759) completed in 0m 0.855s
#   loss: 10.1468 corr: 0 (86784/2257759) completed in 0m 0.804s
#   loss: 10.0857 corr: 1 (86912/2257759) completed in 0m 0.827s
#   loss: 10.1928 corr: 0 (87040/2257759) completed in 0m 0.780s
#   loss: 10.2710 corr: 0 (87168/2257759) completed in 0m 0.800s
#   loss: 10.1546 corr: 1 (87296/2257759) completed in 0m 0.779s
#   loss: 10.0732 corr: 0 (87424/2257759) completed in 0m 0.760s
#   loss: 9.9806 corr: 0 (87552/2257759) completed in 0m 0.719s
#   loss: 10.1504 corr: 1 (87680/2257759) completed in 0m 0.755s
#   loss: 10.2271 corr: 1 (87808/2257759) completed in 0m 0.733s
#   loss: 10.1233 corr: 0 (87936/2257759) completed in 0m 0.745s
#   loss: 10.0949 corr: 0 (88064/2257759) completed in 0m 0.739s
#   loss: 9.8827 corr: 1 (88192/2257759) completed in 0m 0.767s
#   loss: 10.0368 corr: 0 (88320/2257759) completed in 0m 0.789s
#   loss: 9.9284 corr: 0 (88448/2257759) completed in 0m 0.794s
#   loss: 9.9978 corr: 1 (88576/2257759) completed in 0m 0.730s
#   loss: 9.8905 corr: 0 (88704/2257759) completed in 0m 0.767s
#   loss: 10.3202 corr: 1 (88832/2257759) completed in 0m 0.770s
#   loss: 9.9071 corr: 1 (88960/2257759) completed in 0m 0.747s
#   loss: 9.9732 corr: 2 (89088/2257759) completed in 0m 0.696s
#   loss: 10.2846 corr: 1 (89216/2257759) completed in 0m 0.752s
#   loss: 9.9867 corr: 0 (89344/2257759) completed in 0m 0.763s
#   loss: 10.0720 corr: 0 (89472/2257759) completed in 0m 0.695s
#   loss: 9.6456 corr: 1 (89600/2257759) completed in 0m 0.781s
#   loss: 10.3973 corr: 0 (89728/2257759) completed in 0m 0.761s
#   loss: 9.6458 corr: 1 (89856/2257759) completed in 0m 0.770s
#   loss: 10.0512 corr: 0 (89984/2257759) completed in 0m 0.780s
#   loss: 10.1812 corr: 1 (90112/2257759) completed in 0m 0.735s
#   loss: 10.1762 corr: 0 (90240/2257759) completed in 0m 0.755s
#   loss: 9.8249 corr: 1 (90368/2257759) completed in 0m 0.746s
#   loss: 9.7804 corr: 0 (90496/2257759) completed in 0m 0.853s
#   loss: 9.9465 corr: 1 (90624/2257759) completed in 0m 0.766s
#   loss: 9.8818 corr: 1 (90752/2257759) completed in 0m 0.741s
#   loss: 10.0987 corr: 0 (90880/2257759) completed in 0m 0.794s
#   loss: 10.2367 corr: 0 (91008/2257759) completed in 0m 0.780s
#   loss: 9.9818 corr: 1 (91136/2257759) completed in 0m 0.720s
#   loss: 10.1846 corr: 0 (91264/2257759) completed in 0m 0.756s
#   loss: 9.8141 corr: 1 (91392/2257759) completed in 0m 0.893s
#   loss: 10.0595 corr: 0 (91520/2257759) completed in 0m 0.788s
#   loss: 9.9776 corr: 0 (91648/2257759) completed in 0m 0.682s
#   loss: 10.0744 corr: 0 (91776/2257759) completed in 0m 0.759s
#   loss: 9.8140 corr: 0 (91904/2257759) completed in 0m 0.753s
#   loss: 9.9756 corr: 0 (92032/2257759) completed in 0m 0.749s
#   loss: 9.7676 corr: 0 (92160/2257759) completed in 0m 0.759s
#   loss: 9.8782 corr: 1 (92288/2257759) completed in 0m 0.794s
#   loss: 10.2750 corr: 0 (92416/2257759) completed in 0m 0.781s
#   loss: 10.1315 corr: 0 (92544/2257759) completed in 0m 0.729s
#   loss: 9.8673 corr: 0 (92672/2257759) completed in 0m 0.789s
#   loss: 9.9424 corr: 1 (92800/2257759) completed in 0m 0.769s
#   loss: 9.8844 corr: 0 (92928/2257759) completed in 0m 0.763s
#   loss: 9.9845 corr: 0 (93056/2257759) completed in 0m 0.743s
#   loss: 10.1448 corr: 1 (93184/2257759) completed in 0m 0.761s
#   loss: 10.3341 corr: 0 (93312/2257759) completed in 0m 0.737s
#   loss: 10.0518 corr: 0 (93440/2257759) completed in 0m 0.722s
#   loss: 9.8624 corr: 0 (93568/2257759) completed in 0m 0.764s
#   loss: 9.8782 corr: 0 (93696/2257759) completed in 0m 0.800s
#   loss: 10.1866 corr: 0 (93824/2257759) completed in 0m 0.747s
#   loss: 10.0005 corr: 0 (93952/2257759) completed in 0m 0.782s
#   loss: 9.9241 corr: 0 (94080/2257759) completed in 0m 0.741s
#   loss: 9.9632 corr: 0 (94208/2257759) completed in 0m 0.737s
#   loss: 9.8780 corr: 0 (94336/2257759) completed in 0m 0.739s
#   loss: 9.6644 corr: 0 (94464/2257759) completed in 0m 0.729s
#   loss: 9.8266 corr: 0 (94592/2257759) completed in 0m 0.751s
#   loss: 10.1935 corr: 2 (94720/2257759) completed in 0m 0.769s
#   loss: 10.0519 corr: 0 (94848/2257759) completed in 0m 0.758s
#   loss: 10.0895 corr: 0 (94976/2257759) completed in 0m 0.834s
#   loss: 10.0047 corr: 1 (95104/2257759) completed in 0m 0.808s
#   loss: 10.0201 corr: 0 (95232/2257759) completed in 0m 0.798s
#   loss: 9.9689 corr: 0 (95360/2257759) completed in 0m 0.725s
#   loss: 9.9832 corr: 0 (95488/2257759) completed in 0m 0.773s
#   loss: 10.0075 corr: 1 (95616/2257759) completed in 0m 0.751s
#   loss: 9.9670 corr: 1 (95744/2257759) completed in 0m 0.776s
#   loss: 9.9288 corr: 1 (95872/2257759) completed in 0m 0.730s
#   loss: 10.1214 corr: 0 (96000/2257759) completed in 0m 0.808s
#   loss: 10.1131 corr: 1 (96128/2257759) completed in 0m 0.838s
#   loss: 10.0431 corr: 0 (96256/2257759) completed in 0m 0.788s
#   loss: 10.0523 corr: 0 (96384/2257759) completed in 0m 0.746s
#   loss: 10.0575 corr: 0 (96512/2257759) completed in 0m 0.757s
#   loss: 10.0272 corr: 1 (96640/2257759) completed in 0m 0.752s
#   loss: 9.9710 corr: 0 (96768/2257759) completed in 0m 0.780s
#   loss: 10.2759 corr: 0 (96896/2257759) completed in 0m 0.814s
#   loss: 9.8140 corr: 0 (97024/2257759) completed in 0m 0.853s
#   loss: 9.9462 corr: 0 (97152/2257759) completed in 0m 0.861s
#   loss: 9.8303 corr: 0 (97280/2257759) completed in 0m 0.757s
#   loss: 10.2142 corr: 0 (97408/2257759) completed in 0m 0.754s
#   loss: 9.8865 corr: 0 (97536/2257759) completed in 0m 0.714s
#   loss: 10.0320 corr: 0 (97664/2257759) completed in 0m 0.764s
#   loss: 9.8300 corr: 0 (97792/2257759) completed in 0m 0.762s
# ...
#   loss: 4.4105 corr: 30 (2226688/2257759) completed in 0m 0.769s
#   loss: 4.5275 corr: 39 (2226816/2257759) completed in 0m 0.757s
#   loss: 3.5667 corr: 49 (2226944/2257759) completed in 0m 0.692s
#   loss: 3.7181 corr: 52 (2227072/2257759) completed in 0m 0.728s
#   loss: 3.7275 corr: 43 (2227200/2257759) completed in 0m 0.770s
#   loss: 3.8240 corr: 49 (2227328/2257759) completed in 0m 0.818s
#   loss: 3.7467 corr: 43 (2227456/2257759) completed in 0m 0.792s
#   loss: 4.9177 corr: 43 (2227584/2257759) completed in 0m 0.762s
#   loss: 4.1974 corr: 38 (2227712/2257759) completed in 0m 0.742s
#   loss: 4.0339 corr: 48 (2227840/2257759) completed in 0m 0.771s
#   loss: 3.9455 corr: 45 (2227968/2257759) completed in 0m 0.904s
#   loss: 3.9471 corr: 46 (2228096/2257759) completed in 0m 0.786s
#   loss: 4.0497 corr: 41 (2228224/2257759) completed in 0m 0.784s
#   loss: 4.7236 corr: 38 (2228352/2257759) completed in 0m 0.751s
#   loss: 3.4522 corr: 49 (2228480/2257759) completed in 0m 0.776s
#   loss: 4.3122 corr: 49 (2228608/2257759) completed in 0m 0.775s
#   loss: 3.8720 corr: 42 (2228736/2257759) completed in 0m 0.760s
#   loss: 4.3908 corr: 44 (2228864/2257759) completed in 0m 0.740s
#   loss: 4.5463 corr: 44 (2228992/2257759) completed in 0m 0.730s
#   loss: 3.9169 corr: 34 (2229120/2257759) completed in 0m 0.746s
#   loss: 4.2045 corr: 40 (2229248/2257759) completed in 0m 0.748s
#   loss: 3.5750 corr: 41 (2229376/2257759) completed in 0m 0.780s
#   loss: 4.2583 corr: 48 (2229504/2257759) completed in 0m 0.732s
#   loss: 3.5427 corr: 37 (2229632/2257759) completed in 0m 0.769s
#   loss: 4.4875 corr: 45 (2229760/2257759) completed in 0m 0.736s
#   loss: 4.0098 corr: 42 (2229888/2257759) completed in 0m 0.778s
#   loss: 3.9840 corr: 43 (2230016/2257759) completed in 0m 0.747s
#   loss: 4.0647 corr: 40 (2230144/2257759) completed in 0m 0.748s
#   loss: 4.2475 corr: 46 (2230272/2257759) completed in 0m 0.812s
#   loss: 4.3106 corr: 41 (2230400/2257759) completed in 0m 0.766s
#   loss: 3.9809 corr: 39 (2230528/2257759) completed in 0m 0.783s
#   loss: 3.4374 corr: 44 (2230656/2257759) completed in 0m 0.729s
#   loss: 3.8501 corr: 49 (2230784/2257759) completed in 0m 0.854s
#   loss: 3.9909 corr: 40 (2230912/2257759) completed in 0m 0.734s
#   loss: 3.7947 corr: 48 (2231040/2257759) completed in 0m 0.820s
#   loss: 4.3021 corr: 43 (2231168/2257759) completed in 0m 0.801s
#   loss: 4.0170 corr: 44 (2231296/2257759) completed in 0m 0.787s
#   loss: 4.9073 corr: 38 (2231424/2257759) completed in 0m 0.751s
#   loss: 4.4876 corr: 45 (2231552/2257759) completed in 0m 0.702s
#   loss: 4.1721 corr: 44 (2231680/2257759) completed in 0m 0.793s
#   loss: 3.9613 corr: 41 (2231808/2257759) completed in 0m 0.774s
#   loss: 4.5532 corr: 50 (2231936/2257759) completed in 0m 0.775s
#   loss: 4.4538 corr: 33 (2232064/2257759) completed in 0m 0.758s
#   loss: 4.2896 corr: 46 (2232192/2257759) completed in 0m 0.735s
#   loss: 3.7182 corr: 46 (2232320/2257759) completed in 0m 0.765s
#   loss: 4.0335 corr: 41 (2232448/2257759) completed in 0m 0.734s
#   loss: 3.6836 corr: 46 (2232576/2257759) completed in 0m 0.744s
#   loss: 4.0447 corr: 49 (2232704/2257759) completed in 0m 0.752s
#   loss: 4.2798 corr: 44 (2232832/2257759) completed in 0m 0.742s
#   loss: 3.8120 corr: 40 (2232960/2257759) completed in 0m 0.766s
#   loss: 4.1367 corr: 51 (2233088/2257759) completed in 0m 0.752s
#   loss: 4.1849 corr: 44 (2233216/2257759) completed in 0m 0.792s
#   loss: 3.8165 corr: 43 (2233344/2257759) completed in 0m 0.747s
#   loss: 3.8839 corr: 47 (2233472/2257759) completed in 0m 0.740s
#   loss: 4.6347 corr: 34 (2233600/2257759) completed in 0m 0.726s
#   loss: 3.6387 corr: 46 (2233728/2257759) completed in 0m 0.731s
#   loss: 4.2577 corr: 36 (2233856/2257759) completed in 0m 0.756s
#   loss: 3.7669 corr: 48 (2233984/2257759) completed in 0m 0.752s
#   loss: 4.4735 corr: 41 (2234112/2257759) completed in 0m 0.768s
#   loss: 4.4312 corr: 45 (2234240/2257759) completed in 0m 0.744s
#   loss: 4.0327 corr: 44 (2234368/2257759) completed in 0m 0.714s
#   loss: 4.5006 corr: 34 (2234496/2257759) completed in 0m 0.756s
#   loss: 4.0848 corr: 35 (2234624/2257759) completed in 0m 0.788s
#   loss: 4.5329 corr: 46 (2234752/2257759) completed in 0m 0.746s
#   loss: 4.2925 corr: 45 (2234880/2257759) completed in 0m 0.727s
#   loss: 4.3758 corr: 40 (2235008/2257759) completed in 0m 0.748s
#   loss: 3.8985 corr: 45 (2235136/2257759) completed in 0m 0.720s
#   loss: 3.7494 corr: 37 (2235264/2257759) completed in 0m 0.770s
#   loss: 3.9603 corr: 40 (2235392/2257759) completed in 0m 0.810s
#   loss: 4.5353 corr: 39 (2235520/2257759) completed in 0m 0.755s
#   loss: 4.0147 corr: 47 (2235648/2257759) completed in 0m 0.769s
#   loss: 4.1785 corr: 45 (2235776/2257759) completed in 0m 0.869s
#   loss: 4.1013 corr: 50 (2235904/2257759) completed in 0m 0.828s
#   loss: 4.0359 corr: 50 (2236032/2257759) completed in 0m 0.696s
#   loss: 3.7311 corr: 47 (2236160/2257759) completed in 0m 0.900s
#   loss: 3.8365 corr: 46 (2236288/2257759) completed in 0m 0.929s
#   loss: 4.1098 corr: 45 (2236416/2257759) completed in 0m 0.748s
#   loss: 3.6345 corr: 51 (2236544/2257759) completed in 0m 0.798s
#   loss: 4.3526 corr: 36 (2236672/2257759) completed in 0m 0.802s
#   loss: 4.1463 corr: 44 (2236800/2257759) completed in 0m 0.778s
#   loss: 4.3256 corr: 49 (2236928/2257759) completed in 0m 0.792s
#   loss: 3.9908 corr: 43 (2237056/2257759) completed in 0m 0.774s
#   loss: 3.5261 corr: 49 (2237184/2257759) completed in 0m 0.785s
#   loss: 3.3860 corr: 56 (2237312/2257759) completed in 0m 0.749s
#   loss: 4.1006 corr: 46 (2237440/2257759) completed in 0m 0.730s
#   loss: 4.2084 corr: 47 (2237568/2257759) completed in 0m 0.846s
#   loss: 3.3495 corr: 57 (2237696/2257759) completed in 0m 0.752s
#   loss: 3.5553 corr: 49 (2237824/2257759) completed in 0m 0.764s
#   loss: 4.0971 corr: 49 (2237952/2257759) completed in 0m 0.759s
#   loss: 4.4202 corr: 47 (2238080/2257759) completed in 0m 0.760s
#   loss: 3.9272 corr: 50 (2238208/2257759) completed in 0m 0.740s
#   loss: 4.0197 corr: 39 (2238336/2257759) completed in 0m 0.744s
#   loss: 5.1846 corr: 29 (2238464/2257759) completed in 0m 0.759s
#   loss: 3.1801 corr: 55 (2238592/2257759) completed in 0m 0.760s
#   loss: 4.2073 corr: 41 (2238720/2257759) completed in 0m 0.771s
#   loss: 4.1030 corr: 40 (2238848/2257759) completed in 0m 0.766s
#   loss: 3.7858 corr: 46 (2238976/2257759) completed in 0m 0.691s
#   loss: 4.6093 corr: 43 (2239104/2257759) completed in 0m 0.748s
#   loss: 4.3821 corr: 43 (2239232/2257759) completed in 0m 0.760s
#   loss: 5.1678 corr: 39 (2239360/2257759) completed in 0m 0.755s
#   loss: 4.3642 corr: 45 (2239488/2257759) completed in 0m 0.748s
#   loss: 4.1720 corr: 45 (2239616/2257759) completed in 0m 0.740s
#   loss: 4.6925 corr: 42 (2239744/2257759) completed in 0m 0.767s
#   loss: 3.8652 corr: 46 (2239872/2257759) completed in 0m 0.729s
#   loss: 4.3049 corr: 43 (2240000/2257759) completed in 0m 0.777s
#   loss: 4.1438 corr: 50 (2240128/2257759) completed in 0m 0.753s
#   loss: 3.2951 corr: 47 (2240256/2257759) completed in 0m 0.779s
#   loss: 4.9235 corr: 31 (2240384/2257759) completed in 0m 0.775s
#   loss: 4.8207 corr: 34 (2240512/2257759) completed in 0m 0.700s
#   loss: 4.3155 corr: 40 (2240640/2257759) completed in 0m 0.756s
#   loss: 4.4168 corr: 31 (2240768/2257759) completed in 0m 0.769s
#   loss: 3.8008 corr: 48 (2240896/2257759) completed in 0m 0.733s
#   loss: 4.5445 corr: 40 (2241024/2257759) completed in 0m 0.763s
#   loss: 3.8008 corr: 45 (2241152/2257759) completed in 0m 0.761s
#   loss: 3.6320 corr: 45 (2241280/2257759) completed in 0m 0.764s
#   loss: 4.0803 corr: 36 (2241408/2257759) completed in 0m 0.761s
#   loss: 3.8708 corr: 42 (2241536/2257759) completed in 0m 0.868s
#   loss: 4.0057 corr: 47 (2241664/2257759) completed in 0m 0.894s
#   loss: 3.6930 corr: 47 (2241792/2257759) completed in 0m 0.807s
#   loss: 4.6386 corr: 38 (2241920/2257759) completed in 0m 0.786s
#   loss: 3.9755 corr: 39 (2242048/2257759) completed in 0m 0.722s
#   loss: 3.8705 corr: 42 (2242176/2257759) completed in 0m 0.756s
#   loss: 4.1743 corr: 45 (2242304/2257759) completed in 0m 0.784s
#   loss: 4.1669 corr: 40 (2242432/2257759) completed in 0m 0.792s
#   loss: 4.2392 corr: 41 (2242560/2257759) completed in 0m 0.796s
#   loss: 4.3250 corr: 42 (2242688/2257759) completed in 0m 0.779s
#   loss: 3.9165 corr: 42 (2242816/2257759) completed in 0m 0.695s
#   loss: 3.8320 corr: 47 (2242944/2257759) completed in 0m 0.730s
#   loss: 3.6201 corr: 54 (2243072/2257759) completed in 0m 0.732s
#   loss: 4.3720 corr: 29 (2243200/2257759) completed in 0m 0.775s
#   loss: 4.0984 corr: 45 (2243328/2257759) completed in 0m 0.842s
#   loss: 4.6423 corr: 41 (2243456/2257759) completed in 0m 0.765s
#   loss: 3.9750 corr: 49 (2243584/2257759) completed in 0m 0.738s
#   loss: 4.6640 corr: 42 (2243712/2257759) completed in 0m 0.703s
#   loss: 4.1020 corr: 35 (2243840/2257759) completed in 0m 0.744s
#   loss: 4.1423 corr: 45 (2243968/2257759) completed in 0m 0.727s
#   loss: 3.9799 corr: 43 (2244096/2257759) completed in 0m 0.748s
#   loss: 4.1816 corr: 37 (2244224/2257759) completed in 0m 0.745s
#   loss: 4.6599 corr: 40 (2244352/2257759) completed in 0m 0.772s
#   loss: 3.5989 corr: 45 (2244480/2257759) completed in 0m 0.802s
#   loss: 4.0463 corr: 43 (2244608/2257759) completed in 0m 0.782s
#   loss: 4.3474 corr: 40 (2244736/2257759) completed in 0m 0.736s
#   loss: 3.8114 corr: 36 (2244864/2257759) completed in 0m 0.727s
#   loss: 3.8494 corr: 48 (2244992/2257759) completed in 0m 0.685s
#   loss: 4.5246 corr: 41 (2245120/2257759) completed in 0m 0.760s
#   loss: 4.2264 corr: 49 (2245248/2257759) completed in 0m 0.752s
#   loss: 4.4802 corr: 35 (2245376/2257759) completed in 0m 0.751s
#   loss: 4.1270 corr: 37 (2245504/2257759) completed in 0m 0.727s
#   loss: 4.0409 corr: 49 (2245632/2257759) completed in 0m 0.791s
#   loss: 4.0237 corr: 45 (2245760/2257759) completed in 0m 0.759s
#   loss: 4.1483 corr: 39 (2245888/2257759) completed in 0m 0.697s
#   loss: 4.8430 corr: 38 (2246016/2257759) completed in 0m 0.730s
#   loss: 3.8629 corr: 44 (2246144/2257759) completed in 0m 0.780s
#   loss: 3.9336 corr: 41 (2246272/2257759) completed in 0m 0.733s
#   loss: 4.3454 corr: 39 (2246400/2257759) completed in 0m 0.701s
#   loss: 4.2392 corr: 42 (2246528/2257759) completed in 0m 0.752s
#   loss: 3.2349 corr: 52 (2246656/2257759) completed in 0m 0.780s
#   loss: 4.4641 corr: 45 (2246784/2257759) completed in 0m 0.747s
#   loss: 3.5604 corr: 45 (2246912/2257759) completed in 0m 0.756s
#   loss: 3.8728 corr: 47 (2247040/2257759) completed in 0m 0.752s
#   loss: 4.2795 corr: 38 (2247168/2257759) completed in 0m 0.723s
#   loss: 4.1015 corr: 42 (2247296/2257759) completed in 0m 0.793s
#   loss: 4.5488 corr: 37 (2247424/2257759) completed in 0m 0.797s
#   loss: 4.5834 corr: 33 (2247552/2257759) completed in 0m 0.815s
#   loss: 4.6646 corr: 30 (2247680/2257759) completed in 0m 0.758s
#   loss: 3.7810 corr: 53 (2247808/2257759) completed in 0m 0.754s
#   loss: 4.4308 corr: 46 (2247936/2257759) completed in 0m 0.784s
#   loss: 4.1108 corr: 39 (2248064/2257759) completed in 0m 0.724s
#   loss: 4.0077 corr: 47 (2248192/2257759) completed in 0m 0.753s
#   loss: 3.9651 corr: 43 (2248320/2257759) completed in 0m 0.792s
#   loss: 3.4268 corr: 46 (2248448/2257759) completed in 0m 0.692s
#   loss: 4.7374 corr: 30 (2248576/2257759) completed in 0m 0.719s
#   loss: 3.3263 corr: 52 (2248704/2257759) completed in 0m 0.767s
#   loss: 3.9331 corr: 41 (2248832/2257759) completed in 0m 0.753s
#   loss: 4.6094 corr: 39 (2248960/2257759) completed in 0m 0.734s
#   loss: 3.8245 corr: 44 (2249088/2257759) completed in 0m 0.753s
#   loss: 4.2725 corr: 41 (2249216/2257759) completed in 0m 0.782s
#   loss: 3.5283 corr: 38 (2249344/2257759) completed in 0m 0.787s
#   loss: 4.5976 corr: 29 (2249472/2257759) completed in 0m 0.753s
#   loss: 4.0551 corr: 41 (2249600/2257759) completed in 0m 0.765s
#   loss: 4.3645 corr: 37 (2249728/2257759) completed in 0m 0.757s
#   loss: 3.9931 corr: 48 (2249856/2257759) completed in 0m 0.734s
#   loss: 3.3908 corr: 51 (2249984/2257759) completed in 0m 0.741s
#   loss: 3.8175 corr: 42 (2250112/2257759) completed in 0m 0.688s
#   loss: 4.5961 corr: 48 (2250240/2257759) completed in 0m 0.812s
#   loss: 3.6046 corr: 44 (2250368/2257759) completed in 0m 0.742s
#   loss: 4.3970 corr: 35 (2250496/2257759) completed in 0m 0.782s
#   loss: 3.5107 corr: 50 (2250624/2257759) completed in 0m 0.766s
#   loss: 4.0102 corr: 44 (2250752/2257759) completed in 0m 0.750s
#   loss: 3.4052 corr: 48 (2250880/2257759) completed in 0m 0.740s
#   loss: 3.8727 corr: 50 (2251008/2257759) completed in 0m 0.750s
#   loss: 3.2679 corr: 48 (2251136/2257759) completed in 0m 0.767s
#   loss: 3.6766 corr: 42 (2251264/2257759) completed in 0m 0.756s
#   loss: 4.1935 corr: 43 (2251392/2257759) completed in 0m 0.768s
#   loss: 4.6518 corr: 38 (2251520/2257759) completed in 0m 0.771s
#   loss: 4.2293 corr: 47 (2251648/2257759) completed in 0m 0.744s
#   loss: 3.5901 corr: 47 (2251776/2257759) completed in 0m 0.766s
#   loss: 3.8795 corr: 42 (2251904/2257759) completed in 0m 0.760s
#   loss: 3.5124 corr: 50 (2252032/2257759) completed in 0m 0.790s
#   loss: 4.0279 corr: 47 (2252160/2257759) completed in 0m 0.806s
#   loss: 3.7594 corr: 46 (2252288/2257759) completed in 0m 0.772s
#   loss: 3.6707 corr: 59 (2252416/2257759) completed in 0m 0.760s
#   loss: 4.5042 corr: 46 (2252544/2257759) completed in 0m 0.789s
#   loss: 4.2589 corr: 39 (2252672/2257759) completed in 0m 0.757s
#   loss: 4.4755 corr: 41 (2252800/2257759) completed in 0m 0.764s
#   loss: 4.7958 corr: 39 (2252928/2257759) completed in 0m 0.781s
#   loss: 4.4147 corr: 33 (2253056/2257759) completed in 0m 0.790s
#   loss: 3.7227 corr: 48 (2253184/2257759) completed in 0m 0.703s
#   loss: 3.9514 corr: 39 (2253312/2257759) completed in 0m 0.751s
#   loss: 4.0297 corr: 49 (2253440/2257759) completed in 0m 0.767s
#   loss: 4.5885 corr: 35 (2253568/2257759) completed in 0m 0.760s
#   loss: 3.7461 corr: 50 (2253696/2257759) completed in 0m 0.765s
#   loss: 4.9719 corr: 34 (2253824/2257759) completed in 0m 0.746s
#   loss: 5.0192 corr: 36 (2253952/2257759) completed in 0m 0.727s
#   loss: 3.7983 corr: 43 (2254080/2257759) completed in 0m 0.750s
#   loss: 3.9033 corr: 46 (2254208/2257759) completed in 0m 0.734s
#   loss: 3.7187 corr: 46 (2254336/2257759) completed in 0m 0.733s
#   loss: 3.8284 corr: 45 (2254464/2257759) completed in 0m 0.768s
#   loss: 4.2712 corr: 49 (2254592/2257759) completed in 0m 0.762s
#   loss: 4.0865 corr: 46 (2254720/2257759) completed in 0m 0.722s
#   loss: 3.7025 corr: 49 (2254848/2257759) completed in 0m 0.781s
#   loss: 4.4936 corr: 47 (2254976/2257759) completed in 0m 0.753s
#   loss: 4.2183 corr: 41 (2255104/2257759) completed in 0m 0.781s
#   loss: 4.6162 corr: 42 (2255232/2257759) completed in 0m 0.742s
#   loss: 4.9444 corr: 35 (2255360/2257759) completed in 0m 0.765s
#   loss: 4.5921 corr: 41 (2255488/2257759) completed in 0m 0.743s
#   loss: 4.0116 corr: 46 (2255616/2257759) completed in 0m 0.727s
#   loss: 3.8452 corr: 49 (2255744/2257759) completed in 0m 0.734s
#   loss: 4.0188 corr: 46 (2255872/2257759) completed in 0m 0.748s
#   loss: 4.0144 corr: 43 (2256000/2257759) completed in 0m 0.924s
#   loss: 3.8485 corr: 48 (2256128/2257759) completed in 0m 0.695s
#   loss: 4.6168 corr: 38 (2256256/2257759) completed in 0m 0.762s
#   loss: 4.1596 corr: 44 (2256384/2257759) completed in 0m 0.746s
#   loss: 4.7531 corr: 36 (2256512/2257759) completed in 0m 0.736s
#   loss: 3.9931 corr: 47 (2256640/2257759) completed in 0m 0.749s
#   loss: 4.1630 corr: 41 (2256768/2257759) completed in 0m 0.883s
#   loss: 4.1277 corr: 37 (2256896/2257759) completed in 0m 0.746s
#   loss: 3.6024 corr: 45 (2257024/2257759) completed in 0m 0.742s
#   loss: 3.6446 corr: 50 (2257152/2257759) completed in 0m 0.763s
#   loss: 3.7209 corr: 47 (2257280/2257759) completed in 0m 0.779s
#   loss: 4.0568 corr: 47 (2257408/2257759) completed in 0m 0.678s
#   loss: 4.2650 corr: 36 (2257536/2257759) completed in 0m 0.669s
#   loss: 4.6186 corr: 38 (2257664/2257759) completed in 0m 0.671s
#   loss: 4.0460 corr: 28 (2257792/2257759) completed in 0m 0.520s
# /kaggle/working/ResNet50_da_run-01.pth
# Loss: 6.8303 Acc: 0.1279
#
# Loss: 6.8303 Acc: 0.1279
# Training complete in 431m 56.369s

# %% [markdown]
# ## Inference

# %%
model.eval()
model.to(DEVICE)

predictions = np.zeros((len(test_dataset)))

for i,images in tqdm.tqdm(enumerate(test_loader)):
    images = images.to(DEVICE)
    with torch.no_grad():
        y_predictions = model(images)

    predictions[i*BATCH_EVAL:(i+1)*BATCH_EVAL] = y_predictions.to(DEVICE).cpu().numpy().argmax(1)
# Out:
# 1899it [43:02,  1.36s/it]

# %% [markdown]
# ## Submit

# %%
test_df["preds"] = predictions.astype(int)
submission = sample_submission.merge(
    test_df.rename(columns = {"id":"Id"})[["Id","preds"]],on="Id"
).drop(columns="Predicted")
submission["Predicted"] = submission["preds"].map(class_map)
submission = submission.drop(columns="preds")
submission.to_csv("submission.csv",index=False)
submission.head()
# Out:
#    Id  Predicted
# 0   0      45246
# 1   1      12946
# 2   2      35602
# 3   3      38896
# 4   4      17163
